# %%
# %load_ext autoreload
# %autoreload 2

import os, time, pickle
from scripts.tools.issuetracker import IssuetrackerAPI
from scripts.tools.issuetracker.issues import Issues

# %%
def expired(loaded, expires):
    now = time.time()
    age = (now-loaded)/3600
    return age > expires

class IssueCache():
    def __init__(self, issues=None, dltime=None, expires=12, api=None):
        self.issues = None
        self._parse_issues(issues, api)
        self.loaded = dltime or time.time()
        self.expires = expires
        
    def _parse_issues(self, issues, api):
        if isinstance(issues, dict):
            self.issues = Issues(api, list(issues.values()))
        elif issues:
            self.issues = Issues(api, list(issues))
            
    def age(self):
        return self._age(self.loaded)
    
    def get(self):
        return self.issues.find()  # copies all issues
    
    @classmethod
    def from_dl(cls, api, *a, expires=12, **k):
        s = cls(expires=expires)
        s.reload(api, *a, **k)
        return s
    
    def reload(self, api, *a, **k):
        iss = api.download_issues(*a, **k)
        self._parse_issues(iss, api)
        self.loaded = time.time()
    
    def _age(self, t):
        now = time.time()
        hrs = (now - t)/3600
        return hrs        
    
    def expired(self):
        return self.age() > self.expires
    
    def save(self, fn):
        with open(fn, 'wb') as f:
            pickle.dump((self.loaded, self.issues), f)
            
    @classmethod
    def open(cls, fn, api, *a, expires=12, **k):
        try:
            s = cls.load(fn, expires)
        except (FileNotFoundError, EOFError, pickle.PickleError):
            s = cls(None, -1)  # trigger expired
            
        if s.expired():
            s.reload(api, *a, **k)
            s.save(fn)
        return s
        
    @classmethod
    def load(cls, fn, expires=12):
        with open(fn, 'rb') as f:
            ob = pickle.load(f)
        loaded, issues = ob
        return cls(issues, loaded, expires)

# %%
it = IssuetrackerAPI("issue.pbsbiotech.com", "nstarkweather@pbsbiotech.com", "kookychemist")
sf = "./.issuetracker/issue_cache.pkl"

def refresh(sf=sf, it=it):
    global c, issues
    c = IssueCache.from_dl(it, "pbssoftware")
    c.save(sf)
    issues = Issues(it, c.get())
    return c.get()

if not os.path.exists(sf):
    os.makedirs(os.path.dirname(sf), exist_ok=True)
c = IssueCache.open(sf, it, "pbssoftware")
iss = c.get()
issues = Issues(it, iss)
v3_iss = issues.find2(sprint_milestone="3.0")
# Out:
# Downloading projects...
# Downloading issues: 497/497

# %%
refresh()
# Out:
# Downloading issues: 497/497
# <Issues Object: 497 Issues>

# %%
from jpnotebooks.Software.frs_tools import extract, matchers
from jpnotebooks.Software.frs_tools.extract import *

# %%
import sys
class ReleaseNotesFormatter():
    def __init__(self, issues, header=True):
        self.issues = issues
        self.release_notes = []
        self.sections = []
        self.include_header = header
        self.parse()
        
    def check(self, **kw):
        if not self.sections:
            self._extract()
        
        def match(i):
            for k,v in kw.items():
                if isinstance(v, tuple):
                    if getattr(i, k) not in v:
                        return False
                else:
                    if getattr(i, k) != v:
                        return False
            return True
        
        iset = {i.id for i in self.issues if match(i)}
        iset2 = {t[0].id for t in self.sections}
        diff = iset - iset2
        if diff:
            print("Issues without Release Notes:")
            ldiff = sorted(diff)
            for i in ldiff:
                print(" ", i)
        return ldiff
        
    def _extract(self):
        extractor = extract.IssuesExtractor(self.issues)
        self.sections = extractor.extract("Release Notes")
        
    def parse(self):
        self._extract()
        self.release_notes = rnl = []
        for issue, notes in self.sections:
            if notes.lower() == "* n/a":
                continue
            if self.include_header:
                rns = "Issue #%d - %s - %s:\n%s"%(issue.id, issue.tracker, issue.subject, notes)
            else:
                rns = notes
            rnl.append(rns)
            
    def write(self, b):
        b.write("\n\n".join(self.release_notes))
        
    def write2(self, fn):
        with open(fn, 'w') as f:
            self.write(f)
        
    def print(self):
        self.write(sys.stdout)
        
    def parse2(self):
        self.parse()
        self.print()

# %%
for i in issues:
    print(i.id, i.subject)
# Out:
# 3072 Web UI Get Report Server Call
# 3073 3.0 getStatic call
# 3074 3.0 getMainValues and Advanced view
# 3075 3.0 Dashboard and Graphs
# 3077 3.0 Web UI Granular Permissions
# 3078 3.0 Integrity Test
# 3079 3.0 Export data menu
# 3080 3.0 Alarms
# 3081 3.0 Miscellaneous
# 989 Login Behavior
# 3083 Database Events.dat not being read and sent
# 3087 Changes to Get Alarms.vi (including bug discovered via unit testing)
# 2392 Restructure Alarm and Email Settings Configuration
# 3090 Get Sensor States for Web UI.vi and "locked" (discovered via unit testing)
# 1043 Make report file names more clear
# 3093 Error message typo in Get Sensor Calculated Value.vi (discovered via unit testing)
# 1048 Make page name bioreactor name
# 1316 change tab "Graph" to "Graphs"
# 2735 https encryption
# 3101 pH cal global clusters need order changed (bug discovered via unit testing)
# 3102 Get Sensor Calculated Value.vi Default String mod (discovered via unit testing)
# 3106 Check for Recurrent Calls.vi should set Last Access for Cookie ID, not first entry (discovered via unit testing)
# 3107 Update Check for Recurrent Calls.vi for getLight (bug discovered via unit testing)
# 3108 Alarm Handler 2.vi Load Alarms convert For Loop i to U8 not U16 (discovered via unit testing)
# 3109 Alarm Handler 2.vi "Load Alarms" case problem when checking alarm file compatibility (discovered via unit testing)
# 1062 Fluid density setting
# 1713 Create indicating/controlling globals for all inputs/outputs from FPGA
# 3112 Clean Up Alarm Handler 2.vi (discovered via unit testing)
# 3114 Pick a sensor.vi feedback bool will cause control modules to interfere with each other (discovered via unit testing)
# 2092 Split getReport into two server calls.
# 1069 Batch name character limit should be 16 in Service UI
# 3118 Get Static "size" parameter too small (discovered via unit testing)
# 1885 Webcontrol.conf file
# 3120 Bugs in Read and Verify Logger Settings File.vi (discovered via unit testing)
# 2056 Addition Pumps type setting
# 3124 Auto DB Archive Stage 2.vi Error In not wired (bug discovered via unit testing)
# 3130 Auto DB Archive Stage 2.vi Initial SQL Read command incomplete (bug discovered via unit testing)
# 3131 Get Pump Info.vi error message incorrect (discovered via unit testing)
# 3132 Check Admin Allowed to Retry.vi problems
# 3133 Record Failed Admin Login problems w Failed Users Global (discovered via unit testing)
# 3135 Generate Report Filter.vi modifications (discovered via unit testing)
# 3136 Query Active DB for Data.vi - remove "ReportService?" control (discovered via unit testing)
# 2115 Web UI Login events show "Unknown User"
# 3141 Set mode or sp.vi error bug (discovered via unit testing)
# 3145 Process_Data's Data_Value column needs to be DBL (bug discovered via unit testing)
# 1098 Calibration graphs show slight gap when switching screens
# 1100 Time in UTC
# 3150 Fix comment in Get User Info from File.vi (discovered via unit testing)
# 3152 Get Batch Info from DB.vi at odds with Database Read/Write Manager (discovered via unit testing)
# 3153 Get Main Values.vi error handling (discovered via unit testing)
# 3154 Check Alarm in Archived DB.vi creating path
# 3155 Clear Alarm.vi and Check Alarm in Archived DB.vi not used appropriately (discovered via unit testing)
# 3156 Get Batch Data for Reports.vi 'Error In' not wired up to anything (discovered via unit testing)
# 3157 Report Generation Panel.vi "Generate" case won't work for most archived DBs (discovered via unit testing)
# 3158 Get Database Info.vi not actually returning database end time (bug discovered via unit testing)
# 3159 Get Batch Info from DB.vi potentially not correct for end of batch (discovered via unit testing)
# 3161 GetAdvancedValues reports "NaN" instead of "0.0" for O2 controller output
# 3163 Check Alarm in Archived DB.vi fetching data (discovered via unit testing)
# 3164 Find Next DB Start Time Using Database History File.vi doesn't take active into account (discovered via unit testing)
# 3165 Modifications to Error Dialog.vi (discovered via unit testing)
# 3166 Get PBS Users Info.vi and dialog (discovered via unit testing)
# 3167 Handle Database Cases and dialog (discovered via unit testing)
# 3168 SQL Read.vi error out needs to be wired up when called as sub VI (discovered via unit testing)
# 2747 Improving Execution Speed of NetworkSetonRIO
# 3175 Auto DB Archive Stage 3 - Determining next DB name, and error wires (discovered via unit testing)
# 3176 Update pH Module to use SP +/- Deadband
# 3177 Auto DB Archive Stage 1.vi "End Time" should be current time (discovered via unit testing)
# 3178 Modularize DO, pH, Temp Control Module codes
# 3183 Get Batch Data for Reports.vi error wires (discovered via unit testing)
# 1197 DO % covers "Broken"
# 3186 Correct Agitation P Gain name in Sys Var (discovered via unit testing)
# 3188 FilterOvenSP(C) Atom variable should be U8 if RIO Global is U8 (discovered via unit testing)
# 3189 Cal Factors.tl Type Def DO B Cal b should be 0 (discovered via unit testing)
# 3191 Get Batch Info from DB and end time (discovered via unit testing)
# 3192 Get Database Info.vi and error wire (bug discovered via unit testing)
# 3194 3.0 User Requirement Specification (URS)
# 3198 Verify User and Password.vi 'Admin?' always False (discovered via unit testing)
# 3199 Verify User and Password.vi typos in login message (discovered via unit testing)
# 3200 Calculate Time to UTC from Local Time and signs (discovered via unit testing)
# 3201 Determining location permission in Webservice Command Handler.vi (discovered via unit testing)
# 3202 Write Variable to RIO.vi should convert enum to string and put it in queue, not I32 to string (discovered via unit testing)
# 3203 Write Variable to RIO.vi and error (discovered via unit testing)
# 3204 Set Pump A for Web UI.vi and data type (discovered via unit testing)
# 3205 Set Pump X for Web UI.vi preventing hangups (discovered via unit testing)
# 3206 Load Win Alarm Settings.vi and error out (discovered via unit testing)
# 3207 Set Pump Sample for Web UI.vi and scanning string to double (discovered via unit testing)
# 3208 Remove Main Heater Interlock on Level High
# 3209 Problems with Set Sensor States.vi (discovered via unit testing)
# 3210 Set Pump B for Web UI and using sub VI outputs (discovered via unit testing)
# 3211 Revert Trial Cal.vi and indexing Values array (discovered via unit testing)
# 3212 Try Cal.vi bugs (discovered via unit testing)
# 3213 Login for Web UI.vi and indexing Values array (discovered via unit testing)
# 3214 Stop from stop bool, even on 'connect' (discovered via unit testing)
# 3215 Handle Database Cases.vi needs timeouts for dequeueing element from Read Queue (discovered via unit testing)
# 3216 Error Wires in Handle Database Cases.vi (discovered via unit testing)
# 3217 Handle Database Cases.vi does not record first data point (discovered via unit testing)
# 3218 Test if the Web Server leaks memory during operation
# 3219 Modify Appweb Embedthis Server Configuration
# 3220 Improvements to LabVIEW Code
# 1902 Reject m or b if Inf or -Inf
# 3223 Changes to Database Read/Write
# 3224 Changes to Alarm Editor
# 3225 AHHV in 3.0 Parent Issue
# 3226 3.0 O2 Control
# 3229 Execute SQL Write.vi bugs (discovered via unit testing)
# 3230 Handle Database Cases.vi needs a "Synchronous?" bool input
# 3231 SQL Read.vi needs to time out if Lock Database queue is empty
# 3233 Start New Batch.vi needs to use synchronous SQL Write
# 3234 Execute SQL Write needs a timeout for Preview Queue Element of Lock DB queue
# 3235 Calc O2 Limited.vi can divide by 0
# 3236 SQL Write.vi and first non synchronous call (discovered via unit testing)
# 3237 Make Error Handler.vi have "Synchronous?" input
# 3238 Manual Set Point globals should be coerced RIO-side, not in getMainValues VI
# 3239 Manual control menus for dual-sided controls (pH and DO) need a space between number and units
# 3240 Shell Graphs need to show controller output
# 3241 Shell UI - ability to graph 4 arbitrary globals over time
# 3242 2 pt cal in Shell UI is totally wrong
# 3243 getStatic manNames not used everywhere in Web UI
# 3244 Shell Hello UI button shouldn't stay pushed
# 3245 Alarm Config Editor - 'Audible' column isn't responsive
# 3246 Config editors Open > Cancel
# 3247 Saving config files with multiple existing files
# 3248 logger file should open to top of the list
# 3249 Report Generation Panel.vi has been completely disabled
# 3250 SQL Write.vi and errors to asynchronous call
# 3251 Interlock for 3L if top RTD isn't installed
# 3252 Raw Values in Shell Cal menu should be in scientific notation
# 3253 Shutdown call not working
# 2230 Module Performance on sbRIO 9641 and 9642
# 3255 Auto DB Archive Stage 3 hangs forever
# 3258 AgWheelMinMagInterval(Cycle) being set in Load Sys Var file messes up Agitation
# 3259 Get Batch Data for Reports.vi carriage return
# 3260 Ports necessary for LabVIEW function
# 2734 Auto DB Backup
# 3264 Shell UI Interface Improvements
# 3267 Changes to Confirmation Queue
# 3268 Graph Panel.vi PV Valid? indicator
# 3270 List all interlocks in Shell UI
# 3272 RIO disconnect and Reconnect > Server does not work
# 2251 Remove outdated alarms
# 1230 Batch and Data-related features
# 3283 Improvements to pH Controller
# 3286 Shell UI Reports Tab Date / Time Picker Improvements.
# 3287 Project Conventions and Documentation Methods
# 3288 Shell UI On-Screen Keyboard Overlay
# 3289 Shell UI Continue / Cancel Dialog
# 3290 "Save As" Button in CFG Editors
# 3295 Recipe Editor, and Engine, to support "Wait Until Enum ≠ Value" steps
# 2292 Coerce with appropriate possible minimum outputs
# 230 Standby mode needed
# 3308 Level Text Rendering
# 1262 Recipe Steps in Reports are out of order
# 2287 Make changing RIO IP address in project programmatic
# 3313 Error 1026 from Execute SQL Write.vi or SQL Write.vi
# 3314 temporary cals on multiple clients
# 3315 Email reports created in Shell
# 3316 Loading >100 alarms in Web UI fails on some remote clients
# 1338 Change from an Access database to something else
# 2303 Globals 1 2 and 3 saving improvements
# 2304 Granular permissions
# 2306 Make hiding secondary heat button independent of System Variablex XML
# 1750 Make O2/N2 and CO2/Base same order in Dashboard as in Control Overlay
# 2320 Clean up getMainValues call
# 2776 queueing "stop recipe" command
# 2326 Web Socket Logout call
# 2327 getRawValue web socket call
# 2328 User Interface frameworks
# 2329 Make 'Set' calls response JSON format
# 2331 Use same System Variables typedef for both Air and Mag
# 1310 Long alarm names don't fit
# 1311 Make "Base" cover switch and speed selector
# 1312 Change y-axis scaling rules for graphs
# 1693 Send SVs, not globals, to Web Service
# 2109 Graph scale difficult to read
# 1319 Change "Auto Pilot" to "Recipes"?
# 1756 Separate "Message" and "Code" in responses to Web UI
# 1817 Optimize Windows Embedded build
# 3375 Improve System Variables.sys file, and reading it on RIO
# 1076 "Unlock Door" button should be grayed out if door can't open
# 3386 Add ESCON motor configuration software to 3.0 master hard drive.
# 1759 Auto archive DB and create new one
# 2365 Create Mock Server interface for testing Web UI
# 2366 Motor Odometers
# 2367 New Session Framework
# 566 Scroll Bar Access
# 2374 Converting All Doubles and U64 to Single or U32
# 3400 Rearrange alarms
# 396 Back End Documentation
# 3402 Reset Auto Mode Agitation Output on E-Stop Reset for Mag Drive Bioreactors
# 2383 Possibly use a true PDM for base control
# 3415 Allow transferring config files between reactors
# 3416 CDI-Requested 3.0 Features
# 2404 Any recipe with "-" in name is looped
# 2108 Select sensors locks sometimes need to be clicked twice.
# 2415 Remove unnecessary System Variables
# 2416 Why doesn't LED stay on during RIO reboot?
# 3445 Make Filter Oven on/off control
# 3459 Shell UI Help Dialog
# 3461 Changes to globals names
# 2438 Sample setPumpSample could be better
# 1786 Improve Sensor Enable scheme
# 3466 IntegrityTestComplete call
# 3467 Implement lookup table for REST API query string handling.
# 2444 getPumps interlock boolean
# 2445 Web UI Logout unknown user
# 2446 Return IP in getVersion, and Service UI 'System' tab
# 2059 Investigate installer
# 401 Look into installation automation
# 2458 End Batch should be last user event recorded for batch
# 1263 Errors report csv has entries in wrong columns
# 3484 Automated GUI Testing
# 214 Add field for instrument serial number in 'version' tab
# 420 Database sometimes gets corrupt
# 2469 Stress test
# 2460 Startup alarms not audible
# 2476 Report Email Improvements
# 1778 Change to WebSockets from ajax
# 3504 Display Interlocks in Hello UI
# 2482 Replacement to VA's RIO Installer
# 2291 Sub VI to calculate coercion values for PID input
# 1844 3L has pressure interlock
# 3513 3.1 features/changes
# 1951 Optimize Windows bootup
# 2493 Max Media Required Next 24 hrs calculation
# 2500 NI 9219 Software Settings for rtd
# 2502 Defer Panel Updates for Graph Panel
# 2503 Sort variable list in Service UI alphabetically
# 2516 Air and Mag System Variables should have same Max Temp name
# 2522 Alarms triggered on RIO power cycle
# 1500 pH "Fail Rate (pH/min)" and "Base Wait Time (s)" work strangely
# 3549 Normalize REST API response structure
# 1503 Load Alarms.cfg files from Web UI/Recipe
# 1073 Changes to Existing User Events
# 2534 Remove 'dig' and 'analog' from Service UI Pumps tab
# 2536 Investigate limiting monitor beeps
# 1527 Have RIO reboot Windows automatically
# 1183 Sensors updating needs new strategy
# 1109 Valid max and min DO and pH cal settings
# 2563 Warning for closing without "Save" or "Make Active"?
# 1541 Hide unique identifiers from users
# 3593 Change "Load Bag" to "Load Vessel" for 3Ls
# 3594 Move Report Metadata to top of file
# 2573 Reject names longer than 50 characters while typing
# 1553 Configure individual settings to not be editable in Web UI for users lacking some permission
# 2582 Confirm variables list UI
# 2592 Error -63036 (3.0 also)
# 2596 Report Generation Bug
# 2597 Investigate globals vs. other options
# 1572 Sending Email PW Needs Encryption
# 2141 Level cal warning
# 2611 Level Span to value in Cal Actual 2 box not working
# 2142 Remove looping when changing time range options on HELLO UI graph
# 2614 Remove name restriction from Editor VI open dialog
# 1144 Add recipe functionality to change the system variables config file
# 1119 Memory Leak
# 3646 Agitation Control
# 3647 Load Bag menu truncating decimals
# 2626 Re-name DO 1 point Cal button "Span"
# 3651 Temperature
# 3652 DO
# 3653 pH
# 3654 Main Gas
# 3655 Filter Oven
# 3657 Pressure
# 3658 Level
# 3659 Leak
# 3660 Media Pump
# 3661 Sample Pump
# 3664 Addition Pumps
# 2660 Improve version control
# 1637 Log IP addresses of users
# 2662 Schedule tab empty file
# 2321 Merge getMainInfo and getVersion calls into getStatic
# 1282 Change field placement in Bag Options tab
# 2667 LabVIEW and SVN
# 2669 Globals to remove
# 2678 Move history data from limit checker
# 2681 Spamming RIO through Service UI
# 2684 Automate creating new Globals 1 2 and 3 files
# 3714 Web UI "Actions" buttons order
# 3715 Change level and pressure cal warning
# 3716 Web UI and displaying errors
# 3717 Specify Web UI dashboard button error text
# 2694 Globals 1 2 and 3 to XML
# 2697 RIO Architecture Change
# 1303 Prevent users from entering invalid Auto set points
# 1678 Make warning overlays consistent
# 2704 Re-integrate, and selectively hide, perfusion features
# 3731 Adjust the auto-logout timer
# 3732 Shell UI graphs and historical data
# 1685 Select Sensors menu slow to load
# 2711 Correct PID dt to equal loop time
# 2712 CFR 21 Part 11 Issues parent
# 2713 Air/Mag Merge Frontend Issues parent
# 2715 Web Login Improvements (Christian placeholder)
# 2716 Manufacturing Validation Issues Parent
# 3741 Some computer mice prevent auto log out
# 1694 Analog pump max actually 600 RPM
# 3743 Recipe Editor and enums with lots of values
# 3744 "Revert Cal" button in Shell cal menu
# 2721 Have Web UI show errors from Server
# 2722 Let Web UI know which pump is Level pump
# 3749 McAfee for GMP configuration
# 2726 LV Project cleanup/Structure Change
# 2727 Move Web Server and Datasocket to different EXEs
# 2728 De-cluster clustered globals
# 2729 Stop having global labels user-facing
# 2730 Don't allow recipes to 'set' indicators
# 3755 Server timeout/logout at Semma
# 3756 MFC Mismatch and floating positive voltage
# 3757 Graphs panel shouldn't show PVs for nonexistent sensors
# 3758 Hello page and loading on boot up
# 3759 pH control scheme
# 3760 Selecting window
# 3761 New touch screen and beeping
# 2741 3L Level Cal 1-pt and 2-pt instead of Zero and Span
# 2742 License Windows-side software
# 2744 getConfig in JSON format
# 3769 PBS Users.conf file corrupted
# 3771 MFC Mismatch Alarms and FlowFeedback(LPM) calculation
# 2748 Allow control loops to be event-based as well
# 2751 Support WebSocket for getMainValues call
# 1729 Calendar display glitch in "Export Data"
# 2754 RIO clean shut down
# 2755 Don't differentiate between 'Dirty' and 'Resume'
# 3781 Have alarms for outputs
# 2758 Change password for auth sb RIO
# 2759 Sending FilterOvenModeUser with getMainValues
# 3787 Confirmation dialog for Windows Shutdown/Reboot from Shell UI
# 2764 Multiple recipes
# 2769 Recipes and globals in clusters
# 1746 Change pump speed from RPM to %
# 1747 "Wait for User"/"Prompt" recipe step
# 1749 Write tests for all D terms (James tasks)
# 2774 "Unknown Command" in recipe steps report
# 3800 Graph should have dt
# 1753 Pumps&ValvesFillSpeed(RPM) 2 and 3 Windows globlas not changed by recipe
# 1754 MFC slope and intercept in cal factors file
# 1755 Make Addition pumps default 150 RPM for PBS 500
# 2780 getDORAValues Error with RIO disconnected
# 1758 Click "Enter" from external keyboard to log in
# 3807 Email about errors?
# 1760 Scheduled script to clear Chrome cache
# 2787 Correct RIO SN reporting
# 1764 No report link generated if email isn't configured correctly
# 2789 Disable auto sampling code
# 1767 Recognize NaN errors when Web UI loads
# 2796 Allow all alarms to snooze
# 2801 Copyright Software for PBS
# 2802 Upgrade to NI 2015?
# 2805 Remove modifications to current System Variables.cfg file in getConfig Server Call response
# 1783 Web UI Advanced View changes (Christian placeholder)
# 2808 Lock down Chrome
# 2809 Web UI pH and DO cals from raw values
# 2810 McAfee configurations general (James tasks)
# 2813 Use LV to change network configurations
# 2814 Lock down BIOS
# 2815 Proceduralized requirements for users
# 1793 Documentation for Web UI
# 2819 File Dialog and Browser
# 1901 Remote client shows weird timestamps if Bioreactor windows time is way behind.
# 2824 Unit Test Findings
# 2825 Change Process Data records to be in RIO time
# 2827 Prevent users recording all globals in logger settings?
# 2828 Windows Account and Startup Requirements
# 2830 Shell and Local Web UI share login?
# 2044 Server "Context Help"
# 2833 Security things for Christian to investigate
# 1810 On occasion, settings tab fails to load collapsible tabs
# 2835 Change VI passwords
# 2838 Keeping track of requirements in code
# 1815 Update Unit Test code and documentation
# 2841 Windows time
# 2842 Investigate solutions to Web Server crashing on large report generation
# 2843 Generate reports from other computer
# 1583 Improved Select Sensors behavior
# 2847 Server reading PBS Users.conf
# 2848 webcontrol.conf file missing error
# 2851 Report Generation
# 1830 Show selected sensor in Advanced View
# 2855 Version Numbering and random VI changes
# 2856 Shell Interface for 3.0
# 2857 Revisit the Cfg Editors
# 2859 Graph Panel
# 2860 Recipe Editor Modifications
# 1842 Enforce Web Access permission options
# 2862 Variables to remove from NetworkSetOnRIO and move to command handler
# 2863 Remove skipping recipe step from Server
# 2864 Changes to Logger Settings editor
# 2865 Changes to Alarm editor
# 2866 Hard code control module manager loop times
# 1843 Advanced recipe offerings
# 2868 Re-tune all PIDs
# 1845 Make sure RIO time is correct
# 2870 Copy files from LabVIEW Data to external destination
# 2871 Modify DB Logger/DB Client for Handling Backlog
# 2872 Copying files from external source to LabVIEW Data
# 2873 Renaming files in LabVIEW Data
# 2874 Deleting from LabVIEW Data folder
# 2875 Database History file
# 2876 Error Dialog Box
# 2877 3.0 Oxygen Gas Totalizing
# 2878 Server Calls to remove
# 2879 Email reports from Shell
# 2880 Cal Sensors Modifications
# 2881 User Control Panel and PBSUsers.conf file Modifications
# 2884 Welcome page
# 2885 Login Screen
# 2886 System Tools menu
# 2888 Don't allow 2 or more 'Start Batch' or 'End Batch' calls in a row
# 1164 Shutdown countdown should be 30s, 20s, 10s
# 2890 Cfg file initial states
# 2891 About menu
# 1868 Main Temp PID controller incorrectly calculates value on Setpoint Change
# 1869 Auto logout during pH calibration
# 2894 getUserInfo
# 2896 Access DB character limit
# 2897 getUsers Server Call contents
# 2900 Event-based writing Globals cfg files
# 2901 Configure individual recipes to not be run by users lacking some permission
# 2902 Changes to default PBSUsers.conf file (James tasks)
# 2903 Change order of Users
# 2904 Memory issue on Bosch machine
# 2905 Specify event timestamp externally from sub VIs
# 2906 Changes to Load Bag behavior
# 2907 Bioreactor Name storage
# 2908 Changes to Clearing Alarms behavior
# 2909 Logout call changes
# 2910 User event for revert trial cal call
# 1680 Automate Versions
# 1510 Recover recipe place after power loss
# 2919 Confirm RIO changes before writing user event
# 2920 Trial Cals in Web
# 2921 Merge setpumpb and setpumpc calls
# 2922 Power VI
# 2924 Shutdown Server Call
# 2925 'Bag ID' used incorrectly in places.
# 2926 System Variables editor
# 2927 Remove semaphore from Handle Sessions.vi
# 2757 Generate random junk for license.bin creation
# 2065 Secondary Heat PID tuning/other settings
# 1931 Update Atom CPU and memory
# 3736 Bioreactor installation occasionally fails.
# 2031 Server crashes on getAlarms call when there are many alarms
# 2973 Unit Testing investigations
# 2975 'Show Desktop' call
# 1952 SysPrep (James tasks)
# 1953 CFR 21 Part 11
# 1954 Clean up LV code base
# 935 Settings number formatting
# 1961 Remove spaces from server calls
# 1054 3L Agitation problems at 1.5 L volume
# 1020 Recipe countdown future feature
# 2990 GetBatches call
# 2717 Remove Pendotech Pressure settings
# 645 Base and Media addition monitoring
# 2993 Database Indexing
# 2994 Encrypt PBSUsers.bin with Blowfish
# 2995 Investigate Mapping Network Drive
# 2996 Verify Blowfish Algorithm from Cyth
# 2997 RIO write to persistent memory if Atom unavailable
# 2998 Verify Action Before Writing to Database
# 3001 Shell UI Parent (for CFR 21 Part 11)
# 3002 Server Parent (CFR 21 Part 11)
# 3003 Code improvements parent
# 3005 MFC Calculation Tick/Cycle data type incorrect
# 3008 Record globals only when user changes it through UI or recipe
# 3010 Map Network Drive in File Browser
# 3011 AuthsbRIO must delete license.bin file after completion
# 3745 Web UI report generation and crashing
# 3016 Use SysStop instead of Session ID for reboot
# 680 Syncing Email Addresses with User Access
# 2210 Individual fuses, and comb plate, should have alarms
# 977 Alarm and Logger settings config files need errors
# 3033 Lock Down TCP/IP Ports
# 1192 iPhone - warning overlays aren't centered
# 2042 Alarm 'code' handling
# 990 Modal Overlay Graphics and Functionality Break when toggling to/from Full Screen with Overlay Active.
# 2725 User Events Issues Parent
# 3043 Harvest Warning stops server from responding.
# 3046 Make all Enums to Enum U8
# 3049 Harvest Timeout popup appears sometimes when starting Service UI
# 3051 Calculate O2 L should take O2 MFC b into account (unit test found)
# 3052 Calc Gasses for PWM VIs weren't taking b into account when flow rate > min flow rate (unit test found)
# 3053 Checking PW for non-numeric incomplete (unit test found)
# 3055 Password Issues for Manufacturing and In-House Units
# 2032 Settings input options
# 3057  - refresh Web UI when logging out
# 3058 Check for Valid Keys and Value Process.vi and "XML" bool
# 3059 Optimize all web server code
# 2037 Trial cal after inactivity logout
# 3062 Create System Variable String array transposed (bug discovered via unit testing)
# 3063 Incorrect MFC ontime and period calculation
# 3066 Login menu
# 3067 enable and force https
# 3068 3.0 getStatic Call
# 3071 Web UI Show Desktop Button

# %%
formatter = ReleaseNotesFormatter(issues.find2(sprint_milestone="3.0"), False)
formatter.print()
# Out:
# Duplicate Key Warning ('FRS1234')
# Duplicate Key Warning ('Specification')
# Duplicate Key Warning ('Specification')
# Duplicate Key Warning ('Specification')
# Duplicate Key Warning ('Motivation')
# Got 5 warning(s) while parsing issue #3287
#
# * The popup that appears after generating a report has been redesigned:
# ** The report filename is no longer a hyperlink, and does not open the report in a new tab.
# ** An Open Report button now opens the report in a new overlay that shows report contents.
# ** For remote clients, a download button prompts the user to download the file to their own computer.
# * The Get Report popup will now function correctly when Hello is in either windowed or fullscreen mode.
#
# * Misc. network and performance optimizations.
#
# * The Secondary Heat button has been removed for all reactor models and sizes.
# * Timeline selection for the Hello UI's trendline graphs has been reverted to individual button selectors for 15m, 2h, 12h, 24h, 72h, and 7d.
# * Present Value display of Level, Filter Oven, and Main Gas has returned to the left side of the Hello UI, below the button indicators for the other controllers.
#
# * Significantly improved granularity of user permissions for actions taken from the Hello UI.
# * Users without specific permissions will now have the corresponding buttons or menus grayed out.
#
# * The Hello UI will no longer log out due to inactivity during the Integrity Test (pressure decay test).
# ** The inactivity timer will resume once the Integrity Test has completed.
# * Improved logic when canceling the Integrity test to ensure all controls are shut off properly.
#
# * The Alarms tab will now show older unacknowledged alarms if there are too few items in the list or if the user scrolls to the bottom of the list.
# ** Previously, only the first 100 alarms generated were able to be displayed in the alarms tab, which could result in a situation where 100 recent acknowledged alarms would prevent users from seeing any older unacknowledged alarms. Now, the list will continue to populate with older unacknowledged alarms. In addition, it will continue to load alarms if a user scrolls to the bottom of the unacknowledged list, allowing a user to view older alarms without requiring them to acknowledge earlier alarms first.
#
# * Fixed a bug preventing Pressure PV from being displayed in yellow text when a high or low alarm is being triggered, if the pressure sensor had been recently disconnected.
# * Fixed a display bug in the Pumps tab when selecting "Addition A" for base bump after having previously selected "Addition b".
#
# * Significant improvements have been made to the security of user login attempts:
# ** Users may now be designated as account administrators by assigning the "Account Management" permission.
# ** Users will now only be allowed up to 10 failed login attempts before requiring an administrator password reset.
# ** Logging in successfully will reset the failed login counter to 0.
# ** An administrator is required to unlock a locked account.
# ** An administrator can never become locked out due to failed password attempts, but must wait 3 seconds between failed attempts.
# * Login failure events will trigger additional alerts and failure messages:
# ** A user event will be logged to the database in all circumstances indicating a successful or unsuccessful attempt.
# ** If a user fails a login due to incorrect password:
# *** A UI message will indicate login failure, including the number of remaining attempts before lockout.
# *** An email will be sent to each administrator as well as the account owner. No emails will be sent to accounts without email addresses assigned.
# ** User passwords can now be configured to expire after a set amount of time (eg. two weeks).
# ** If a user's password expires in less than two weeks, they will now receive an alert when logging into the Web UI.
#
# * All Web Server traffic now uses SSL Encryption using SHA 256 with RSA 4096 encryption.
#
# * Fixed a bug that caused all Hello UI login events to be recorded as "Unknown User".
#
# * The Advanced Menu will no longer show NaN for O2 Flow when output is 0.
#
# * Improved performance of network communication with the RIO improve response times when changing controller settings.
#
#
#
# * Fixed a bug that could cause calibration values to be saved as Inf or -Inf.
#
# * The Harvest Mode interface is now accessed on the Graphs -> Agitation menu.
# * An End Harvest button has been added to allow users to exit harvest mode. Users no longer need to turn agitation on manually to exit harvest mode.
# * The Web UI now displays an Agitation Interlock when in harvest mode.
#
# * Global variables related to DO control now indicate whether they are specific to Air Drive or Mag Drive bioreactors.
#
# * Fixed an issue that could cause the bioreactor to occasionally fail to accept a set point change from the Web UI.
#
# * The logger settings editor now always correctly starts at the top of the list when opening a new file.
#
# * Raw values in the Calibration menu will now be listed in scientific notation.
#
# * Fixed an issue which could cause agitation to always appear as 0 under certain circumstances during startup.
#
# * New functionality has been added to automatically back up all bioreactor databases automatically at a user-configurable interval.
# ** Users can set the backup interval in hourly increments from 1 to any number of hours. Setting the value to 0 disables the auto-backup.
# ** The backup feature will attempt to backup to any destination mapped to the Z: drive. If no drive is mapped, no backup will occur, and a user event will record the error.
# ** All database files which do not exist on the destination drive will be copied over. Existing archived databases will not be overridden, but the active database and database history file will be.
#
# * Fixed an issue which could cause the RIO to fail to reconnect to the Shell UI after a disconnect or reboot.
#
# * Removed references to several unused alarms from config files and documentation.
#
# * An on-screen keyboard now allows users to enter text in input boxes in the Shell UI, eliminating the need for an external keyboard.
#
# * A continue/cancel dialog box now prompts the user before taking certain actions in the Shell UI.
#
# * Order of steps listed in a Recipe Steps report will now always match the order of execution when multiple steps are completed with the same timestamp.
#
# * Optimized persistence of user set points between bioreactor power cycles.
#
# * User permissions may now be set at a much more granular level, allowing more fine-tuned access to certain features of the Hello or Desktop UI. The permission groups are as follows:
# ** _Account Management_ permissions are used to manage user accounts and user groups, including password resets and permissions.
# ** _Advanced Calibration_ permissions allow a user to calibrate sensors from the Desktop UI.
# ** _Alarms Editor_ permissions allow a user to edit alarm notification and email settings.
# ** _Controls_ permissions allow a user to change set points and modes for Agitation, Temperature, pH, DO, and Main Gas.
# ** _DB Management_ permissions allow a user to delete, archive, or backup databases.
# ** _Logger Editor_ permissions allow a user to edit the logger settings file.
# ** _Recipe Editor_ permissions allow a user to delete, modify, or create new recipes.
# ** _Reports_ permissions allow a user to generate and export reports.
# ** _Settings Editor_ permissions allow a user to edit system variables from the Desktop UI.
# ** _System Management_ permissions allow a user to log off, reboot, or shutdown the Windows computer.
# ** _Acknowledge Alarms_ permissions allow a user to acknowledge any unacknowledged alarms.
# ** _Batch_ permissions allow a user to create or end batches.
# ** _Door_ permissions allow a user to unlock the door on a 15L or larger unit.
# ** _Hello Access_ permissions allow a user to login to the Hello UI.
# ** _Hello Settings_ permissions allow a user to edit system variables from the Hello UI.
# ** _Light_ permissions allow a user to turn the LED light on or off.
# ** _Pumps_ permissions allow a user to control the media, addition, or sample pumps.
# ** _Recipe Start_ permissions allow a user to start recipes.
# ** _Recipe End_ permissions allow a user to end recipes.
# ** _Remote Hello Access_ permissions control whether a user is able to log in through the remote interface (unrelated to LogMeIn).
# ** _Sensors_ permissions allow a user to change the sensor status of pH, Temperature, and DO sensors.
#
# * An archive feature has been added to archive the active database when the file size grows too large.
# ** The database will be automatically archived when the size is greater than 1.6gb with no batch running, or 1.9gb when a batch is currently running.
# ** The database size will be checked for auto-archive once every hour and when a batch is ended.
# ** A database can be manually archived by clicking an "Archive" button in the Desktop UI's "File Browser" tab.
# ** If any batch is running during the archive, it will be renamed "... (truncated)" in the old database, and "... (continued)" in the new database
# ** Database files will be renamed "Archive001", "Archive002", etc when archived.
# ** A Database History File will list dates for creation and archive of each database file on the bioreactor.
#
# * Fixed a bug which could cause user events to record the wrong username if multiple users log into the Hello UI at the same time.
#
# * Agitation will now ramp up from low RPM to Set Point when resuming after the comb plate has been popped.
#
# * Fixed a bug which caused any recipe whose name contained a hyphen ("-") to be looped, even if the name did not end with "-LoopRecipe".
#
# * Eliminated several unnecessary system variables and globals which are no longer used.
#
# * The start pressure, end pressure, and decay rate obtained during the pressure decay test (integrity test) in the Web UI will now be recorded as a User Event in the database.
#
# * Fixed a bug which would cause a Web UI Logout user event with "Unknown User" to be recorded every 10 minutes when no user was logged in.
#
# * User events reports generated for a completed batch will now include the "End Batch" event at the end of the report.
#
# * Fixed a bug causing CSV files generated by the reports feature to be parsed incorrectly due to improper escaping of carriage returns or commas in message strings.
#
# * Fixed a bug that could cause the database to become corrupted by writing NaN values to numeric fields.
#
# * Failing to send an email will no longer prevent a user from accessing a report from the Hello UI. In addition, a user event will now be recorded to the database.
#
# * The safety setting for maximum media temperature is now called "Max Temp (C)" for both Air and Mag drive bioreactors.
#
# * Certain alarms will no longer be triggered on startup due to faulty hardware readings during initialization.
#
# * Many existing user events have had their names or descriptions improved or clarified.
#
# * Fixed a bug when generating a data report that caused a single data point to be missing from the variable with the most recorded data points.
# * Fixed a bug when generating a data report that resulted in an empty file if only a single variable was being recorded.
#
# * The email password used for the return address for all email functionality is now encrypted separately from plaintext email settings.
#
# * Changing a variable via recipe that corresponds to a setting in the System Variables will now update that System Variable.
# ** Previously, changing a setting via recipe would take effect until the System Variables file was reloaded. Now, these changes are captured by the settings file itself, and will persist until explicitly changed again.
#
# * The "Tare 1" button has been renamed to "Span" in the Desktop UI's calibration menu for DO A and DO B 1 point calibrations.
#
# * Fixed a bug that could cause the RIO to disconnect when syncing time with the Windows computer.
#
# * Several PID controllers have been converted to use actual elapsed time as an input parameter each iteration rather than a static and possibly incorrect constant value.
#
# * Corrected an issue causing the large media pump to run slightly faster than intended in all circumstances.
#
# * Placeholder
#
# * Fixed an issue preventing a Recipe from being able to edit some variables whose IDs were stored internally in a hierarchical fashion.
#
# * MFC flow output can now be calibrated similar to other sensors to improve flow accuracy, particularly at very low flow rates.
# ** Note the reported flow rate may be slightly different than requested, as the feedback voltage is not calibrated.
#
# * Corrected an issue that caused the Hello UI to show an excessive number of error messages when the RIO is disconnected.
#
# * Fixed a bug that caused the RIO's serial number to be displayed incorrectly in the Hello UI.
#
# * All alarms now obey the Alarm Snooze Time setting, not just process alarms.
#
# * The Hello UI now operates in Kiosk mode when opening directly on the bioreactor.
# * Users are no longer allowed to access websites other than Hello on the bioreactor.
# * Users will no longer have access to the underlying filesystem through Chrome's download or save-as dialog.
#
# * The bioreactor BIOS is now password-protected to prevent unauthorized access. The password will be provided to the customer to be used at their discretion.
#
# * A custom file browser is now used by all relevant parts of the Desktop UI to ensure file selections and file saves are performed securely.
#
# * Fixed an issue which could cause timestamps for Process Data records to be slightly incorrect if there was a delay between the time generated and time written to the database.
#
# * Three Windows user accounts are now included for GMP machine configurations:
# ** The Employee account is the default account for standard bioreactor operation.
# ** The PBS Biotech account is intended for use by PBS Biotech employees for field service.
# ** The Admin account is intended for use by the customer's authorized IT personnel for in-house configuration.
# * The Employee account for GMP machines is configured to disable most items from the ctrl-alt-del menu.
#
# * Only James understand select sensors, so he can write release notes for it.
#
# * The Report Generation menu in the Desktop UI has been updated, and now uses buttons rather than dropdown menus to select options.
# * A Go To File button now automatically switches tabs and selects the most recently generated report in the File Browser tab of the Desktop UI.
#
# * The Service UI has been converted to the brand-new Desktop UI, with a completely new design.
# ** All menu navigation now uses buttons instead of tabs. Some tabs open dropdown menus, which contain additional menu options.
# ** Hello UI - Launches Hello UI if it is not open in the background, or switches back to the Hello UI if it is.
# ** Graph - Switches to Graph menu.
# ** Config - opens a dropdown containing a list of configuration editor options.
# *** Alarm - opens Alarms Config and Email Settings editor.
# *** Calibration - Opens the calibration menu.
# *** Logger - Opens the logger settings editor.
# *** Recipe - Opens the Recipe Editor.
# *** Settings - Opens the System Variables Editor.
# ** Reports - Opens the Reports tab, containing report generation feature, database list, and batch file list.
# ** File Browser - Opens the file browser, data export, and network configuration menu.
# ** System - Opens a dropdown containing system options.
# *** Tools - Contains misc. tools including bioreactor name and current date/time.
# *** Power - Contains windows shutdown, reboot, and log off options.
# ** About - Contains information about bioreactor configuration and database history.
# ** Account - Opens a dropdown with a link to account settings and an option to log out.
#
# * Individual tabs for Agitation, DO, pH, Main Gas, Gas Flow, and Filter Oven have been condensed into a single Graphs tab.
# * Users may no longer change most modes or set points from the Graphs tab.
# * Users may switch between different graphs by clicking on the buttons at the top of the Graphs tab.
# * The graphs tab now shows 3 minutes of data updated in 0.25 second intervals.
#
# * The Recipe Editor has been updated with a new, more intuitive interface.
# ** Appearance of the Recipe List and Recipe Command List has changed slightly.
# ** The Recipe List no longer uses a separate popup menu to add or delete recipes.
# ** The toggle between a looping and non-looping recipe is now controlled by a two-button selection.
# ** Action selection is now controlled by a three-button selection.
#
# * The alarms editor now has three columns for "Notify", "Audible", and "Email", instead of "Ignore", "Audible", and "Email".
#
# * All PID controllers have been re-tuned to improve performance.
# ** Controllers have been optimized to seek set points without overshoot and maintain stability under standard operation.
# ** The DO controller is now much more stable at set point, and calls for significantly less unnecessary gas.
# ** The pH controller is now much more stable at set point, and no longer spikes up and down unnecessarily.
#
# * Time is now automatically synced between the Windows and RIO under the following circumstances:
# ** A user clicks the "Set Time" button
# ** The Desktop UI is loaded
# ** Every day at midnight
# * All timestamps used by the RIO will now be stored in UTC. They will be converted to local time when presented to the user.
#
# * File extensions of several config files have been modified to distinguish them from other file types.
# ** Alarms files now end in ".alm".
# ** System variables files now end in ".sys".
# ** Logger Settings files now end in ".log"
# ** Encrypted config files now end in ".cfgx"
#
# * A Database History File now tracks the history of databases on the bioreactor.
# ** The name, start time, end time, date deleted, user who deleted, and MD5 checksum are recorded for all databases which have been used on the bioreactor.
# ** Database Name and Start Time are recorded when a database is created.
# ** Database Name is modified and End Time and MD5 checksum are recorded when a database is archived.
# ** Date Deleted and User are recorded when a database is deleted.
#
# * Serious errors in the Desktop UI will now trigger a popup menu, rather than appearing in a box on the current tab.
#
# * For Mag Drive bioreactors, CO2, N2, and O2 flow are now all controlled and reported as a percentage of total flow.
# * For Air Drive bioreactors, total flow is calculated as the sum of agitation flow plus O2 flow. CO2, N2, and Air are still controlled as a percentage of Main Gas flow, while O2 is controlled as a separate flow rate.
#
# * Appearance of the calibration menu has been updated and improved.
# * Calibration values for MFCs can now be entered in the calibration menu. Slope and intercept values must be determined separately and input manually.
#
# * The Edit User and Edit User Groups dialogs have been improved significantly.
# ** Edit User
# *** The menu has been redesigned with a new appearance.
# *** The menu now shows the last time the user's password was changed, and time until password expires.
# *** An alert box shows any errors that have occurred while setting up the current user.
# ** Configure Groups
# *** The menu has been redesigned with a new appearance.
# *** Many different permissions are selectable to restrict access to certain parts of bioreactor functionality (see elsewhere for description)
# *** Each group can now be assigned a password expiration period for all users within the group.
#
# * When no menus are selected in the Desktop UI, a welcome menu will be shown with the PBS Logo.
#
# * The login screen now allows use of an on-screen keyboard to enter username and password.
#
# * The new System Tools menu allows access to several features merged from multiple tabs of the Service UI:
# ** View and change the current bioreactor name.
# ** Manual RIO reboot.
# ** View current time and sync with RIO.
# ** Test Alarm buzzer functionality.
# ** Restart Hello UI.
#
# * Factory settings for all config files are now stored in the bioreactor database for reference purposes. They may be viewed by finding the relevant entries generated from a User Events report.
#
# * The new About menu displays information about the bioreactor system:
# ** Software version numbers for Desktop UI, DB Logger, Web Server, Network, RIO, and Database.
# ** Bioreactor model, RIO serial number, startup status, and config file status.
# ** The bioreactor's link-local IPv4 address. This is the address it receives on the current local area network.
# ** Serial number, product number, and expiration date of the currently loaded bag (set by Load Bag in the Hello UI).
# ** Parsed contents of the Database History file.
#
#
#
# * Improved error checking when using the Load Bag feature to prevent erroneous behavior.
#
# * The bioreactor name is now recorded in a special field in the database. This field is overwritten if the name is changed.
#
# * Alarms that were generated before a database was archived, which still had not been acknowledged by the time the database is archived, will be cleared from memory when acknowledged, but will not be modified in the archived database. A user event will be logged in this circumstance.
#
# * The user event generated when reverting a trial calibration now indicates whether it originated from the Desktop or Hello UI.
#
# * Recipes will now resume from their previous location when the bioreactor reboots after power loss.
#
# * The new Power menu contains buttons that initiate shutdown, restart, or log off of the Windows computer.
#
# * The System Variables editor has been redesigned to resemble the Logger Settings editor. All settings are listed with category and current value.
#
# * Fixed a bug that could cause the Hello UI to crash when attempting to access the alarms tabs with a very high number of unacknowledged alarms.
#
#
#
# * All software functionality has been approved by a 3rd party audit to be CFR 21 part 11 compliant.
#
# * When the RIO is disconnected, it will now continue logging data until it can reconnect to Windows, or it runs out of memory store additional data.
#
# * Actions generating User Events will now always verify the action has been executed before being written to the database, except for the following exceptions:
# ** During shutdown (the shutdown attempt is recorded before it occurs).
# ** When a batch is ended (so the event is recorded as part of the batch itself).
#
# * MFC 'pulsing' is more accurate
#
#
#
# * The new Map Network Drive menu allows users to map any network drives to an available drive letter.
# ** The interface displays available drive letters, currently mapped drives and status of drives, and entry fields for network path, username, password.
# ** Drives can be mapped by selecting a drive letter and entering info in the relevant boxes. Username and password are only required for networks that require it.
# ** Drives can be unmapped by selecting the "Delete All" button.
#
# * Alarms have been added for blown electrical fuses on the internal bioreactor electronics as well as the E-Stop switch (comb plate switch).
# * When the E-Stop is triggered, alarms will now be generated for fuses whose power is cut off by the switch.
#
# * Incompatible logger settings files will now generate an error and user alert if there are missing settings or file format errors.
# * Incompatible alarms files will now generate an error and user alert if there are missing alarms or file format errors.
#
# * The bioreactor's OS now blocks all network connections except those used by PBS Software and installed components.
#
# * The Hello UI will now refresh on logout to reset session-specific options.
#
# * Fixed an issue causing MFCs to pulse for the incorrect amount of time while in pulse mode. Note that the net flow rate was previously correct and has not changed.
#
# * Improved level of detail in error messages shown to users after Login failures.
#
# * All local and remote connections to the Hello Interface will now use HTTPS.
#
# * The "Toggle Fullscreen" button has been relabeled "Show Desktop"
# * The "Show Desktop" button now allows the user to toggle between Hello and Desktop UIs.

# %%
unchecked = formatter.check()
# Out:
# Issues without Release Notes:
#   2230
#   2460
#   2469
#   2500
#   3177
#   3178
#   3183
#   3186
#   3188
#   3189
#   3191
#   3192
#   3194
#   3198
#   3199
#   3200
#   3201
#   3202
#   3203
#   3204
#   3205
#   3206
#   3207
#   3209
#   3210
#   3211
#   3212
#   3213
#   3214
#   3215
#   3216
#   3217
#   3218
#   3223
#   3224
#   3229
#   3230
#   3231
#   3233
#   3234
#   3235
#   3236
#   3237
#   3240
#   3246
#   3247
#   3264
#   3267
#   3287
#   3416
#   3741

# %%
for m in unchecked:
    url = "https://issue.pbsbiotech.com/issues/%s"%str(m)
    print("Issue %s: %s"%(m,url))
# Out:
# Issue 2230: https://issue.pbsbiotech.com/issues/2230
# Issue 2460: https://issue.pbsbiotech.com/issues/2460
# Issue 2469: https://issue.pbsbiotech.com/issues/2469
# Issue 2500: https://issue.pbsbiotech.com/issues/2500
# Issue 3177: https://issue.pbsbiotech.com/issues/3177
# Issue 3178: https://issue.pbsbiotech.com/issues/3178
# Issue 3183: https://issue.pbsbiotech.com/issues/3183
# Issue 3186: https://issue.pbsbiotech.com/issues/3186
# Issue 3188: https://issue.pbsbiotech.com/issues/3188
# Issue 3189: https://issue.pbsbiotech.com/issues/3189
# Issue 3191: https://issue.pbsbiotech.com/issues/3191
# Issue 3192: https://issue.pbsbiotech.com/issues/3192
# Issue 3194: https://issue.pbsbiotech.com/issues/3194
# Issue 3198: https://issue.pbsbiotech.com/issues/3198
# Issue 3199: https://issue.pbsbiotech.com/issues/3199
# Issue 3200: https://issue.pbsbiotech.com/issues/3200
# Issue 3201: https://issue.pbsbiotech.com/issues/3201
# Issue 3202: https://issue.pbsbiotech.com/issues/3202
# Issue 3203: https://issue.pbsbiotech.com/issues/3203
# Issue 3204: https://issue.pbsbiotech.com/issues/3204
# Issue 3205: https://issue.pbsbiotech.com/issues/3205
# Issue 3206: https://issue.pbsbiotech.com/issues/3206
# Issue 3207: https://issue.pbsbiotech.com/issues/3207
# Issue 3209: https://issue.pbsbiotech.com/issues/3209
# Issue 3210: https://issue.pbsbiotech.com/issues/3210
# Issue 3211: https://issue.pbsbiotech.com/issues/3211
# Issue 3212: https://issue.pbsbiotech.com/issues/3212
# Issue 3213: https://issue.pbsbiotech.com/issues/3213
# Issue 3214: https://issue.pbsbiotech.com/issues/3214
# Issue 3215: https://issue.pbsbiotech.com/issues/3215
# Issue 3216: https://issue.pbsbiotech.com/issues/3216
# Issue 3217: https://issue.pbsbiotech.com/issues/3217
# Issue 3218: https://issue.pbsbiotech.com/issues/3218
# Issue 3223: https://issue.pbsbiotech.com/issues/3223
# Issue 3224: https://issue.pbsbiotech.com/issues/3224
# Issue 3229: https://issue.pbsbiotech.com/issues/3229
# Issue 3230: https://issue.pbsbiotech.com/issues/3230
# Issue 3231: https://issue.pbsbiotech.com/issues/3231
# Issue 3233: https://issue.pbsbiotech.com/issues/3233
# Issue 3234: https://issue.pbsbiotech.com/issues/3234
# Issue 3235: https://issue.pbsbiotech.com/issues/3235
# Issue 3236: https://issue.pbsbiotech.com/issues/3236
# Issue 3237: https://issue.pbsbiotech.com/issues/3237
# Issue 3240: https://issue.pbsbiotech.com/issues/3240
# Issue 3246: https://issue.pbsbiotech.com/issues/3246
# Issue 3247: https://issue.pbsbiotech.com/issues/3247
# Issue 3264: https://issue.pbsbiotech.com/issues/3264
# Issue 3267: https://issue.pbsbiotech.com/issues/3267
# Issue 3287: https://issue.pbsbiotech.com/issues/3287
# Issue 3416: https://issue.pbsbiotech.com/issues/3416
# Issue 3741: https://issue.pbsbiotech.com/issues/3741

# %%
import time
import webbrowser
for i, m in enumerate(unchecked, 1):
    url = "https://issue.pbsbiotech.com/issues/%s"%str(m)
    if not i%5: input("Press enter to continue")
    time.sleep(0.5)
    webbrowser.open_new_tab(url)
# Out:
# Press enter to continue
# Press enter to continue
# Press enter to continue
# Press enter to continue
# Press enter to continue
# Press enter to continue
# Press enter to continue
# Press enter to continue
# Press enter to continue
# Press enter to continue

# %%
from scripts.software_frs.frs_traceability2 import load_frs_from_issuetracker, build_frs_tree
items = load_frs_from_issuetracker()
reqs= build_frs_tree(items)
# Out:
# Downloading projects...
# Downloading issues: 503/503

# %%
refresh()
# Out:
# Downloading issues: 503/503

# %%
webfrs_match = re.compile(r"^[-\*\+]+(3\.0WebFRS\d+)\:?[\*\+]+").match
def sort_webfrs(s):
    return int(s[-3:])
def webf(d):
    frs = []
    for l in d.splitlines():
        m = webfrs_match(l)
        if m:
            frs.append(m.group(1))
    return sorted(frs, key=sort_webfrs)

cmp = []
for i in issues:
    frs = webf(i.description)
    cmp.extend(frs)
    if frs:
        print(i.id)
        for f in frs:
            print("", f)
cmp.sort(key=sort_webfrs)
# Out:
# 3057
#  3.0WebFRS121
# 3066
#  3.0WebFRS001
#  3.0WebFRS002
#  3.0WebFRS119
# 3067
#  3.0WebFRS003
# 3071
#  3.0WebFRS004
#  3.0WebFRS005
#  3.0WebFRS006
# 3072
#  3.0WebFRS007
#  3.0WebFRS008
#  3.0WebFRS009
#  3.0WebFRS010
#  3.0WebFRS011
#  3.0WebFRS012
#  3.0WebFRS013
#  3.0WebFRS014
# 3073
#  3.0WebFRS015
#  3.0WebFRS016
#  3.0WebFRS017
#  3.0WebFRS018
#  3.0WebFRS019
#  3.0WebFRS020
#  3.0WebFRS021
#  3.0WebFRS022
#  3.0WebFRS023
#  3.0WebFRS024
#  3.0WebFRS025
#  3.0WebFRS026
#  3.0WebFRS027
#  3.0WebFRS028
#  3.0WebFRS029
#  3.0WebFRS030
#  3.0WebFRS031
#  3.0WebFRS032
#  3.0WebFRS033
#  3.0WebFRS034
#  3.0WebFRS035
#  3.0WebFRS036
#  3.0WebFRS037
#  3.0WebFRS038
#  3.0WebFRS039
#  3.0WebFRS040
#  3.0WebFRS041
#  3.0WebFRS042
#  3.0WebFRS043
#  3.0WebFRS044
#  3.0WebFRS045
#  3.0WebFRS046
#  3.0WebFRS047
#  3.0WebFRS048
#  3.0WebFRS049
#  3.0WebFRS050
#  3.0WebFRS051
#  3.0WebFRS052
#  3.0WebFRS053
#  3.0WebFRS054
#  3.0WebFRS055
#  3.0WebFRS056
#  3.0WebFRS057
#  3.0WebFRS058
#  3.0WebFRS059
#  3.0WebFRS060
#  3.0WebFRS061
#  3.0WebFRS062
#  3.0WebFRS063
#  3.0WebFRS064
#  3.0WebFRS065
#  3.0WebFRS066
#  3.0WebFRS067
#  3.0WebFRS120
# 3074
#  3.0WebFRS068
#  3.0WebFRS069
#  3.0WebFRS070
#  3.0WebFRS071
#  3.0WebFRS072
#  3.0WebFRS073
#  3.0WebFRS074
#  3.0WebFRS075
#  3.0WebFRS076
#  3.0WebFRS077
#  3.0WebFRS078
#  3.0WebFRS079
#  3.0WebFRS080
#  3.0WebFRS081
#  3.0WebFRS082
#  3.0WebFRS083
#  3.0WebFRS084
# 3075
#  3.0WebFRS085
#  3.0WebFRS086
#  3.0WebFRS087
#  3.0WebFRS088
#  3.0WebFRS089
# 3077
#  3.0WebFRS091
#  3.0WebFRS092
#  3.0WebFRS093
#  3.0WebFRS094
#  3.0WebFRS095
#  3.0WebFRS096
#  3.0WebFRS097
#  3.0WebFRS098
#  3.0WebFRS099
#  3.0WebFRS100
#  3.0WebFRS101
#  3.0WebFRS102
#  3.0WebFRS103
#  3.0WebFRS104
#  3.0WebFRS105
# 3078
#  3.0WebFRS106
#  3.0WebFRS107
# 3079
#  3.0WebFRS108
#  3.0WebFRS109
# 3080
#  3.0WebFRS110
#  3.0WebFRS111
# 3081
#  3.0WebFRS090
#  3.0WebFRS112
#  3.0WebFRS113
#  3.0WebFRS114
#  3.0WebFRS115
#  3.0WebFRS116
#  3.0WebFRS117
#  3.0WebFRS118
# 3308
#  3.0WebFRS087

# %%
{"3.0WebFRS%03d"%i for i in range(1,122)} - set(cmp)
# Out:
# set()

# %%
for i in issues:
    if "3.0Web" in i.description:
        print("==========================")
        print("---Issue: %d---"%i.id)
        print("==========================")
# Out:
# ==========================
# ---Issue: 3057---
# ==========================
# ==========================
# ---Issue: 3066---
# ==========================
# ==========================
# ---Issue: 3067---
# ==========================
# ==========================
# ---Issue: 3071---
# ==========================
# ==========================
# ---Issue: 3072---
# ==========================
# ==========================
# ---Issue: 3073---
# ==========================
# ==========================
# ---Issue: 3074---
# ==========================
# ==========================
# ---Issue: 3075---
# ==========================
# ==========================
# ---Issue: 3077---
# ==========================
# ==========================
# ---Issue: 3078---
# ==========================
# ==========================
# ---Issue: 3079---
# ==========================
# ==========================
# ---Issue: 3080---
# ==========================
# ==========================
# ---Issue: 3081---
# ==========================
# ==========================
# ---Issue: 3308---
# ==========================

# %%
from clipboard import *
s = paste()
lz = []
for line in s.splitlines():
    if line.startswith("3.0Web"):
        a,b = line.split(" ", 1)
        line = "\n*+" + a + "+* " + b
    lz.append(line)
copy("\n".join(lz))
