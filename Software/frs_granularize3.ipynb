# %%
""" Auto-number FRS items from formatted list
*+FRS1234+*
#
##
###
*** Non-numbered FRS text or sub-item
#
##
###

becomes 

*+FRS1234+*
* *FRS1234.1:*
** *FRS1234.1.1:*
*** *FRS1234.1.1.1:*
**** Non-numbered FRS text or sub-item

* *FRS1234.2:*
** *FRS1234.2.1:*
*** *FRS1234.2.1.1:* 
"""
# Out:
# ' Auto-number FRS items from formatted list\n*+FRS1234+*\n#\n##\n###\n*** Non-numbered FRS text or sub-item\n#\n##\n###\n\nbecomes \n\n*+FRS1234+*\n* *FRS1234.1:*\n** *FRS1234.1.1:*\n*** *FRS1234.1.1.1:*\n**** Non-numbered FRS text or sub-item\n\n* *FRS1234.2:*\n** *FRS1234.2.1:*\n*** *FRS1234.2.1.1:* \n'

# %%
import re
subitem_match = re.compile(r"^(?:([#]+)\s*)").match
magic_match = re.compile(r"^@lm\:\<(.+)\>").match
header_match = re.compile(r"^(?:([\*\#]*) )?\-?([\+\*]+)([^\*\+]+?)\:?([\+\*]+)\:?\s*(.+)?\-?$").match
frs_match = re.compile(r"([FU]RS\d*)\.?([\d\.]+)?").match
num_escape_match = re.compile(r"^(\*{2})(\#+)").match
image_caption_match = re.compile(r"(Image \d+)").match
toplevel_match = re.compile(r"^([\+\*]+)([^\*\+]+?)\:?([\+\*]+)\:?\s*(.+)?$").match

class FRSNumberStateMachine():
    VALID_INDENTS = "*+"
    
    # inputs
    LINE_FRS = 0
    LINE_SUBITEM = 1
    LINE_OTHER = 2
    LINE_HEADER = 3
    LINE_NUM_ESCAPE = 4
    LINE_IMG_CAPTION = 5
    
    # states
    ST_INIT = 0
    ST_NONUM = 1
    ST_FRS = 2
    
    def __init__(self, depth=None, startval=1, indent_char="*"):
        self._startval = startval
        self.state = []
        self.ilvl = 0
        self.nlvl = 0 
        self.clvl = 0
        self.frs = ""
        self.nums = ""
        self.fmt = ""
        self.depth = depth
        if indent_char not in self.VALID_INDENTS:
            raise ValueError("Invalid Indent Character " + indent_char)
        self.indent_char = indent_char
        self.line = ""
        
        self.sm_st = self.ST_INIT
        self.sm = [
            # ST_INIT             ST_NONUM             ST_FRS
            [self.set_frs,        self.set_frs,        self.set_frs],        # LINE_FRS
            [None,                None,                self.set_subitem],    # LINE_SUBITEM
            [None,                None,                None],                # LINE_OTHER
            [self.set_header,     self.set_header,     self.set_header],     # LINE_HEADER
            [self.set_num_escape, self.set_num_escape, self.set_num_escape], # LINE_NUM_ESCAPE
            [None,                None,                None],                # LINE_IMG_CAPTION
        ]
        
    def _grow(self, n):
        while len(self.state) < n:
            self.state.append(self._startval)
        
    def indent(self, n=1):
        maxn = self.clvl + self.nlvl + n
        minn = self.clvl + self.nlvl
        self._grow(maxn)
        for i in range(minn, maxn):
            self.state[i] = 1
        self.clvl += n
    
    def dedent(self, n=1):
        self.clvl -= n
        self.next()
        
    def next(self):
        self.state[self.clvl+self.nlvl-1] += 1
        
    def set_indent(self, n):
        diff = n - (self.ilvl + self.clvl)
        if diff == 0:
            self.next()
        elif diff > 0:
            self.indent(diff)
        else:
            self.dedent(-diff)
            
    def curr_state(self, lvl):
        return self.state[:self.nlvl + lvl]
    
    def format_lvl(self, lvl):
        idl = lvl + self.ilvl
        if idl < 0: idl = 0
        ind = self.indent_char * idl
        if self.depth is not None and idl > self.depth:
            return ind
        space = " " if ind else ""
        frs = self.frs
        fmt = "*"
        nums = ".".join(str(n) for n in self.curr_state(lvl))
        dot = "." if nums else ""
        post = ":*"
        return "".join((ind, space, fmt, frs, dot, nums, post))
    
    def set_state_from_nums(self, nums):
        if not nums:
            lnums = []
        else:
            lnums = nums.split(".")
        self.state = [self._startval] * len(lnums)
        for i, n in enumerate(lnums):
            self.state[i] = int(n)
        return len(lnums)
    
    def feed(self, line):
        ev, arg = self._parse_input(line)
        func = self.sm[ev][self.sm_st]
        if func:
            st, rv = func(arg)
            self.sm_st = st
        else:
            rv = line
        return rv
    
    def _parse_input(self, line): 
        """Parse the input line to determine the 
        type of input, and any arguments to be passed
        to the input event handler.
        """
        m = header_match(line)
        if m:
            ind, fmt, s, fmt2, _ = m.groups()

            # Verify format to avoid false positive
            # if other * or + characters appear in the string
            if fmt == fmt2[::-1]:
                m2 = frs_match(s)
                if m2:
                    typ = self.LINE_FRS
                    frs, nums = m2.groups()
                    arg = (line, ind, fmt, frs, nums)
                    return typ, arg
                if image_caption_match(s):
                    return self.LINE_IMG_CAPTION, ()
                else:
                    typ = self.LINE_HEADER
                    arg = (line, ind, fmt, s)
                return typ, arg
        m = subitem_match(line)
        if m:
            typ = self.LINE_SUBITEM
            arg = line, len(m.group(1) or "")
            return typ, arg
        m = num_escape_match(line)
        if m:
            typ = self.LINE_NUM_ESCAPE
            arg = line,
            return typ, arg
        return self.LINE_OTHER, (line,)
    
    def frs_string(self):
        return self.format_lvl(self.clvl)
    
    def parse_text(self, text):
        for line in text.splitlines():
            yield self.feed(line)
    
    # State machine methods
                                
    def set_frs(self, arg):
        line, indent, fmt, frs, nums = arg
        self.ilvl = len(indent or "")
        self.fmt = fmt
        self.frs = frs
        self.nlvl = self.set_state_from_nums(nums)
        self.clvl = 0
        return self.ST_FRS, line
    
    def set_header(self, arg):
        return self.ST_NONUM, arg[0]
    
    def set_subitem(self, arg):
        line, n = arg
        self.set_indent(n)
        fmt = self.frs_string()
        try:
            _, tail = line.split(" ", 1)
        except ValueError:
            v = fmt
        else:
            v = " ".join((fmt, tail))
        return self.sm_st, v
    
    def set_num_escape(self, arg):
        line, = arg
        return self.sm_st, line.lstrip("*")
    
NumState = FRSNumberStateMachine

# %%
ntests = 0
passed = 0
errors = []
def assert_ab(a, b, equal=True):
    global ntests, passed, errors
    ntests += 1
    try:
        if equal:
            assert a == b, "%r != %r" % (a, b)
        else:
            assert a != b, "%r == %r" % (a, b)
    except AssertionError as e:
        val = str(e)
        if isinstance(a, str) and isinstance(b, str):
            val += "\n" + str(a.splitlines()) + "\n" + str(b.splitlines())
        errors.append(val)
    else:
        passed += 1

def assert_header_match(s, exp):
    assert_ab(header_match(s).groups(), exp)
        
assert header_match("**") == None
assert header_match("***") == None
assert_header_match("*FRS1234*", (None, "*", "FRS1234", "*", None))
assert_header_match("*URS*", (None, "*", "URS", "*", None))
assert_header_match("*FRS1234*", (None, "*", "FRS1234", "*", None))
assert_header_match("* *FRS1234*", ("*", "*", "FRS1234", "*", None))
assert_header_match("*FRS1234.5.6*", (None, "*", "FRS1234.5.6", "*", None))
assert_header_match("*+FRS1234.5.6+*", (None, "*+", "FRS1234.5.6", "+*", None))
assert_header_match("** *+FRS1234.5.6.7.8+*", ("**", "*+", "FRS1234.5.6.7.8", "+*", None))
assert_header_match("* *FRS1234:*", ("*", "*", "FRS1234", "*", None))
assert_header_match("* *FRS1234*:", ("*", "*", "FRS1234", "*", None))
assert_header_match("* *FRS1234*: Bob", ("*", "*", "FRS1234", "*", "Bob"))



def assert_num_escape(s, exp):
    m = num_escape_match(s)
    r = m.groups() if m else None
    assert_ab(r, exp)
    
assert_num_escape("**# Bob", ("**", "#"))
assert_num_escape("**## Bob", ("**", "##"))
assert_num_escape("**### Bob", ("**", "###"))
assert_num_escape("# Bob", None)
assert_num_escape("## Bob", None)
assert_num_escape("### Bob", None)
assert_num_escape("* Bob", None)
assert_num_escape("** Bob", None)
assert_num_escape("*** Bob", None)

#def assert_img_match(s):
#    m = image_match(s)
#    assert_ab(bool(m), True)
    
#assert_img_match("Image 1")

def set_str(st, s):
    ind, fmt, fs, _, _ = header_match(s).groups()
    frs, nums = frs_match(fs).groups()
    st.set_frs((s, ind, fmt, frs, nums))
    

def test_state(s):
    state = NumState()
    set_str(state, s)
    return state
    
def assert_state(s, statevals, ilvl, nlvl):
    state = test_state(s)
    assert_ab(state.ilvl, ilvl)
    assert_ab(state.nlvl, nlvl)
    assert_ab(state.state, statevals)

def test_ilvl(s, ilvl):
    state = NumState()
    set_str(state, s)
    return state
    
def assert_ilvl(s, ilvl):
    state = test_ilvl(s, ilvl)
    assert_ab(state.ilvl, ilvl)
    
def test_fmt(s):
    state = NumState()
    set_str(state, s)
    return state
    
def assert_fmt1(s, id, fmt):
    state = test_fmt(s)
    state.indent(id)
    assert_ab(state.frs_string(), fmt)
    
def assert_fmt2(s, id, fmt):
    state = test_fmt(s)
    for _ in range(id):
        state.indent(1)
    assert_ab(state.frs_string(), fmt)
    
def assert_indent(s, id, fmt):
    assert_fmt1(s, id, fmt)
    assert_fmt2(s, id, fmt)

assert_ilvl("*FRS1234*", 0)
assert_ilvl("*FRS1234.5.6*", 0)
assert_ilvl("** *FRS1234.5.6*", 2)

assert_state("*FRS1234*", [], 0, 0)
assert_state("*FRS1234.5.6*", [5, 6], 0, 2)
assert_state("** *FRS1234.5.6*", [5, 6], 2, 2)
assert_state("** *FRS1234*", [], 2, 0)

def assert_state2(s, ilvl, nlvl, clvl):
    state = test_state(s)
    st = state.state.copy()
    state.indent()
    st.append(1)
    assert_ab(state.state, st)
    assert_ab(state.ilvl, ilvl)
    assert_ab(state.nlvl, nlvl)
    assert_ab(state.clvl, clvl)

assert_state2("*FRS1234*", 0, 0, 1)
assert_state2("* *FRS1234*", 1, 0, 1)
assert_indent("*FRS1234*", 1, "* *FRS1234.1:*")
assert_indent("*FRS1234*", 1, "* *FRS1234.1:*")
assert_indent("* *FRS1234*", 1, "** *FRS1234.1:*")
assert_indent("*FRS1234.1*", 1, "* *FRS1234.1.1:*")
assert_indent("*FRS1234.1*", 2, "** *FRS1234.1.1.1:*")

def assert_next(s, exp):
    st = NumState()
    set_str(st, s)
    st.next()
    assert_ab(st.frs_string(), exp)

def assert_dedent(s, id, nxt, dd, fmt, typ=1):
    st = NumState()
    set_str(st, s)
    st.indent(id)
    for _ in range(nxt):
        st.next()
    if typ == 1:
        st.dedent(dd)
    else:
        for _ in range(dd):
            st.dedent(1)
    assert_ab(st.frs_string(), fmt)

assert_next("*FRS1234.1*", "*FRS1234.2:*")
assert_next("* *FRS1234.1*", "* *FRS1234.2:*")
assert_next("*FRS1234.1.2*", "*FRS1234.1.3:*")
assert_next("* *FRS1234.1.2*", "* *FRS1234.1.3:*")
assert_dedent("*FRS1234.1*", 1, 2, 1, "*FRS1234.2:*")
assert_dedent("*FRS1234.1*", 1, 1, 1, "*FRS1234.2:*")
assert_dedent("*FRS1234.1*", 2, 1, 1, "* *FRS1234.1.2:*")
assert_dedent("*FRS1234.1*", 2, 1, 1, "* *FRS1234.1.2:*")
assert_dedent("*FRS1234.1*", 2, 1, 2, "*FRS1234.2:*")
assert_dedent("*FRS1234.1*", 3, 1, 2, "* *FRS1234.1.2:*")
assert_dedent("* *FRS1234.1*", 1, 2, 1, "* *FRS1234.2:*")
assert_dedent("* *FRS1234.1*", 1, 1, 1, "* *FRS1234.2:*")
assert_dedent("* *FRS1234.1*", 2, 1, 1, "** *FRS1234.1.2:*")
assert_dedent("* *FRS1234.1*", 2, 1, 1, "** *FRS1234.1.2:*")
assert_dedent("* *FRS1234.1*", 2, 1, 2, "* *FRS1234.2:*")
assert_dedent("* *FRS1234.1*", 3, 1, 2, "** *FRS1234.1.2:*")

def assert_feed_indent(s, feed, exp):
    st = NumState()
    set_str(st, s)
    st.sm_st = st.ST_FRS
    st.feed(feed)
    assert_ab(st.frs_string(), exp)
    
assert_feed_indent("*FRS1234*", "# Bob", "* *FRS1234.1:*")
assert_feed_indent("*FRS1234*", "## Bob", "** *FRS1234.1.1:*")
assert_feed_indent("*FRS1234.1*", "# Bob", "* *FRS1234.1.1:*")
assert_feed_indent("*FRS1234.1*", "## Bob", "** *FRS1234.1.1.1:*")
assert_feed_indent("* *FRS1234.1*", "# Bob", "* *FRS1234.2:*")
assert_feed_indent("* *FRS1234*", "## Bob", "** *FRS1234.1:*")
assert_feed_indent("** *FRS1234.1*", "## Bob", "** *FRS1234.2:*")
assert_feed_indent("* *FRS1234.1*", "## Bob", "** *FRS1234.1.1:*")
assert_feed_indent("** *FRS1234.1.1*", "# Bob", "* *FRS1234.2:*")
assert_feed_indent("*FRS1234.1*", "# ", "* *FRS1234.1.1:*")
assert_feed_indent("*FRS1234.1*", "## ", "** *FRS1234.1.1.1:*")
assert_feed_indent("*FRS1234.1*", "#", "* *FRS1234.1.1:*")
assert_feed_indent("*FRS1234.1*", "##", "** *FRS1234.1.1.1:*")

def assert_double_parse(t, d=5):
    r = list(NumState(d).parse_text(t))
    r2 = list(NumState(d).parse_text("\n".join(r)))
    assert_ab(r, r2)
    
dpt = """*FRS2881.4*
# PBSUsers.conf file will keep track of the following data:
## Per User
### User Name
### Group
### Password
### Email Address
### Date Password was Saved
### Number of Failed Login Attempts
## Per Group
### Group Name
### Password Expiration Period (Days)
## 2-D Permission Table
### Each row corresponds to each group"""
assert_double_parse(dpt)

def assert_new_state(s, exp, nxt=1, ind=0):
    st = NumState()
    for l in s.splitlines():
        st.feed(l)
    for _ in range(nxt):
        st.next()
    for _ in range(ind):
        st.indent()
    assert_ab(st.frs_string(), exp)
    
assert_new_state("*FRS123.1*\n*FRS31.2*", "*FRS31.3:*")
assert_new_state("*FRS123.1*\n*FRS123.3*", "*FRS123.4:*")

def assert_parse_text(txt, exp):
    st = NumState()
    lines = list(st.parse_text(txt))
    res = "\n".join(lines)
    assert_ab(res, exp)

lines = """*FRS1234.1:*
#"""
exp = """*FRS1234.1:*
* *FRS1234.1.1:*"""
assert_parse_text(lines, exp)

lines="""*FRS1234.1:*
#
## Item two!
*** Non-numbered FRS text or sub-item
*FRS1234.2:*
Foobar
# !Foobar.jpg!
#
##
"""
exp = """*FRS1234.1:*
* *FRS1234.1.1:*
** *FRS1234.1.1.1:* Item two!
*** Non-numbered FRS text or sub-item
*FRS1234.2:*
Foobar
# !Foobar.jpg!
* *FRS1234.2.1:*
** *FRS1234.2.1.1:*"""

assert_parse_text(lines, exp)

lines = "+*FRS*+\n*FRS1234:*\n#"
exp = "+*FRS*+\n*FRS1234:*\n* *FRS1234.1:*"
assert_parse_text(lines, exp)

lines = """*FRS2908.1*
# Fred
*** Bob
## Zoe"""

exp = """*FRS2908.1*
* *FRS2908.1.1:* Fred
*** Bob
** *FRS2908.1.1.1:* Zoe"""

assert_parse_text(lines, exp)

lines = """*FRS2908.1*
# Fred
#### Biff
*** Bob
# Zoe"""

exp = """*FRS2908.1*
* *FRS2908.1.1:* Fred
**** *FRS2908.1.1.1.1.1:* Biff
*** Bob
* *FRS2908.1.2:* Zoe"""

assert_parse_text(lines, exp)

lines = """*FRS2908.0*
# Bob1
## Bob2
*** Fred1
*** Fred2
## Bob3
## Bob4
## Bob5
*** Fred3
#### Bob6
#### Bob7
#### Bob8
*** Fred4
# Bob9
"""

exp = """*FRS2908.0*
* *FRS2908.0.1:* Bob1
** *FRS2908.0.1.1:* Bob2
*** Fred1
*** Fred2
** *FRS2908.0.1.2:* Bob3
** *FRS2908.0.1.3:* Bob4
** *FRS2908.0.1.4:* Bob5
*** Fred3
**** *FRS2908.0.1.4.1.1:* Bob6
**** *FRS2908.0.1.4.1.2:* Bob7
**** *FRS2908.0.1.4.1.3:* Bob8
*** Fred4
* *FRS2908.0.2:* Bob9"""
assert_parse_text(lines, exp)

lines = """*FRS2908.0* 
# Bob
** Fred:
# Bob"""

exp = """*FRS2908.0* 
* *FRS2908.0.1:* Bob
** Fred:
* *FRS2908.0.2:* Bob"""
assert_parse_text(lines, exp)

lines = """*FRS2908.0* 
# Bob
** considered +/- 15 degrees
# Bob"""

exp = """*FRS2908.0* 
* *FRS2908.0.1:* Bob
** considered +/- 15 degrees
* *FRS2908.0.2:* Bob"""
assert_parse_text(lines, exp)

lines = """*FRS123* 
# Bob
*Image 1*: Bob's image
# Bob"""

exp = """*FRS123* 
* *FRS123.1:* Bob
*Image 1*: Bob's image
* *FRS123.2:* Bob"""
assert_parse_text(lines, exp)

lines = """*URS2908.0* 
# Bob
** considered +/- 15 degrees
# Bob"""

exp = """*URS2908.0* 
* *URS2908.0.1:* Bob
** considered +/- 15 degrees
* *URS2908.0.2:* Bob"""
assert_parse_text(lines, exp)

def assert_parse_empty(s, exp):
    st = NumState()
    res = None
    for res in st.parse_text(s):
        pass
    assert_ab(res, exp)
    
assert_parse_empty("*User Requirements*\n# Bar", "# Bar")

def finish():
    print("%d/%d tests passed successfully" % (passed, ntests))
    for e in errors:
        print(e)
    if errors:
        raise Exception("Unit testing suite failed")
finish()
# Out:
# 95/95 tests passed successfully

# %%
dg_re = re.compile("^\**\s*[\+\*]+([FU]RS[\d\.]+)\:?[\+\*]+\:?\s*(.*)$").match
import clipboard
def degranularize():
    s = clipboard.paste()
    lines = []
    for line in s.splitlines():
        m = dg_re(line)
        if m:
            sand = ("#" * m.group(1).count("."))
            if sand: sand += " "
            line = sand + m.group(2)
        lines.append(line)
    clipboard.copy("\n".join(lines))
    print("\n".join(lines))
degranularize()
# Out:
# # The software can control 2 Additions pumps.
# # Users can configure an Additions pump as the Base pump, to be used by the pH controller.
#
#
# * -*+FRS3662.1+* When Addition Pump A or Addition Pump B is set to "Off" in software (and is not the Base pump), no voltage is delivered to the pump.-
# * -*+FRS3662.2+* Non-500L speeds-
# ** -*+FRS3662.2.1+* On a bioreactor that is not a 500L, when Addition Pump A or Addition Pump B is set to "Slow" in software (and is not the Base pump), the output fed to the particular pump is the fraction of the Pumps "Aux Low Duty" setting out of 2^16.-
# ** -*+FRS3662.2.2+* On a bioreactor that is not a 500L, when Addition Pump A or Addition Pump B is set to "Medium" in software (and is not the Base pump), the output fed to the particular pump is the fraction of the Pumps "Aux Med Duty" setting out of 2^16.-
# ** -*+FRS3662.2.3+* On a bioreactor that is not a 500L, when Addition Pump A or Addition Pump B is set to "Fast" in software (and is not the Base pump), the output fed to the particular pump is 2^16 out of 2^16.-
# * -*+FRS3662.3+* 500L speeds-
# ** -*+FRS3662.3.1+* On a bioreactor that is a 500L, the user can set Addition Pump A and Addition Pump B to be on and off.-
# ** -*+FRS3662.3.2+* When one of the pumps is on, the user can control the speed in RPM.-
# ** -*+FRS3662.3.3+* The voltage delivered is 0.00833 (the 3 is repeating; 5V/600 RPM is the ratio) volts per requested RPM. An RPM of 600 would deliver 5 volts, but the user interface only allows values up to 500 RPM-
# * -*+FRS3662.4+*- Base pump
# ** -*+FRS3662.4.1+* Users can configure the base pump to be Addition Pump A, Addition Pump B, or None.-
# ** -*+FRS3662.4.2+* When Addition Pump A or Addition Pump B is configured to be the Base Pump, the % Base Pump Duty output by the pH controller is converted to an output fed to the pump using the Pumps "Base On Time (s)" setting, which determines how long each 'on' pulse of the base pump must be, and the Pumps "Base Max Period (s)" setting, which determines the smallest % Base Pump Duty that can be delivered.-
# ** -*+FRS3662.4.3+* A % Base Pump Duty that is less than the "Base On Time (s)" as a percent of "Base Max Period (s)" will result in the pump being off.-
# ** -*+FRS3662.4.4+* On a bioreactor that is not a 500L, when Addition Pump A or Addition Pump B is configured to be the Base Pump and it should be on, the pump turns on at the 'fast' speed (defined in FRS3662.2.3).-
# ** -*+FRS3662.4.5+* On a bioreactor that is a 500L, when Addition Pump A or Addition Pump B is configured to be the Base Pump and it should be on, the pump turns on at the RPM set by the Pumps "Analog Base Speed (RPM)" setting.-

# %%
template=  r'''lines=r"""%s
"""
res = "\n".join(NumState(7).parse_text(lines))
print(res)
import clipboard
clipboard.copy(res)
'''
s = template % clipboard.paste()
clipboard.copy(s)
#exec(s)

# %%
lines=r"""
*+URS4094+* Database
# The system should log various PVs, SPs, and other raw data at regular intervals. 
# A user should be able to select which variables to log, and how often to log them. 
# Users should be able to log specific system parameters determined to be important, such as Agitation PV, Temperature, etc. 
# All Alarms generated should be logged to the database
# Internal errors should be logged to the database. 
 
*+FRS4094+* Database
# Data Logger
** Note: In this FRS, "the database" refers to any sort of database used to store the data (Access, sqlite, postgres, etc.)
## Each datapoint recorded should have an associated timestamp. 
## All variables configured to be logged should be logged to the database at the appropriate time. 
## The maximum time a variable may go without being logged will be defined by System Variable "System" "Max Data Log Interval (min)"
## Each variable will be configurable whether that variable is logged.
## Each variable will have a configurable deadband. Whenever the current value differs from the previously recorded value by more than the deadband, the variable will be recorded. 
## The following variables will be made available to the Data Logger:
*** Note: Other variables may be made available (currently, a LOT more are). However, this list will ONLY contain variables which we determine definitely SHOULD be made available. Whether others are available is an implementation detail.
*** Note: Some of these depend on the existence of / implementation of certain features. Ensuring this list is complete requires knowledge of all system functions. The list should be reviewed when features are added, modified, or removed.
### Agitation PV, SP, current output, mode
### Temperature PV, SP, current output, mode
### DO PV, SP, controller request, current outputs, mode
### pH PV, SP, controller request, current outputs, mode
### Main Gas PV, SP, current output, mode
### Gas Flow Request (LPM): Air, N2, O2, CO2
### Gas Flow Delivered (LPM): Air, N2, O2, CO2
### Level PV
### Pressure PV
### Harvest Mode status
# Alarms
## Each alarm recorded should have a timestamp. 
## Each alarm recorded should have an alarm code. 
## When acknowledged, each alarm record should be modified to indicate the username and time of acknowledgement. 
## For process alarms, each alarm should include the current PV. 
# Errors
## Any internal errors should generate a record. Specific errors will be specified by respective FRS items. 
# User Events
** Note: some specific user events depend on implementation details of the HMI. This event list must be updated accordingly if the interface changes. 
## Each descrete action a user takes, which results in modifying the system state, should generate a user event. 
## Each user event record should include a timestamp, username, and description of the change. 
## Each user event record should be entered after verifying the action occurred, unless it is impossible to do so (such as system shutdown).

"""
res = "\n".join(NumState(7).parse_text(lines))
print(res)
import clipboard
clipboard.copy(res)
# Out:
# *+URS4094+* Database
# * *URS4094.1:* The system should log various PVs, SPs, and other raw data at regular intervals.
# * *URS4094.2:* A user should be able to select which variables to log, and how often to log them.
# * *URS4094.3:* Users should be able to log specific system parameters determined to be important, such as Agitation PV, Temperature, etc.
# * *URS4094.4:* All Alarms generated should be logged to the database
# * *URS4094.5:* Internal errors should be logged to the database.
#
# *+FRS4094+* Database
# * *FRS4094.1:* Data Logger
# ** Note: In this FRS, "the database" refers to any sort of database used to store the data (Access, sqlite, postgres, etc.)
# ** *FRS4094.1.1:* Each datapoint recorded should have an associated timestamp.
# ** *FRS4094.1.2:* All variables configured to be logged should be logged to the database at the appropriate time.
# ** *FRS4094.1.3:* The maximum time a variable may go without being logged will be defined by System Variable "System" "Max Data Log Interval (min)"
# ** *FRS4094.1.4:* Each variable will be configurable whether that variable is logged.
# ** *FRS4094.1.5:* Each variable will have a configurable deadband. Whenever the current value differs from the previously recorded value by more than the deadband, the variable will be recorded.
# ** *FRS4094.1.6:* The following variables will be made available to the Data Logger:
# *** Note: Other variables may be made available (currently, a LOT more are). However, this list will ONLY contain variables which we determine definitely SHOULD be made available. Whether others are available is an implementation detail.
# *** Note: Some of these depend on the existence of / implementation of certain features. Ensuring this list is complete requires knowledge of all system functions. The list should be reviewed when features are added, modified, or removed.
# *** *FRS4094.1.6.1:* Agitation PV, SP, current output, mode
# *** *FRS4094.1.6.2:* Temperature PV, SP, current output, mode
# *** *FRS4094.1.6.3:* DO PV, SP, controller request, current outputs, mode
# *** *FRS4094.1.6.4:* pH PV, SP, controller request, current outputs, mode
# *** *FRS4094.1.6.5:* Main Gas PV, SP, current output, mode
# *** *FRS4094.1.6.6:* Gas Flow Request (LPM): Air, N2, O2, CO2
# *** *FRS4094.1.6.7:* Gas Flow Delivered (LPM): Air, N2, O2, CO2
# *** *FRS4094.1.6.8:* Level PV
# *** *FRS4094.1.6.9:* Pressure PV
# *** *FRS4094.1.6.10:* Harvest Mode status
# * *FRS4094.2:* Alarms
# ** *FRS4094.2.1:* Each alarm recorded should have a timestamp.
# ** *FRS4094.2.2:* Each alarm recorded should have an alarm code.
# ** *FRS4094.2.3:* When acknowledged, each alarm record should be modified to indicate the username and time of acknowledgement.
# ** *FRS4094.2.4:* For process alarms, each alarm should include the current PV.
# * *FRS4094.3:* Errors
# ** *FRS4094.3.1:* Any internal errors should generate a record. Specific errors will be specified by respective FRS items.
# * *FRS4094.4:* User Events
# ** Note: some specific user events depend on implementation details of the HMI. This event list must be updated accordingly if the interface changes.
# ** *FRS4094.4.1:* Each descrete action a user takes, which results in modifying the system state, should generate a user event.
# ** *FRS4094.4.2:* Each user event record should include a timestamp, username, and description of the change.
# ** *FRS4094.4.3:* Each user event record should be entered after verifying the action occurred, unless it is impossible to do so (such as system shutdown).
