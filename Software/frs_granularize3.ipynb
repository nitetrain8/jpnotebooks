# %%
""" Auto-number FRS items from formatted list
*+FRS1234+*
#
##
###
*** Non-numbered FRS text or sub-item
#
##
###

becomes 

*+FRS1234+*
* *FRS1234.1:*
** *FRS1234.1.1:*
*** *FRS1234.1.1.1:*
**** Non-numbered FRS text or sub-item

* *FRS1234.2:*
** *FRS1234.2.1:*
*** *FRS1234.2.1.1:* 
"""
# Out:
# ' Auto-number FRS items from formatted list\n*+FRS1234+*\n#\n##\n###\n*** Non-numbered FRS text or sub-item\n#\n##\n###\n\nbecomes \n\n*+FRS1234+*\n* *FRS1234.1:*\n** *FRS1234.1.1:*\n*** *FRS1234.1.1.1:*\n**** Non-numbered FRS text or sub-item\n\n* *FRS1234.2:*\n** *FRS1234.2.1:*\n*** *FRS1234.2.1.1:* \n'

# %%
import re
subitem_match = re.compile(r"^(?:([#]+)\s*)").match
magic_match = re.compile(r"^@lm\:\<(.+)\>").match
header_match = re.compile(r"^(?:([\*\#]*) )?([\+\*]+)([^\*\+]+?)\:?([\+\*]+)\:?\s*(.+)?$").match
frs_match = re.compile(r"([FU]RS\d*)\.?([\d\.]+)?").match
num_escape_match = re.compile(r"^(\*{2})(\#+)").match
image_caption_match = re.compile(r"(Image \d+)").match
toplevel_match = re.compile(r"^([\+\*]+)([^\*\+]+?)\:?([\+\*]+)\:?\s*(.+)?$").match

class FRSNumberStateMachine():
    VALID_INDENTS = "*+"
    
    # inputs
    LINE_FRS = 0
    LINE_SUBITEM = 1
    LINE_OTHER = 2
    LINE_HEADER = 3
    LINE_NUM_ESCAPE = 4
    LINE_IMG_CAPTION = 5
    
    # states
    ST_INIT = 0
    ST_NONUM = 1
    ST_FRS = 2
    
    def __init__(self, depth=None, startval=1, indent_char="*"):
        self._startval = startval
        self.state = []
        self.ilvl = 0
        self.nlvl = 0 
        self.clvl = 0
        self.frs = ""
        self.nums = ""
        self.fmt = ""
        self.depth = depth
        if indent_char not in self.VALID_INDENTS:
            raise ValueError("Invalid Indent Character " + indent_char)
        self.indent_char = indent_char
        self.line = ""
        
        self.sm_st = self.ST_INIT
        self.sm = [
            # ST_INIT             ST_NONUM             ST_FRS
            [self.set_frs,        self.set_frs,        self.set_frs],        # LINE_FRS
            [None,                None,                self.set_subitem],    # LINE_SUBITEM
            [None,                None,                None],                # LINE_OTHER
            [self.set_header,     self.set_header,     self.set_header],     # LINE_HEADER
            [self.set_num_escape, self.set_num_escape, self.set_num_escape], # LINE_NUM_ESCAPE
            [None,                None,                None],                # LINE_IMG_CAPTION
        ]
        
    def _grow(self, n):
        while len(self.state) < n:
            self.state.append(self._startval)
        
    def indent(self, n=1):
        maxn = self.clvl + self.nlvl + n
        minn = self.clvl + self.nlvl
        self._grow(maxn)
        for i in range(minn, maxn):
            self.state[i] = 1
        self.clvl += n
    
    def dedent(self, n=1):
        self.clvl -= n
        self.next()
        
    def next(self):
        self.state[self.clvl+self.nlvl-1] += 1
        
    def set_indent(self, n):
        diff = n - (self.ilvl + self.clvl)
        if diff == 0:
            self.next()
        elif diff > 0:
            self.indent(diff)
        else:
            self.dedent(-diff)
            
    def curr_state(self, lvl):
        return self.state[:self.nlvl + lvl]
    
    def format_lvl(self, lvl):
        idl = lvl + self.ilvl
        if idl < 0: idl = 0
        ind = self.indent_char * idl
        if self.depth is not None and idl > self.depth:
            return ind
        space = " " if ind else ""
        frs = self.frs
        fmt = "*"
        nums = ".".join(str(n) for n in self.curr_state(lvl))
        dot = "." if nums else ""
        post = ":*"
        return "".join((ind, space, fmt, frs, dot, nums, post))
    
    def set_state_from_nums(self, nums):
        if not nums:
            lnums = []
        else:
            lnums = nums.split(".")
        self.state = [self._startval] * len(lnums)
        for i, n in enumerate(lnums):
            self.state[i] = int(n)
        return len(lnums)
    
    def feed(self, line):
        ev, arg = self._parse_input(line)
        func = self.sm[ev][self.sm_st]
        if func:
            st, rv = func(arg)
            self.sm_st = st
        else:
            rv = line
        return rv
    
    def _parse_input(self, line): 
        """Parse the input line to determine the 
        type of input, and any arguments to be passed
        to the input event handler.
        """
        m = header_match(line)
        if m:
            ind, fmt, s, fmt2, _ = m.groups()

            # Verify format to avoid false positive
            # if other * or + characters appear in the string
            if fmt == fmt2[::-1]:
                m2 = frs_match(s)
                if m2:
                    typ = self.LINE_FRS
                    frs, nums = m2.groups()
                    arg = (line, ind, fmt, frs, nums)
                    return typ, arg
                if image_caption_match(s):
                    return self.LINE_IMG_CAPTION, ()
                else:
                    typ = self.LINE_HEADER
                    arg = (line, ind, fmt, s)
                return typ, arg
        m = subitem_match(line)
        if m:
            typ = self.LINE_SUBITEM
            arg = line, len(m.group(1) or "")
            return typ, arg
        m = num_escape_match(line)
        if m:
            typ = self.LINE_NUM_ESCAPE
            arg = line,
            return typ, arg
        return self.LINE_OTHER, (line,)
    
    def frs_string(self):
        return self.format_lvl(self.clvl)
    
    def parse_text(self, text):
        for line in text.splitlines():
            yield self.feed(line)
    
    # State machine methods
                                
    def set_frs(self, arg):
        line, indent, fmt, frs, nums = arg
        self.ilvl = len(indent or "")
        self.fmt = fmt
        self.frs = frs
        self.nlvl = self.set_state_from_nums(nums)
        self.clvl = 0
        return self.ST_FRS, line
    
    def set_header(self, arg):
        return self.ST_NONUM, arg[0]
    
    def set_subitem(self, arg):
        line, n = arg
        self.set_indent(n)
        fmt = self.frs_string()
        try:
            _, tail = line.split(" ", 1)
        except ValueError:
            v = fmt
        else:
            v = " ".join((fmt, tail))
        return self.sm_st, v
    
    def set_num_escape(self, arg):
        line, = arg
        return self.sm_st, line.lstrip("*")
    
NumState = FRSNumberStateMachine

# %%
ntests = 0
passed = 0
errors = []
def assert_ab(a, b, equal=True):
    global ntests, passed, errors
    ntests += 1
    try:
        if equal:
            assert a == b, "%r != %r" % (a, b)
        else:
            assert a != b, "%r == %r" % (a, b)
    except AssertionError as e:
        val = str(e)
        if isinstance(a, str) and isinstance(b, str):
            val += "\n" + str(a.splitlines()) + "\n" + str(b.splitlines())
        errors.append(val)
    else:
        passed += 1

def assert_header_match(s, exp):
    assert_ab(header_match(s).groups(), exp)
        
assert header_match("**") == None
assert header_match("***") == None
assert_header_match("*FRS1234*", (None, "*", "FRS1234", "*", None))
assert_header_match("*URS*", (None, "*", "URS", "*", None))
assert_header_match("*FRS1234*", (None, "*", "FRS1234", "*", None))
assert_header_match("* *FRS1234*", ("*", "*", "FRS1234", "*", None))
assert_header_match("*FRS1234.5.6*", (None, "*", "FRS1234.5.6", "*", None))
assert_header_match("*+FRS1234.5.6+*", (None, "*+", "FRS1234.5.6", "+*", None))
assert_header_match("** *+FRS1234.5.6.7.8+*", ("**", "*+", "FRS1234.5.6.7.8", "+*", None))
assert_header_match("* *FRS1234:*", ("*", "*", "FRS1234", "*", None))
assert_header_match("* *FRS1234*:", ("*", "*", "FRS1234", "*", None))
assert_header_match("* *FRS1234*: Bob", ("*", "*", "FRS1234", "*", "Bob"))



def assert_num_escape(s, exp):
    m = num_escape_match(s)
    r = m.groups() if m else None
    assert_ab(r, exp)
    
assert_num_escape("**# Bob", ("**", "#"))
assert_num_escape("**## Bob", ("**", "##"))
assert_num_escape("**### Bob", ("**", "###"))
assert_num_escape("# Bob", None)
assert_num_escape("## Bob", None)
assert_num_escape("### Bob", None)
assert_num_escape("* Bob", None)
assert_num_escape("** Bob", None)
assert_num_escape("*** Bob", None)

#def assert_img_match(s):
#    m = image_match(s)
#    assert_ab(bool(m), True)
    
#assert_img_match("Image 1")

def set_str(st, s):
    ind, fmt, fs, _, _ = header_match(s).groups()
    frs, nums = frs_match(fs).groups()
    st.set_frs((s, ind, fmt, frs, nums))
    

def test_state(s):
    state = NumState()
    set_str(state, s)
    return state
    
def assert_state(s, statevals, ilvl, nlvl):
    state = test_state(s)
    assert_ab(state.ilvl, ilvl)
    assert_ab(state.nlvl, nlvl)
    assert_ab(state.state, statevals)

def test_ilvl(s, ilvl):
    state = NumState()
    set_str(state, s)
    return state
    
def assert_ilvl(s, ilvl):
    state = test_ilvl(s, ilvl)
    assert_ab(state.ilvl, ilvl)
    
def test_fmt(s):
    state = NumState()
    set_str(state, s)
    return state
    
def assert_fmt1(s, id, fmt):
    state = test_fmt(s)
    state.indent(id)
    assert_ab(state.frs_string(), fmt)
    
def assert_fmt2(s, id, fmt):
    state = test_fmt(s)
    for _ in range(id):
        state.indent(1)
    assert_ab(state.frs_string(), fmt)
    
def assert_indent(s, id, fmt):
    assert_fmt1(s, id, fmt)
    assert_fmt2(s, id, fmt)

assert_ilvl("*FRS1234*", 0)
assert_ilvl("*FRS1234.5.6*", 0)
assert_ilvl("** *FRS1234.5.6*", 2)

assert_state("*FRS1234*", [], 0, 0)
assert_state("*FRS1234.5.6*", [5, 6], 0, 2)
assert_state("** *FRS1234.5.6*", [5, 6], 2, 2)
assert_state("** *FRS1234*", [], 2, 0)

def assert_state2(s, ilvl, nlvl, clvl):
    state = test_state(s)
    st = state.state.copy()
    state.indent()
    st.append(1)
    assert_ab(state.state, st)
    assert_ab(state.ilvl, ilvl)
    assert_ab(state.nlvl, nlvl)
    assert_ab(state.clvl, clvl)

assert_state2("*FRS1234*", 0, 0, 1)
assert_state2("* *FRS1234*", 1, 0, 1)
assert_indent("*FRS1234*", 1, "* *FRS1234.1:*")
assert_indent("*FRS1234*", 1, "* *FRS1234.1:*")
assert_indent("* *FRS1234*", 1, "** *FRS1234.1:*")
assert_indent("*FRS1234.1*", 1, "* *FRS1234.1.1:*")
assert_indent("*FRS1234.1*", 2, "** *FRS1234.1.1.1:*")

def assert_next(s, exp):
    st = NumState()
    set_str(st, s)
    st.next()
    assert_ab(st.frs_string(), exp)

def assert_dedent(s, id, nxt, dd, fmt, typ=1):
    st = NumState()
    set_str(st, s)
    st.indent(id)
    for _ in range(nxt):
        st.next()
    if typ == 1:
        st.dedent(dd)
    else:
        for _ in range(dd):
            st.dedent(1)
    assert_ab(st.frs_string(), fmt)

assert_next("*FRS1234.1*", "*FRS1234.2:*")
assert_next("* *FRS1234.1*", "* *FRS1234.2:*")
assert_next("*FRS1234.1.2*", "*FRS1234.1.3:*")
assert_next("* *FRS1234.1.2*", "* *FRS1234.1.3:*")
assert_dedent("*FRS1234.1*", 1, 2, 1, "*FRS1234.2:*")
assert_dedent("*FRS1234.1*", 1, 1, 1, "*FRS1234.2:*")
assert_dedent("*FRS1234.1*", 2, 1, 1, "* *FRS1234.1.2:*")
assert_dedent("*FRS1234.1*", 2, 1, 1, "* *FRS1234.1.2:*")
assert_dedent("*FRS1234.1*", 2, 1, 2, "*FRS1234.2:*")
assert_dedent("*FRS1234.1*", 3, 1, 2, "* *FRS1234.1.2:*")
assert_dedent("* *FRS1234.1*", 1, 2, 1, "* *FRS1234.2:*")
assert_dedent("* *FRS1234.1*", 1, 1, 1, "* *FRS1234.2:*")
assert_dedent("* *FRS1234.1*", 2, 1, 1, "** *FRS1234.1.2:*")
assert_dedent("* *FRS1234.1*", 2, 1, 1, "** *FRS1234.1.2:*")
assert_dedent("* *FRS1234.1*", 2, 1, 2, "* *FRS1234.2:*")
assert_dedent("* *FRS1234.1*", 3, 1, 2, "** *FRS1234.1.2:*")

def assert_feed_indent(s, feed, exp):
    st = NumState()
    set_str(st, s)
    st.sm_st = st.ST_FRS
    st.feed(feed)
    assert_ab(st.frs_string(), exp)
    
assert_feed_indent("*FRS1234*", "# Bob", "* *FRS1234.1:*")
assert_feed_indent("*FRS1234*", "## Bob", "** *FRS1234.1.1:*")
assert_feed_indent("*FRS1234.1*", "# Bob", "* *FRS1234.1.1:*")
assert_feed_indent("*FRS1234.1*", "## Bob", "** *FRS1234.1.1.1:*")
assert_feed_indent("* *FRS1234.1*", "# Bob", "* *FRS1234.2:*")
assert_feed_indent("* *FRS1234*", "## Bob", "** *FRS1234.1:*")
assert_feed_indent("** *FRS1234.1*", "## Bob", "** *FRS1234.2:*")
assert_feed_indent("* *FRS1234.1*", "## Bob", "** *FRS1234.1.1:*")
assert_feed_indent("** *FRS1234.1.1*", "# Bob", "* *FRS1234.2:*")
assert_feed_indent("*FRS1234.1*", "# ", "* *FRS1234.1.1:*")
assert_feed_indent("*FRS1234.1*", "## ", "** *FRS1234.1.1.1:*")
assert_feed_indent("*FRS1234.1*", "#", "* *FRS1234.1.1:*")
assert_feed_indent("*FRS1234.1*", "##", "** *FRS1234.1.1.1:*")

def assert_double_parse(t, d=5):
    r = list(NumState(d).parse_text(t))
    r2 = list(NumState(d).parse_text("\n".join(r)))
    assert_ab(r, r2)
    
dpt = """*FRS2881.4*
# PBSUsers.conf file will keep track of the following data:
## Per User
### User Name
### Group
### Password
### Email Address
### Date Password was Saved
### Number of Failed Login Attempts
## Per Group
### Group Name
### Password Expiration Period (Days)
## 2-D Permission Table
### Each row corresponds to each group"""
assert_double_parse(dpt)

def assert_new_state(s, exp, nxt=1, ind=0):
    st = NumState()
    for l in s.splitlines():
        st.feed(l)
    for _ in range(nxt):
        st.next()
    for _ in range(ind):
        st.indent()
    assert_ab(st.frs_string(), exp)
    
assert_new_state("*FRS123.1*\n*FRS31.2*", "*FRS31.3:*")
assert_new_state("*FRS123.1*\n*FRS123.3*", "*FRS123.4:*")

def assert_parse_text(txt, exp):
    st = NumState()
    lines = list(st.parse_text(txt))
    res = "\n".join(lines)
    assert_ab(res, exp)

lines = """*FRS1234.1:*
#"""
exp = """*FRS1234.1:*
* *FRS1234.1.1:*"""
assert_parse_text(lines, exp)

lines="""*FRS1234.1:*
#
## Item two!
*** Non-numbered FRS text or sub-item
*FRS1234.2:*
Foobar
# !Foobar.jpg!
#
##
"""
exp = """*FRS1234.1:*
* *FRS1234.1.1:*
** *FRS1234.1.1.1:* Item two!
*** Non-numbered FRS text or sub-item
*FRS1234.2:*
Foobar
# !Foobar.jpg!
* *FRS1234.2.1:*
** *FRS1234.2.1.1:*"""

assert_parse_text(lines, exp)

lines = "+*FRS*+\n*FRS1234:*\n#"
exp = "+*FRS*+\n*FRS1234:*\n* *FRS1234.1:*"
assert_parse_text(lines, exp)

lines = """*FRS2908.1*
# Fred
*** Bob
## Zoe"""

exp = """*FRS2908.1*
* *FRS2908.1.1:* Fred
*** Bob
** *FRS2908.1.1.1:* Zoe"""

assert_parse_text(lines, exp)

lines = """*FRS2908.1*
# Fred
#### Biff
*** Bob
# Zoe"""

exp = """*FRS2908.1*
* *FRS2908.1.1:* Fred
**** *FRS2908.1.1.1.1.1:* Biff
*** Bob
* *FRS2908.1.2:* Zoe"""

assert_parse_text(lines, exp)

lines = """*FRS2908.0*
# Bob1
## Bob2
*** Fred1
*** Fred2
## Bob3
## Bob4
## Bob5
*** Fred3
#### Bob6
#### Bob7
#### Bob8
*** Fred4
# Bob9
"""

exp = """*FRS2908.0*
* *FRS2908.0.1:* Bob1
** *FRS2908.0.1.1:* Bob2
*** Fred1
*** Fred2
** *FRS2908.0.1.2:* Bob3
** *FRS2908.0.1.3:* Bob4
** *FRS2908.0.1.4:* Bob5
*** Fred3
**** *FRS2908.0.1.4.1.1:* Bob6
**** *FRS2908.0.1.4.1.2:* Bob7
**** *FRS2908.0.1.4.1.3:* Bob8
*** Fred4
* *FRS2908.0.2:* Bob9"""
assert_parse_text(lines, exp)

lines = """*FRS2908.0* 
# Bob
** Fred:
# Bob"""

exp = """*FRS2908.0* 
* *FRS2908.0.1:* Bob
** Fred:
* *FRS2908.0.2:* Bob"""
assert_parse_text(lines, exp)

lines = """*FRS2908.0* 
# Bob
** considered +/- 15 degrees
# Bob"""

exp = """*FRS2908.0* 
* *FRS2908.0.1:* Bob
** considered +/- 15 degrees
* *FRS2908.0.2:* Bob"""
assert_parse_text(lines, exp)

lines = """*FRS123* 
# Bob
*Image 1*: Bob's image
# Bob"""

exp = """*FRS123* 
* *FRS123.1:* Bob
*Image 1*: Bob's image
* *FRS123.2:* Bob"""
assert_parse_text(lines, exp)

lines = """*URS2908.0* 
# Bob
** considered +/- 15 degrees
# Bob"""

exp = """*URS2908.0* 
* *URS2908.0.1:* Bob
** considered +/- 15 degrees
* *URS2908.0.2:* Bob"""
assert_parse_text(lines, exp)

def assert_parse_empty(s, exp):
    st = NumState()
    res = None
    for res in st.parse_text(s):
        pass
    assert_ab(res, exp)
    
assert_parse_empty("*User Requirements*\n# Bar", "# Bar")

def finish():
    print("%d/%d tests passed successfully" % (passed, ntests))
    for e in errors:
        print(e)
    if errors:
        raise Exception("Unit testing suite failed")
finish()
# Out:
# 95/95 tests passed successfully

# %%
toplevel_match = re.compile(r"^([\+\*]+)([^\*\+]+?)\:?([\+\*]+)\:?\s*(.+)?$").match
def assert_ab2(a, b, equal=True):
    if equal:
        assert a == b, "%r != %r" % (a, b)
    else:
        assert a != b, "%r == %r" % (a, b)
    
            
def assert_toplevel_match(s, exp):
    assert_ab(toplevel_match(s).groups(), exp)
assert_ab2(toplevel_match("Test"), None)
assert_ab2(toplevel_match("* *+Test Test+*"), None)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-14-6169ba6cfa75> in <module>()
#      10     assert_ab(toplevel_match(s).groups(), exp)
#      11 assert_ab2(toplevel_match("Test"), None)
# ---> 12 assert_ab2(toplevel_match("* *+Test Test+*"), None)
#
# <ipython-input-14-6169ba6cfa75> in assert_ab2(a, b, equal)
#       2 def assert_ab2(a, b, equal=True):
#       3     if equal:
# ----> 4         assert a == b, "%r != %r" % (a, b)
#       5     else:
#       6         assert a != b, "%r == %r" % (a, b)
#
# AssertionError: <_sre.SRE_Match object; span=(0, 15), match='* *+Test Test+*'> != None

# %%
import clipboard

# %%
template=  r'''lines=r"""%s
"""
res = "\n".join(NumState(7).parse_text(lines))
print(res)
import clipboard
clipboard.copy(res)
'''
s = template % clipboard.paste()
clipboard.copy(s)
exec(s)
# Out:
# *+Background+*
# This request began as a set of features to be used for the IQ/OQ process, and includes some features that would be useful during that process which may also be useful for customers for other purposes.
#
# Ultimately, the desired result is to simplify the process of sharing configurations between multiple bioreactors, particularly on GMP configured machines. On these units, config files must be either transferred by hand (slow and error-prone) or they must be configured by a Windows account admin (requiring IT support). Currently, only a customer's IT personnel are expected to have access to the Windows admin account rather than process administrators. Simplifying this process would reduce error rates and make it easier for customers to ensure configuration uniformity across multiple bioreactors.
#
# For example, a customer may have units A and B with custom configurations for Logger Settings, Alarms, and System Variables. To transfer these settings to unit C, they have to manually transfer the files to the correct locations, reboot the RIO, reboot the Shell UI, and ensure that they didn't do anything in the wrong order that might cause the files to be accidentally overridden. A builtin mechanism to perform this process would greatly simplify it.
#
# This has happened to some customers before (CDI? Semma?), who attempted to transfer config files between units of different sizes, and ended up screwing up their settings badly enough to require hours worth of correspondence with engineers at PBS to resolve the issue.
#
# The config file import/export is a bit trickier to implement than it seems at face value, because several questions arise about how *exactly* to handle the process. What I settled on was exporting should be done using a
#
# This initial set of feature requests is intended to be simple and straightforward. Future improvements can incrementally build on this system to include features such as sanity checks, file bundles, partial files, or others.
#
# Other features to be implemented include using the recorder.exe to save factory defaults and providing a facility to restore config files to factory defaults. Among other things, this is a much easier way of allowing customers to restore defaults in the case of an issue than digging through the database. While the database method fulfills the purpose of providing a permanent record, its much easier to just have the actual file there and ready to use.
#
# Some of the URS/FRS items below are labeled with "(Low)" or "(Med)", indicating they are not strictly necessary for the features to be used by customers, but would be convenient and should be included if it doesn't take a significant amount of time to implement or test.
#
# *+Notes+*
# The URS is pretty straight forward, but the FRS goes a bit all over the place and may need some fixing up. Fundamentally, both import and export are simple directory copies of config files from one set of folders to the other. The complexity comes mostly from doing sanity checks on folder structure, file structure, edge cases, permissions, and customizing behavior. Export from recorder.exe and Desktop UI should be identical, with whatever special name we use for factory set defaults. Users should also be able to import settings straight to the local backup folder.
#
# Folders end in ".pbssettings" mostly for cosmetic reasons. Originally I was going to require it and have both import and export only operate on ".pbssettings" folders, but I backed down. The idea was that we would strictly control the contents of what goes in each settings folder so that users had less of a chance of shooting themselves in the foot. In practice, they should only be importing or exporting anyway without modifying files by hand, so it should be fine either way.
#
# All functionality here should be implemented in a model-view scheme that will make it easy for us to expose the underlying functional logic if we decide to include this functionality in the standalone application as discussed in #3867.
#
# *+URS3881+*
# * *URS3881.1:* During the manufacturing process, in IM00226 and IM00211, recorder.exe should back up all config files to a read-only folder.
# * *URS3881.2:* An Export menu in the Desktop UI should allow users to back up current config files from LabVIEW Data and RIO to a designated folder for export, in the same manner as the above requirement, using an appropriate folder name.
# ** *URS3881.2.1:* The backup folder should be accessible from the file browser tab, so that it can be transferred to a network drive or USB.
# ** *URS3881.2.2:* (Low) Users should be able to select which files to backup and the name of the folder to backup to.
# * *URS3881.3:* There should be a method to import config files from either an external drive or the above backup folder.
# ** *URS3881.3.1:* Appropriate permissions should be checked to ensure that an unauthorized user cannot override files.
# * *URS3881.4:* Users should be able to view a checksum of currently loaded config files.
#
# *+FRS3881+*
# * *FRS3881.1:* A new folder should be present in LabVIEW data named "Backup Config Files" or something similar.
# ** *FRS3881.1.1:* This folder will be visible in the File Browser.
# ** *FRS3881.1.2:* Each folder within the backup folder will correspond to a set of config files generated by the file backup mechanism..
# ** *FRS3881.1.3:* Each folder should be split into "LabVIEW Data" and "RIO" subfolders.
# * *FRS3881.2:* Config files will now be backed up when recorder.exe is run.
# ** *FRS3881.2.1:* The folder name will be "factory defaults YYMMDD". If the folder exists, a space and integer or something else sensible will be added to create a unique filename.
# ** *FRS3881.2.2:* All config files except Global Settings should be backed up.
# * *FRS3881.3:* Permissions:
# ** *FRS3881.3.1:* (Option 1) Two new permissions will be created, "Config Import" and "Config Export".
# *** *FRS3881.3.1.1:* Config import will be required to import settings.
# *** *FRS3881.3.1.2:* Config export will be required to export settings.
# ** *FRS3881.3.2:* (Option 2) The system will use existing permissions to handle import and export:
# *** *FRS3881.3.2.1:* "System Management" for import or export functionality.
# *** *FRS3881.3.2.2:* "System Management" to import bioreactor configuration.txt file.
# *** *FRS3881.3.2.3:* " System Management" to import ReportSettings.cfg file.
# *** *FRS3881.3.2.4:* "Alarms Editor" to import .alm files.
# *** *FRS3881.3.2.5:* "Alarms Editor" to import Email Alerts Settings.xml or Email Password.cfgx files.
# *** *FRS3881.3.2.6:* "Logger Editor" to import .log files.
# *** *FRS3881.3.2.7:* "Settings Editor" to import .sys files.
# *** *FRS3881.3.2.8:* "Recipe Editor" to import Bioreactor Recipes.cfg file.
# *** *FRS3881.3.2.9:* "Advanced Calibration" to import Cal Factors.cfg.
# *** *FRS3881.3.2.10:* Anything else that closes any loopholes I didn't think of.
# * *FRS3881.4:* Two new menus, "Import" and "Export", will accessible from corresponding new buttons in the "Config" dropdown.
# * *FRS3881.5:* The export menu will allow a user to export config files to the "Backup Config Files" folder.
# ** *FRS3881.5.1:* (Med) The user should be able to enter a folder name. The default name should be "export settings YYMMDD".
# ** *FRS3881.5.2:* (Low) The User should be able to select which files to backup.
# ** *FRS3881.5.3:* (Low) The menu should include select all and deselect all buttons.
# ** *FRS3881.5.4:* Information from the bioreactor configuration.txt file should always be included. Either the file itself, or a processed version that is more human-friendly to read while being easy to parse. This file will be used while sanity-checking imported files.
# * *FRS3881.6:* The import menu will allow a user to import config files from a mapped drive or the "Backup Config Files" folder. Any sensible combination of buttons and menus can be used to allow a user to select the location.
# ** *FRS3881.6.1:* There will be two import modes - single file, and batch mode. The buttons for these should have sensible names (TBD).
# ** *FRS3881.6.2:* In single file mode, user will be able to navigate to the folder containing the file and select it.
# *** *FRS3881.6.2.1:* User will be prompted for confirmation along with any warning(s), and the file will be copied to the LabVIEW data folder.
# *** *FRS3881.6.2.2:* The user is responsible for transferring to RIO through the standard config tab mechanisms.
# *** *FRS3881.6.2.3:* If the file is System Variables, transfer to RIO automatically.
# ** *FRS3881.6.3:* In batch import mode, user will select the settings folder instead:
# *** *FRS3881.6.3.1:* Wherever System Variables.sys file is imported, ensure that it ends up in both LVData and RIO.
# *** *FRS3881.6.3.2:* Verify that System Variables.sys from the RIO and LVData folders is identical, and abort if not.
# *** *FRS3881.6.3.3:* The system will compare the bioreactor configuration.txt file to its own on record. If they differ, warn the user with a BIG WARNING, and a continue/abort dialog. Require a 3 second countdown before a user can continue.
# *** *FRS3881.6.3.4:* If bioreactor configuration.txt is not found, issue a warning in the same manner as above.
# *** *FRS3881.6.3.5:* If either the RIO or the LabVIEW data folders aren't present, treat them as empty folders instead of issuing an error.
# *** *FRS3881.6.3.6:* If any file present in the RIO folder isn't present in the bioreactor's RIO folder, issue a warning and abort.
# *** *FRS3881.6.3.7:* Ask the user whether they want to make the files active, or import to a backup location. If they select backup, prompt for a filename, with default being the name of the import folder. Copy all of the files there as if using the export function.
# *** *FRS3881.6.3.8:* Once all the files are ready for import, prepare a list of all conflicting file names and location (RIO or LVData) and show it to the user. Prompt them to confirm import & file overwrite.
# *** *FRS3881.6.3.9:* (Med) Allow user to deselect individual files for import.
# *** *FRS3881.6.3.10:* Transfer the files to the correct locations, overwriting whatever is already there.
# *** *FRS3881.6.3.11:* Reload all config files into memory on the RIO and Desktop UI.
# * *FRS3881.7:* A new menu item "Info" in the config dropdown will open an "Info" menu.
# ** *FRS3881.7.1:* Each config file will be listed along with its md5 checksum.
# ** *FRS3881.7.2:* (very very low) User can select a file and press a "compare" button to obtain a smart comparison report.
# *** *FRS3881.7.2.1:* The button will allow user to select another file from local file system, backup config files, or external drive.
# *** *FRS3881.7.2.2:* The compare button will then run filecompare.exe and spit out a report or whatever to display to the user. If an error occurs, it will show a useful error instead.

# %%
lines=r"""*+Background+*
This request began as a set of features to be used for the IQ/OQ process, and includes some features that would be useful during that process which may also be useful for customers for other purposes. Ultimately, the desired result is to simplify the process of sharing configurations between multiple bioreactors, particularly on GMP configured machines. On these units, config files must be either transferred by hand, which is slow and error-prone, or they must be configured by a Windows account admin. Currently, only a customer's IT personnel are expected to have access to the Windows admin account. Simplifying this process would reduce error rates and make it easier for customers to ensure configuration uniformity across multiple bioreactors. 

For example, a customer may have units A and B with custom configurations for Logger Settings, Alarms, and System Variables. To transfer these settings to unit C, they have to manually transfer the files to the correct locations, reboot the RIO, reboot the Shell UI, and ensure that they didn't do anything in the wrong order that might cause the files to be accidentally overridden. A builtin mechanism to perform this process would greatly simplify it. 

This has happened to some customers before (CDI? Semma?), who attempted to transfer config files between units of different sizes, and ended up screwing up their settings badly enough to require hours worth of correspondence with engineers at PBS to resolve the issue. 

This initial set of feature requests is intended to be simple and straightforward. Future improvements can incrementally build on this system to include features such as sanity checks, file bundles, partial files, or others. 

Some of the URS/FRS items below are labeled with "(Low)" or "(Med)", indicating they are not strictly necessary for the features to be used by customers, but would be convenient and should be included if it doesn't take a significant amount of time to implement or test. 

Other features to be implemented include using the recorder.exe to save factory defaults, and providing a facility to restore config files to factory defaults. Among other things, this is a much easier way of allowing customers to restore defaults in the case of an issue than digging through the database. While the database method fulfills the purpose of providing a permanent record, its much easier to just have the actual file there and ready to use. 

*+URS+*
# During the manufacturing process, in IM00226 and IM00211, recorder.exe should back up all config files to a read-only folder. 
# There should be a method present in the Desktop UI to back up current config files from LabVIEW Data and RIO to a designated folder. 
## The backup folder should be accessible from the file browser tab, so that it can be transferred to a network drive or USB. 
## (Low) Users should be able to select which files to backup and the name of the folder to backup to. 
# There should be a method to import config files from either USB or a backup folder as created by recorder.exe.  
## Config files should be checked for structure before being imported
## Appropriate permissions should be checked to ensure that an unauthorized user cannot override files. 


*+FRS+*
# A new menu will be added, accessible from a new button present in the "System" dropdown menu. 
## (Med) The user should be able to enter a folder 
## (Low) The User should be able to select which files to backup. 
## (Low) The menu should include select all and deselect all buttons. 
"""
res = "\n".join(NumState(7).parse_text(lines))
print(res)
import clipboard
clipboard.copy(res)
# Out:
# *+Background+*
# This request began as a set of features to be used for the IQ/OQ process, and includes some features that would be useful during that process which may also be useful for customers for other purposes. Ultimately, the desired result is to simplify the process of sharing configurations between multiple bioreactors, particularly on GMP configured machines. On these units, config files must be either transferred by hand, which is slow and error-prone, or they must be configured by a Windows account admin. Currently, only a customer's IT personnel are expected to have access to the Windows admin account. Simplifying this process would reduce error rates and make it easier for customers to ensure configuration uniformity across multiple bioreactors.
#
# For example, a customer may have units A and B with custom configurations for Logger Settings, Alarms, and System Variables. To transfer these settings to unit C, they have to manually transfer the files to the correct locations, reboot the RIO, reboot the Shell UI, and ensure that they didn't do anything in the wrong order that might cause the files to be accidentally overridden. A builtin mechanism to perform this process would greatly simplify it.
#
# This has happened to some customers before (CDI? Semma?), who attempted to transfer config files between units of different sizes, and ended up screwing up their settings badly enough to require hours worth of correspondence with engineers at PBS to resolve the issue.
#
# This initial set of feature requests is intended to be simple and straightforward. Future improvements can incrementally build on this system to include features such as sanity checks, file bundles, partial files, or others.
#
# Some of the URS/FRS items below are labeled with "(Low)" or "(Med)", indicating they are not strictly necessary for the features to be used by customers, but would be convenient and should be included if it doesn't take a significant amount of time to implement or test.
#
# Other features to be implemented include using the recorder.exe to save factory defaults, and providing a facility to restore config files to factory defaults. Among other things, this is a much easier way of allowing customers to restore defaults in the case of an issue than digging through the database. While the database method fulfills the purpose of providing a permanent record, its much easier to just have the actual file there and ready to use.
#
# *+URS+*
# * *URS.1:* During the manufacturing process, in IM00226 and IM00211, recorder.exe should back up all config files to a read-only folder.
# * *URS.2:* There should be a method present in the Desktop UI to back up current config files from LabVIEW Data and RIO to a designated folder.
# ** *URS.2.1:* The backup folder should be accessible from the file browser tab, so that it can be transferred to a network drive or USB.
# ** *URS.2.2:* (Low) Users should be able to select which files to backup and the name of the folder to backup to.
# * *URS.3:* There should be a method to import config files from either USB or a backup folder as created by recorder.exe.
# ** *URS.3.1:* Config files should be checked for structure before being imported
# ** *URS.3.2:* Appropriate permissions should be checked to ensure that an unauthorized user cannot override files.
#
#
# *+FRS+*
# * *FRS.1:* A new menu will be added, accessible from a new button present in the "System" dropdown menu.
# ** *FRS.1.1:* (Med) The user should be able to enter a folder
# ** *FRS.1.2:* (Low) The User should be able to select which files to backup.
# ** *FRS.1.3:* (Low) The menu should include select all and deselect all buttons.
