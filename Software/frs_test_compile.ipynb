# %%
from scripts.software_frs import frs_traceability2
from officelib.xllib import *
from officelib.const import xlconst as xlc
import sys
import os

# %%
# caching scheme for test purposes. 
try:
    _cache
except NameError:
    _cache = None

try:
    _lffi
except NameError:
    _lffi = frs_traceability2.load_frs_from_issuetracker
    
def load_frs_from_issuetracker():
    global _cache
    if _cache is None:
        frs = _lffi()
        _cache = frs
    else:
        frs = _cache
    return frs

frs_traceability2.load_frs_from_issuetracker = load_frs_from_issuetracker

# %%
def ws_data(ws):
    cr = ws.Cells.Range
    first = cr("A2")
    last_col = cr("A1").End(xlc.xlToRight).Column
    last = first.End(xlc.xlDown).Offset(1, last_col)
    return cr(first, last).Value

def split_frs(frs):
    return [f for f in frs.split() if f]

def load_test_list(user_tests):
    xl = Excel(visible=False)
    with HiddenXl(xl):
        wb = xl.Workbooks.Open(user_tests)
        ws = wb.Worksheets(1)
        id_test, name, purpose, start, steps, accept, frs = \
                        frs_traceability2.find_cols(ws, 
                            "ID_TEST", "NAME", "PURPOSE", "STARTING POINT", 
                                "STEPS", "ACCEPTANCE_CRITERIA", "List Web FRS")
        data = ws_data(ws)
    
    wb.Close(False)
    xl.Quit()
    
    res = []
    for row in data:
        i = row[id_test]
        n = row[name]
        p = row[purpose]
        sta = row[start]
        ste = row[steps]
        a = row[accept]
        f = row[frs]
        if not f: continue
        res.append((i, n, p, sta, ste, a, split_frs(f)))
    res.sort(key=lambda t: t[0])
    return res

# %%
def node_data(node):
    return node.id, node.text.strip()

def make_frs_line(items):
    lines = []
    items2 = sorted(items, key=frs_traceability2.sort_frs_item)
    for id, line in items2:
        if not line:
            lines.append("%s" % id)
        else:
            lines.append("%s: %s" % (id, line.rstrip()))
    return "\n".join(lines)

def ifmt(i):
    if int(i) == i:
        return "%d" % i
    return "%s" % i

def write_test(reqs, test, file):
    tmplt = _frs_tmplt
    i, name, p, sta, ste, a, frs = test
    items = set()
    for f in frs:
        node = reqs.lookup(f)
        if not node: raise ValueError(f)
        if node.is_na(): continue
        items.add((node.id, node.text))
        indent = node.id.count(".")
        for n in node.iter():
            nindent = n.id.count(".") - indent
            items.add((" " * nindent + n.id, n.text))
    frs_line = make_frs_line(items)
    s = tmplt % (ifmt(i), name, frs_line, p.rstrip(), sta.rstrip(), ste.rstrip(), a.rstrip())
    print(s, file=file)

# %%
_c = "cache.pkl"
import os, pickle
def download_relevant_issues():
    global _c
    if os.path.exists(_c):
        return pickle.load(open(_c, 'rb'))
    else:
        d = _dl()
        pickle.dump(d, open(_c, 'wb'))
        return d
try:
    _dl
except NameError:
    _dl = frs_traceability2.download_relevant_issues
    frs_traceability2.download_relevant_issues = download_relevant_issues

# %%
try:
    _reqs
except NameError:
    _reqs = None

def main(user_tests, unit_tests, code_reviews, fp=None):
    global _reqs
    reqs = _reqs or frs_traceability2.full_frs_tree(user_tests, unit_tests, code_reviews)
    _reqs = reqs
    test_list = load_test_list(user_tests)
    if fp is None:
        f = sys.stdout
        close = False
    else:
        f = open(fp, 'w')
        close = True
    try:
        for test in test_list: write_test(reqs, test, f)
    finally:
        if close:
            f.close()

# %%
trace_path = "C:\\Users\\Nathan\\Documents\\PBS\\SW test\\3.0 User Test\\Traceability"
user_tests = "Hello tests 161122 1.xlsx"
unit_tests = "Traceability Matrix (Reqs and VI) 161123.csv"
code_review_path = '\\\\PBSSTATION\\PBSCloudShare\\(2) R&D-Product Engineering\\Software Development\\3.0 Project\\Phase 2 Working Copy\\IS00038B5 Rev A Code Reviews\\'
p1 = os.path.join(trace_path, user_tests)
p2 = os.path.join(trace_path, unit_tests)
p3 = code_review_path

# %%
_frs_tmplt = \
"""
=============================================
Id: %s
Name: %s
=============================================
FRS:
# %s

Purpose: %s

Starting Point:
# %s

Steps:
# %s

Acceptance Criteria:
# %s
"""

# %%
from datetime import date
def dateify(f):
    a, b = f.split(".")
    t = date.today()
    a += "_" + t.strftime("%y%m%d")
    return ".".join((a,b))

# %%
_reqs = None
#os.remove(_relcache)
f = "frs.txt"
f = dateify(f)
#main(p1, p2, p3, f)
#os.startfile(f)

# %%
main(p1, p2, p3)
# Out:
# Downloading FRS items from issuetracker...
# Loading User Test Matrix...
# Loading Unit Test Matrix...
# Loading Code Review Matrix...
#
# =============================================
# Id: 13
# Name: Automatic Logout
# =============================================
# FRS:
# 3.0WebFRS121
# FRS2445
#  FRS2445.1: When a user logs out, a log out event shall be generated indicating who logged out.
#  FRS2445.2: "Unknown user" logout events shall never occur due to periodic programmatic logouts.
#
# Purpose: Confirm that the software logs the user out after 10 minutes of inactivity, and that any screen that was opened is replaced by a view of Screen A: Dashboard/DORA Bar and Screen 5: Graph tab
#
# Starting Point:
# Screen A: Dashboard/DORA Bar; user is logged in
#
# Steps:
# 1) Navigate to a screen other than Screen A: Dashboard/DORA Bar and Screen 5: Graph tab
# 2) Wait 10 minutes.
# 3) Click anywhere on the screen.
# 4) Wait an additional 15 minutes.
# 4) Log in and generate a user events report for the last 24 hours.
#
# Acceptance Criteria:
# 2) The Hello UI refreshes.  Screen A: Dashboard/DORA Bar and Screen 5: Graph tab appear.
# 3) When the user clicks anywhere, they are directed to the Login Screen
# 4) For each "Logout" event in the user events report, the user name field shows the actual username, and never shows "unknown user".
#
#
# =============================================
# Id: 19
# Name: Graph tab navigation
# =============================================
# FRS:
# 3.0WebFRS088
#
# Purpose: Confirm that clicking "Graph" results in Screen 5: Graph tab being displayed
#
# Starting Point:
# Screen A: Dashboard/DORA Bar and Screen 8: Settings tab
#
# Steps:
# 1) Click "Graph"
#
# Acceptance Criteria:
# Screen 5: Graph tab appears
# Six buttons are present, labeled "15m", '2h", "12h", "24h", "72h", and "7d".
# One of the buttons is highlighted in blue.
#
#
# =============================================
# Id: 31
# Name: Level Sensor Off switch
# =============================================
# FRS:
# 3.0WebFRS053
# 3.0WebFRS087
# 3.0WebFRS102
#
# Purpose: Confirm that setting Level "Enable Sensor (0 or 1)" setting to '0' results in Level box disappearing and Filter Oven Temp and Pressure (not on 3L) boxes expanding to fill the "void" in the Dashboard.  The Advanced View menu still shows the Level box with no change.
#
# Starting Point:
# Tester is logged in as a user with "Hello Settings" permission
# Screen 7 Settings Tab - Level "Enable Sensor (0 or 1)" setting set to 1
#
# Steps:
# 1) Change the Level "Enable Sensor (0 or 1)" setting to '0'
# 2) Refresh the HELLO page
#
# Acceptance Criteria:
# In the Dashboard, the Level box disappears.  Filter Oven box, Pressure box (not on 3L) and Main Gas button (not on Air drive) are in the same place.  The Advanced View menu still shows the Level box (it's OK for Level box to indicate a process alarm w/ red or yellow due to PV of 0 L)
#
#
# =============================================
# Id: 32
# Name: Level Sensor Enabled
# =============================================
# FRS:
# 3.0WebFRS053
# 3.0WebFRS087
#
# Purpose: Confirm that when Level "Enable Sensor (0 or 1)" setting is '1', Level box is displayed along with Filter Oven Temp and Pressure (not on 3L) Dashboard boxes
#
# Starting Point:
# Screen 7 Settings Tab - previous test was just performed
#
# Steps:
# 1) Change the Level "Enable Sensor (0 or 1)" setting to '1'
# 2) Refresh the HELLO web page
#
# Acceptance Criteria:
# Level box reappears, and Filter Oven box, Pressure box (not on 3L) and Main Gas button (not on Air drive) are in the same locations
#
#
# =============================================
# Id: 317
# Name: Shutdown warning - "Shutdown"
# =============================================
# FRS:
# 3.0WebFRS117
#
# Purpose: Confirm that clicking "Shutdown" from Shutdown Warning results in Action tab's "Shutdown" button turning red, saying "Cancel Shutdown", showing countdown, blue messages periodically announcing countdown, and Windows computer shutting down after 30 seconds
#
# Starting Point:
# Tester is logged in as a user with "System Management" permission
# Screen 6: Actions tab
# Chrome developer tools is open.
#
# Steps:
# 1) Click "Shut Down" (goes to Shutdown Warning)
# 2) Click "Shutdown"
#
# Acceptance Criteria:
# A shutdown server call is sent, with no parameters except for "call=shutdown".
#
# Action tab's "Shutdown" button turns red, says "Cancel Shutdown" and displays countdown.  Blue messages periodically announce countdown, and Windows computer shuts down after 30 seconds. Turn the bioreactor back on by unplugging and plugging back in
#
#
# =============================================
# Id: 1003
# Name: Control Pumps - Base pull-down
# =============================================
# FRS:
# 3.0WebFRS115
#
# Purpose: Confirm that changing selected Base Pump drop-down option functions correctly
#
# Starting Point:
# Tester is logged in as a user with "Controls" permission
# Screen 6.4: Control Pumps Menu - Base Pump pull-down menu has "None" selected, and all pumps are off
# pH is in Manual mode with Base % called for at least 5, but less than 100 by enough for the user to tell that the PWM is limiting the pump's output.
# Pressure PV is below Safety Max Pressure, and Level sensor is either disabled, or Level PV is below Safety Max Level.
# "Base On Time (s)", "Base Max Period (s)" and "Analog Base Speed (RPM)" are appropriate values for the model.
#
# Steps:
# After each step, note the following:
# 	What the pull-down menu reads
# 	Which Addition slider switch is covered, if any
# 	Which Addition pump is on, if any, and its duty
#
# 1) Change Base Pump from "None" to "Addition A"
# 2) Change to "Addition B"
# 3) Change to "Addition A"
# 4) Change to "None"
# 5) Change to "Addition B"
# 6) Change to "None"
#
# Acceptance Criteria:
# For all steps, Base Pump drop-down disappears, and Base Pump indicator displays what the user selected.
# If an Addition pump is selected, the word "Base" covers only that pump's slider, the other pump's slider is visible, and the pump on the housing pulses with the appropriate duty.
# If no Addition pump is selected, all pump sliders are visible, and no pumps are on.
#
#
# =============================================
# Id: 1026.7
# Name: Select Sensors - get rid of 'DNE' symbol
# =============================================
# FRS:
# FRS1583.9.2: Clicking a "DNE" icon shall be interpreted as making a sensor Active.
#
# Purpose: Confirm that clicking a 'DNE' symbol results in it disappearing
#
# Starting Point:
# There's a pair of sensors where the selected one is white with no DNE, the unselected one is white with a DNE, and the lock is open
#
# Steps:
# 1) Click the 'DNE' symbol
# 2) Click the slider.
# 3) Note displayed PV.
#
# Acceptance Criteria:
# 1) The 'DNE' symbol is no longer displayed
# 2) Slider selects the new sensor.
# 3) System now shows PV for the previously disabled sensor.
#
#
# =============================================
# Id: 1110
# Name: Settings - Versions submenu
# =============================================
# FRS:
# 3.0WebFRS015
# 3.0WebFRS016
# 3.0WebFRS017
# 3.0WebFRS020
# 3.0WebFRS021
# 3.0WebFRS022
#
# Purpose: Confirm the Versions submenu shows the settings it should
#
# Starting Point:
# Screen A: Dashboard/DORA Bar
#
# Steps:
# 1) Click "Settings" (goes to Screen 8: Settings tab)
# 2) Click "Versions"
#
# Acceptance Criteria:
# Versions submenu displays Hello, RIO, Server, Model, Database, Serial Number, and UI
#
#
# =============================================
# Id: 1110.14
# Name: Settings - collapse Versions submenu
# =============================================
# FRS:
# 3.0WebFRS015
# 3.0WebFRS016
# 3.0WebFRS017
#
# Purpose: Confirm that collapsing the Versions submenu results in the scroll bar disappearing
#
# Starting Point:
# Screen 8: Settings tab - Versions submenu is open
#
# Steps:
# 1) Click "Versions"
#
# Acceptance Criteria:
# Versions submenu collapses, and scroll bar disappears
#
#
# =============================================
# Id: 2042
# Name: pH Deadband Verification
# =============================================
# FRS:
# FRS3176:
#  # The CO2 flow rate PID controller shall control to SP + deadband.
#  # The Base flow rate PID controller shall control to SP - deadband
#  # No hard-shutoff shall be used to shut off CO2 flow.
#
# Purpose: Ensure Deadband value is functional.
#
# Starting Point:
# Settings tab.  pH Deadband is 0.
# CO2 Auto and Manual max are 100.
# Base Auto and Manual max are 100.
#
# Steps:
# 1) Set pH to Manual, 25% Base and 25% Co2.
# 2) Set pH to Auto mode, SP = PV - 1, and observe CO2 Duty and base duty.
# 3) Set the Deadband to 1, and observe CO2 Duty and base duty.
# 4) Set pH to manual, 25% Base and 25% CO2.
# 5) Set pH to Auto mode, SP = PV + 1, and observe CO2 Duty and base duty.
#
# Acceptance Criteria:
# 2) CO2 duty begins to increase. Base begins to decrease.
# 3) CO2 duty stops increasing or decreasing. Base continues to decrease, but at a lower rate than before.
# 5) CO2 duty begins to decrease, but does not instantly fall to 0. Base duty does not increase or decrease.
#
#
# =============================================
# Id: 2119
# Name: Show Desktop
# =============================================
# FRS:
# 3.0WebFRS004
# 3.0WebFRS005
#
# Purpose: Confirm user can get out of Full Screen kiosk mode
#
# Starting Point:
# Screen 6: Actions tab.  Google Chrome is in kiosk or fullscreen mode.
#
# Steps:
# 1) Verify a button is present labeled "Show Desktop", not "Toggle Fullscreen" or "Show Shell".
# 2) Click "Show Desktop" button
# 3) Follow any on-screen prompts to show Desktop
# 4) Click the "Hello" button in the Shell.
#
# Acceptance Criteria:
# 1) Button is labeled correctly
# 3) Hello window disappears and the shell is shown.
# 4) Hello window reappears, in Full Screen mode, and continues being displayed.  It shows the Actions tab.
#
#
# =============================================
# Id: 2122
# Name: Settings - Correct submenus and entries
# =============================================
# FRS:
# 3.0WebFRS112
#
# Purpose: Confirm that all groups and settings are displayed in the Settings tab
#
# Starting Point:
# Screen 8: Settings tab
#
# Steps:
# 1) Compare the group names, and order, in the System Variables.sys file with what's displayed in the Web UI's Settings tab.
# 2) Within each group, compare the settings' names and order in the System Variables.sys file with what's displayed in the Web UI's Settings tab.
# 3) Change the reactor from Air to Mag, or from Mag to Air, and repeat steps 1 and 2
#
# Acceptance Criteria:
# All groups, and settings, which are in the System Variables.sys file are displayed correctly in the Settings tab of the Web UI.
# Exceptions:
# The "Versions" group should be in the Web UI, but not the System Variables.sys file.
# Any "EW"-type setting should be in the config file but not the Web UI
#
#
# =============================================
# Id: 2140
# Name: Web UI rendering based on Model
# =============================================
# FRS:
# 3.0WebFRS018
# 3.0WebFRS019
# 3.0WebFRS086
#
# Purpose: Ensure Web UI renders correctly for all Models
#
# Starting Point:
# Server is open.  Model is PBS 3 Air.
# Level sensor is enabled.
#
# Steps:
# 1) Close and reopen Hello
# 2) Note the stated model in the "Versions" section of the Settings tab.
# 3) Note how the following layouts/objects are rendered in the Web UI:
# 	The "Select Sensors" and "Unlock Door" buttons in the "Actions" tab
# 	The "Pressure" box in the Advanced View menu
# 	The "Pressure" box in the dashboard
# 	The sensors in the "Calibrate" menu
# 	The sensors in the "Load Bag" menu
# 	The "Integrity Test" option in the "Load Bag" menu
# 	The sensors in the "Select Sensors" menu
# 	The "Control Pumps" menu - speed selector for media pump, and type of speed able to be selected for additions pumps
# 	The "Level" box in the dashboard.
# 	The "Level" box in the advanced menu.
# 	The "Main Gas" box in the dashboard (or absence of it).
#
# Repeat the test for all model sizes (3L, 15L, 80L, and 500L).
# Change reactor to a Mag Drive and repeat the test.
#
# After finishing, restore the "Bioreactor Model" setting to its correct value, and make the appropriate Web UI version active.
#
# Acceptance Criteria:
# The layouts/objects appear as follows:
#
# The "Pressure" boxes in the Dashboard and Advanced View menu - not rendered for the PBS 3 Air or PBS 3 Mag; rendered for all other models
#
# The "Select Sensors" button in the "Actions" tab - never rendered for PBS 3 Air or PBS 3 Mag; rendered for all other models
#
# The "Unlock Door" button in the "Actions" tab - not rendered for the PBS 3 Air or PBS 3 Mag; rendered for all other models
#
# The sensors in the "Calibrate" menu - no "pH B or DO B" for PBS 3 Air, PBS 3 Mag, PBS 15 Air, and PBS 15 Mag.  No "Pressure" for PBS 3 Air or PBS 3 Mag.  All other models have all sensors
#
# The sensors in the "Load Bag"menu - "pH B" and "DO B" not rendered for the PBS 3 Air, PBS 3 Mag, PBS 15 Air, PBS 15 Mag; rendered for all other models
#
# The "Integrity Test" option isn't there for the PBS 3 Air or PBS 3 Mag; exists for all other models
#
# The sensors in the "Select Sensors" menu - no menu for PBS 3 Air or PBS 3 Mag; PBS 15 Air and PBS 15 Mag just have Temperature; PBS 80 Air, PBS 500 Air, PBS 80 Mag and PBS 500 Mag have Temperature pH and DO
#
# The "Control Pumps" menu - speed selector for media pump, and type of speed able to be selected for additions pumps
# 	No Media speed selector for PBS 3 Air or PBS 3 Mag - RPM selector for all other models
# 	Additions speed is RPM for PBS 500 Air and PBS 500 Mag, and is words ("slow" "medium" and "fast" for all other models
#
# The "Level" boxes on the Dashboard and Advanced Menu:
#          2 decimals on 3L size
#          1 decimal on 15L and 80L sizes
#          0 decimals on 500L size
#          Boxes are large enough to fit PV for all sizes.
#
# Main Gas button never appears for Air Drive configuration, and always for Mag Drive.
#
#
# =============================================
# Id: 2223
# Name: Advanced View Menu - confirm Controller Output column
# =============================================
# FRS:
# 3.0WebFRS068
# 3.0WebFRS069
# 3.0WebFRS070
# 3.0WebFRS071
# 3.0WebFRS072
# 3.0WebFRS073
# 3.0WebFRS074
# 3.0WebFRS075
# 3.0WebFRS076
# 3.0WebFRS077
# 3.0WebFRS080
# 3.0WebFRS081
# 3.0WebFRS082
# 3.0WebFRS083
# 3.0WebFRS084
#
# Purpose: Confirm the Controller Outputs displayed in the Advanced View menu are correct, for both versions of the Web UI (and for both Air and Mag models)
#
# Starting Point:
# Bioreactor is configured as an Air model.
# All controllers are in Auto mode.  All MFCs have source pressure.  No sensors are "Broken", no controllers are interlocked, and the following settings have correct values for the bioreactor:
# 	All P, I and D values
# 	All Auto Max and Auto Min values
# 	All Valid High and Valid Low values
# 	All Agitation settings
# 	pH and DO deadbands
#
# Steps:
# 1) Compare the controller outputs displayed in the Advanced View menu with what the Shell UI displays, or generate a data report or use the DB Client to know what the outputs are.
# 2) Change either the set point or the PV (see note above) or (for Filter Oven, at least, the Max Output) so the Controller Output for EACH controller changes (i.e. both N2 and O2 output should change from the new DO set point), and compare what the Web UI shows with what the Service UI (or other method as in step 1) shows.
# 3) Set Main Gas, DO and pH to Manual mode, with set points such that Air, N2, CO2 and O2 flows are all nonzero and different from each other (confirm with the Shell UI's Gases tab).  Confirm that the Web UI shows the correct gas Controller Outputs in the correct places (i.e. it's not showing O2 flow where CO2 flow should be).
# 4) Disconnect the source gas, and compare what the Web UI shows with what the Shell UI shows.
#
# Acceptance Criteria:
# For all steps:
# For Air Drive, Agitation Controller Output Total = AgMainGasFeedback(LPM), or what its Shell UI tab shows
# For Mag Drive, Main Gas Controller Output Total = MainGasFeedback(LPM), or what its Shell UI tab shows
# Air CO = Air voltage in Gases tab times the Air LPM/V.  Thus, can be nonzero after step 4.  Displayed in Agitation CO column for Air drive, in Gas Flow Row for Mag drive.
# N2 CO = N2 voltage in Gases tab times the N2 LPM/V.  Thus, can be nonzero after step 4.  Displayed in Agitation CO column for Air drive, in Gas Flow Row for Mag drive.
# CO2 CO = CO2 voltage in Gases tab times the CO2 LPM/V.  Thus, can be nonzero after step 4.  Displayed in Agitation CO column for Air drive, in Gas Flow Row for Mag drive.
# O2 CO = O2 voltage in Gases tab times the O2 LPM/V.  Thus, can be nonzero after step 4.  Displayed in DO CO column for Air drive, in Gas Flow Row for Mag drive.
#
# For Mag Drive, Agitation CO = SUI Agitation tab "Output"
# Temperature CO = SUI Temp tab "Heat Duty"
# DO N2 CO = SUI DO tab N2 %
# For Mag drive, DO O2 CO = SUI DO tab O2 (mLPM).  For Air drive, it's the MFC flow feedback (as specified above).
# pH Base and CO2 CO = SUI pH tab "Liq Duty" and "CO2 Duty"
# Filter Oven CO = SUI Filter Oven tab "Actual Duty"
#
# ** If the test fails, state what the Shell UI/reports displayed vs what the Web UI displayed.
#
#
# =============================================
# Id: 2226
# Name: Actions tab to Advanced View menu
# =============================================
# FRS:
# 3.0WebFRS090
#
# Purpose: Confirm that clicking "Advanced" results in the Advanced View menu being displayed
#
# Starting Point:
# Screen 6: Actions tab
#
# Steps:
# 1) Click "Advanced"
#
# Acceptance Criteria:
# Advanced View menu appears.  Rows are (in this order): Agitation, Temperature, Dissolved Oxygen, pH, Main Gas, Filter Oven, Level, and Pressure (unless on a PBS 3 - then there shouldn't be Pressure)
# Columns are (in this order): Mode, PV, Set Point, Controller Output, ALERT.  The PV entries show the same number of decimals (and the same number) as in the Dashboard.  Filter Oven PV has 1 decimal place.
# The entry is 'N/A' in the following places:
#  - Main Gas PV
#  - Level and Pressure Mode
#  - Level and Pressure Set Point
#  - Level and Pressure Controller Output
#
#
# =============================================
# Id: 2241
# Name: Integrity Test - clicking red "Stop Test" button during "Charge Time"
# =============================================
# FRS:
# 3.0WebFRS107
#
# Purpose: Confirm clicking the red "Stop Test" button during "Charge Time" has the desired effect.
#
# Starting Point:
# Tester is logged in as a user with "Recipe Start" and "Recipe End" permissions
# Integrity Test layout - red "Stop Test" button is displayed, and test is in "Charge Time".  Main Gas is in Manual mode for Mag drive, and Agitation is in Auto mode for Air drive.
#
# Steps:
# 1) Click the red "Stop Test" button
# 2) Change the test from Air to Mag, or from Mag to Air (including changing the Bioreactor Recipe.cfg file) and repeat the test
#
# Acceptance Criteria:
# The graph stops updating, the DORA bar shows that there is no recipe/sequence running, and the "Start Test" button is green IFF the Pressure sensor is connected, and the Pressure PV is between -0.05 psi and 0.05 psi.  Otherwise, the "Start Test" button is gray.
# For Mag drive Main Gas is in Off mode and for Air drive Agitation is in Off mode
#
#
# =============================================
# Id: 2248
# Name: Integrity Test - automatically cancel
# =============================================
# FRS:
# 3.0WebFRS107
#
# Purpose: Confirm the test is automatically canceled when appropriate
#
# Starting Point:
# Tester is logged in as a user with "Recipe Start" permission
# Bioreactor is configured correctly to run the test.
#
# Steps:
# 1) Start the test
# 2) When the test gets to "Settle" time, turn Agitation on.  Note the results.
# 3) Start the test again.  When the test gets to "Settle" time, turn DO on so O2 flows.  Note the results.
# 4) Start the test again.  When the test gets to "Settle" time, turn Main Gas on.  Note the results.
# 5) Start the test again.  When the test gets to "Test" time, turn Agitation on.  Note the results.
# 6) Start the test again.  When the test gets to "Test" time, turn DO on so O2 flows.  Note the results.
# 7) Configure the reactor as a Mag drive.  Start the test again.  When the test gets to "Test" time, turn Main Gas on.  Note the results.
#
# Acceptance Criteria:
# The test is automatically canceled for all 6 conditions, and Agitation, Main Gas and DO are all off.
#
#
# =============================================
# Id: 2258
# Name: Recipe Looping
# =============================================
# FRS:
# FRS2404:
#  A recipe shall be looped if and only if it has "-LoopRecipe" at the end of its name
#
# Purpose: Confirm recipes loop as they are supposed to
#
# Starting Point:
# Hello Interface.  Bioreactor has a looping recipe with "-LoopRecipe" at the end of its name, configured as follows:
# 	Turn something on (like the light or a pump)
# 	Wait some amount of time
# 	Turn the thing off
# 	Wait some amount of time
# And no interlock is preventing "the thing" from turning on.
# Bioreactor also has a non-looping recipe with no hyphen in the name, a recipe with a hyphen in the name, and a recipe with no hyphen that ends with "LoopRecipe".
# For all recipes to be run in the test, they are configured so it will be obvious whether they are running
#
# Steps:
# 1) Start the looping recipe in the Web UI
# 2) Observe the Recipe menu, and the thing that's supposed to be turning on and off, for at least 3 cycles of the recipe.
# 3) Stop the recipe during the Wait period after the thing turns on.
#
# 4) Run the recipe without a hyphen in its name to completion.
# 5) Run the recipe from step 4, but stop it in the middle.
#
# 6) Run the recipe with a hyphen in its name.
#
# 7) Run the recipe which ends with "LoopRecipe" but doesn't contain a hyphen.
#
# Acceptance Criteria:
# 1, 2 and 3: The looping recipe successfully loops, and that is indicated in the Web UI (it's ok if the current step isn't highlighted yellow, as long as the current step is indicated).
# Stopping the looping recipe works properly, and "the thing" stays on after the recipe has stopped.
# 4: The recipe runs to completion normally, then stops
# 5: Stopping the recipe in the middle works correctly
# 6: The recipe with a hyphen in its name behaves like a non-looping recipe
# 7: Recipe does not loop.
#
#
# =============================================
# Id: 2363
# Name: PV decimals and units
# =============================================
# FRS:
# 3.0WebFRS023
# 3.0WebFRS026
# 3.0WebFRS028
# 3.0WebFRS031
# 3.0WebFRS033
# 3.0WebFRS038
# 3.0WebFRS041
# 3.0WebFRS046
# 3.0WebFRS049
# 3.0WebFRS050
# 3.0WebFRS051
# 3.0WebFRS052
# 3.0WebFRS054
# 3.0WebFRS057
# 3.0WebFRS059
# 3.0WebFRS062
#
# Purpose: Confirm PVs are displayed with the correct number of decimals and units
#
# Starting Point:
# Bioreactor is configured as a 3 Air
# Dashboard - all sensors are recognized by software as being connected
# All PVs displayed in the Dashboard (Pressure, if visible, shows numbers, and Filter Oven and Level also show numbers)
#
# Steps:
# 1) Observe units and number of decimals shown for each parameter's PV
# 2) Navigate to "Advanced View" in Actions Tab.
# 3) Repeat step 1, observing "PV" column.
# 4) Repeat the test, changing the model configuration, until all models have been tested
#
# Acceptance Criteria:
# For all models:
# 	Agitation: 0 decimals, RPM
# 	Temperature: 1, °C
# 	Dissolved Oxygen: 1, %
# 	pH: 2, no units
#
# For all Mag Drive models:
# 	Main Gas: 2, L/min
#
# For non-3L models:
# 	Pressure: 1, psi
#
# Level:
# 	Air 3 and Mag 3: 2, L
# 	Air 15, Mag 15, Air 80, Mag 80: 1, L
# 	Air 500, Mag 500: 0, L
#
#
# =============================================
# Id: 2382
# Name: Dirty Startup
# =============================================
# FRS:
# FRS2891.2.4.1: "Dirty Startup" for dirty startup
#
# Purpose: Confirm the "Dirty Startup" alarm functions properly
#
# Starting Point:
# RIO is on
# "Dirty Startup" alarm isn't ignored, and is the only "Audible" one
# "Dirty Startup" alarm isn't currently triggered
#
# Steps:
# 1) Remove power from the RIO
# 2) Wait 5 minutes or more
# 3) Plug the RIO back in
# 4) Check the About tab of the Shell UI.
# 5) Check the alarms report or Web UI's Alarms tab.
#
# Acceptance Criteria:
# 3) A "Dirty Startup" alarm was triggered - the buzzer sounded as the RIO booted up
# 4) Item 5 shows "Dirty" or "Dirty Startup".
# 5) The alarm showed up in the database (either in an Alarms report, or in the Web UI's Alarms tab)
#
#
# =============================================
# Id: 2383
# Name: Clean Startup
# =============================================
# FRS:
# FRS2891.2.4.2: "Clean Startup" for clean startup
#
# Purpose: Confirm the "Clean Startup" alarm functions properly
#
# Starting Point:
# RIO is on
# "Clean Startup" alarm isn't ignored, and is the only alarm configured to be audible
# "Clean Startup" alarm isn't currently triggered
# Service UI is open
#
# Steps:
# 1) Click the Reboot RIO button in the Shell UI.
# 2) Wait 90 seconds
# 3) Confirm the load bar doesn't say "Attempting Force Reboot" (if it does, wait for reboot to finish, then repeat from step 1.  If it does a Force Reboot 3 times in a row, fail the test)
# 4) Wait for reboot to finish
# 5) Examine Shell UI's about tab.
# 6) Check the Web UI's alarms tab or generate an alarms report.
#
# Acceptance Criteria:
# 4) A "Clean Startup" alarm was triggered - the buzzer sounded as the RIO booted up.
# 5) Item 5 shows "Clean Startup".
# 6) The alarm showed up in the database (either in an Alarms report, or in the Web UI's Alarms tab)
#
#
# =============================================
# Id: 2384
# Name: Resume
# =============================================
# FRS:
# FRS2891.2.4.3: "Resume" for resume
#
# Purpose: Confirm the "Resume" alarm functions properly
#
# Starting Point:
# RIO is on
# "Resume" alarm isn't ignored, and is the only Audible alarm
# "Resume" alarm isn't currently triggered
#
# Steps:
# 1) Remove power from the RIO
# 2) Wait less than 5 minutes
# 3) Plug the RIO back in
# 4) Check the Shell UI's about tab.
# 5) Check the Web UI's alarms tab, or generate an alarms report.
#
# Acceptance Criteria:
# 3) A "Resume" alarm was triggered - the buzzer sounded as the RIO booted up
# 4) Item 5 shows "Resume".
# 5) The alarm showed up in the database (either in an Alarms report, or in the Web UI's Alarms tab)
#
#
# =============================================
# Id: 2409
# Name: Pressure Disconnected - Low/High Alarm
# =============================================
# FRS:
# 3.0WebFRS114
#
# Purpose: Test that disconnecting and reconnecting the pressure sensor causes the yellow (low/high) alarm to not show up in advanced menu.
#
# Starting Point:
# Reactor is configured as an Air drive
# Pressure is recognized as connected
# Pressure "Reusable Sensor (0 or 1)" setting is 0
#
# Steps:
# 1) Set Process Alarms Pressure Low or Pressure High so that pressure triggers a low or high alarm.
# 2) Note color of Pressure box in Dashboard and Pressure PV in Advanced menu.
# 3) Set pressure disconnected voltage to -5. Repeat step 2.
# 4) Set pressure so it's recognized as connected again. Repeat step 2.
# 5) Set pressure disconnected voltage to -5.  Repeat step 2.
# 6) Restore Process Alarms and disconnected voltage so that no alarm is triggered.  Repeat step 2.
#
# Acceptance Criteria:
# box/PV Text is yellow after steps 2, and 4, red after steps 3 and 5, and black after step 6
#
#
# =============================================
# Id: 2423
# Name: Disconnect RIO -  Network Fetch on Atom
# =============================================
# FRS:
# FRS2780:
#  When the Web UI is open and the network cable is disconnected, the web server should return blank data to the Web UI, so it doesn't force a reload.  All displayed data values will be 0.
#
# Purpose: Confirm that control is un-interupted during and after disconnecting/reconnecting the RIO, and that after the RIO is reconnected data such as PVs are correctly sent to the Atom
#
# Starting Point:
# Screen A: Dashboard/DORA Bar
#
# Steps:
# 1) Set Agitation to 25 RPM
# 2) Set Temperature to 35 C
# 3) Set D.O. to 20% N2 flow
# 4) Disconnect the Ethernet cable connecting the Atom and RIO
# 5) Re-connect the cable.  Note the results.
# 6) Change a PV that is visible in Hello by changing the actual input to the RIO board (disconnect a sensor, attach a pH or DO Simulator, heat up the temperature sensors, etc) and confirm the change shows up in Hello.
#
# Acceptance Criteria:
# 4) and 5) Control is un-interrupted during and after disconnect/reconnect - modes and setpoints are maintained.  While disconnected, HELLO displays 0 for everything, including the DORA bar.  HELLO displays correct information after re-connecting cable.  HELLO doesn't try to re-load during disconnect, and there are no blue banner warnings.
# 6) The change to the PV is reflected in Hello
#
#
# =============================================
# Id: 2543
# Name: Advanced View menu - Filter Oven set point
# =============================================
# FRS:
# 3.0WebFRS078
# 3.0WebFRS079
#
# Purpose: Confirm Filter Oven set point is returned by the get main values call, and that it's shown in the correct place in the Advanced menu
#
# Starting Point:
# Hello is open
# Filter Oven is in Auto mode
#
# Steps:
# 1) Observe Filter Oven set point in the Advanced menu
# 2) Change the Filter Oven auto set point (either in the Shell UI, or via recipe), and check if the change was reflected in the Advanced menu
#
# 3) Change Filter Oven to Manual mode
# 4) Observe Filter Oven set point in the Advanced menu
# 5) Change the Filter Oven manual set point (either in the Shell UI, or via recipe), and check if the change was reflected in the Advanced menu
#
# Acceptance Criteria:
# The Advanced menu shows correct Auto and Manual set points
#
#
# =============================================
# Id: 2651
# Name: RIO power up and alarms
# =============================================
# FRS:
# FRS2522:
#  There should be no alarms on reboot or RIO power cycle and then no alarms afterward. If it is reading an erroneous value, it should be discarded.
#
# Purpose: Confirm weird alarms aren't triggered when RIO powers up
#
# Starting Point:
# Bioreactor is not configured to be a 3L
# No alarms are ignored
# No alarms are currently being triggered (if they were triggered, acknowledge them and make sure the Snooze Time has passed since)
# Level sensor is not ignored
# Agitation, DO and Main Gas (if applicable) are in Off mode
# Main Temp, Filter Ove, temp, DO, pH, level, pressure and MFC slopes and intercepts are within normal ranges
# Also, all Valid Range settings are normal (valid high/low for Temp is 110/-5, for example), associated PVs are well within them (no risk of signal noise pushing them out of valid range), and Process Alarm Limits are also configured to be within those valid ranges
#
# Steps:
# 1) Unplug the power cord from the socket
# 2) Wait 15 seconds
# 3) Plug power cord back in
# 4) Note which alarms were triggered
#
# Perform steps 1-4 a total of 5 times
#
# Acceptance Criteria:
# For each time, the only alarm triggered was the Startup alarm
#
#
# =============================================
# Id: 2732
# Name: DO O2 Output Display - Mag
# =============================================
# FRS:
# 3.0WebFRS033
# 3.0WebFRS034
# 3.0WebFRS035
# 3.0WebFRS036
# 3.0WebFRS037
# 3.0WebFRS038
# 3.0WebFRS039
# 3.0WebFRS040
#
# Purpose: Confirm the O2 display used in the Web UI is correct for a Mag Drive bioreactor
#
# Starting Point:
# Web UI is running
# Reactor is configured to be a mag drive.
#
# Steps:
# Put DO in Manual mode and check the O2 indicators for output and PV in the following places:
# DO button in Dashboard
# DO button in Advanced View menu
# DO Manual overlay
#
# Acceptance Criteria:
# All locations use % as the units
# All locations list O2 output labeled as "O2"
# All locations list N2 output labeled as "N2"
# All locations show one decimal of precision
#
#
# =============================================
# Id: 2739
# Name: Integrity Test and auto log out - charge
# =============================================
# FRS:
# 3.0WebFRS106
#
# Purpose: Confirm auto log out exceptions for Integrity Test
#
# Starting Point:
# Tester is logged in as a user with "Recipe Start" permission
# Bag is not clamped, and so will never pressurize (i.e. test will remain in "Charge" stage until manually canceled)
# Hello is open to 6.7.1: Pressure Decay Test Menu
# "Start" button is green
#
# Steps:
# 1) Start the test
# 2) Wait 10 minutes.  During that time, do not do the following:
# 	navigate away from the test menu
# 	provide mouse or keyboard input to the client
# 	stop the recipe
# 	change the Agitation, DO or Main Gas modes or set points
# 	reload the client
# 	disconnect the pressure sensor
# 	perform a pressure or level calibration
# 3) Observe the client after 10 minutes
#
# Acceptance Criteria:
# The client has logged out due to inactivity
#
#
# =============================================
# Id: 2742
# Name: Web Door permissions
# =============================================
# FRS:
# 3.0WebFRS094
# FRS2304.15: Door
#
# Purpose: Confirm the Door permission works correctly in the Web UI
#
# Starting Point:
# There is at least 1 user in a group with 'Hello Access', 'Remote Access', and 'Door' permissions, and no other permissions.
# There is at least 1 user in a group with all permissions but 'Door' permissions
# Bioreactor is configured as a non-3L, and the door is not interlocked (Agitation is 0, Level is disabled, Pressure is connected)
#
# Steps:
# 1) Log in to the Web UI as the user with 'Door' permission
# 2) Note appearance of "Unlock Door" button.
# 3) Attempt to unlock the door
# 4) Log out
# 5) Log in to the Web UI as the user without 'Door' permission
# 6) Note appearance of "Unlock Door" button.
# 7) Attempt to unlock the door
#
# Acceptance Criteria:
# 2) The button appears normal.
# 3) The door unlocks
# 6) The button appears grayed out.
# 7) A blue toaster alert appears saying "You do not have the 'Door' permission, which is required to perform this action."
#
#
# =============================================
# Id: 2743
# Name: Web Light permission
# =============================================
# FRS:
# 3.0WebFRS095
# FRS2304.18: Light
#
# Purpose: Confirm the Light permission works correctly in the Web UI
#
# Starting Point:
# There is at least 1 user in a group with 'Hello Access', 'Remote Access', and 'Light' permissions, and no other permissions.
# There is at least 1 user in a group with all permissions but 'Light' permissions
#
# Steps:
# 1) Log in to the Web UI as the user with 'Light' permission
# 2) Note appearance of "Main Light" button.
# 3) Attempt to turn the light on, or turn it off (depending on its current state).
# 4) Note appearance of "Main Light" button.
# 5) Turn the light back on if it was off.
# 6) Log out
# 7) Log in to the Web UI as the user without 'Light' permission
# 8) Note appearance of "Main Light" button.
# 9) Attempt to turn the light off.
# 10) Log into an account with main light permissions, turn the light off, and log back into an account without main light permissions.
# 11) Note appearance of "Main Light" button.
# 12) Attempt to turn the light off.
#
# Acceptance Criteria:
# 2&4) Main light button is black when light is off, bright blue when light is on.
# 3) The light turns on (or off, whatever it was supposed to do)
# 8,11) The main light button is grayed out. When the light is on, the button is still blue but faded.
# 9) A blue toaster alert appears saying "You do not have the 'Light' permission, which is required to perform this action."
#
#
# =============================================
# Id: 2744
# Name: Web Batch permission
# =============================================
# FRS:
# 3.0WebFRS096
# FRS2304.14: Batch
#
# Purpose: Confirm the Batch permission works correctly in the Web UI
#
# Starting Point:
# There is at least 1 user in a group with 'Hello Access', 'Remote Access', and 'Batch' permissions, and no other permissions.
# There is at least 1 user in a group with all permissions but 'Batch' permissions
#
# Steps:
# 1) Log in to the Web UI as the user with 'Batch' permission
# 2) Go to the Actions tab and note the appearance of the "Batch" button.
# 3) Click the "Batch" button
# 4) Log out
# 5) Log in to the Web UI as the user without 'Batch' permission
# 6) Go to the Actions tab and note the appearance of the "Batch" button.
# 7) Click the "Batch" button
#
# Acceptance Criteria:
# 2) The "Batch" button appears normal.
# 3) The Batch menu loads
# 6) The "Batch" button appears grayed-out
# 7) A blue toaster alert appears saying "You do not have the 'Batch' permission, which is required to perform this action."
#
#
# =============================================
# Id: 2745
# Name: Web Recipe Start permission
# =============================================
# FRS:
# 3.0WebFRS097
# FRS2304.21: Recipe Start
#
# Purpose: Confirm the Recipe Start permission works correctly in the Web UI
#
# Starting Point:
# There is at least 1 user in a group with 'Hello Access', 'Remote Access', and 'Recipe Start' permissions, and no other permissions.
# There is at least 1 user in a group with all permissions but 'Recipe Start' permissions
# A recipe is not running
# Bioreactor is not configured as a 3L
# Level is disabled
# Agitation DO and Main Gas are Off
# Pressure is connected and 0 psi
#
# Steps:
# 1) Log in to the Web UI as the user with 'Recipe Start' permission
# 2) Go to the Actions tab and note apperance of the "Auto Pilot" button.
# 3) Click the "Auto Pilot" button
# 4) Go back to the Actions tab and click "Load Bag", then go to the Integrity Test menu and click the "Start Test" button
# 5) Log out
# 6) Log in to the Web UI as the user without 'Recipe Start' permission
# 7) Go to the Actions tab and note apperance of the "Auto Pilot" button.
# 8) Click the "Auto Pilot" button
# 9) Go to the Integrity Test menu and click the "Start Test" button
#
# Acceptance Criteria:
# 2) The button appears normal.
# 3) The Auto Pilot menu opens
# 4) The "Load Bag" button is not grayed out, you are able to navigate to the Integrity Test Menu, and the "Integrity Test Confirmation" dialog is displayed
# 6) and 8) A blue toaster alert is displayed saying "You do not have the 'Recipe Start' permission, which is required to perform this action."
# 7) The button appears grayed-out.
#
#
# =============================================
# Id: 2746
# Name: Web Recipe End permission
# =============================================
# FRS:
# 3.0WebFRS097
# 3.0WebFRS098
# FRS2304.20: Recipe End
#
# Purpose: Confirm the Recipe End permission works correctly in the Web UI
#
# Starting Point:
# There is at least 1 user in a group with 'Hello Access', 'Remote Access', 'Recipe Start' and 'Recipe End' permissions, and no other permissions.
# There is at least 1 user in a group with all permissions but 'Recipe End' permissions
#
# Steps:
# 1) Log in to the Web UI as the user with 'Recipe Start' and 'Recipe End' permissions.
# 2) Go to the Auto Pilot menu, and if a recipe is not running start one.
# 3) Note appearance of the "End" button.
# 4) Click the "End" button in the Auto Pilot menu.
# 5) Get the bioreactor in a state that it will allow you to run the Integrity Test, go to the Integrity Test menu, and start the Integrity Test.
# 6) Note appearance of "Stop" button.
# 7) Click the "Stop" button.
# 8) Log Out
# 9) Log in to the Web UI as the user without 'Recipe End' permission
# 10) Go to the Auto Pilot menu, and if a recipe is not running start one (but not a looping one!)
# 11) Note the appearance of the "End" button.
# 12) Click the "End" button in the Auto Pilot menu
# 13) Get the bioreactor in a state that it will allow you to run the Integrity Test, go to the Integrity Test menu, and start the Integrity Test
# 14) Note appearance of the "End" button.
# 15) Click the "Stop" button
#
# Acceptance Criteria:
# 3) End button appears normal.
# 4) The "End Recipe Confirmation" dialogue appears
# 6) Stop button appears normal.
# 7) The "End Integrity Test Confirmation" dialogue appears
# 11) Button appears grayed out.
# 12) and 15) a blue toaster alert is displayed saying "You do not have the 'Recipe End' permission, which is required to perform this action."
# 14) Button appears grayed out.
#
#
# =============================================
# Id: 2747
# Name: Web Pumps permission
# =============================================
# FRS:
# 3.0WebFRS099
# FRS2304.19: Pumps
#
# Purpose: Confirm the Pumps permission works correctly in the Web UI
#
# Starting Point:
# There is at least 1 user in a group with 'Hello Access', 'Remote Access', and 'Pumps' permissions, and no other permissions.
# There is at least 1 user in a group with all permissions but 'Pumps' permissions
# There is a looping recipe that turns sample pump and 1 other pump on and off every 2-5 seconds.
# Pumps are not interlocked.
#
# Steps:
# 1) Log in to the Web UI as the user with 'Pumps' permission
# 2) Go to the Actions tab and note the appearance of the "Control Pumps" and "Take Sample" buttons
# 3) Go to the Take Sample menu, and toggle both switches
# 4) Go to the Control Pumps menu, and click each 'up' arrow, then each 'down' arrow, then toggle each switch
# 5) Log out, log in as a user with 'Recipe Start' permissions, navigate to the auto pilot menu, start the looping recipe, log out, and log back in as the user with 'Pumps' permission
# 6) Go back to the Control Pumps menu and note slider activity.
# 7) Go back to the Take Sample menu and note slider activity
# 8) Log Out
# 9) Log in to the Web UI as the user without 'Pumps' permission
# 10) Go to the Actions tab and note the appearance of the "Control Pumps" and "Take Sample" buttons
# 11) Go to the Control Pumps menu, and observe slider activity.
# 12) Go to the Take Sample menu, and observe slider activity.
# 13) Stop the recipe from running
# 14) Navigate back to Control Pumps menu, and click each 'up' arrow, then each 'down' arrow, and all sliders.
# 15) Navigate back to Take Sample menu, and toggle both switches
#
# Acceptance Criteria:
# 2) and 10) Both buttons appear normal
# 3) and 4) All user actions are accepted
# 5) Sliders update as recipe runs.
# 6) 7) 11) and 12) Sliders update as recipe runs
# 14) and 15) Each time the user clicks an arrow or a slider, a blue toaster alert is displayed "You do not have the 'Pumps' permission, which is required to perform this action."
#
#
# =============================================
# Id: 2748
# Name: Web Acknowledge Alarms permission
# =============================================
# FRS:
# 3.0WebFRS100
# FRS2304.12: Acknowledge Alarms
#
# Purpose: Confirm the Acknowledge Alarms permission works correctly in the Web UI
#
# Starting Point:
# There is at least 1 user in a group with 'Hello Access', 'Remote Access', and 'Acknowledge Alarms' permissions, and no other permissions.
# There is at least 1 user in a group with all permissions but 'Acknowledge Alarms' permissions
# There are unacknowledged alarms
#
# Steps:
# 1) Log in to the Web UI as the user with 'Acknowledge Alarms' permission
# 2) Go to the Alarms tab and click an unacknowledged alarm
# 3) Log out
# 4) Log in to the Web UI as the user without 'Acknowledge Alarms' permission
# 5) Go to the Alarms tab and click an unacknowledged alarm
#
# Acceptance Criteria:
# 2) The user is presented with a choice of actions to acknowledge the alarm, all alarms of that type, all alarms, or cancel
# 5) A blue toaster alert is displayed "You do not have the 'Acknowledge Alarms' permission, which is required to perform this action."
#
#
# =============================================
# Id: 2749
# Name: Web Sensors permission
# =============================================
# FRS:
# 3.0WebFRS101
# FRS2304.23: Sensors
#
#  *+Notes:+*
#  The attached Excel spreadsheet specifies all LabVIEW UI functions, and Server calls, along with their associated permission option.
#
# Purpose: Confirm the Sensors permission works correctly in the Web UI
#
# Starting Point:
# There is at least 1 user in a group with 'Hello Access', 'Remote Access', and 'Sensors' permissions, and no other permissions.
# There is at least 1 user in a group with all permissions but 'Sensors' permissions
# Bioreactor is not configured as a 3L
# Bioreactor is configured with two temperature sensors, such that user can switch between them.
# A looping recipe exists which sets the temperature sensor in and out of valid range using Temp Valid High every 3-5 seconds.
#
# Steps:
# 1) Log in to the Web UI as the user with 'Sensors' permission
# 2) Go to the Select Sensors menu and click the locks, then the DNE symbols (create some if there aren't any), then the switches
# 3) Go to the Load Bag menu, put valid entries in all the fields, and click the "Load Bag" button
# 4) Click the "Calibrate" button in the Actions tab.
# 5) Log out, log in as a user with 'Recipe Start' permission, log out, and log back in as the user with 'Sensors' permission
# 6) Navigate to the Select Sensors menu and observe the font color activity
# 7) Log out
# 8) Log in to the Web UI as the user without 'Sensors' permission
# 9) Go to the Select Sensors menu and observe the font color activity
# 10) Stop the looping recipe and navigate back to Select Sensors.  Click the locks, then the DNE symbols (create some if there aren't any), then the sliders
# 11) Go to the Load Bag menu, put valid entries in all the fields, and click the "Load Bag" button.
# 12) Click the "Calibrate" button in the Actions tab
#
# Acceptance Criteria:
# 2) User actions are accepted
# 3) The user is returned to the Actions tab and the bag is loaded
# 4) The pH A calibration menu appears
# 6) and 9) The font colors change as the sensor PVs go in and out of range.  The sliders may also change position.
# 10) 11) and 12) A blue toaster alert is displayed to the user saying "You do not have the 'Sensors' permission, which is required to perform this action."
#
#
# =============================================
# Id: 2750
# Name: Web Hello Settings permission
# =============================================
# FRS:
# 3.0WebFRS102
# FRS2304.17: Hello Settings
#
# Purpose: Confirm the Hello Settings permission works correctly in the Web UI
#
# Starting Point:
# There is at least 1 user in a group with 'Hello Access', 'Remote Access', and 'Hello Settings' permissions, and no other permissions.
# There is at least 1 user in a group with all permissions but 'Hello Settings' permissions
#
# Steps:
# 1) Log in to the Web UI as the user with 'Hello Settings' permission
# 2) Go to the Settings tab and attempt to edit the value of a setting
# 3) Log out
# 4) Log in to the Web UI as the user without 'Hello Settings' permission
# 5) Go to the Settings tab and attempt to edit the value of a setting
#
# Acceptance Criteria:
# 2) The user is able to edit the value of the setting
# 5) The user is not able to edit the value of the setting - no number pad shows up, etc.
#
#
# =============================================
# Id: 2775
# Name: Report Permissions
# =============================================
# FRS:
# 3.0WebFRS103
#
# Purpose: Confirm the Report permission works correctly in the Web UI
#
# Starting Point:
# There is at least 1 user in a group with 'Hello Access', 'Remote Access', and ‘Report’ permissions, and no other permissions.
# There is at least 1 user in a group with all permissions but ‘Report’ permissions
#
# Steps:
# 1) Log in to the Web UI as the user with ‘Report’ permission
# 2) Go to the Actions tab and note the appearance of the "Export Data" button.
# 3) Click the "Export Data" button
# 4) Log out
# 5) Log in to the Web UI as the user without “Report” permission
# 6) Go to the Actions tab and note the appearance of the "Export Data" button.
# 7) Click the "Export Data" button
#
# Acceptance Criteria:
# 2) The "Export Data" button appears normal.
# 3) The Export Data menu loads
# 6) The "Export Data" button appears grayed-out
# 7) A blue toaster alert appears saying "You do not have the 'Report' permission, which is required to perform this action."
#
#
# =============================================
# Id: 2776
# Name: Controls Permissions
# =============================================
# FRS:
# 3.0WebFRS104
# FRS2304.5: Controls
#
# Purpose: Confirm the Controls permission works correctly in the Web UI.
#
# Starting Point:
# There is at least 1 user in a group with 'Hello Access', 'Remote Access', and ‘Controls’ permissions, and no other permissions.
# There is at least 1 user in a group with all permissions but ‘Controls’ permissions
# Bioreactor is configured as a Mag Drive.
#
# Steps:
# 1) Log in to the Web UI as the user with ‘Controls’ permission
# 2) Note appearance of “Agitation”, “Temperature”, “DO”, “pH”, and “Main Gas” buttons.
# 3) Click each button.
# 4) Go to the "Actions" tab and note the appearance of the "Control Pumps" and "Advanced" buttons
# 5) Navigate to the "Advanced" menu and note appearance of “Agitation”, “Temperature”, “DO”, “pH”, and “Main Gas” buttons.
# 6) Click each button
# 7) Go to the "Control Pumps" menu and attempt to change the selected base pump
# 8) Log out.
#
# 9) Log in to the Web UI as the user without “Controls” permission
# 10) Note appearance of “Agitation”, “Temperature”, “DO”, “pH”, and “Main Gas” buttons.
# 11) Click each button.
# 12) Go to the "Actions" tab and note the appearance of the "Control Pumps" and "Advanced" buttons
# 13) Navigate to the "Advanced" menu and note appearance of “Agitation”, “Temperature”, “DO”, “pH”, and “Main Gas” buttons.
# 14) Click each button.
# ...
# 2) Open the shell UI and navigate to config -> settings.
# 3) Compare contents of system variables to the contents of item 6.
# 4) Create a copy of the system variables file and change a value and save.
# 5) Leave the settings panel, navigate back, and open the file from step 4.
#
# Acceptance Criteria:
# 3) All settings are listed in item 6. They are listed in the same order as in System variables, and the value and group are correct.
# 5) Item 6 shows contents of the new file, not the one on the RIO.
#
#
# =============================================
# Id: 3036
# Name: Shell UI Harvest Feature - Numpad and SP Restore
# =============================================
# FRS:
# FRS3225.5.1.1: Clicking Item 1 will trigger a numpad overlay per FRS3288.
# FRS3225.5.1.5: The current auto and manual set points will be saved to be restored later (see below).
#
# Purpose: Verify numpad appearance, and verify set points are restored after harvest mode.
#
# Starting Point:
# Bioreactor is not currently in harvest mode.
# Agitation is running
# Shell UI is open
# Hello UI is open
# User has all necessary permissions.
#
# Steps:
# 1) Note item 1's current value, click it, and note appearance of overlay.
# 2) Enter '7' or '8' (pick one that wasn't the old value) and press enter.
# 3) Enter new, unique values for auto and manual agitation set points. Note values.
# 4) Press the harvest button and let the system run to completion.
# 5) Note the values for auto and manual set point: in Hello, click "auto" or "man" and note the value displayed by the keyboard.
#
# Acceptance Criteria:
# 1) Numpad (not keyboard) appears, with 0-9 buttons.
# 2) Numpad disappears, the correct number appears in item 1.
# 5) Values entered in step 3 appear correctly in step 5.
#
#
# =============================================
# Id: 3037
# Name: Shell UI Harvest Feature - Queued Inputs Part 1
# =============================================
# FRS:
# FRS3225.5.2.3: Clicking Item 3 will queue a transition from states 9-6 (see below).
# FRS3225.5.3.2: Clicking Item 3 will queue a transition from states 9-6 (see below).
#
# Purpose: Verify that harvest button inputs are queued during harvest modes.
#
# Starting Point:
# System is not in harvest mode.
# Shell UI is open.
# User has all necessary permissions.
#
# Steps:
# 1) Start harvest mode. While item 2 shows "Ramping down speed", press the harvest button again.
# 2) Wait for the impeller to stop, then start again.
# 3) Repeat the above, but press the harvest button twice.
#
# 4) Exit harvest mode.
#
# 5) Start harvest mode. When item 2 first says "Attempting to align wheel", but before a magnet pass goes by, press the harvest button.
# 6) Wait for the impeller to stop, then start again.
# 7) Repeat the above, but press the harvest button twice.
#
# Acceptance Criteria:
# 2) Impeller briefly stops, then runs again for another half-turn.
# 3) Same as step 2, but stops and runs a second time.
#
# 6) Same as step 2
# 7) Same as step 2
#
#
# =============================================
# Id: 3038
# Name: Shell UI Harvest Feature - Queued Inputs Part 2
# =============================================
# FRS:
# FRS3225.5.4.1: Clicking Item 3 will queue a transition from states 9-6 (see below).
#
# Purpose: Verify queued inputs work correctly.
#
# Starting Point:
# Shell UI is open.
# Bioreactor is not in harvest mode.
#
# Steps:
# 1) Start harvest mode. While item 2 shows "Attempting to align wheel", wait for a magnet to pass by, and press the harvest button again.
# 2) Wait for the impeller to stop, then start again.
# 3) Repeat the above, but press the harvest button twice.
#
# 4) Press the harvest button twice.
#
# Acceptance Criteria:
# 2) Impeller briefly stops, then runs again for another half-turn.
# 3) Same as step 2, but stops and runs a second time.
#
# 4) Same as step 3.
#
#
# =============================================
# Id: 3041
# Name: Shell UI Keyboard - Appearance
# =============================================
# FRS:
# FRS3288.1: Appearance for Keyboard Overlay:
#  !ShellUI_KeyboardOverlay_161024.png!
# FRS3288.2: Appearance for Numpad Overlay:
#  !ShellUI_NumpadOverlay_161024.png!
# FRS3288.3.1: Item 1 shall be a string entry field
# FRS3288.3.2: The label for Item 1 shall be configurable by the caller.
# FRS3288.3.3: The text displayed may be visible or obscured by asterisks. This shall be caller configurable.
# FRS3288.3.4: Item 2 for the keyboard overlay shall be a keyboard in standard Qwerty layout.
#  *** Tilde ("~"), tab, caps lock, ctrl, alt keys are not necessary. Only keys needed for typical input are necessary.
#  *** Escape, backspace, and enter keys may be rearranged as necessary to improve layout or aesthetic.
# FRS3288.3.5: Item 2 for the numpad overlay shall be a similar to the numpad found on a phone
#  *** Keypad should also include ".", "-", backspace, escape, and enter keys.
#  *** Names of keys may be abbreviated to fit in the available space.
#  *** Orientation of numbers 1-9 top down vs. bottom up isn't explicitly specified, but they should be in order.
# FRS3288.4.1: Keyboard shall be called to be used to populate a specific entry control at the request of the caller.
# FRS3288.4.2: On keyboard overlay, the Shift key shall swap between upper and lower case letters, and between numbers and symbols, as per a standard keyboard.
# FRS3288.4.4: For callers which request the text field to be obscured, asterisk ("****") characters shall be added to Item 1 in place of the true value.
#
# Purpose: Verify the keyboard is rendered appropriately.
#
# Starting Point:
# Shell UI is open
# User is not logged in
#
# Steps:
# 1) Open the login screen and click the username field. Examine contents of the overlay, including changes after pressing "Shift".
# 2) Type in a username.
# 3) Press enter.
#
# 4) Click the password field.
# 5) Type in a password.
# 6) Press enter.
#
# 7) Navigate to the graphs -> agitation tab and click the "delay" field.
# 8) Enter a multidigit number.
# 9) Press enter.
#
# Acceptance Criteria:
# 1) Appearance matches issue #3288 image #1.
# * Item 1 is a string field labeled "Username".
# * Item 2 is a QWERTY keyboard. ctrl, tab, caps lock, and alt keys may not be present.
# * All 0-9, A-Z, and symbols are accessible.
# * Quotes may not be accessible.
# * Pressing shift swaps between upper and lower case, and showing symbols vs. numbers.
# * The overlay is partially transparent, and stuff can be seen behind it.
# 2) Text is plaintext.
# 3) Keyboard disappears. The text populates the box that was clicked to trigger it.
#
# 4) Appearance is similar to step 1, except item 1 is named "Password".
# 5) Text is obscured by **** characters.
# 6) Same as step 3.
#
# 7) Overlay matches issue #3288 image #2:
# * Numpad has all digits 0-9, a decimal, and a minus sign.
# * Numpad has escape and Ok buttons.
# * Overlay is partially transparent.
# * Item 1 is a string field with a label.
# 8) Text appears.
# 9) Overlay disappears. The value now populates the entry control that triggered it.
#
#
# =============================================
# Id: 3042
# Name: Shell UI Keyboard - Functionality
# =============================================
# FRS:
# FRS3288.3.6: The font size of all text, including keyboard, shall be visible when viewed directly on the bioreactor.
#  *** Standard viewing angle can be considered +/- 15 degrees, roughly, from perpendicular
#  *** Font size should account for customers with bad eyes.
# FRS3288.4.3: Pressing an input key on the keyboard shall append that character to the end of the current value of Item 1.
# FRS3288.4.5: Backspace key shall delete the last character in Item 1.
# FRS3288.4.7: Pressing cancel shall close the keyboard overlay and submit no value to the caller.
# FRS3288.4.8: Input through an external keyboard shall be processed through the same set of rules as input sent from the on-screen keyboard.
#
# Purpose: Verify keyboard functionality.
#
# Starting Point:
# Shell UI is open
# User has all necessary permissions.
#
# Steps:
# 1) Directly on a 3L or 15L bioreactor (small screen), open the keyboard and examine font size of keys.
# 2) Repeat step 10 with the numpad instead of keyboard.
# 3) Repeat steps 10 and 11 on an 80L or 500L bioreactor (large screen).
# 4) Access the keyboard and enter a value. Press backspace once.
# 5) Press cancel.
#
# 6) Repeat steps 4-5 with the numpad.
# 7) Repeat steps 4-5 with an external keyboard.
#
# Acceptance Criteria:
# 1-3) Text is easily visible on the screen, even at a slight viewing angle. Text would be visible to someone with bad eyes.
# 4) Each new character is appended to the end of the string. Backspace deletes the last character in the string.
# 5) The new value does not appear in the field that triggered the keyboard.
#
# 6) Same as steps 4 and 5.
# 7) Same as steps 4 and 5.
#
#
# =============================================
# Id: 3044
# Name: Select Sensors Hardware Configuration
# =============================================
# FRS:
# FRS1583.1: The system shall be able to be configured whether Sensor A is present, Sensor B is present, or both are Present.
#
# Purpose: Verify that sensor A/B hardware configuration occurs correctly.
#
# Starting Point:
# Bioreactor is configured as a 15L or 80L Mag Drive
# Shell UI is open
# WinSCP is accessible
# User has all necessary permissions.
#
# Steps:
# 1) Open the Bioreactor Configuration.txt file in the config folder on the RIO.
# 2) Edit the last three numbers in the first line to be "0,0,0".
# 3) Restart the Shell and RIO.
# 4) Navigate to the graphs tab.
# 5) Examine the PV display on pH, DO, and Temp panels. PV shows the value of that sensor.
# 6) Attempt to navigate to the Hello UI Select Sensors screen.
# 7) Repeat steps 1-6, setting the numbers to "1,1,1".
# 8) Repeat steps 1-6, setting the numbers to "2,2,2".
#
# Acceptance Criteria:
# 5) Only Sensor A is displayed in each tab.
# 6) Select sensors button is not present in actions tab.
# 7) Only sensor B is displayed in each tab. Select sensors button is not present.
# 8) Sensors A and B are displayed in each tab. Select sensors button exists.
#
#
# =============================================
# Id: 3045
# Name: Select Sensors User Configuration
# =============================================
# FRS:
# FRS1583.2: Users shall be able to Enable or Disable specific sensors if present.  They cannot disable both sensors of a set.
# FRS1583.3: If both sensors are Enabled, a user shall be able to prefer a sensor.
# FRS1583.9.1: Clicking a lock icon shall be interpreted as Enabling or Disabling a sensor.
# FRS1583.9.3: Changing a slider shall be interpreted as making a sensor Preferred.
#
# Purpose: Verify that users can configure select sensors correctly.
#
# Starting Point:
# User has all necessary permissions
# Shell UI is open
# Hello UI is open
# Bioreactor is configured to have sensors A and B present for pH, DO, and temp
# A/B sensors for each sensor type have different PVs.
# PVs for all sensors are in valid range.
#
# Steps:
# 1) Navigate to the Shell UI's graphs tab.
# 2) Note PV for pH, DO, and Temp, and PV for A and B sensor for each.
# 3) In select sensors menu in the Hello UI, use the slider to prefer sensor A for all sensors, and examine PVs.
# 4) In select sensors menu in the Hello UI, use the slider to prefer sensor B for all sensors, and examine PVs.
# 5) In select sensors menu, click the lock icon to disable sensor B for all sensors. Click the slider icon.
# 6) Repeat step 5 for Sensor A.
# 7) Click the lock icon for Sensor B, then use the slider.
# 8) Click the lock icon for sensor A, then the slider.
#
# Acceptance Criteria:
# 3) PVs show sensor A PV for all sensors.
# 4) PVs show sensor B PV for all sensors.
# 5) Sensor B is disabled. PV now switches to Sensor A. Clicking the slider does nothing after Sensor B is disabled.
# 6) Sensor A is still disabled. User can't disable both sensors at the same time.
# 7) Sensor B is now enabled. PV switches to show Sensor B.
# 8) Sensor A is now locked, and the slider does nothing.
#
#
# =============================================
# Id: 3047
# Name: Fail Rate - Sensors not Present
# =============================================
# FRS:
# FRS1583.4: pH failure rate alarms shall not be triggered sensors that are Disabled or not Present.
#
# Purpose: Verify that fail rate alarms are not generated for sensors that are configured to be hardware present.
#
# Starting Point:
# Hello and Shell UI are open, and user has all necessary permissions.
# pH Valid High and Low are normal
# Fail Rate is 1 pH/min
# Base Wait Time is 30 seconds
# pH simulator has been connected to Sensor A and sending a value of '4' for over 30 seconds
# Base duty is 0 (under 1 of the following circumstances):
# 	If pH is in Auto mode, set point is less than 4
# 	If Manual mode, Base Duty is 0
# 	pH is in Off mode
#
# Steps:
# 1) Configure the bioreactor so that only pH sensor B is present (edit Bioreactor Configurations.txt and reboot).
# 2) Set simulator to output 10.  Check for alarm generation.
# 3) Wait at least 30 seconds from when the alarm was generated (so sensor A will no longer be in "rate fail" state), and then set the simulator to output 4 again.
#
# 4) Configure the bioreactor so that both pH A and B are present, and then disable sensor A.
# 5) Repeat 2-3.
#
# Acceptance Criteria:
# No alarms are generated.
#
#
# =============================================
# Id: 3049
# Name: Permissions - Any Client
# =============================================
# FRS:
# FRS2304.13: Any Client
#
# Purpose: Verify that the basic set of actions works for users without permissions.
#
# Starting Point:
# Shell UI is open.
# Hello UI is not open.
# A user exists with no permissions.
#
# Steps:
# 1) Open Hello UI. Verify it loads correctly.
# 2) Log in with a user with no permissions.
#
# Acceptance Criteria:
# 1,2) Everything loads correctly, including main values, alarm count, users list, DORA bar information, and the trend graphs.
# 2) After logging in, everything continues to work.
#
#
# =============================================
# Id: 3050
# Name: Bioreactor Recipes - Variables in Clusters
# =============================================
# FRS:
# FRS2769.1: Recipe is able to edit variables in cluster correctly.
# FRS2769.2: Recipe can read clustered global variables correctly.
#  ** Wait until
#  ** Set
#
# Purpose: Verify that Global Variables stored in clusters can be edited by the recipe editor, and read from a recipe by the recipe engine.
#
# Starting Point:
# Shell UI is open
# User has all necessary permissions
#
# Steps:
# Note all values modified during this test so they can be reverted after the test is over.
#
# 1) Navigate to the recipe editor in the service UI.
# 2) Create a new recipe with a unique name.
# 3) Add a Set step for Agitation PGain = 3.
# 4) Add a Wait Until step for Agitation PGain = 5.
# 5) Run the Recipe.
# 6) Set Agitation PGain to 5.
# 7) Verify the recipe finishes.
#
# Acceptance Criteria:
# 3) User is able to add a step for that parameter.
# 7) The recipe finishes after setting agitation P Gain to 5.
#
#
# =============================================
# Id: 3051
# Name: Shell UI Reports Menu - Error
# =============================================
# FRS:
# FRS2851.14: If an error occurs during report generation, display the error dialog.
#
# Purpose: Verify an error pops up to alert the user if an error occurs during report generation.
#
# Starting Point:
# Shell UI is open.
# File explorer is accessible.
#
# Steps:
# 1) Rename the current database. If a file in use error occurs, close the shell and then rename the current database before reopening.
# 2) Navigate to the reports tab.
# 3) Attempt to generate a report by time.
#
# Acceptance Criteria:
# 3) An error occurs when the user attempts to generate the report. It triggers a popup dialog with an error message.
#
#
# =============================================
# Id: 3052
# Name: Shell UI Alarm Config Editor - Error
# =============================================
# FRS:
# FRS2865.2.9: If there is an error, an error dialog will pop up.
#
# Purpose: Verify an error dialog appears when an error occurs.
#
# Starting Point:
# Shell UI is open.
# User has all necessary permissions.
#
# Steps:
# 1) Create a copy of an alarm file in the LabVIEW data folder.
# 2) Corrupt it by opening it and deleting one of the xml tags.
# 3) Attempt to open the file in the Shell UI's alarm config editor.
#
# Acceptance Criteria:
# 3) An error dialog popup appears with a useful error message.

# %%
#reqs = frs_traceability2.full_frs_tree(p1, p2, p3)

# %%
#import clipboard
#clipboard.copy(clipboard.paste().replace("shall", "will"))

# %%
t = clipboard.paste()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-52b6f32d4232> in <module>()
# ----> 1 t = clipboard.paste()
#
# NameError: name 'clipboard' is not defined

# %%
def _extract_frs_lines(lines):
    start_matches = (
        (_toplevel_match, 0),
        (_subitem_match, 0),
        (_canceled_match, 1),
    )
    end_matches = (
        _toplevel_match,
        _subitem_match,
        _canceled_match,
        _header_match
    )
    i = 0
    while True:
        try:
            line = lines[i]
        except IndexError:
            break
        i += 1
        for match, flags in start_matches:
            done = False
            m = match(line)
            
            if m:
                f = m.group(1)
                t = m.group(2).strip()
                l = [t]
                while True:
                    try:
                        line = lines[i]
                        
                    except IndexError:
                        done = True
                        break
                    if any(m(line) for m in end_matches):
                        done = True
                        break
                    
                    l.append(" " + line.strip())
                    i += 1
                text = "\n".join(l)
                # if l and not t:
                #     text = "\n" + text
                yield f, flags, text
            if done:
                break

# %%
for line in _extract_frs_lines(t.splitlines()):
    print(line[2])

# %%
l = "**** This will be a tab labeled \"Configure Users\""
_header_match = re.compile(r"^\>?[\+\*]{2}(.+)[\+\*]{2}").match
for m in (
        _toplevel_match,
        _subitem_match,
        _canceled_match,
        _header_match
    ) :
    if m(l):
        print(m.__self__.pattern, ((
        _toplevel_match,
        _subitem_match,
        _canceled_match,
        _header_match
    ).index(m)))
#frs_traceability2._header_match = _header_match

# %%
_header_match(l)
