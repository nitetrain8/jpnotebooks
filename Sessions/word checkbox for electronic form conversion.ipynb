# %%
from officelib.wordlib import *

# %%
w = Word()
d = w.RecentFiles(1).Open()
d.Name
# Out:
# 'IF00118 Rev B PM Procedure report 3L 180321.docx'

# %%
def pd(o):
    for a in dir(o):
        if a[0] != '_':
            print(a)
def pmg(o):
    for n in o._prop_map_get_:
        print(n)

# %%
pmg(d)
# Out:
# InlineShapes
# Shapes
# DocumentTheme
# MailEnvelope
# ActiveTheme
# DefaultTargetFrame
# Comments
# Characters
# TablesOfFigures
# ActiveThemeDisplayName
# FormFields
# Variables
# Kind
# SmartTagsAsXMLProps
# ConsecutiveHyphensLimit
# KerningByAlgorithm
# DefaultTableStyle
# Windows
# XMLHideNamespaces
# ContentTypeProperties
# Routed
# FormsDesign
# HasRoutingSlip
# EmbedSmartTags
# ContentControls
# StoryRanges
# Path
# Permission
# Subdocuments
# Sections
# GridOriginHorizontal
# PasswordEncryptionProvider
# Hyperlinks
# ChildNodeSuggestions
# EmbedLinguisticData
# SmartTags
# TextLineEnding
# Dummy3
# XMLSaveThroughXSLT
# HasVBProject
# GridDistanceHorizontal
# ProtectionType
# ShowSpellingErrors
# AutoFormatOverride
# Background
# SaveFormsData
# PrintPostScriptOverText
# GridSpaceBetweenHorizontalLines
# XMLNodes
# ShowRevisions
# Signatures
# Footnotes
# OMathWrap
# LockTheme
# WriteReserved
# TablesOfAuthorities
# XMLSchemaViolations
# Research
# NoLineBreakBefore
# ...

# %%
pmg(d.FormFields("checkBoxFoo"))
# Out:
# DropDown
# Result
# CalculateOnExit
# Name
# Type
# ExitMacro
# Parent
# CheckBox
# OwnHelp
# StatusText
# Next
# Enabled
# Previous
# Application
# OwnStatus
# Creator
# Range
# EntryMacro
# HelpText
# TextInput

# %%
d.FormFields("checkBoxFoo").CheckBox.Value = 1

# %%
d.FormFields("resistanceMainHeater").Result = "Test"
