# %%
import weakref, sys, math
    
class GanttBase():
    def __init__(self, name):
        self.subitems = {}
        self.name = name
        
    def add_item(self, item):
        self.subitems[item.uid] = item
        
    def iter_all(self):
        for it in self.subitems.values():
            yield from it.iter_all()
            yield it
        
        
class GanttItem(GanttBase):
    def __init__(self, project, name, duration):
        super().__init__(name)
        self.duration = duration
        self.uid = project.allocate_uid()
        self.project = project
        self.descendents = weakref.WeakSet()
        self.precedents = weakref.WeakSet()
        
    def minstart(self):
        m = 0
        for p in self.precedents:
            mt = p.duration + p.minstart()
            if mt > m:
                m = mt
        return m
        
    def add_precedent(self, it):
        if isinstance(it, int):
            it = self.project.get_by_uid(it)
        self.precedents.add(it)
        
    def add_descendent(self, it):
        if isinstance(it, int):
            it = self.project.get_by_uid(it)
        self.descendents.add(it)
        
    def new_item(self, project, name, duration):
        new = self.__class__(project, name, duration)
        self.add_descendent(new)
        new.add_precedent(self)
        self.add_item(new)
        
    def iter_items(self):
        return iter(self.subitems.values())
        
    def free(self):
        for it in self.iter_items():
            it.free()
        self.subitems = []
        self.project = None    
        
    def __repr__(self):
        return "GanttItem(%r, %r, %r)"%(self.project, self.name, self.duration)
        
        
class GanttProject(GanttBase):
    def __init__(self, name):
        super().__init__(name)
        self._cur_id = 0
        
    def __repr__(self):
        return "GanttProject(%r)"%self.name
        
    def allocate_uid(self):
        rv = self._cur_id
        self._cur_id += 1
        return rv
    
    def get_by_uid(self, n):
        return self.subitems[n]
    
    def new_item(self, name, duration, prec=None):
        new = GanttItem(self, name, duration)
        if prec is not None:
            if isinstance(prec, int):
                prec = self.get_by_uid(prec)
            new.add_precedent(prec)
            prec.add_descendent(new)
        self.add_item(new)
        return new
    
    def print(self, fp=None):
        if fp is None:
            fp = sys.stdout
        
        tmpl = "%-40s |%s"
        
        out = []
        for it in self.iter_all():
            out.append((it.name, it.minstart(), it.duration))
            
        out.sort(key=lambda t: t[1])
        last = out[-1]
        end = last[1] + last[2]
        end = math.ceil(end/60)*60 
        
        nhours = math.ceil(end / 60)
        xaxis = []
#         for i in range(nhours):
#             s = str(i)
#             sl = len(s)
#             nleft = int((12 // 2) - (sl // 2))
#             nright = 12 - nleft - sl
#             xaxis.append("%s%s%s"%(nleft * " ", s, nright * " "))

            
        nhours = math.ceil(end / 60)
        nright = 11
        for i in range(nhours):
            s = str(i)
            sl = len(s)
            xaxis.append(" " * nright)
            xaxis.append(s)
            nright = int(10 - (sl // 2))
            
            
        sout = tmpl%("Activity", " ".join(xaxis))
        print(sout, file=fp)
        print("_"*len(sout), file=fp)
        
        for name, start, dur in out:
            sb = []
            i = 0
            dend = start + dur
            
            for j in range(int(end/5)+1):
                
                if i > 0 and not i % 60:
                    sb.append("|")
                if start <= (5*j) < dend:
                    sb.append("-")
                else:
                    sb.append(" ")
                i += 5
                
            padbar = "".join(sb)
            print(tmpl%(name, padbar), file=fp)

# %%
def add_to_proj(proj, qp, last=None):
    for name, dur in qp:
        new = proj.new_item(name, dur, last)
        last = new
    return last

proj = GanttProject("SemmaIQOQ")
last = add_to_proj(proj, iqp)
add_to_proj(proj, oqp, last)
with open("test.txt", 'w') as f:
    proj.print(f)

# %%
proj = GanttProject("SemmaIQOQ")
it = proj.new_item("Document Approvals", 10)
proj.new_item("Test Equipment", 10, it)
proj.print()
# Out:
# Document Approvals                       | --
# Test Equipment                           |   --

# %%
from officelib.xllib import *
xl = Excel()

# %%
wb = xl.Workbooks("IOQ Time Estimate.xlsx")
ws = wb.Worksheets("IOQ")
cells = ws.Cells
cr = cells.Range

def data(c1):
    c2 = c1.End(xlc.xlDown).Offset(1, 6)
    return cr(c1, c2).Value

iq1 = cr("A3")
iq = data(iq1)

oq1 = cr("A27")
oq = data(oq1)

# %%
def parse(data):
    out = []
    for name, _, _, _, _, total in data:
        out.append((name, total / 60))
    return out

iqp = parse(iq)
oqp = parse(oq)

# %%
def add_to_proj(proj, qp, last=None):
    for name, dur in qp:
        new = proj.new_item(name, dur, last)
        last = new
    return last

proj = GanttProject("SemmaIQOQ")
last = add_to_proj(proj, iqp)
add_to_proj(proj, oqp, last)
with open("test.txt", 'w') as f:
    proj.print(f)

# %%
tasks = [
    ('Document Approvals', 10.0, False),
    ('Test Equipment', 10.0, False),
    ('System Accessories', 10.0, False),
    ('Product Info', 10.0, False),
    ('Physical inspection', 20.0, False),
    ('Plant utilities', 10.0, False),
    ('Gas Lines', 20.0, False),
    ('Bios Config / battery', 10.0, False),
    ('Power Up', 10.0, False),
    ('Software verif', 5.0, False),
    ('OS Config', 5.0, False),
    ('McAfee Config', 5.0, False),
    ('Inbound Firewall', 10.0, False),
    ('Outbound Firewall', 10.0, False),
    ('System Vars', 10.0, False),
    ('Alarms Off', 10.0, False),
    ('Alarms On', 10.0, False),
    ('Logging Off', 10.0, False),
    ('Logging On', 10.0, False),
    ('Email Settings', 5.0, False),
    ('Verify User Groups', 5.0, False),
    ('Protocol Completion', 10.0, False),
    ('Document Approvals', 10.0, False),
    ('Test Equipment', 30.0, False),
    ('Power On', 10.0, False),
    ('Vessel Fit', 10.0, False),
    ('Level Verification', 10.0, False),
    ('Agitation Control', 20.0, False),
    ('Transfer Config Files', 20.0, False),
    
    ('Temp Setup', 5, False),
    ('Temp Wait 1', 6.5*60, True),
    ('Temp Check', 25, False),
    ('Temp Wait 2', 4*60, True),
    ('Temp Check 2', 25, False),
#     ('Temp Control', 60.0, False),
    
    ('pH / DO Sensor Input', 5.0, False),
    
    ('pH Setup', 10, False),
    ('pH Wait 1', 60, True),
    ('pH Check', 5, False),
    
    ('DO Setup', 10, False),
    ('DO Wait 1', 40, True),
    ('DO Check 1', 5, False),
    ('DO Wait 2', 40, True),
    ('DO Check 2', 5, False),
    
#     ('Sensor Validation', 20.0, False),
    ('Gas Request', 5.0, False),
    ('Gas Flow Accuracy ', 15.0, False),
    ('Pumps', 5.0, False),
    
    ('Filter Oven Setup', 5, False),
    ('Filter Oven Wait', 60, True),
    ('Filter Oven Check', 5, False),
#     ('Filter Oven Temp', 5.0, False),
    
    ('Recipe Verification', 5.0, False),
    ('Power Loss & Restore', 15.0, False),
    ('Interlocks', 10.0, False),
    ('Process Alarms', 10.0, False),
    ('Clear Alarms', 5.0, False),
    ('Cleanup', 10.0, False),
    ('Flash Drive Verif', 10.0, False),
    ('Protocol Completion', 10.0, False),
]

# %%
import datetime

def fmt(dt):
    return dt.strftime("%I:%M %p")

def fmt2(dt):
    return dt.strftime("%m/%d/%y %I:%M:%S %p")

current = start

class Task():
    def __init__(self, br, name, dur, para, prec):
        self.br = br
        self.name = name
        self.dur = dur
        self.st = None
        self.prec = prec
        self.para = para
        self._done = False
        
    def running(self):
        return self.st is not None
    
    def finish(self):
        self._done = True
        
    def start(self, dt):
        self.st = dt
        
    def done(self, dt):
        if self._done:
            return True
        if not self.st:
            return False
        elapsed = self.elapsed(dt)
        return elapsed >= self.dur
        
    def elapsed(self, dt):
        return (dt - self.st).total_seconds() / 60 
    
    def __repr__(self):
        return "Task(%r, %r, Task<%s>)"%(self.name, self.dur, self.prec.name if self.prec else "Empty")
    

ioq_tasks = []

for br in range(4):
    br += 1
    prev = None
    for name, dur, para in tasks:
        task = Task(br, name, dur, para, prev)
        prev = task
        ioq_tasks.append(task)

start = startstart = current = datetime.datetime(2018, 12, 6, 9)
end_of_day = datetime.datetime(2018, 12, 6, 12+6)
oneday = datetime.timedelta(hours=24)
minute = datetime.timedelta(minutes=1)
brs = [
    0,
    0,
    0,
    0,
    0
]

out = []
def showtask(task, start, end):
    print("%d %-30s %30s %30s %s"%(task.br, task.name, fmt(start), fmt(end), "para" if task.para else ""))
    out.append((task.br, "<%d>%s"%(task.br, task.name), task.dur / 1440, fmt2(start)))

def elapsed():
    return (current - start).total_seconds() / 60

while ioq_tasks:
    el = elapsed()
    for task in ioq_tasks:
        if task.para and task.running() and task.done(current):
            ioq_tasks.remove(task)
            brs[task.br] = 0
            break
        
        prec = task.prec
        #import pdb;pdb.set_trace()
        if (prec is None or prec.done(current)) and brs[task.br] == 0:
            if task.para:
                task.start(current)
                end = current + datetime.timedelta(minutes=task.dur)
                showtask(task, current, end)
                brs[task.br] = 1
            else:
                if datetime.timedelta(minutes=task.dur) + current < end_of_day:
                    task.start(current)
                    end = current + datetime.timedelta(minutes=task.dur)
                    ioq_tasks.remove(task)
                    showtask(task, current, end)
                    current = end
                    break
    else:
        current += minute
        if current > end_of_day:
            start += oneday
            end_of_day += oneday
            current = start
                


#ioq_tasks
# Out:
# 1 Document Approvals                                   09:00 AM                       09:10 AM
# 1 Test Equipment                                       09:10 AM                       09:20 AM
# 1 System Accessories                                   09:20 AM                       09:30 AM
# 1 Product Info                                         09:30 AM                       09:40 AM
# 1 Physical inspection                                  09:40 AM                       10:00 AM
# 1 Plant utilities                                      10:00 AM                       10:10 AM
# 1 Gas Lines                                            10:10 AM                       10:30 AM
# 1 Bios Config / battery                                10:30 AM                       10:40 AM
# 1 Power Up                                             10:40 AM                       10:50 AM
# 1 Software verif                                       10:50 AM                       10:55 AM
# 1 OS Config                                            10:55 AM                       11:00 AM
# 1 McAfee Config                                        11:00 AM                       11:05 AM
# 1 Inbound Firewall                                     11:05 AM                       11:15 AM
# 1 Outbound Firewall                                    11:15 AM                       11:25 AM
# 1 System Vars                                          11:25 AM                       11:35 AM
# 1 Alarms Off                                           11:35 AM                       11:45 AM
# 1 Alarms On                                            11:45 AM                       11:55 AM
# 1 Logging Off                                          11:55 AM                       12:05 PM
# 1 Logging On                                           12:05 PM                       12:15 PM
# 1 Email Settings                                       12:15 PM                       12:20 PM
# 1 Verify User Groups                                   12:20 PM                       12:25 PM
# 1 Protocol Completion                                  12:25 PM                       12:35 PM
# 1 Document Approvals                                   12:35 PM                       12:45 PM
# 1 Test Equipment                                       12:45 PM                       01:15 PM
# 1 Power On                                             01:15 PM                       01:25 PM
# 1 Vessel Fit                                           01:25 PM                       01:35 PM
# 1 Level Verification                                   01:35 PM                       01:45 PM
# 1 Agitation Control                                    01:45 PM                       02:05 PM
# 1 Transfer Config Files                                02:05 PM                       02:25 PM
# 1 Temp Setup                                           02:25 PM                       02:30 PM
# 1 Temp Wait 1                                          02:30 PM                       09:00 PM para
# 2 Document Approvals                                   02:30 PM                       02:40 PM
# 2 Test Equipment                                       02:40 PM                       02:50 PM
# 2 System Accessories                                   02:50 PM                       03:00 PM
# 2 Product Info                                         03:00 PM                       03:10 PM
# 2 Physical inspection                                  03:10 PM                       03:30 PM
# 2 Plant utilities                                      03:30 PM                       03:40 PM
# 2 Gas Lines                                            03:40 PM                       04:00 PM
# 2 Bios Config / battery                                04:00 PM                       04:10 PM
# 2 Power Up                                             04:10 PM                       04:20 PM
# 2 Software verif                                       04:20 PM                       04:25 PM
# 2 OS Config                                            04:25 PM                       04:30 PM
# 2 McAfee Config                                        04:30 PM                       04:35 PM
# 2 Inbound Firewall                                     04:35 PM                       04:45 PM
# 2 Outbound Firewall                                    04:45 PM                       04:55 PM
# 2 System Vars                                          04:55 PM                       05:05 PM
# 2 Alarms Off                                           05:05 PM                       05:15 PM
# 2 Alarms On                                            05:15 PM                       05:25 PM
# 2 Logging Off                                          05:25 PM                       05:35 PM
# 2 Logging On                                           05:35 PM                       05:45 PM
# 2 Email Settings                                       05:45 PM                       05:50 PM
# 2 Verify User Groups                                   05:50 PM                       05:55 PM
# 1 Temp Check                                           09:00 AM                       09:25 AM
# 1 Temp Wait 2                                          09:25 AM                       01:25 PM para
# 2 Protocol Completion                                  09:25 AM                       09:35 AM
# 2 Document Approvals                                   09:35 AM                       09:45 AM
# 2 Test Equipment                                       09:45 AM                       10:15 AM
# 2 Power On                                             10:15 AM                       10:25 AM
# 2 Vessel Fit                                           10:25 AM                       10:35 AM
# 2 Level Verification                                   10:35 AM                       10:45 AM
# 2 Agitation Control                                    10:45 AM                       11:05 AM
# 2 Transfer Config Files                                11:05 AM                       11:25 AM
# 2 Temp Setup                                           11:25 AM                       11:30 AM
# 2 Temp Wait 1                                          11:30 AM                       06:00 PM para
# 3 Document Approvals                                   11:30 AM                       11:40 AM
# 3 Test Equipment                                       11:40 AM                       11:50 AM
# 3 System Accessories                                   11:50 AM                       12:00 PM
# 3 Product Info                                         12:00 PM                       12:10 PM
# 3 Physical inspection                                  12:10 PM                       12:30 PM
# 3 Plant utilities                                      12:30 PM                       12:40 PM
# 3 Gas Lines                                            12:40 PM                       01:00 PM
# 3 Bios Config / battery                                01:00 PM                       01:10 PM
# 3 Power Up                                             01:10 PM                       01:20 PM
# 3 Software verif                                       01:20 PM                       01:25 PM
# 1 Temp Check 2                                         01:25 PM                       01:50 PM
# 1 pH / DO Sensor Input                                 01:50 PM                       01:55 PM
# 1 pH Setup                                             01:55 PM                       02:05 PM
# 1 pH Wait 1                                            02:05 PM                       03:05 PM para
# 3 OS Config                                            02:05 PM                       02:10 PM
# 3 McAfee Config                                        02:10 PM                       02:15 PM
# 3 Inbound Firewall                                     02:15 PM                       02:25 PM
# 3 Outbound Firewall                                    02:25 PM                       02:35 PM
# 3 System Vars                                          02:35 PM                       02:45 PM
# 3 Alarms Off                                           02:45 PM                       02:55 PM
# 3 Alarms On                                            02:55 PM                       03:05 PM
# 1 pH Check                                             03:05 PM                       03:10 PM
# 1 DO Setup                                             03:10 PM                       03:20 PM
# 1 DO Wait 1                                            03:20 PM                       04:00 PM para
# 3 Logging Off                                          03:20 PM                       03:30 PM
# 3 Logging On                                           03:30 PM                       03:40 PM
# 3 Email Settings                                       03:40 PM                       03:45 PM
# 3 Verify User Groups                                   03:45 PM                       03:50 PM
# 3 Protocol Completion                                  03:50 PM                       04:00 PM
# 1 DO Check 1                                           04:00 PM                       04:05 PM
# 1 DO Wait 2                                            04:05 PM                       04:45 PM para
# 3 Document Approvals                                   04:05 PM                       04:15 PM
# 3 Test Equipment                                       04:15 PM                       04:45 PM
# 1 DO Check 2                                           04:45 PM                       04:50 PM
# 1 Gas Request                                          04:50 PM                       04:55 PM
# 1 Gas Flow Accuracy                                    04:55 PM                       05:10 PM
# 1 Pumps                                                05:10 PM                       05:15 PM
# 1 Filter Oven Setup                                    05:15 PM                       05:20 PM
# 1 Filter Oven Wait                                     05:20 PM                       06:20 PM para
# 3 Power On                                             05:20 PM                       05:30 PM
# 3 Vessel Fit                                           05:30 PM                       05:40 PM
# 3 Level Verification                                   05:40 PM                       05:50 PM
# 1 Filter Oven Check                                    09:00 AM                       09:05 AM
# 1 Recipe Verification                                  09:05 AM                       09:10 AM
# 1 Power Loss & Restore                                 09:10 AM                       09:25 AM
# 1 Interlocks                                           09:25 AM                       09:35 AM
# 1 Process Alarms                                       09:35 AM                       09:45 AM
# 1 Clear Alarms                                         09:45 AM                       09:50 AM
# 1 Cleanup                                              09:50 AM                       10:00 AM
# 1 Flash Drive Verif                                    10:00 AM                       10:10 AM
# 1 Protocol Completion                                  10:10 AM                       10:20 AM
# 2 Temp Check                                           10:20 AM                       10:45 AM
# 2 Temp Wait 2                                          10:45 AM                       02:45 PM para
# 3 Agitation Control                                    10:45 AM                       11:05 AM
# 3 Transfer Config Files                                11:05 AM                       11:25 AM
# 3 Temp Setup                                           11:25 AM                       11:30 AM
# 3 Temp Wait 1                                          11:30 AM                       06:00 PM para
# 4 Document Approvals                                   11:30 AM                       11:40 AM
# 4 Test Equipment                                       11:40 AM                       11:50 AM
# 4 System Accessories                                   11:50 AM                       12:00 PM
# 4 Product Info                                         12:00 PM                       12:10 PM
# 4 Physical inspection                                  12:10 PM                       12:30 PM
# 4 Plant utilities                                      12:30 PM                       12:40 PM
# 4 Gas Lines                                            12:40 PM                       01:00 PM
# 4 Bios Config / battery                                01:00 PM                       01:10 PM
# 4 Power Up                                             01:10 PM                       01:20 PM
# 4 Software verif                                       01:20 PM                       01:25 PM
# 4 OS Config                                            01:25 PM                       01:30 PM
# 4 McAfee Config                                        01:30 PM                       01:35 PM
# 4 Inbound Firewall                                     01:35 PM                       01:45 PM
# 4 Outbound Firewall                                    01:45 PM                       01:55 PM
# 4 System Vars                                          01:55 PM                       02:05 PM
# 4 Alarms Off                                           02:05 PM                       02:15 PM
# 4 Alarms On                                            02:15 PM                       02:25 PM
# 4 Logging Off                                          02:25 PM                       02:35 PM
# 4 Logging On                                           02:35 PM                       02:45 PM
# 2 Temp Check 2                                         02:45 PM                       03:10 PM
# 2 pH / DO Sensor Input                                 03:10 PM                       03:15 PM
# 2 pH Setup                                             03:15 PM                       03:25 PM
# 2 pH Wait 1                                            03:25 PM                       04:25 PM para
# 4 Email Settings                                       03:25 PM                       03:30 PM
# 4 Verify User Groups                                   03:30 PM                       03:35 PM
# 4 Protocol Completion                                  03:35 PM                       03:45 PM
# 4 Document Approvals                                   03:45 PM                       03:55 PM
# 4 Test Equipment                                       03:55 PM                       04:25 PM
# 2 pH Check                                             04:25 PM                       04:30 PM
# 2 DO Setup                                             04:30 PM                       04:40 PM
# 2 DO Wait 1                                            04:40 PM                       05:20 PM para
# 4 Power On                                             04:40 PM                       04:50 PM
# 4 Vessel Fit                                           04:50 PM                       05:00 PM
# 4 Level Verification                                   05:00 PM                       05:10 PM
# 4 Agitation Control                                    05:10 PM                       05:30 PM
# 2 DO Check 1                                           05:30 PM                       05:35 PM
# 2 DO Wait 2                                            05:35 PM                       06:15 PM para
# 4 Transfer Config Files                                05:35 PM                       05:55 PM
# 2 DO Check 2                                           09:00 AM                       09:05 AM
# 2 Gas Request                                          09:05 AM                       09:10 AM
# 2 Gas Flow Accuracy                                    09:10 AM                       09:25 AM
# 2 Pumps                                                09:25 AM                       09:30 AM
# 2 Filter Oven Setup                                    09:30 AM                       09:35 AM
# 2 Filter Oven Wait                                     09:35 AM                       10:35 AM para
# 3 Temp Check                                           09:35 AM                       10:00 AM
# 3 Temp Wait 2                                          10:00 AM                       02:00 PM para
# 4 Temp Setup                                           10:00 AM                       10:05 AM
# 4 Temp Wait 1                                          10:05 AM                       04:35 PM para
# 2 Filter Oven Check                                    10:35 AM                       10:40 AM
# 2 Recipe Verification                                  10:40 AM                       10:45 AM
# 2 Power Loss & Restore                                 10:45 AM                       11:00 AM
# 2 Interlocks                                           11:00 AM                       11:10 AM
# 2 Process Alarms                                       11:10 AM                       11:20 AM
# 2 Clear Alarms                                         11:20 AM                       11:25 AM
# 2 Cleanup                                              11:25 AM                       11:35 AM
# 2 Flash Drive Verif                                    11:35 AM                       11:45 AM
# 2 Protocol Completion                                  11:45 AM                       11:55 AM
# 3 Temp Check 2                                         02:00 PM                       02:25 PM
# 3 pH / DO Sensor Input                                 02:25 PM                       02:30 PM
# 3 pH Setup                                             02:30 PM                       02:40 PM
# 3 pH Wait 1                                            02:40 PM                       03:40 PM para
# 3 pH Check                                             03:40 PM                       03:45 PM
# 3 DO Setup                                             03:45 PM                       03:55 PM
# 3 DO Wait 1                                            03:55 PM                       04:35 PM para
# 3 DO Check 1                                           04:35 PM                       04:40 PM
# 3 DO Wait 2                                            04:40 PM                       05:20 PM para
# 4 Temp Check                                           04:40 PM                       05:05 PM
# 4 Temp Wait 2                                          05:05 PM                       09:05 PM para
# 3 DO Check 2                                           05:20 PM                       05:25 PM
# 3 Gas Request                                          05:25 PM                       05:30 PM
# 3 Gas Flow Accuracy                                    05:30 PM                       05:45 PM
# 3 Pumps                                                05:45 PM                       05:50 PM
# 3 Filter Oven Setup                                    05:50 PM                       05:55 PM
# 3 Filter Oven Wait                                     05:55 PM                       06:55 PM para
# 3 Filter Oven Check                                    09:00 AM                       09:05 AM
# 3 Recipe Verification                                  09:05 AM                       09:10 AM
# 3 Power Loss & Restore                                 09:10 AM                       09:25 AM
# 3 Interlocks                                           09:25 AM                       09:35 AM
# 3 Process Alarms                                       09:35 AM                       09:45 AM
# 3 Clear Alarms                                         09:45 AM                       09:50 AM
# 3 Cleanup                                              09:50 AM                       10:00 AM
# 3 Flash Drive Verif                                    10:00 AM                       10:10 AM
# 3 Protocol Completion                                  10:10 AM                       10:20 AM
# 4 Temp Check 2                                         10:20 AM                       10:45 AM
# 4 pH / DO Sensor Input                                 10:45 AM                       10:50 AM
# 4 pH Setup                                             10:50 AM                       11:00 AM
# 4 pH Wait 1                                            11:00 AM                       12:00 PM para
# 4 pH Check                                             12:00 PM                       12:05 PM
# 4 DO Setup                                             12:05 PM                       12:15 PM
# 4 DO Wait 1                                            12:15 PM                       12:55 PM para
# 4 DO Check 1                                           12:55 PM                       01:00 PM
# 4 DO Wait 2                                            01:00 PM                       01:40 PM para
# 4 DO Check 2                                           01:40 PM                       01:45 PM
# 4 Gas Request                                          01:45 PM                       01:50 PM
# 4 Gas Flow Accuracy                                    01:50 PM                       02:05 PM
# 4 Pumps                                                02:05 PM                       02:10 PM
# 4 Filter Oven Setup                                    02:10 PM                       02:15 PM
# 4 Filter Oven Wait                                     02:15 PM                       03:15 PM para
# 4 Filter Oven Check                                    03:15 PM                       03:20 PM
# 4 Recipe Verification                                  03:20 PM                       03:25 PM
# 4 Power Loss & Restore                                 03:25 PM                       03:40 PM
# 4 Interlocks                                           03:40 PM                       03:50 PM
# 4 Process Alarms                                       03:50 PM                       04:00 PM
# 4 Clear Alarms                                         04:00 PM                       04:05 PM
# 4 Cleanup                                              04:05 PM                       04:15 PM
# 4 Flash Drive Verif                                    04:15 PM                       04:25 PM
# 4 Protocol Completion                                  04:25 PM                       04:35 PM

# %%
def paste(values):
    c1 = xl.Selection
    c2 = c1.Offset(len(values), len(values[0]))
    cr = c1.Parent.Cells.Range
    cr(c1, c2).Value = values
paste(out)

# %%
def RGB(red, green, blue):
    return (red << 16) | (green << 8) | blue
# Out:
# (1, 'Document Approvals', 0.006944444444444444, '12/06/18 09:00:00 AM')

# %%
colors = {
    '1':(255,0,0),
    '2':(0,255,0),
    '3':(0,0,255),
    '4':(120,120,0),
}

ws = wb.Worksheets("Gantt2")
chart = ws.ChartObjects(ws.ChartObjects().Count).Chart
series = chart.SeriesCollection("Duration")
for x, p in zip(series.XValues, series.Points()):
    r,g,b = colors[x[1]]
    p.Interior.Color = RGB(r,g,b)
