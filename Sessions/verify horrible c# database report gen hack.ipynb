# %%
import os, itertools
os.chdir("C:\\Users\\Nathan\\Documents\\Personal\\test")

# %%
def get_line(f):
    with open(f, 'r') as f:
        return f.read().splitlines()

def get_lines():
    lines = get_line('test_out.csv')
    lines2 = get_line('test_out2.csv')
    return lines, lines2

# %%
def compare(i):
    return l1[i] == l2[i]

def compareline(i):
    for j, (a,b) in enumerate(itertools.zip_longest(l1[i], l2[i], fillvalue="")):
        if a != b:
            print(j, a, b)
            
def comparerng(i, a,b):
    print(l1[i][a:b])
    print(l2[i][a:b])

# %%
l1, l2 = get_lines()

# %%
compare(0)
# Out:
# True

# %%
len(l1)
# Out:
# 420

# %%
len(l2)
# Out:
# 420

# %%
for i in range(420):
    print(i, compare(i))
# Out:
# 0 True
# 1 True
# 2 True
# 3 True
# 4 True
# 5 True
# 6 True
# 7 True
# 8 True
# 9 True
# 10 True
# 11 True
# 12 True
# 13 True
# 14 True
# 15 True
# 16 True
# 17 True
# 18 True
# 19 True
# 20 True
# 21 True
# 22 True
# 23 True
# 24 True
# 25 True
# 26 True
# 27 True
# 28 True
# 29 True
# 30 True
# 31 True
# 32 True
# 33 True
# 34 True
# 35 True
# 36 True
# 37 True
# 38 True
# 39 True
# 40 True
# 41 True
# 42 True
# 43 True
# 44 True
# 45 True
# 46 True
# 47 True
# 48 True
# 49 True
# 50 True
# 51 True
# 52 True
# 53 True
# 54 True
# 55 True
# 56 True
# 57 True
# 58 True
# 59 True
# 60 True
# 61 True
# 62 True
# 63 True
# 64 True
# 65 True
# 66 True
# 67 True
# 68 True
# 69 True
# 70 True
# 71 True
# 72 True
# 73 True
# 74 False
# 75 True
# 76 True
# 77 True
# 78 True
# 79 True
# 80 True
# 81 True
# 82 True
# 83 True
# 84 True
# 85 True
# 86 True
# 87 True
# 88 True
# 89 True
# 90 True
# 91 True
# 92 True
# 93 True
# 94 True
# 95 True
# 96 True
# 97 True
# 98 True
# 99 True
# ...

# %%
compareline(273)
# Out:
# 4494   ,
# 4495 1 3
# 4496 2 3
# 4497 : 3
# 4498 0 .
# 4499 0 1
# 4500 : 1
# 4501 0 9
# 4502 0 6
# 4503   2
# 4504 A 9
# 4505 M ,
# 4507 3 1
# 4508 3 /
# 4510 . /
# 4511 1 2
# 4512 1 0
# 4513 9 1
# 4514 6 8
# 4515 2
# 4517 , :
# 4518 , 0
# 4520 / :
# 4522 / 5
# 4523 2
# 4524 0 P
# 4525 1 M
# 4526 8 ,
# 4527   3
# 4528 9 7
# 4529 : 9
# 4530 0 .
# 4532 : 4
# 4534 5 3
# 4535   4
# 4536 P 1
# 4537 M ,
# 4539 3 1
# 4540 7 /
# 4541 9 3
# 4542 . /
# 4543 1 2
# 4544 4 0
# 4545 3 1
# 4546 3 8
# 4547 4
# 4548 1 8
# 4549 , :
# 4550 , 0
# 4551 1 5
# 4552 / :
# 4553 3 4
# 4554 / 6
# 4555 2
# 4556 0 P
# 4557 1 M
# 4558 8 ,
# 4559   4
# 4560 8 6
# 4561 : 9
# 4562 0 .
# 4563 5 1
# 4564 : 2
# 4565 4 5
# 4566 6 8
# 4567   2
# 4568 P 4
# 4569 M ,
# 4571 4 1
# 4572 6 /
# 4573 9 3
# 4574 . /
# 4575 1 2
# 4576 2 0
# 4577 5 1
# 4579 2
# 4580 4 8
# 4581 , :
# 4582 , 1
# 4583 1 7
# 4584 / :
# 4585 3 4
# 4586 / 5
# 4587 2
# 4588 0 P
# 4589 1 M
# 4590 8 ,
# 4591   -
# 4593 : 5
# 4594 1 6
# 4595 7 .
# 4596 : 1
# ...

# %%
comparerng(273, 4490, 4490+50)
# Out:
# 2018 12:00:00 AM,333.119629,,1/3/2018 9:01:35 PM,3
# 2018,333.119629,,1/3/2018 9:01:35 PM,379.143341,,1

# %%
for i in range(70, 77):
    print(i, compare(i))
# Out:
# 70 True
# 71 True
# 72 True
# 73 True
# 74 False
# 75 True
# 76 True
