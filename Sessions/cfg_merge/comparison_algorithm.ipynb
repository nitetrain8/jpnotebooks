# %%
import collections
import inspect
OD = collections.OrderedDict

def _nargs(f):
    return len(inspect.signature(f).parameters)

def _derr(*args):
    if args[0] is None:
        print("Got NONE argument")
        raise
    else:
        print("ERROR: argument %s is incorrect in some way!" % args[0])
        import pdb; pdb.set_trace()
    # dummy lines to allower user to examine the arg stack without
    # leaving by mistake
    args
    args
    
class NotFound(KeyError):
    """ Signal that variable was not found in the list.
    To be raised by user code as a signal to `compare_lists`. 
    """
    pass

NotFoundErrors = (NotFound, KeyError, IndexError)

def _equal(a,b):
    return a == b

def _skipvar(v):
    return False

def _getvar(l,v):
    return l[v]

def _special(v):
    return None

def _notfound(v):
    return "", "", "", "Not Found"

def _str(v):
    """ Wrapper to allow default argument to be inspectable for debug purposes ... """
    return str(v)

def compare_lists(cf, of, nf, getvar=_getvar, var2str=_str, skipvar=_skipvar, 
                  vequal=_equal, special=_special, notfound=_notfound, out=print, setvar=lambda a,b:None):
    
    """ Fill in callables!!!
    Copy the templates below....
    
    def getvar(l, v):
        return l[v]
    def var2str(vval):
        return str(vval)
    def skipvar(vname):
        return False
    def vequal(vval, vval2):
        return vval == vval2
    def special(vname):
        return False
    def notfound(vname):
        return "", "", "", "Not Found"
    def out(s):
        print(s)
    """
    
    # sanity check the arguments, since this function is somewhat abstract
    assert isinstance(cf, dict), _derr(cf)
    assert isinstance(of, dict), _derr(of)
    assert isinstance(nf, dict), _derr(nf)
    assert callable(getvar) and _nargs(getvar) == 2, _derr(getvar)
    assert callable(var2str) and _nargs(var2str) == 1, _derr(var2str)
    assert callable(skipvar) and _nargs(skipvar) == 1, _derr(skipvar)  
    assert callable(vequal) and _nargs(vequal) == 2, _derr(vequal)
    assert callable(special) and _nargs(special) == 1, _derr(special)
    assert callable(notfound) and _nargs(notfound) == 1, _derr(notfound)
    assert callable(setvar) and _nargs(setvar) == 2, _derr(setvar)

    olines = []
    wvar = len("Variable")  # min width is width of the header
    for name in nf:
        if skipvar(name):
            continue
        cs = os = ns = m = ""
        s = special(name)
        if s is not None and s is not False:
            cs, os, ns, m = s
        else:
            try:
                cv = getvar(cf, name)
                ov = getvar(of, name)
                nv = getvar(nf, name)
            except NotFoundErrors:
                cs, os, ns, m = notfound(name)
            else:
                if vequal(nv, ov) and vequal(ov, cv):
                    cs = os = ns = ""
                    m = "No Change"
                elif not vequal(nv, ov) and vequal(ov, cv):
                    cs = ""
                    os = var2str(ov)
                    ns = var2str(nv)
                    m  = "N    N"
                elif vequal(nv, ov) and not vequal(ov, cv):
                    cs = var2str(cv)
                    os = ""
                    ns = var2str(nv)
                    m  = "N    Y"
                elif vequal(nv, cv) and not vequal(ov, cv):
                    cs = var2str(cv)
                    os = ""
                    ns = var2str(nv)
                    m  = "Y    N"
                elif not vequal(nv, cv) and not vequal(cv, ov):
                    cs = var2str(cv)
                    os = var2str(ov)
                    ns = var2str(nv)
                    m  = "N    N"
                else:
                    # should be unreachable
                    cs = var2str(cv)
                    os = var2str(ov)
                    ns = var2str(nv)
                    m  = "???"
        olines.append((name, cs, os, ns, m))
        wvar = max(wvar, len(name))
            
            # todo - variable column width 
#             wc1  = max(wc1, len(cs))
#             wc2  = max(wc2, len(os))
#             wc3  = max(wc3, len(ns))
#             wc4  = max(wc4, len(m))
                
    linefmt = "%%-%ds: %%-10s| %%-10s| %%-10s| %%-10s| " % (wvar + 1)
    w1 = 10
    w2 = 10
    w3 = 10
    w4 = 10
    linefmt = "%%-%ds: %%-%ds| %%-%ds| %%-%ds| %%-%ds|  " % (wvar + 1, w1, w2, w3, w4)
    header1 = "%-*s  %-*s  %-*s  %-*s  %-*s  " % (wvar + 1, "", w1, "", w2, "Contents", w3, "", w4, "Matches") + "Restore"
    header2 = linefmt%("Variable", "Cust File", "Old File", "New File", "USR  PBS") + "Action"
    header3 = len(header2) * "-"

    out(header1)
    out(header2)
    out(header3)
    for l in olines:
        out(linefmt%l)

# %%
from jpnotebooks.Sessions.cfg_merge.sys_vars import _parse_sysvars
from jpnotebooks.Sessions.cfg_merge.lv_parse import flatten as lv_flatten

def compare_sysvars(cff, off, nff):
    """
    Since the naming is confusing in this function
    and compare_sysvars2, let me explain:
    
    There are 4 levels of xxxf variables:
        xxxf (parameter) -> dict of all files in folder
         xff             -> filename of sys vars file
         xLV             -> parsed contents of file (LVType)
          xf             -> flattened, parsed contents (OrderdDict)
          
    All the comparison functions can follow the same basic template:
     1) callback functions for compare_lists (verify var2str and vequal, they're important!)
     2) take the filename for each file and parse it into a dict of dotted names -> values,
        e.g. Agitation.Minimum(RPM) -> 3. No nesting!
     3) Call compare_lists
     
    Sys vars is a bit special, since the output has to be "XML" and 
    Type information would be lost if we just flattened straight to python values 
    (e.g. I32 vs I16, etc). So, the value passed in the list is the LVType, and the callbacks
    extract the value where appropriate. 
    """
    # callbacks for compare_lists
    def getvar(l, v): return l[v]
    def var2str(vval): return vval.tostr()                         # vvals are LVType, not str!
    def skipvar(vname): return False
    def vequal(vval, vval2): return vval.tostr() == vval2.tostr()  # vvals are LVType, not str!
    def special(vname): return False
    def notfound(vname): return "", "", "", "Not Found"
    def out(s): print(s)
        
    # parse scheme for sys vars file
    def parse_sysvars(ff): return _parse_sysvars(ff)  # was already programmed :)
    def _flatten(LV):
        d = OD()
        for g in LV.val:
            for v in g.val:
                d[g.name+"."+v.name] = v
        return d
            
    # prepare the list (dict) for compare_lists...
    cLV = _parse_sysvars(cff)
    oLV = _parse_sysvars(off)
    nLV = _parse_sysvars(nff)
    
    cf  = _flatten(cLV)
    of  = _flatten(oLV)
    nf  = _flatten(nLV)
    
    compare_lists(cf, of, nf, getvar, var2str, skipvar, vequal, special, notfound, out)
    
def compare_sysvars2(custf, oldf, newf):
    cff = custf['system variables']
    off =  oldf['system variables']
    nff =  newf['system variables']
    return compare_sysvars(cff, off, nff)

# %%
# PBS 3 CDI 3
# Example using PBS 3 CDI 3
cff = 'D:\\Customer_Backups\\000311T2902 180102\\Rio_Config\\System Variables.cfg'
off = 'D:\\auto_hd_install\\default configs\\IC3405 Rev C\\Mag 3 150727\\System Variables.cfg'
nff = 'd:\\auto_hd_install\\default configs\\IM00226 Rev B\\Mag 3\\System Variables.sys'
compare_sysvars(cff, off, nff)
# Out:
#                                                        Contents                Matches     Restore
# Variable                                 : Cust File | Old File  | New File  | USR  PBS  |  Action
# --------------------------------------------------------------------------------------------------
# Temperature.P Gain (%/C)                 :           | 40.00000  | 50.00000  | N    N    |
# Temperature.I Time (min)                 :           | 6.00000   | 26.00000  | N    N    |
# Temperature.D Time (min)                 :           |           |           | No Change |
# Temperature.Alpha                        :           |           |           | Not Found |
# Temperature.Beta                         :           |           |           | Not Found |
# Temperature.Gamma                        :           |           |           | Not Found |
# Temperature.Linearity                    :           |           |           | Not Found |
# Temperature.Heat Manual Max (%)          :           |           |           | No Change |
# Temperature.Heat Auto Max (%)            :           |           |           | No Change |
# Temperature.Valid High (C)               :           |           |           | No Change |
# Temperature.Valid Low (C)                :           |           |           | No Change |
# Temperature.Mismatch Thresh (C)          :           |           |           | Not Found |
# Filter Oven.P Gain (%/C)                 :           |           |           | No Change |
# Filter Oven.I Time (min)                 :           |           |           | No Change |
# Filter Oven.D Time (min)                 :           |           |           | No Change |
# Filter Oven.Alpha                        :           |           |           | Not Found |
# Filter Oven.Beta                         :           |           |           | Not Found |
# Filter Oven.Gamma                        :           |           |           | Not Found |
# Filter Oven.Linearity                    :           |           |           | Not Found |
# Filter Oven.Heat Manual Max (%)          :           |           |           | No Change |
# Filter Oven.Heat Auto Max (%)            :           |           |           | No Change |
# Agitation.P Gain (%/RPM)                 :           |           |           | Not Found |
# Agitation.I Time (min)                   :           | 5.00000e-03| 1.00000e-02| N    N    |
# Agitation.D Time (min)                   :           |           |           | No Change |
# Agitation.Alpha                          :           |           |           | Not Found |
# Agitation.Beta                           :           |           |           | Not Found |
# Agitation.Gamma                          :           |           |           | Not Found |
# Agitation.Linearity                      :           |           |           | Not Found |
# Agitation.Minimum (RPM)                  : 2.00000   |           | 3.00000   | N    Y    |
# Agitation.Pulse Mode Timeout (s)         :           |           |           | No Change |
# Agitation.Lookup Mode Timeout (s)        :           |           |           | No Change |
# Agitation.Lookup Factor (%/RPM)          :           |           |           | No Change |
# Agitation.Power Auto Max (%)             :           |           |           | No Change |
# Agitation.Power Auto Min (%)             :           |           |           | No Change |
# Agitation.Auto Max Startup (%)           :           | 17.00000  | 20.00000  | N    N    |
# Agitation.Power Manual Max (%)           :           |           |           | No Change |
# Agitation.Number of Magnets              :           |           |           | No Change |
# Agitation.Samples To Average             :           | 1         | 3         | N    N    |
# pH.Mismatch Thresh                       :           |           |           | Not Found |
# pH.Rate Fail Delta PV                    :           |           |           | Not Found |
# pH.Rate Fail Delta Time (s)              :           |           |           | Not Found |
# pH.CO2 P Gain (%/pH)                     :           | -2.00000e+02| 15.00000  | N    N    |
# pH.CO2 I Time (min)                      :           | 2.00000   | 80.00000  | N    N    |
# pH.CO2 D Time (min)                      :           |           |           | No Change |
# pH.CO2 Alpha                             :           |           |           | Not Found |
# pH.CO2 Beta                              :           |           |           | Not Found |
# pH.CO2 Gamma                             :           |           |           | Not Found |
# pH.CO2 Linearity                         :           |           |           | Not Found |
# pH.CO2 Manual Max (%)                    :           |           |           | No Change |
# pH.CO2 Auto Max (%)                      : 7.50000   | 30.00000  | 100.00000 | N    N    |
# pH.Base P Gain (%/pH)                    :           | 10.00000  | -1.00000e+01| N    N    |
# pH.Base I Time (min)                     :           | 10.00000  | 80.00000  | N    N    |
# pH.Base D Time (min)                     :           |           |           | No Change |
# pH.Base Alpha                            :           |           |           | Not Found |
# pH.Base Beta                             :           |           |           | Not Found |
# pH.Base Gamma                            :           |           |           | Not Found |
# pH.Base Linearity                        :           |           |           | Not Found |
# pH.Base Manual Max (%)                   : 0.00000e+00|           | 50.00000  | N    Y    |
# pH.Base Auto Max (%)                     : 0.00000e+00|           | 50.00000  | N    Y    |
# pH.A Use Temp Comp?                      :           |           |           | No Change |
# pH.B Use Temp Comp?                      :           |           |           | No Change |
# pH.Deadband                              : 1.00000e-02|           | 2.00000e-02| N    Y    |
# pH.Valid High (pH)                       :           |           |           | No Change |
# pH.Valid Low (pH)                        :           |           |           | No Change |
# DO.Mismatch Thresh (DO%)                 :           |           |           | Not Found |
# DO.Valid High (DO%)                      :           |           |           | No Change |
# DO.Valid Low (DO%)                       :           |           |           | No Change |
# DO.O2 P Gain (%/DO%)                     :           |           |           | Not Found |
# DO.O2 I Time (min)                       :           | 1.00000e-01| 120.00000 | N    N    |
# DO.O2 D Time (min)                       :           |           |           | No Change |
# DO.O2 Alpha                              :           |           |           | Not Found |
# DO.O2 Beta                               :           |           |           | Not Found |
# DO.O2 Gamma                              :           |           |           | Not Found |
# DO.O2 Linearity                          :           |           |           | Not Found |
# DO.O2 Manual Max (%)                     :           |           |           | Not Found |
# DO.O2 Auto Max (%)                       :           |           |           | Not Found |
# DO.N2 P Gain (%/DO%)                     :           |           |           | No Change |
# DO.N2 I Time (min)                       : 1.00000   | 10.00000  | 50.00000  | N    N    |
# DO.N2 D Time (min)                       :           |           |           | No Change |
# DO.N2 Alpha                              :           |           |           | Not Found |
# DO.N2 Beta                               :           |           |           | Not Found |
# DO.N2 Gamma                              :           |           |           | Not Found |
# DO.N2 Linearity                          :           |           |           | Not Found |
# DO.N2 Manual Max (%)                     :           |           |           | No Change |
# DO.N2 Auto Max (%)                       : 100.00000 |           | 100.00000 | Y    N    |
# DO.Deadband (DO%)                        :           |           |           | No Change |
# Level.Radius (cm)                        :           |           |           | No Change |
# Level.Empty Level (V)                    :           |           |           | No Change |
# Level.Empty Level (L)                    :           |           |           | No Change |
# Level.cm/psi                             :           |           |           | No Change |
# Level.Vessel Depth (cm)                  :           |           |           | No Change |
# Level.Bottom Gap (cm)                    :           |           |           | No Change |
# Level.Enable Sensor (0 or 1)             :           |           |           | No Change |
# Level.CalLevelSlopeMax(psi/V)            :           |           |           | No Change |
# Level.CalLevelSlopeMin(psi/V)            :           |           |           | No Change |
# Level.CalLevelInterceptMax(psi)          :           |           |           | No Change |
# Level.CalLevelInterceptMin(psi)          :           |           |           | No Change |
# Pressure.Disconnected Pressure (V)       :           |           |           | No Change |
# Pressure.CalPressureInterceptMax(psi)    :           |           |           | No Change |
# Pressure.CalPressureInterceptMin(psi)    :           |           |           | No Change |
# Pressure.CalPressureSlopeMax(psi/V)      :           |           |           | No Change |
# Pressure.CalPressureSlopeMin(psi/V)      :           |           |           | No Change |
# Pressure.Reusable Sensor (0 or 1)        :           |           |           | No Change |
# Gas Data.CO2 Min (LPM)                   : 3.00000e-02|           | 3.00000e-02| Y    N    |
# Gas Data.CO2 Off (V)                     :           |           |           | No Change |
# Gas Data.N2 Min (LPM)                    :           |           |           | No Change |
# Gas Data.N2 Off (V)                      :           |           |           | No Change |
# Gas Data.Air Min (LPM)                   :           |           |           | No Change |
# Gas Data.Air Off (V)                     :           |           |           | No Change |
# Gas Data.O2 Min (LPM)                    :           |           |           | No Change |
# Gas Data.O2 Off (V)                      :           |           |           | No Change |
# Gas Data.PWM On Time (s)                 :           | 3.00000   | 10.00000  | N    N    |
# Gas Data.PWM Max Period (s)              :           | 60.00000  | 200.00000 | N    N    |
# Gas Data.Mismatch Thresh (V)             : 2.00000e-01|           | 1.00000e-01| N    Y    |
# Gas Data.O2 Min Volume (L)               :           |           |           | No Change |
# Gas Data.Manual Max (LPM)                : 1.00000   |           | 5.00000e-01| N    Y    |
# Safety.Min Ag Power (%)                  :           |           |           | No Change |
# Safety.Max Temp (C)                      :           |           |           | Not Found |
# Safety.Max Pressure (psi)                :           |           |           | No Change |
# Safety.Max Pressure Door (psi)           :           |           |           | No Change |
# Safety.Min Level (L)                     :           |           |           | No Change |
# Safety.Max Level (L)                     : 4.00000   |           | 4.00000   | Y    N    |
# Safety.Buzzer Period (ms)                :           |           |           | No Change |
# Safety.DoorPressureSensor (0 or 1)       :           |           |           | No Change |
# Pumps.Aux Low Duty                       :           |           |           | No Change |
# Pumps.Aux Med Duty                       :           |           |           | No Change |
# Pumps.Base On Time (s)                   :           |           |           | No Change |
# Pumps.Base Max Period (s)                :           |           |           | No Change |
# Pumps.Analog Base Speed (RPM)            :           |           |           | No Change |
# Pumps.Sample Reverse CW and CCW (0 or 1) :           |           |           | Not Found |
# Process Alarms.Agitation Low Low (RPM)   : 30.00000  |           | 10.00000  | N    Y    |
# Process Alarms.Agitation Low (RPM)       : 32.00000  |           | 15.00000  | N    Y    |
# Process Alarms.Agitation High (RPM)      : 38.00000  |           | 35.00000  | N    Y    |
# Process Alarms.Agitation High High (RPM) : 40.00000  |           | 38.00000  | N    Y    |
# Process Alarms.Temp Low Low (C)          :           |           |           | No Change |
# Process Alarms.Temp Low (C)              :           |           |           | No Change |
# Process Alarms.Temp High (C)             : 37.10000  |           | 38.00000  | N    Y    |
# Process Alarms.Temp High High (C)        : 37.20000  |           | 39.00000  | N    Y    |
# Process Alarms.DO Low Low (%)            : 70.00000  |           | 30.00000  | N    Y    |
# Process Alarms.DO Low (%)                : 75.00000  |           | 40.00000  | N    Y    |
# Process Alarms.DO High (%)               : 155.00000 |           | 60.00000  | N    Y    |
# Process Alarms.DO High High (%)          : 160.00000 |           | 70.00000  | N    Y    |
# Process Alarms.pH Low Low                : 5.90000   |           | 7.10000   | N    Y    |
# Process Alarms.pH Low                    : 6.00000   |           | 7.15000   | N    Y    |
# Process Alarms.pH High                   : 7.60000   |           | 7.25000   | N    Y    |
# Process Alarms.pH High High              : 7.70000   |           | 7.30000   | N    Y    |
# Process Alarms.Pressure Low Low (psi)    :           |           |           | No Change |
# Process Alarms.Pressure Low (psi)        :           |           |           | No Change |
# Process Alarms.Pressure High (psi)       :           |           |           | No Change |
# Process Alarms.Pressure High High (psi)  :           |           |           | No Change |
# Process Alarms.Level Low Low (L)         : 1.50000   |           | 5.00000e-01| N    Y    |
# Process Alarms.Level Low (L)             : 1.75000   |           | 1.30000   | N    Y    |
# Process Alarms.Level High (L)            : 2.50000   |           | 3.25000   | N    Y    |
# Process Alarms.Level High High (L)       : 2.70000   |           | 3.50000   | N    Y    |
# Process Alarms.Filter Oven Low Low (C)   : 30.00000  |           | 45.00000  | N    Y    |
# Process Alarms.Filter Oven Low (C)       : 37.00000  |           | 47.00000  | N    Y    |
# Process Alarms.Filter Oven High (C)      : 52.00000  |           | 53.00000  | N    Y    |
# Process Alarms.Filter Oven High High (C) :           |           |           | No Change |
# Process Alarms.Main Gas Low Low (LPM)    : 2.00000e-01|           | 5.00000e-02| N    Y    |
# Process Alarms.Main Gas Low (LPM)        : 2.50000e-01|           | 1.00000e-01| N    Y    |
# Process Alarms.Main Gas High (LPM)       : 3.50000e-01|           | 4.00000e-01| N    Y    |
# Process Alarms.Main Gas High High (LPM)  : 4.00000e-01|           | 4.50000e-01| N    Y    |
# System.Max Data Log Interval (min)       :           |           |           | No Change |
# System.Alarm Snooze Time (s)             :           |           |           | No Change |
# System.Available Mem Limit (KB)          :           |           |           | Not Found |
# System.LCB Mem Limit (KB)                :           |           |           | Not Found |

# %%
import collections
import inspect
OD = collections.OrderedDict
from jpnotebooks.Sessions.cfg_merge.sys_vars import _parse_sysvars

class NotFound(KeyError):
    """ Signal that variable was not found in the list.
    To be raised by user code as a signal to `compare_lists`. 
    """
    pass

NotFoundErrors = (NotFound, KeyError, IndexError)

def _update(var, val):
    pass

def merge_lists(cf, of, nf, getvar, skipvar, vequal, notfound, setvar):
    for name in nf:
        if skipvar(name):
            continue
        nv = getvar(nf, name)
        try:
            cv = getvar(cf, name)
            ov = getvar(of, name)
        except NotFoundErrors:
            v = notfound(name)
            if v is None:
                v = nv
        else:
            if vequal(nv, ov) and vequal(ov, cv):
                v = nv
            elif not vequal(nv, ov) and vequal(ov, cv):
                v = nv                
            elif vequal(nv, ov) and not vequal(ov, cv):
                # XXX Conflict
                v = cv
            elif vequal(nv, cv) and not vequal(ov, cv):
                v = nv
            elif not vequal(nv, cv) and not vequal(cv, ov):
                # XXX Conflict
                v = cv
            else:
                # should be unreachable
                raise NameError("Unreachable code for %r"%name)
        setvar(name, v)
    for name in cf:
        if name not in nf:
            notfound(name)
        
        
def merge_sysvars_inner(cf, of, nf, ignore, force):
    ign = frozenset(ignore)
    # Callbacks
    def getvar(f,name):
        return f[name]
    def skipvar(v):
        return v in ign
    def vequal(a,b):
        return a.val == b.val
    def notfound(n):
        if n not in nf:
            print("Old Name: %s"%n)
        return None
    
    def setvar(name, v):
        # only message if value is updated
        if name in force:
            print("Forcing %-45s: %.5f -> %.5f"%(name, nf[name].val, force[name]))
            nf[name].val = force[name]
        elif nf[name].val != v.val:
            print("Updating %-45s: %.5f -> %.5f"%(name, nf[name].val, v.val))
            nf[name] = v
    
    return merge_lists(cf, of, nf, getvar, skipvar, vequal, notfound, setvar)

# %%
def merge_sysvars(cff, off, nff, outf=None, ignore=(), force=None):
    """
    1. Parse
    2. Flatten ("Group.Varname" = "Value")
    3. Merge
    4. Output
    """
    def parse_sysvars(ff): 
        return _parse_sysvars(ff)
    
    def _flatten(LV):
        d = OD()
        for g in LV.val:
            for v in g.val:
                d[g.name+"."+v.name] = v
        return d
            
    cLV = _parse_sysvars(cff)
    oLV = _parse_sysvars(off)
    nLV = _parse_sysvars(nff)
    
    cf  = _flatten(cLV)
    of  = _flatten(oLV)
    nf  = _flatten(nLV)
    merge_sysvars_inner(cf, of, nf, ignore, force or {})

    if outf:
        with open(outf, 'w') as f:
            f.write(nLV.toxml())

# %%
# Example using PBS 3 CDI 3
cff = 'D:\\Customer_Backups\\000311T2902 180102\\Rio_Config\\System Variables.cfg'
off = 'D:\\auto_hd_install\\default configs\\IC3405 Rev C\\Mag 3 150727\\System Variables.cfg'
nff = 'D:\\auto_hd_install\\default configs\\IM00226 Rev B\\Mag 3\\System Variables.sys'
merge_sysvars(cff, off, nff, "test.xml") #, force={"Agitation.Minimum (RPM)": 5}) #, ["Agitation.Minimum (RPM)"])
# Out:
# Updating Agitation.Minimum (RPM)                      : 3.00000 -> 2.00000
# Updating pH.CO2 Auto Max (%)                          : 100.00000 -> 7.50000
# Updating pH.Base Manual Max (%)                       : 50.00000 -> 0.00000
# Updating pH.Base Auto Max (%)                         : 50.00000 -> 0.00000
# Updating pH.Deadband                                  : 0.02000 -> 0.01000
# Updating DO.N2 I Time (min)                           : 50.00000 -> 1.00000
# Updating Gas Data.Mismatch Thresh (V)                 : 0.10000 -> 0.20000
# Updating Gas Data.Manual Max (LPM)                    : 0.50000 -> 1.00000
# Updating Process Alarms.Agitation Low Low (RPM)       : 10.00000 -> 30.00000
# Updating Process Alarms.Agitation Low (RPM)           : 15.00000 -> 32.00000
# Updating Process Alarms.Agitation High (RPM)          : 35.00000 -> 38.00000
# Updating Process Alarms.Agitation High High (RPM)     : 38.00000 -> 40.00000
# Updating Process Alarms.Temp High (C)                 : 38.00000 -> 37.10000
# Updating Process Alarms.Temp High High (C)            : 39.00000 -> 37.20000
# Updating Process Alarms.DO Low Low (%)                : 30.00000 -> 70.00000
# Updating Process Alarms.DO Low (%)                    : 40.00000 -> 75.00000
# Updating Process Alarms.DO High (%)                   : 60.00000 -> 155.00000
# Updating Process Alarms.DO High High (%)              : 70.00000 -> 160.00000
# Updating Process Alarms.pH Low Low                    : 7.10000 -> 5.90000
# Updating Process Alarms.pH Low                        : 7.15000 -> 6.00000
# Updating Process Alarms.pH High                       : 7.25000 -> 7.60000
# Updating Process Alarms.pH High High                  : 7.30000 -> 7.70000
# Updating Process Alarms.Level Low Low (L)             : 0.50000 -> 1.50000
# Updating Process Alarms.Level Low (L)                 : 1.30000 -> 1.75000
# Updating Process Alarms.Level High (L)                : 3.25000 -> 2.50000
# Updating Process Alarms.Level High High (L)           : 3.50000 -> 2.70000
# Updating Process Alarms.Filter Oven Low Low (C)       : 45.00000 -> 30.00000
# Updating Process Alarms.Filter Oven Low (C)           : 47.00000 -> 37.00000
# Updating Process Alarms.Filter Oven High (C)          : 53.00000 -> 52.00000
# Updating Process Alarms.Main Gas Low Low (LPM)        : 0.05000 -> 0.20000
# Updating Process Alarms.Main Gas Low (LPM)            : 0.10000 -> 0.25000
# Updating Process Alarms.Main Gas High (LPM)           : 0.40000 -> 0.35000
# Updating Process Alarms.Main Gas High High (LPM)      : 0.45000 -> 0.40000
# Old Name: Temperature.Max Delta (C)
# Old Name: Temperature.PWM Period (ms)
# Old Name: Filter Oven.PWM Period (ms)
# Old Name: Filter Oven.Enable Heater (0 or 1)
# Old Name: Agitation.P Gain  (%/RPM)
# Old Name: Agitation.Min Mag Interval (s)
# Old Name: pH.Max Delta
# Old Name: pH.Fail Rate (pH/min)
# Old Name: pH.Base Wait Time (s)
# Old Name: DO.Max Delta
# Old Name: DO.O2 P Gain (mLPM/DO%)
# Old Name: DO.O2 Manual Max (mLPM)
# Old Name: DO.O2 Auto Max (mLPM)
# Old Name: Level.LevelTempCompFactor(1/C)
# Old Name: Level.Enable Pressure Differential (0 or 1)
# Old Name: Gas Data.CO2 LPM/V
# Old Name: Gas Data.N2 LPM/V
# Old Name: Gas Data.Air LPM/V
# Old Name: Gas Data.O2 LPM/V
# Old Name: Safety.Main Temp Max (C)
# Old Name: Sample Settings.Presample 1 (s)
# Old Name: Sample Settings.Presample 2 (s)
# Old Name: Sample Settings.Sample Time m (s/mL)
# Old Name: Sample Settings.Sample Time b (s)
# Old Name: Sample Settings.Drain 1 (s)
# Old Name: Sample Settings.Drain 2 (s)
# Old Name: Sample Settings.Reverse CW and CCW (0 or 1)

# %%
import configparser

c = configparser.ConfigParser()

c.read_file("test.sysvars.patch")
