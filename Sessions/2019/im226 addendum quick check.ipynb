# %%
import os
from itertools import zip_longest
from scripts.tools.patcher.src.merge import lv_parse
from collections import OrderedDict

def ld(d):
    for file in os.listdir(d):
        return os.path.join(d, file)
    
    
import difflib
def diff2(a,b):
    if isinstance(a, str):
        a = a.splitlines()
    if isinstance(b, str):
        b = b.splitlines()

    # inserting a blank line here here doesn't impact
    # any real use case, but ensures that the message printed
    # by pytest's assert failure thingy 
    res = [""]
    res.extend(s.strip() for s in difflib.ndiff(a,b) if s[0] in ("+", "-", "?", "!"))
    return res

def diff3(a,b):
    res = diff2(a,b)
    if len(res) == 1 and res[0] == "":  # no diff found
        return ["<Unknown mismatch - processed files are identical. Compare raw text>"]
    return res
    
def rdf(fp):
    with open(fp, 'r') as f:
        return f.read()
rfp = rdf

def loadlv(file, find):
    return lv_parse.lv_parse_string(rfp(find(file)))

def compare(sn):
    l = lvd% sn
    d = rc % sn
    for p in (l,d):
        if not os.path.exists(p):
            print("Error - improper serial number (customer folder not found!)")
            return
    
    def findc(file,dirs=(l,d)):
        for dir in dirs:
            fp = os.path.join(dir, file)
            if os.path.exists(fp):
                return fp
        raise FileNotFoundError(fp)
    
    def findr(file):
        fp = os.path.join(ref, file)
        if not os.path.exists(fp):
            raise FileNotFoundError(fp)
        return fp
    
    t1 = t2 = ""
    def basic(file, cdirs=(l,d), rf=None):
        nonlocal t1, t2
        fc = findc(file, cdirs)
        fr = findr(rf or file)
        t1 = rdf(fc)
        t2 = rdf(fr)
        op = "==" if t1 == t2 else "!="
        print("%-35s: User %s Reference"%(file, op))
        return op == "=="
    
    def b2lv(file):
        return basic(file, (l,))
    
    def b2rc(file):
        return basic(file, (d,))
    
    def b22lv(file):
        return basic2(file, (l,))
    
    def b22rc(file):
        return basic2(file, (d,))
    
    diffs = []
    def basic2(file, cdirs=(l,d), show=True):
        b = basic(file, cdirs)
        if not b and show:
            dl = []
            l1 = t1.splitlines()
            l2 = t2.splitlines()
            for i, (s1, s2) in enumerate(zip_longest(l1, l2, fillvalue=""), 1):
                if s1 != s2:
                    dl.append("Line %d: %r != %r"%(i, s1, s2))
            diffs.append((file, dl))   
        return b
            
    def testlog(file):
        if not basic(file):
            dl = []
            def tabfix(s):
                return s.replace("\t", "    ")
            l1 = list(map(tabfix, t1.splitlines()))
            l2 = list(map(tabfix, t2.splitlines()))
            dl.extend(diff3(l1, l2))            
            if dl:
                diffs.append((file, dl))   
            else:
                # file wasn't sorted properly
                diffs.append((file, ["Improper sort order"]))
            
    def existclv(file):
        fp = os.path.join(l, file)
        if not os.path.exists(fp):
            print("Not found in LabVIEW Data: %s"%file)
        else:
            print("%-35s: Found"%file)
            
    def existcrc(file):
        fp = os.path.join(d, file)
        if not os.path.exists(fp):
            print("Not found in RIO Config: %s"%file)
        else :
            print("%-35s: Found"%file)
            
    def testsv(file):
        if not basic(file, rf="System Variables.sys"):
            lv1 = loadlv(file, findc)
            lv2 = loadlv("System Variables.sys", findr)
            fmt = "%-45s %-6s %-6s != %s"
            dl = [(fmt%("var", "type", "user", "pbs")).replace("!=", "  ")]
            def diff(m, v, a, b):
                if getattr(a, v) != getattr(b, v):
                    dl.append(fmt%(m, v, getattr(a,v), getattr(b,v)))
                    #dl.append("%-20s %s mismatch : %s != %s"%(m, v, getattr(a,v), getattr(b,v)))
            for g1, g2 in zip(lv1, lv2):
                diff("Group", "name", g1, g2)
                diff("Group", "type", g1, g2)
                for v1, v2 in zip(g1, g2):
                    diff("Variable", "name", v1, v2)
                    diff(g1.name+"."+v1.name, "type", v1, v2)
                    diff(g1.name+"."+v1.name, "val", v1, v2)
            diffs.append((file, dl))
            
    def testcal(file):
        if not basic(file):
            lv1 = loadlv(file, findc)
            lv2 = loadlv(file, findr)
            dl = []
            def diff(m, v, a, b):
                if getattr(a, v) != getattr(b, v):
                    dl.append("%-20s %s mismatch : %s != %s"%(m, v, getattr(a,v), getattr(b,v)))
            def diff2(a,b):pass
                
            for rv in lv2:
                cv = lv1.lookup(rv.name)
                diff("Var", "name", rv, cv)
                diff("Var", "type", rv, cv)
                if rv.isiter():
                    for rv2 in rv:
                        cv2 = cv.lookup(rv2.name)
                        diff(rv.name+rv2.name, "name", cv2, rv2)
                        diff(rv.name+rv2.name, "type", cv2, rv2)
                else:
                    diff(rv.name, "name", cv, rv)
                    diff(rv.name, "type", cv, rv)
            if dl:
                diffs.append((file, dl))
            else:
                print("%-35s: File structure verified"%file)
                
    def testrecipes(file):
        if not basic(file, (l,)):
            l1 = t1.splitlines()
            l2 = t2.splitlines()
            crecipe = []
            rrecipe = set()
            dl = []
            for l3 in l1:
                if l3.startswith("Func"):
                    crecipe.append(l3.split(" ",1)[1])
            for l3 in l2:
                if l3.startswith("Func"):
                    rrecipe.add(l3.split(" ", 1)[1])
            for r in crecipe:
                if r not in rrecipe:
                    dl.append("Extra Recipe: %s"%r)
            if dl:
                diffs.append((file, dl))
                    
                
    def findothers():
        xpl = {
            ".alm": ("Alarms On.alm", "Alarms Off.alm"),
            ".sys": ("System Variables.sys",),
            ".log": ("Logging On.log", "Logging Off.log")
        }
        xprc = {
            ".alm": ("Alarms.alm",),
            ".sys": ("System Variables.sys",),
            ".log": ("Logger Settings.log",)
        }
        for xp, dir in zip((xpl, xprc), (l, d)):
            for file in os.listdir(dir):
                ext = os.path.splitext(file)[1]
                if ext not in xp: continue
                if file not in xp[ext]:
                    print("Found extra file: %s"%("\\".join((dir.split("\\")[-1], file))))
    
    # meat 
    b22lv("Alarms Off.alm")
    b22lv("Alarms On.alm")
    #b22rc("Alarms.alm")
    
    testrecipes("Bioreactor Recipes.cfg")
    b22lv("Email Alerts Settings.xml")
    
    testlog("Logging Off.log")
    testlog("Logging On.log")
    testlog("Logger Settings.log")
    
    b22lv("ReportSettings.cfg")
    
    for file in os.listdir(l):
        if file.endswith(".sys"):
            testsv(file)
    #testsv("System Variables.sys")
    
    
    existclv("Email Password.cfgx")
    existclv("Network Drives.cfgx")
    existclv("PBS Users.conf")
    
    #testcal("Cal Factors.cfg")
    
    #b22rc("Bioreactor Configuration.txt")
    #b22rc("pH Control.txt")
    
    #existcrc("Bag Info.cfg")
    #existcrc("Global Variables I.conf")
    #existcrc("Global Variables II.conf")
    #existcrc("Global Variables III.conf")
    
    #findothers()
    

    def showdiff():
        for fp, lines in diffs:
            print()
            print("%s:"%fp)
            for line in lines:
                print(" "*3, line)
    showdiff()
            
    def checklogger():
        l1 = rdf(findc("Logging On.log")).splitlines()
        l2 = rdf(findr("Logging On.log")).splitlines()
        def toset(l):
            s = set()
            for line in l:
                if line:
                    s.add(line.split("\t", 1)[0])
            return s
        def tabfix(s):
            return s.replace("\t", "    ")
        s1 = toset(map(tabfix, l1))
        s2 = toset(map(tabfix, l2))
        print("Extra in customer: ", s1 - s2)
        print("Extra in reference: ", s2 - s1)
    #checklogger()

# %%
ref = 'D:\\auto_hd_install\\default configs\\IM00226 Rev C\\Mag 03'
lvd = 'D:\\Customer_Backups\\%s\\LabVIEW_Data'
rc  = 'D:\\Customer_Backups\\%s\\Rio_Config'

# %%
import contextlib, sys
@contextlib.contextmanager
def redirect_stdout(fp):
    stdout = sys.stdout
    with open(fp, 'w') as f:
        sys.stdout = f
        try:
            yield
        finally:
            sys.stdout=stdout

# %%
class DumbDumb(Exception): pass
sns = ["PBS 3 CDI %d"%i for i in range(2,7)]
ref = 'D:\\auto_hd_install\\default configs\\IM00226 Rev C\\Mag 03'
sns.append("PBS 15 CDI 1")
for sn in sns:
    with redirect_stdout(sn+" simple report.txt"):
        if sn.split()[1] == "3":
            ref = 'D:\\auto_hd_install\\default configs\\IM00226 Rev C\\Mag 03'
        elif sn.split()[1] == "15":
            ref = 'D:\\auto_hd_install\\default configs\\IM00226 Rev C\\Mag 15'
        else:
            raise DumbDumb()
        compare(sn)

# %%
ref = 'D:\\auto_hd_install\\default configs\\IM00226 Rev C\\Mag 15'
cdisn = "PBS 3 CDI 5"
compare(cdisn)
# Out:
# Alarms Off.alm                     : User == Reference
# Alarms On.alm                      : User == Reference
# Alarms.alm                         : User == Reference
# Bioreactor Recipes.cfg             : User == Reference
# Email Alerts Settings.xml          : User != Reference
# Logging Off.log                    : User != Reference
# Logging On.log                     : User != Reference
# ReportSettings.cfg                 : User == Reference
# System Variables.sys               : User != Reference
# Email Password.cfgx                : Found
# Network Drives.cfgx                : Found
# PBS Users.conf                     : Found
# Cal Factors.cfg                    : User != Reference
# Cal Factors.cfg                    : File structure verified
# Bioreactor Configuration.txt       : User == Reference
# pH Control.txt                     : User == Reference
# Bag Info.cfg                       : Found
# Global Variables I.conf            : Found
# Global Variables II.conf           : Found
# Global Variables III.conf          : Found
#
# Email Alerts Settings.xml:
#     Line 2: 'Subject,PBS 3 CDI 5' != 'Subject,PBS'
#     Line 3: 'SMTP Address,10.0.0.85' != 'SMTP Address,smtp.1and1.com'
#     Line 4: 'SMTP Port,587' != 'SMTP Port,25'
#     Line 5: 'Return Address,3LBioreactor5@cellulardynamics.com' != 'Return Address,'
#     Line 6: 'EnableSSL,FALSE' != 'EnableSSL,TRUE'
#
# Logging Off.log:
#
#     - DON2RangeAuto(%).Max	0	FALSE	DO
#     ?                 ----
#     + DON2RangeAutoMax(%)	0	FALSE	DO
#     ?              +++
#     - DON2RangeAuto(%).Min	0	FALSE	DO
#     - DOO2RangeAuto(%).Max	0	FALSE	DO
#     ?                 ----
#     + DOO2RangeAutoMax(%)	0	FALSE	DO
#     ?              +++
#     - DOO2RangeAuto(%).Min	0	FALSE	DO
#     - DOO2RangeAuto(mLPM).Max	0	FALSE	DO
#     ?                    ----
#     + DOO2RangeAutoMax(mLPM)	0	FALSE	DO
#     ?              +++
#     - DOO2RangeAuto(mLPM).Min	0	FALSE	DO
#     - FilterOvenDutyRangeAuto(%).Max	0	FALSE	Filter Oven
#     ?                           ----
#     + FilterOvenDutyRangeAutoMax(%)	0	FALSE	Filter Oven
#     ?                        +++
#     - FilterOvenDutyRangeAuto(%).Min	0	FALSE	Filter Oven
#
# Logging On.log:
#
#     - DON2RangeAuto(%).Max	0.001	FALSE	DO
#     ?                 ----
#     + DON2RangeAutoMax(%)	0.001	FALSE	DO
#     ?              +++
#     - DON2RangeAuto(%).Min	0.001	FALSE	DO
#     - DOO2RangeAuto(%).Max	1	FALSE	DO
#     ?                 ----
#     + DOO2RangeAutoMax(%)	1	FALSE	DO
#     ?              +++
#     - DOO2RangeAuto(%).Min	1	FALSE	DO
#     - DOO2RangeAuto(mLPM).Max	0.001	FALSE	DO
#     ?                    ----
#     + DOO2RangeAutoMax(mLPM)	0.001	FALSE	DO
#     ?              +++
#     - DOO2RangeAuto(mLPM).Min	0.001	FALSE	DO
#     - FilterOvenDutyRangeAuto(%).Max	0.001	FALSE	Filter Oven
#     ?                           ----
#     + FilterOvenDutyRangeAutoMax(%)	0.001	FALSE	Filter Oven
#     ?                        +++
#     - FilterOvenDutyRangeAuto(%).Min	0.001	FALSE	Filter Oven
#
# System Variables.sys:
#     CO2 P Gain (%/pH)    val mismatch : 15.0 != -200.0
#     CO2 I Time (min)     val mismatch : 80.0 != 2.0
#     CO2 Beta             val mismatch : 0.0 != 1.0
#     CO2 Manual Max (%)   val mismatch : 25.0 != 100.0
#     CO2 Auto Max (%)     val mismatch : 100.0 != 30.0
#     Base P Gain (%/pH)   val mismatch : -10.0 != 10.0
#     Base I Time (min)    val mismatch : 80.0 != 10.0
#     Base Beta            val mismatch : 0.0 != 1.0
#     N2 Min (LPM)         val mismatch : 0.02 != 0.03
#     Air Min (LPM)        val mismatch : 0.02 != 0.03
#     O2 Min (LPM)         val mismatch : 0.02 != 0.03

# %%
cdisn = "PBS 3 CDI 6"
compare(cdisn)
# Out:
# Alarms Off.alm                     : User == Reference
# Alarms On.alm                      : User == Reference
# Alarms.alm                         : User == Reference
# Bioreactor Recipes.cfg             : User == Reference
# Email Alerts Settings.xml          : User != Reference
# Logging Off.log                    : User != Reference
# Logging On.log                     : User != Reference
# ReportSettings.cfg                 : User == Reference
# System Variables.sys               : User != Reference
# Email Password.cfgx                : Found
# Network Drives.cfgx                : Found
# PBS Users.conf                     : Found
# Cal Factors.cfg                    : User != Reference
# Cal Factors.cfg                    : File structure verified
# Bioreactor Configuration.txt       : User == Reference
# pH Control.txt                     : User == Reference
# Bag Info.cfg                       : Found
# Global Variables I.conf            : Found
# Global Variables II.conf           : Found
# Global Variables III.conf          : Found
#
# Email Alerts Settings.xml:
#     Line 2: 'Subject,PBS 3 CDI 6' != 'Subject,PBS'
#     Line 4: 'SMTP Port,587' != 'SMTP Port,25'
#     Line 5: 'Return Address,3Lbioreactor6@cellulardynamics.com' != 'Return Address,'
#     Line 6: 'EnableSSL,FALSE' != 'EnableSSL,TRUE'
#
# Logging Off.log:
#
#     - DON2RangeAuto(%).Max	0	FALSE	DO
#     ?                 ----
#     + DON2RangeAutoMax(%)	0	FALSE	DO
#     ?              +++
#     - DON2RangeAuto(%).Min	0	FALSE	DO
#     - DOO2RangeAuto(%).Max	0	FALSE	DO
#     ?                 ----
#     + DOO2RangeAutoMax(%)	0	FALSE	DO
#     ?              +++
#     - DOO2RangeAuto(%).Min	0	FALSE	DO
#     - DOO2RangeAuto(mLPM).Max	0	FALSE	DO
#     ?                    ----
#     + DOO2RangeAutoMax(mLPM)	0	FALSE	DO
#     ?              +++
#     - DOO2RangeAuto(mLPM).Min	0	FALSE	DO
#     - FilterOvenDutyRangeAuto(%).Max	0	FALSE	Filter Oven
#     ?                           ----
#     + FilterOvenDutyRangeAutoMax(%)	0	FALSE	Filter Oven
#     ?                        +++
#     - FilterOvenDutyRangeAuto(%).Min	0	FALSE	Filter Oven
#
# Logging On.log:
#
#     - DON2RangeAuto(%).Max	0.001	FALSE	DO
#     ?                 ----
#     + DON2RangeAutoMax(%)	0.001	FALSE	DO
#     ?              +++
#     - DON2RangeAuto(%).Min	0.001	FALSE	DO
#     - DOO2RangeAuto(%).Max	1	FALSE	DO
#     ?                 ----
#     + DOO2RangeAutoMax(%)	1	FALSE	DO
#     ?              +++
#     - DOO2RangeAuto(%).Min	1	FALSE	DO
#     - DOO2RangeAuto(mLPM).Max	0.001	FALSE	DO
#     ?                    ----
#     + DOO2RangeAutoMax(mLPM)	0.001	FALSE	DO
#     ?              +++
#     - DOO2RangeAuto(mLPM).Min	0.001	FALSE	DO
#     - FilterOvenDutyRangeAuto(%).Max	0.001	FALSE	Filter Oven
#     ?                           ----
#     + FilterOvenDutyRangeAutoMax(%)	0.001	FALSE	Filter Oven
#     ?                        +++
#     - FilterOvenDutyRangeAuto(%).Min	0.001	FALSE	Filter Oven
#
# System Variables.sys:
#     N2 Min (LPM)         val mismatch : 0.02 != 0.03
#     Air Min (LPM)        val mismatch : 0.02 != 0.03
#     O2 Min (LPM)         val mismatch : 0.02 != 0.03

# %%
scrum1sn = "000317S1902 180207"
#compare(scrum1sn)

# %%
sn = "000317S1903_check 180207"
compare(sn)

# %%
sn = "000318J0302_check 180214"
compare(sn)

# %%
sn = "000314P2201_backup 180326"
compare(sn)
# Out:
# Alarms Off.alm                     : User == Reference
# Alarms On.alm                      : User == Reference
# Bioreactor Recipes.cfg             : User != Reference
# Email Alerts Settings.xml          : User != Reference
# Logging Off.log                    : User == Reference
# Logging On.log                     : User == Reference
# Logger Settings.log                : User != Reference
# ReportSettings.cfg                 : User == Reference
# OQ-Alarms Verification.sys         : User != Reference
# sv backup.sys                      : User != Reference
# System Variables.sys               : User != Reference
# Email Password.cfgx                : Found
# Network Drives.cfgx                : Found
# PBS Users.conf                     : Found
#
# Bioreactor Recipes.cfg:
#     Extra Recipe: intelliaheat
#     Extra Recipe: SampleTest
#     Extra Recipe: OQ-Recipe1
#     Extra Recipe: OQ-PowerLoss
#
# Email Alerts Settings.xml:
#     Line 2: 'Subject,PBS 3 Mag Eng 1' != 'Subject,PBS'
#     Line 5: 'Return Address,pbs@pbsbiotech.com' != 'Return Address,'
#     Line 9: 'Agitation Low Low,0' != 'Agitation Low Low,1'
#     Line 10: 'Main Gas Low Low,0' != 'Main Gas Low Low,1'
#     Line 11: 'Temperature Low Low,0' != 'Temperature Low Low,1'
#     Line 12: 'DO Low Low,0' != 'DO Low Low,1'
#     Line 13: 'pH Low Low,0' != 'pH Low Low,1'
#     Line 15: 'Level Low Low,0' != 'Level Low Low,1'
#     Line 16: 'Filter Oven Low Low,0' != 'Filter Oven Low Low,1'
#     Line 21: 'O2 MFC Mismatch,0' != 'O2 MFC Mismatch,1'
#     Line 22: 'N2 MFC Mismatch,0' != 'N2 MFC Mismatch,1'
#     Line 23: 'Air MFC Mismatch,0' != 'Air MFC Mismatch,1'
#     Line 24: 'CO2 MFC Mismatch,0' != 'CO2 MFC Mismatch,1'
#     Line 33: 'Agitation Sensor Failure,0' != 'Agitation Sensor Failure,1'
#     Line 34: 'Temp Sensor A Failure (range),0' != 'Temp Sensor A Failure (range),1'
#     Line 37: 'DO Sensor A Failure (range),0' != 'DO Sensor A Failure (range),1'
#     Line 40: 'pH Sensor A Failure (range),0' != 'pH Sensor A Failure (range),1'
#     Line 42: 'pH Sensor A Failure (rate),0' != 'pH Sensor A Failure (rate),1'
#     Line 49: 'Agitation High High,0' != 'Agitation High High,1'
#     Line 50: 'Main Gas High High,0' != 'Main Gas High High,1'
#     Line 51: 'Temperature High High,0' != 'Temperature High High,1'
#     Line 52: 'DO High High,0' != 'DO High High,1'
#     Line 53: 'pH High High,0' != 'pH High High,1'
#     Line 55: 'Level High High,0' != 'Level High High,1'
#     Line 65: 'RT Mem Fragmented,0' != 'RT Mem Fragmented,1'
#     Line 66: 'RT Mem Nearly Full,0' != 'RT Mem Nearly Full,1'
#     Line 67: 'NI 9205 Error,0' != 'NI 9205 Error,1'
#     Line 68: 'NI 9425/Onboard Error,0' != 'NI 9425/Onboard Error,1'
#     Line 69: 'NI 9219 Error,0' != 'NI 9219 Error,1'
#     Line 70: 'NI 9476 Error,0' != 'NI 9476 Error,1'
#     Line 71: 'NI 9263 Error,0' != 'NI 9263 Error,1'
#     Line 88: 'Restarted Recipe,0' != 'Restarted Recipe,1'
#
# Logger Settings.log:
#
#     - Data Name    Threshold change to record    Record    Group
#     ?                                                  ---------
#     + Data Name    Threshold change to record    Record
#     + AgAtLeast1GoodSensor    0.5    FALSE
#     + AgAutoMaxStartup(%)    0.001    FALSE
#     + AgControlAlpha    0.001    FALSE
#     + AgControlBeta    0.001    FALSE
#     + AgControlGamma    0.001    FALSE
#     + AgControlLinearity    0.001    FALSE
#     + AgGasAutoMaxStartup(LPM)    0.001    FALSE
#     + AgLookupFactor(LPM/RPM)    0.001    FALSE
#     + AgLookupModeTimeout (ms)    0.001    FALSE
#     - TempARaw(C)    0    FALSE
#     - TempHeatDutyActual(%)    0    FALSE
#     - TempHeatPeriod(Cycle)    0    FALSE
#     - TempA(C)    0    FALSE
#     - MFCAirMeasRaw(V)    0    FALSE
#     - FilterOvenPV(C)    0    FALSE
#     - MFCN2MeasRaw(V)    0    FALSE
#     - MFCO2MeasRaw(V)    0    FALSE
#     - TempHeatOnTime(Cycle)    0    FALSE
#     - FilterOvenOnTime(Cycle)    0    FALSE
#     - PressureRaw(V)    0    FALSE
#     - LevelRaw(V)    0    FALSE
#     - AlarmLeak    0    FALSE
#     - ReusablePressureConnected    0    FALSE
#     - pHCO2ActualRequest(%)    0    FALSE
#     - AgMainGasActualRequest(LPM)    0    FALSE
#     ?                                          ----
#     + AgMainGasActualRequest(LPM)    0.1    FALSE
#     ?                                 ++
#     - MFCN2OutRaw(V).AO(V)    0    FALSE
#     - MFCN2OutRaw(V).On(iter)    0    FALSE
#     - MFCN2OutRaw(V).Period(iter)    0    FALSE
#     - MFCO2OutRaw.AO(V)    0    FALSE
#     - MFCO2OutRaw.On(iter)    0    FALSE
#     - MFCO2OutRaw.Period(iter)    0    FALSE
#     - DoorLockActual    0    FALSE
#     - FilterOvenRaw(C)    0    FALSE
#     - TempBRaw(C)    0    FALSE
#     - TempB(C)    0    FALSE
#     - pHARaw    0    FALSE
#     - pHBRaw    0    FALSE
#     - pHB    0    FALSE
#     - FilterOvenPeriod(Cycle)    0    FALSE
#     + AgMainGasControl.DTime(min)    0.001    FALSE
#     + AgMainGasControl.ITime(min)    0.001    FALSE
#     + AgMainGasControl.PGain(LPM/RPM)    0.001    FALSE
#     + AgMainGasRangeAuto(LPM).Max    0.001    FALSE
#     + AgMainGasRangeAuto(LPM).Min    0.001    FALSE
#     + AgMainGasRangeManMax(LPM)    0.001    FALSE
#     + AgMainGasUser(LPM)    0.1    FALSE
#     + AgMin(RPM)    0.001    FALSE
#     + AgMinGasSum(V)    0.001    FALSE
#     + AgMinPower(%)    0.001    FALSE
#     + AgModeActual    0.5    TRUE
#     + AgModeUser    0.5    FALSE
#     + AgMotorPWM.Duty    0.1    FALSE
#     + AgMotorPWM.OnTime(Cycle)    1    FALSE
#     + AgMotorPWM.Period(Cycle)    1    FALSE
#     + AgMotorPower(V)    0.1    FALSE
#     + AgPV(RPM)    0.5    TRUE
#     + AgPowerActualRequest(%)    2    TRUE
#     + AgPowerControl.DTime(min)    0.01    FALSE
#     + AgPowerControl.ITime(min)    0.01    FALSE
#     + AgPowerControl.PGain(%/RPM)    0.01    FALSE
#     + AgPowerRangeAuto(%).Max    0.01    FALSE
#     + AgPowerRangeAuto(%).Min    0.01    FALSE
#     + AgPowerRangeManMax(%)    0.01    FALSE
#     + AgPowerUser(%)    0.1    TRUE
#     + AgPulseModeTimeout(ms)    1    FALSE
#     + AgPwrLookupFactor(%/RPM)    0.001    FALSE
#     + AgRPMLoopTime(ticks/Cycle)    0.5    FALSE
#     + AgSP(RPM)    0.5    TRUE
#     - AgWheelCount    0    FALSE
#     ?                 ^         ----
#     + AgWheelCount    1    FALSE
#     ?                 ^
#     - AgPV(RPM)    0    FALSE
#     + AgWheelLastPeriod(iter)    1    FALSE
#     + AgWheelMagnetCount    0.5    FALSE
#     - AgWheelSamplesToAverage    0    FALSE
#     ?                                      ----
#     + AgWheelSamplesToAverage    0.5    FALSE
#     ?                             ++
#     + AgWheelSense    0.5    FALSE
#     + AgWheelTimeSinceLastMag(Cycle)    1    FALSE
#     + HarvestDelay(s)    0.001    FALSE
#     + HarvestMode    0.5    FALSE
#     + HarvestTimeout    0.5    FALSE
#     - PressurePV(psi)    0    FALSE
#     - DOBRaw(%)    0    FALSE
#     - TempAIsActive    0    FALSE
#     - TempBIsActive    0    FALSE
#     - TempModeActual    0    FALSE
#     - InterlockHeater    0    FALSE
#     - InterlockPressureMax(psi)    0    FALSE
#     - LevelMin(L)    0    FALSE
#     - TempPV(C)    0    FALSE
#     - TempHeatManMax(%)    0    FALSE
#     - TempHeatDutyControl.PGain(min)    0    FALSE
#     - TempHeatDutyControl.ITime(min)    0    FALSE
#     - TempHeatDutyControl.DTime(min)    0    FALSE
#     - TempValidMax(C)    0    FALSE
#     - TempValidMin(C)    0    FALSE
#     - AgPulseModeTimeout(ms)    0    FALSE
#     - AgLookupModeTimeout (ms)    0    FALSE
#     - AgMin(RPM)    0    FALSE
#     - AgMainGasControl.PGain(LPM/RPM)    0    FALSE
#     - AgMainGasControl.ITime(min)    0    FALSE
#     - AgMainGasControl.DTime(min)    0    FALSE
#     - AgMainGasRangeAuto(LPM).Max    0    FALSE
#     - AgMainGasRangeAuto(LPM).Min    0    FALSE
#     - AgLookupFactor(LPM/RPM)    0    FALSE
#     - AgModeActual    0    FALSE
#     - DOPV(%)    0.2    TRUE
#     - AlarmBuzzerOnTime(Cycle)    0    FALSE
#     ?                                       ----
#     + AlarmBuzzerOnTime(Cycle)    10    FALSE
#     ?                             +
#     - AlarmBuzzerPeriod(Cycle)    0    FALSE
#     ?                                       ----
#     + AlarmBuzzerPeriod(Cycle)    10    FALSE
#     ?                             +
#     - Pumps&ValvesPumpSmplRevrs    0    FALSE
#     - Pumps&ValvesPumpSmpl    0    FALSE
#     - pHAIsActive    0    FALSE
#     - pHBIsActive    0    FALSE
#     - pHValidMax    0    FALSE
#     - pHValidMin    0    FALSE
#     - pHModeActual    0    FALSE
#     - pHA    0    FALSE
#     - pHBaseDutyActual(%)    0    FALSE
#     - pHActiveMode    0    FALSE
#     - pHCO2Control.PGain(%)    0    FALSE
#     - pHCO2Control.ITime(min)    0    FALSE
#     - pHCO2Control.DTime(min)    0    FALSE
#     - pHBaseDutyControl.PGain(%)    0    FALSE
#     - pHBaseDutyControl.ITime(min)    0    FALSE
#     - pHBaseDutyControl.DTime(min)    0    FALSE
#     - DOO2ControlAir.PGain(mLPM/%)    0    FALSE
#     - DOO2ControlAir.ITime(min)    0    FALSE
#     - DOO2ControlAir.DTime(min)    0    FALSE
#     - DOBisActive    0    FALSE
#     + AlarmBuzzerUser    0.5    FALSE
#     + AlarmFuseStatus    0.5    FALSE
#     + AlarmLeak    0.5    FALSE
#     + AlarmSnoozeTime(ms)    1    FALSE
#     + Alm_CombPlate    0.5    FALSE
#     + CalDOA.Offset(%)    0.01    FALSE
#     + CalDOA.Slope    0.01    FALSE
#     + CalDOB.Offset(%)    0.01    FALSE
#     + CalDOB.Slope    0.01    FALSE
#     + CalFilterOvenTemp.Offset(C)    0.01    FALSE
#     + CalFilterOvenTemp.Slope    0.01    FALSE
#     + CalLevel.b    0.01    FALSE
#     + CalLevel.m    0.01    FALSE
#     + CalLimitsLevel.CalLevelInterceptMax(psi)    0.001    FALSE
#     + CalLimitsLevel.CalLevelInterceptMin(psi)    0.001    FALSE
#     + CalLimitsLevel.CalLevelSlopeMax(psi/V)    0.001    FALSE
#     + CalLimitsLevel.CalLevelSlopeMin(psi/V)    0.001    FALSE
#     + CalLimitsPressure.CalPressureInterceptMax(psi)    0.001    FALSE
#     + CalLimitsPressure.CalPressureInterceptMin(psi)    0.001    FALSE
#     + CalLimitsPressure.CalPressureSlopeMax(psi/V)    0.001    FALSE
#     + CalLimitsPressure.CalPressureSlopeMin(psi/V)    0.001    FALSE
#     + CalMFCAir.b(LPM)    0.001    FALSE
#     + CalMFCAir.m(LPM/V)    0.001    FALSE
#     + CalMFCCO2.b(LPM)    0.001    FALSE
#     + CalMFCCO2.m(LPM/V)    0.001    FALSE
#     + CalMFCN2.b(LPM)    0.001    FALSE
#     + CalMFCN2.m(LPM/V)    0.001    FALSE
#     + CalMFCO2.b(LPM)    0.001    FALSE
#     + CalMFCO2.m(LPM/V)    0.001    FALSE
#     + CalPressure.Offset(psi)    0.01    FALSE
#     + CalPressure.Slope    0.01    FALSE
#     + CalTempA.Offset(C)    0.01    FALSE
#     + CalTempA.Slope    0.01    FALSE
#     + CalTempB.Offset(C)    0.01    FALSE
#     + CalTempB.Slope    0.01    FALSE
#     + CalpHA.Offset(%)    0.01    FALSE
#     + CalpHA.Slope    0.01    FALSE
#     + CalpHA.Temp(C)    0.01    FALSE
#     + CalpHB.Offset(%)    0.01    FALSE
#     + CalpHB.Slope    0.1    FALSE
#     + CalpHB.Temp(C)    0.1    FALSE
#     + DOA(%)    2    FALSE
#     + DOAIsPrimaryActual    0.5    FALSE
#     + DOARaw(%)    0.1    FALSE
#     - DOAisActive    0    FALSE
#     ?                          ----
#     + DOAisActive    0.5    FALSE
#     ?                 ++
#     + DOAisPrimaryUser    0.5    FALSE
#     + DOAtLeast1GoodSensor    0.5    FALSE
#     + DOB(%)    2    FALSE
#     - DOARaw(%)    0    FALSE
#     ?   ^                    ----
#     + DOBRaw(%)    0.1    FALSE
#     ?   ^           ++
#     - DOValidMax(%)    0    FALSE
#     - DOValidMin(%)    0    FALSE
#     + DOBisActive    0.5    FALSE
#     + DODeadband(%)    0.001    TRUE
#     + DOHardware    0.5    FALSE
#     + DOInRange.A    0.5    FALSE
#     + DOInRange.B    0.5    FALSE
#     + DOMismatchThresh(%)    0.001    FALSE
#     - DOModeActual    0    TRUE
#     ?                          ----
#     + DOModeActual    0.5    TRUE
#     ?                  ++
#     + DOModeUser    0.5    FALSE
#     - DOB(%)    0    FALSE
#     - MFCCO2MeasRaw(V)    0    FALSE
#     - TempHeatDutyAutoMax(%)    0    FALSE
#     - pHMismatchThresh    0    FALSE
#     - pHRateFailDeltaPV    0    FALSE
#     - pHCO2ManMax(%)    0    FALSE
#     - pHBaseDutyManMax(%)    0    FALSE
#     - DOMismatchThresh(%)    0    FALSE
#     - DON2Control.PGain(%/%)    0    FALSE
#     - DON2Control.ITime(min)    0    FALSE
#     - DON2Control.DTime(min)    0    FALSE
#     ?                                     ----
#     + DON2Control.DTime(min)    0.001    FALSE
#     ?                            ++++
#     - LevelMax(L)    0    FALSE
#     - Pumps&ValvesReverseCCandCW    0    FALSE
#     - InterlockTempMax(C)    0    FALSE
#     - LevelPV(L)    0    FALSE
#     + DON2Control.ITime(min)    0.001    FALSE
#     + DON2Control.PGain(%/%)    0.001    FALSE
#     + DON2ControlAlpha    0.001    FALSE
#     + DON2ControlBeta    0.001    FALSE
#     + DON2ControlGamma    0.001    FALSE
#     + DON2ControlLinearity    0.001    FALSE
#     - DON2FlowActualRequest(%)    1    TRUE
#     ?                             ^        ----
#     + DON2FlowActualRequest(%)    2    TRUE
#     ?                             ^
#     + DON2FlowControllerRequest(%)    2    FALSE
#     + DON2FlowUser(%)    1    TRUE
#     + DON2RangeAutoMax(%)    0.001    FALSE
#     + DON2RangeManMax(%)    0.001    FALSE
#     + DOO2ControlAir.DTime(min)    0.001    FALSE
#     + DOO2ControlAir.ITime(min)    0.001    FALSE
#     + DOO2ControlAir.PGain(mLPM/%)    0.001    FALSE
#     + DOO2ControlAlpha    0.001    FALSE
#     + DOO2ControlBeta    0.001    FALSE
#     + DOO2ControlGamma    0.001    FALSE
#     + DOO2ControlLinearity    0.001    FALSE
#     + DOO2ControlMag.DTime(min)    0.001    FALSE
#     + DOO2ControlMag.ITime(min)    0.001    FALSE
#     + DOO2ControlMag.PGain(%/%)    0.001    FALSE
#     + DOO2FlowControllerRequest(%)    2    FALSE
#     + DOO2FlowControllerRequest(mLPM)    5    FALSE
#     + DOO2FlowControllerRequestLimited(%)    2    TRUE
#     + DOO2FlowControllerRequestLimited(mLPM)    5    FALSE
#     + DOO2FlowUser(%)    0.1    TRUE
#     + DOO2FlowUser(mLPM)    1    FALSE
#     + DOO2RangeAutoMax(%)    1    FALSE
#     + DOO2RangeAutoMax(mLPM)    0.001    FALSE
#     + DOO2RangeManMax(%)    0.001    FALSE
#     + DOO2RangeManMax(mLPM)    0.001    FALSE
#     + DOPV(%)    2    TRUE
#     + DOSP(%)    1    TRUE
#     + DOUserConfig    0.5    FALSE
#     + DOValidMax(%)    0.001    FALSE
#     + DOValidMin(%)    0.001    FALSE
#     + DoorLockActual    0.5    FALSE
#     + DoorPressureSafe    0.5    FALSE
#     + DoorPressureSensor    0.5    FALSE
#     + DoorUnlockUser    0.5    FALSE
#     + ReusablePressureConnected    0.5    FALSE
#     + FilterOvenDutyActual(%)    50    TRUE
#     + FilterOvenDutyControl.DTime(min)    0.001    FALSE
#     + FilterOvenDutyControl.Gain(%/C)    0.001    FALSE
#     + FilterOvenDutyControl.ITime(min)    0.001    FALSE
#     + FilterOvenDutyControlAlpha    0.001    FALSE
#     + FilterOvenDutyControlBeta    0.001    FALSE
#     + FilterOvenDutyControlGamma    0.001    FALSE
#     + FilterOvenDutyControlLinearity    0.001    FALSE
#     + FilterOvenDutyRangeAutoMax(%)    0.001    FALSE
#     + FilterOvenDutyRangeManMax(%)    0.001    FALSE
#     + FilterOvenDutyUser(%)    1    TRUE
#     + FilterOvenModeActual    0.5    TRUE
#     + FilterOvenModeUser    0.5    FALSE
#     + FilterOvenOnTime(Cycle)    10    FALSE
#     + FilterOvenPV(C)    5    TRUE
#     + FilterOvenPeriod(Cycle)    10    FALSE
#     + FilterOvenRaw(C)    5    FALSE
#     + FilterOvenSP(C)    1    TRUE
#     + FilterOvenSensorActive    0.5    FALSE
#     + MFCAirFlowFeedback(LPM)    0.025    TRUE
#     + MFCAirMeasRaw(V)    0.1    FALSE
#     + MFCAirMin(LPM)    0.001    FALSE
#     + MFCAirOff(V)    0.001    FALSE
#     + MFCAirOutRaw(V).AO(V)    0.1    FALSE
#     + MFCAirOutRaw(V).On(iter)    0.1    FALSE
#     + MFCAirOutRaw(V).Period(iter)    0.1    FALSE
#     + MFCCO2FlowFeedback(LPM)    0.02    TRUE
#     + MFCCO2MeasRaw(V)    0.1    FALSE
#     + MFCCO2Min(LPM)    0.001    FALSE
#     + MFCCO2Off(V)    0.001    FALSE
#     - MFCCO2OutRaw.AO(V)    0    FALSE
#     ?                                 ----
#     + MFCCO2OutRaw.AO(V)    0.1    FALSE
#     ?                        ++
#     - MFCCO2OutRaw.On(iter)    0    FALSE
#     ?                                    ----
#     + MFCCO2OutRaw.On(iter)    0.1    FALSE
#     ?                           ++
#     - MFCCO2OutRaw.Period(iter)    0    FALSE
#     ?                                        ----
#     + MFCCO2OutRaw.Period(iter)    0.1    FALSE
#     ?                               ++
#     + MFCLoopTime(ticks/Cycle)    1    FALSE
#     + MFCMaxPeriod(s)    0.001    FALSE
#     - TempMismatchThresh(C)    0    FALSE
#     ? ^^^^               ^               ----
#     + MFCMismatchThresh(V)    0.001    FALSE
#     ? ^^^               ^      ++++
#     - AgWheelMagnetCount    0    FALSE
#     - pHPV    0    FALSE
#     - CalTempA.Slope    0    FALSE
#     - CalTempA.Offset(C)    0    FALSE
#     - CalFilterOvenTemp.Slope    0    FALSE
#     - CalFilterOvenTemp.Offset(C)    0    FALSE
#     - CalDOA.Slope    0    FALSE
#     - CalDOA.Offset(%)    0    FALSE
#     - CalpHA.Slope    0    FALSE
#     - CalpHA.Offset(%)    0    FALSE
#     - CalpHA.Temp(C)    0    FALSE
#     - CalPressure.Slope    0    FALSE
#     - CalPressure.Offset(psi)    0    FALSE
#     - RecipeSkipStep    0    FALSE
#     - AgWheelSense    0    FALSE
#     - DoorUnlockUser    0    FALSE
#     - FilterOvenDutyControl.Gain(%/C)    0    FALSE
#     - FilterOvenDutyControl.ITime(min)    0    FALSE
#     - FilterOvenDutyControl.DTime(min)    0    FALSE
#     - FilterOvenDutyActual(%)    0    FALSE
#     - pHRateFailDeltaTime(ms)    0    FALSE
#     - FilterOvenModeActual    0    FALSE
#     - DOA(%)    0    FALSE
#     - Pumps&ValvesPump2.Duty    0    FALSE
#     - Pumps&ValvesPump2.OnTime(Cycle)    0    FALSE
#     - Pumps&ValvesPump2.Period(Cycle)    0    FALSE
#     + MFCN2FlowFeedback(LPM)    0.025    TRUE
#     + MFCN2MeasRaw(V)    0.1    FALSE
#     + MFCN2Min(LPM)    0.001    FALSE
#     + MFCN2Off(V)    0.001    FALSE
#     + MFCN2OutRaw(V).AO(V)    0.1    FALSE
#     + MFCN2OutRaw(V).On(iter)    0.1    FALSE
#     + MFCN2OutRaw(V).Period(iter)    0.1    FALSE
#     + MFCO2FlowFeedback(LPM)    0.025    TRUE
#     + MFCO2MeasRaw(V)    0.1    FALSE
#     + MFCO2Min(LPM)    0.001    FALSE
#     + MFCO2Off(V)    0.001    FALSE
#     + MFCO2OutRaw.AO(V)    0.1    FALSE
#     + MFCO2OutRaw.On(iter)    0.1    FALSE
#     + MFCO2OutRaw.Period(iter)    0.1    FALSE
#     + MFCOnTime(s)    0.001    FALSE
#     + O2 Min Volume (L)    0.001    FALSE
#     + InterlockAgMotor    0.5    FALSE
#     + InterlockAll    0.5    FALSE
#     + InterlockDoor    0.5    FALSE
#     + InterlockDoorPressureMax(psi)    0.001    FALSE
#     + InterlockGasFlow    0.5    FALSE
#     + InterlockHeater    0.5    FALSE
#     + InterlockPressureMax(psi)    0.001    FALSE
#     + InterlockPumps    0.5    FALSE
#     + InterlockTempMax(C)    0.001    FALSE
#     + LEDWhiteLEDOn    0.5    FALSE
#     + LevelCalCluster.Bottom Gap (cm)    0.001    FALSE
#     + LevelCalCluster.Cm/psi    0.001    FALSE
#     + LevelCalCluster.Depth    0.001    FALSE
#     + LevelCalCluster.LevelEmpty(L)    0.001    FALSE
#     + LevelCalCluster.LevelEmpty(V)    0.001    FALSE
#     + LevelCalCluster.Radius(cm)    0.001    FALSE
#     + LevelColumn(psi)    0.1    FALSE
#     + LevelMax(L)    0.001    FALSE
#     + LevelMin(L)    0.001    FALSE
#     + LevelNet(cm)    1    FALSE
#     + LevelNoCal(L)    0.15    FALSE
#     + LevelPV(L)    0.1    TRUE
#     + LevelRaw(V)    0.1    FALSE
#     + LevelSensorEnable    0.5    FALSE
#     + LevelTotal(cm)    1    FALSE
#     + Limits.Agitation High (RPM)    0.001    FALSE
#     + Limits.Agitation High High (RPM)    0.001    FALSE
#     + Limits.Agitation Low (RPM)    0.001    FALSE
#     + Limits.Agitation Low Low (RPM)    0.001    FALSE
#     + Limits.DO High (%)    0.001    FALSE
#     + Limits.DO High High (%)    0.001    FALSE
#     + Limits.DO Low (%)    0.001    FALSE
#     + Limits.DO Low Low (%)    0.001    FALSE
#     + Limits.Filter Oven High (C)    0.001    FALSE
#     + Limits.Filter Oven High High (C)    0.001    FALSE
#     + Limits.Filter Oven Low (C)    0.001    FALSE
#     + Limits.Filter Oven Low Low (C)    0.001    FALSE
#     + Limits.Level High (L)    0.001    FALSE
#     + Limits.Level High High (L)    0.001    FALSE
#     + Limits.Level Low (L)    0.001    FALSE
#     + Limits.Level Low Low (L)    0.001    FALSE
#     + Limits.Main Gas High (LPM)    0.001    FALSE
#     + Limits.Main Gas High High (LPM)    0.001    FALSE
#     + Limits.Main Gas Low (LPM)    0.001    FALSE
#     + Limits.Main Gas Low Low (LPM)    0.001    FALSE
#     + Limits.Pressure High (psi)    0.001    FALSE
#     + Limits.Pressure High High (psi)    0.001    FALSE
#     + Limits.Pressure Low (psi)    0.001    FALSE
#     + Limits.Pressure Low Low (psi)    0.001    FALSE
#     + Limits.Temp High (C)    0.001    FALSE
#     + Limits.Temp High High (C)    0.001    FALSE
#     + Limits.Temp Low (C)    0.001    FALSE
#     + Limits.Temp Low Low (C)    0.001    FALSE
#     + Limits.pH High    0.001    FALSE
#     + Limits.pH High High    0.001    FALSE
#     + Limits.pH Low    0.001    FALSE
#     + Limits.pH Low Low    0.001    FALSE
#     + SensorStates.Agitation    0.5    FALSE
#     + SensorStates.DO    0.5    FALSE
#     + SensorStates.Filter Oven    0.5    FALSE
#     + SensorStates.Level    0.5    FALSE
#     + SensorStates.Main Gas    0.5    FALSE
#     + SensorStates.Pressure    0.5    FALSE
#     + SensorStates.Temperature    0.5    FALSE
#     + SensorStates.pH    0.5    FALSE
#     + LoggerLoadedCount    0.5    FALSE
#     + LoggerMaxLogInterval(ms)    60    FALSE
#     + MainGasActualRequest(LPM)    0.1    TRUE
#     + MainGasFeedback(LPM)    0.1    FALSE
#     + MainGasModeActual    0.5    TRUE
#     + MainGasModeUser    0.5    FALSE
#     + MainGasRangeManMax(LPM)    0.001    FALSE
#     + MainGasUser(LPM)    0.1    TRUE
#     + PressureDisconnected(V)    0.001    FALSE
#     + PressurePV(psi)    0.05    FALSE
#     + PressureRaw(V)    0.1    FALSE
#     + PressureSensorIsActive    0.5    FALSE
#     + Reusable Sensor (0 or 1)    0.5    FALSE
#     + Pumps&ValvesAnalogBaseSpeed(RPM)    1    FALSE
#     + Pumps&ValvesBaseMaxPeriod(s)    0.001    FALSE
#     + Pumps&ValvesBaseOnTime(s)    0.001    FALSE
#     + Pumps&ValvesBasePumpSelection    0.5    TRUE
#     + Pumps&ValvesFillMotorRaw(V)    0.1    FALSE
#     + Pumps&ValvesFillMotorRaw(V) 2    0.1    FALSE
#     + Pumps&ValvesFillMotorRaw(V) 3    0.1    FALSE
#     + Pumps&ValvesFillSpeed(RPM)    5    FALSE
#     + Pumps&ValvesFillSpeed(RPM) 2    5    FALSE
#     + Pumps&ValvesFillSpeed(RPM) 3    5    FALSE
#     - Pumps&ValvesPump1.Duty    0    FALSE
#     ?                           ^         ----
#     + Pumps&ValvesPump1.Duty    1    FALSE
#     ?                           ^
#     - Pumps&ValvesPump1.OnTime(Cycle)    0    FALSE
#     ?                                              ----
#     + Pumps&ValvesPump1.OnTime(Cycle)    10    FALSE
#     ?                                    +
#     - Pumps&ValvesPump1.Period(Cycle)    0    FALSE
#     ?                                              ----
#     + Pumps&ValvesPump1.Period(Cycle)    10    FALSE
#     ?                                    +
#     + Pumps&ValvesPump2.Duty    1    FALSE
#     + Pumps&ValvesPump2.OnTime(Cycle)    10    FALSE
#     + Pumps&ValvesPump2.Period(Cycle)    10    FALSE
#     - Sys_StartupCond    0    FALSE
#     - InterlockGasFlow    0    FALSE
#     - RecipeSkipSequence    0    FALSE
#     - pHAIsPrimaryActual    0    FALSE
#     - TempAIsPrimaryActual    0    FALSE
#     - Pumps&ValvesFillMotorRaw(V)    0    FALSE
#     - CalLevel.m    0    FALSE
#     - CalLevel.b    0    FALSE
#     - pHBUseTempComp    0    FALSE
#     - pHAUseTempComp    0    FALSE
#     - DOO2FlowControllerRequest(mLPM)    0    FALSE
#     - pHCO2AutoMax(%)    0    FALSE
#     - pHBaseAutoMax    0    FALSE
#     - PromptIssued(tick)    0    FALSE
#     - AlarmSnoozeTime(ms)    0    FALSE
#     - AlarmFuseStatus    0    FALSE
#     - Limits.Agitation Low Low (RPM)    0    FALSE
#     - Limits.Agitation Low (RPM)    0    FALSE
#     - Limits.Agitation High (RPM)    0    FALSE
#     - Limits.Agitation High High (RPM)    0    FALSE
#     - Limits.Temp Low Low (C)    0    FALSE
#     - Limits.Temp Low (C)    0    FALSE
#     - Limits.Temp High (C)    0    FALSE
#     - Limits.Temp High High (C)    0    FALSE
#     - Limits.DO Low Low (%)    0    FALSE
#     - Limits.DO Low (%)    0    FALSE
#     - Limits.DO High (%)    0    FALSE
#     - Limits.DO High High (%)    0    FALSE
#     - Limits.pH Low Low    0    FALSE
#     - Limits.pH Low    0    FALSE
#     - Limits.pH High    0    FALSE
#     - Limits.pH High High    0    FALSE
#     - Limits.Pressure Low Low (psi)    0    FALSE
#     - Limits.Pressure Low (psi)    0    FALSE
#     - Limits.Pressure High (psi)    0    FALSE
#     - Limits.Pressure High High (psi)    0    FALSE
#     - Limits.Level Low Low (L)    0    FALSE
#     - Limits.Level Low (L)    0    FALSE
#     - Limits.Level High (L)    0    FALSE
#     - Limits.Level High High (L)    0    FALSE
#     - Limits.Filter Oven Low Low (C)    0    FALSE
#     - Limits.Filter Oven Low (C)    0    FALSE
#     - Limits.Filter Oven High (C)    0    FALSE
#     - Limits.Filter Oven High High (C)    0    FALSE
#     - Limits.Main Gas Low Low (LPM)    0    FALSE
#     - Limits.Main Gas Low (LPM)    0    FALSE
#     - Limits.Main Gas High (LPM)    0    FALSE
#     - Limits.Main Gas High High (LPM)    0    FALSE
#     - PressureDisconnected(V)    0    FALSE
#     - DODeadband(%)    0    FALSE
#     - pHDeadband    0    FALSE
#     - pHInRange.A    0    FALSE
#     - pHInRange.B    0    FALSE
#     - DOInRange.A    0    FALSE
#     - DOInRange.B    0    FALSE
#     - TempInRange.A    0    FALSE
#     - TempInRange.B    0    FALSE
#     - MFCO2Min(LPM)    0    FALSE
#     - MFCCO2Min(LPM)    0    FALSE
#     - MFCAirMin(LPM)    0    FALSE
#     - MFCN2Min(LPM)    0    FALSE
#     - MFCO2Off(V)    0    FALSE
#     - MFCCO2Off(V)    0    FALSE
#     - MFCAirOff(V)    0    FALSE
#     - MFCN2Off(V)    0    FALSE
#     - AgWheelTimeSinceLastMag(Cycle)    0    FALSE
#     - AgWheelLastPeriod(iter)    0    FALSE
#     - Sys_PWMLoopTime(ticks/Cycle)    0    FALSE
#     - LoggerLoadedCount    0    FALSE
#     - LoggerMaxLogInterval(ms)    0    FALSE
#     - AgMinGasSum(V)    0    FALSE
#     - SysLCBMem(KB)    0    FALSE
#     - SysAvailableMem(KB)    0    FALSE
#     - SysLCBMemLimit(KB)    0    FALSE
#     - SysAvailableMemLimit(KB)    0    FALSE
#     - CalTempB.Slope    0    FALSE
#     - CalTempB.Offset(C)    0    FALSE
#     - CalDOB.Slope    0    FALSE
#     - CalDOB.Offset(%)    0    FALSE
#     - CalpHB.Slope    0    FALSE
#     - CalpHB.Offset(%)    0    FALSE
#     - CalpHB.Temp(C)    0    FALSE
#     - SysStop    0    FALSE
#     - SysSessionID    0    FALSE
#     - Pumps&ValvesPumpMedAuxSpeed    0    FALSE
#     - Pumps&ValvesPumpLowAuxSpeed    0    FALSE
#     ?                                ^         ----
#     + Pumps&ValvesPumpLowAuxSpeed    1    FALSE
#     ?                                ^
#     - Pumps&ValvesBaseMaxPeriod(s)    0    FALSE
#     - Pumps&ValvesBaseOnTime(s)    0    FALSE
#     - MFCMaxPeriod(s)    0    FALSE
#     - MFCOnTime(s)    0    FALSE
#     + Pumps&ValvesPumpMedAuxSpeed    1    FALSE
#     + Pumps&ValvesPumpSmpl    0.5    FALSE
#     + Pumps&ValvesPumpSmplReq    0.5    FALSE
#     + Pumps&ValvesPumpSmplRevrs    0.5    FALSE
#     + Pumps&ValvesPumpSmplRevrsReq    0.5    FALSE
#     + Pumps&ValvesPumpUser1    0.5    TRUE
#     + Pumps&ValvesPumpUser2    0.5    TRUE
#     + Pumps&ValvesReverseCCandCW    0.5    FALSE
#     + PromptIssued(tick)    0.1    FALSE
#     + Recipe Index    0.5    FALSE
#     + RecipeSkipSequence    0.5    FALSE
#     + RecipeSkipStep    0.5    FALSE
#     + BioreactorModel    0.5    FALSE
#     + SysAvailableMem(KB)    0.001    FALSE
#     + SysAvailableMemLimit(KB)    0.001    FALSE
#     + SysLCBMem(KB)    0.001    FALSE
#     + SysLCBMemLimit(KB)    0.001    FALSE
#     + SysSessionID    0.5    FALSE
#     + SysStop    0.5    FALSE
#     - Sys_FPGAError.NI 9205    0    FALSE
#     ?                                    ----
#     + Sys_FPGAError.NI 9205    0.5    FALSE
#     ?                           ++
#     + Sys_FPGAError.NI 9219    0.5    FALSE
#     + Sys_FPGAError.NI 9263    0.5    FALSE
#     - Sys_FPGAError.NI 9425/Onboard    0    FALSE
#     ?                                            ----
#     + Sys_FPGAError.NI 9425/Onboard    0.5    FALSE
#     ?                                   ++
#     - Sys_FPGAError.NI 9219    0    FALSE
#     - Sys_FPGAError.NI 9476    0    FALSE
#     ?                                    ----
#     + Sys_FPGAError.NI 9476    0.5    FALSE
#     ?                           ++
#     - Sys_FPGAError.NI 9263    0    FALSE
#     + Sys_PWMLoopTime(ticks/Cycle)    1    FALSE
#     + Sys_StartupCond    0.5    FALSE
#     + TempA(C)    0.2    FALSE
#     + TempAIsActive    0.5    FALSE
#     + TempAIsPrimaryActual    0.5    FALSE
#     + TempAIsPrimaryUser    0.5    FALSE
#     + TempARaw(C)    0.1    FALSE
#     - TempAtLeast1GoodSensor    0    FALSE
#     ?                                     ----
#     + TempAtLeast1GoodSensor    0.5    FALSE
#     ?                            ++
#     - AgAtLeast1GoodSensor    0    FALSE
#     + TempB(C)    0.2    FALSE
#     + TempBIsActive    0.5    FALSE
#     + TempBRaw(C)    0.1    FALSE
#     + TempHardware    0.5    FALSE
#     + TempHeatDutyActual(%)    2    TRUE
#     + TempHeatDutyAutoMax(%)    0.001    FALSE
#     + TempHeatDutyControl.DTime(min)    0.001    FALSE
#     + TempHeatDutyControl.ITime(min)    0.001    FALSE
#     + TempHeatDutyControl.PGain(min)    0.001    FALSE
#     + TempHeatDutyControlAlpha    0.001    FALSE
#     + TempHeatDutyControlBeta    0.001    FALSE
#     + TempHeatDutyControlGamma    0.001    FALSE
#     + TempHeatDutyControlLinearity    0.001    FALSE
#     + TempHeatDutyUser(%)    1    TRUE
#     + TempHeatManMax(%)    0.001    FALSE
#     + TempHeatOnTime(Cycle)    1    FALSE
#     + TempHeatPeriod(Cycle)    1    FALSE
#     + TempInRange.A    0.5    FALSE
#     + TempInRange.B    0.5    FALSE
#     + TempMismatchThresh(C)    0.001    FALSE
#     + TempModeActual    0.5    TRUE
#     + TempModeUser    0.5    FALSE
#     + TempPV(C)    0.2    TRUE
#     + TempSP(C)    0.1    TRUE
#     + TempUserConfig    0.5    FALSE
#     + TempValidMax(C)    0.001    FALSE
#     + TempValidMin(C)    0.001    FALSE
#     + pHA    0.05    FALSE
#     + pHAIsActive    0.5    FALSE
#     + pHAIsPrimaryActual    0.5    FALSE
#     + pHAIsPrimaryUser    0.5    FALSE
#     + pHARaw    0.01    FALSE
#     + pHAUseTempComp    0.5    FALSE
#     + pHActiveMode    0.5    FALSE
#     - pHAtLeast1GoodSensor    0    FALSE
#     ?                                   ----
#     + pHAtLeast1GoodSensor    0.5    FALSE
#     ?                          ++
#     + pHB    0.05    FALSE
#     + pHBIsActive    0.5    FALSE
#     + pHBRaw    0.01    FALSE
#     + pHBUseTempComp    0.5    FALSE
#     + pHBaseAutoMax    0.001    FALSE
#     + pHBaseDutyActual(%)    1    TRUE
#     + pHBaseDutyControl.DTime(min)    0.001    FALSE
#     + pHBaseDutyControl.ITime(min)    0.001    FALSE
#     + pHBaseDutyControl.PGain(%)    0.001    FALSE
#     + pHBaseDutyControlAlpha    0.001    FALSE
#     + pHBaseDutyControlBeta    0.001    FALSE
#     + pHBaseDutyControlGamma    0.001    FALSE
#     + pHBaseDutyControlLinearity    0.001    FALSE
#     + pHBaseDutyManMax(%)    0.001    FALSE
#     + pHBaseDutyUser(%)    1    TRUE
#     + pHCO2ActualRequest(%)    1    TRUE
#     + pHCO2AutoMax(%)    0.001    FALSE
#     + pHCO2Control.DTime(min)    0.001    FALSE
#     + pHCO2Control.ITime(min)    0.001    FALSE
#     + pHCO2Control.PGain(%)    0.001    FALSE
#     + pHCO2ControlAlpha    0.001    FALSE
#     + pHCO2ControlBeta    0.001    FALSE
#     + pHCO2ControlGamma    0.001    FALSE
#     + pHCO2ControlLinearity    0.001    FALSE
#     - PressureSensorIsActive    0    FALSE
#     - SensorStates.Agitation    0    FALSE
#     - SensorStates.Temperature    0    FALSE
#     - SensorStates.DO    0    FALSE
#     - SensorStates.pH    0    FALSE
#     - SensorStates.Pressure    0    FALSE
#     - SensorStates.Level    0    FALSE
#     - SensorStates.Filter Oven    0    FALSE
#     - SensorStates.Main Gas    0    FALSE
#     - Recipe Index    0    FALSE
#     - InterlockDoorPressureMax(psi)    0    FALSE
#     - InterlockAll    0    FALSE
#     - InterlockPumps    0    FALSE
#     - InterlockDoor    0    FALSE
#     - MFCMismatchThresh(V)    0    FALSE
#     - LevelTotal(cm)    0    FALSE
#     - LevelNet(cm)    0    FALSE
#     - LevelColumn(psi)    0    FALSE
#     - Pumps&ValvesFillMotorRaw(V) 2    0    FALSE
#     - Pumps&ValvesFillMotorRaw(V) 3    0    FALSE
#     - LevelCalCluster.Radius(cm)    0    FALSE
#     - LevelCalCluster.Depth    0    FALSE
#     - LevelCalCluster.Bottom Gap (cm)    0    FALSE
#     - LevelCalCluster.Cm/psi    0    FALSE
#     - LevelCalCluster.LevelEmpty(V)    0    FALSE
#     - LevelCalCluster.LevelEmpty(L)    0    FALSE
#     - CalLimitsLevel.CalLevelSlopeMax(psi/V)    0    FALSE
#     - CalLimitsLevel.CalLevelSlopeMin(psi/V)    0    FALSE
#     - CalLimitsLevel.CalLevelInterceptMax(psi)    0    FALSE
#     - CalLimitsLevel.CalLevelInterceptMin(psi)    0    FALSE
#     - CalLimitsPressure.CalPressureSlopeMax(psi/V)    0    FALSE
#     - CalLimitsPressure.CalPressureSlopeMin(psi/V)    0    FALSE
#     - CalLimitsPressure.CalPressureInterceptMax(psi)    0    FALSE
#     - CalLimitsPressure.CalPressureInterceptMin(psi)    0    FALSE
#     - Pumps&ValvesAnalogBaseSpeed(RPM)    0    FALSE
#     - BioreactorModel    0    FALSE
#     - Reusable Sensor (0 or 1)    0    FALSE
#     - O2 Min Volume (L)    0    FALSE
#     - MFCAirOutRaw(V).AO(V)    0    FALSE
#     - MFCAirOutRaw(V).On(iter)    0    FALSE
#     - MFCAirOutRaw(V).Period(iter)    0    FALSE
#     - DON2FlowControllerRequest(%)    0    FALSE
#     - pHCO2FlowControllerRequest(%)    0    FALSE
#     ?                                  ^         ----
#     + pHCO2FlowControllerRequest(%)    1    FALSE
#     ?                                  ^
#     + pHCO2ManMax(%)    0.001    FALSE
#     - DoorPressureSafe    0    FALSE
#     - MFCAirFlowFeedback(LPM)    0.01    TRUE
#     - MFCN2FlowFeedback(LPM)    0.01    TRUE
#     - MFCO2FlowFeedback(LPM)    0.01    TRUE
#     - MFCCO2FlowFeedback(LPM)    0.01    TRUE
#     - DoorPressureSensor    0    FALSE
#     - LevelNoCal(L)    0    FALSE
#     - Alm_CombPlate    0    FALSE
#     - AgMotorPower(V)    0    FALSE
#     - AgMotorPWM.Duty    0    FALSE
#     - AgMotorPWM.OnTime(Cycle)    0    FALSE
#     - AgMotorPWM.Period(Cycle)    0    FALSE
#     - AgPowerControl.PGain(%/RPM)    0    FALSE
#     - AgPowerControl.ITime(min)    0    FALSE
#     - AgPowerControl.DTime(min)    0    FALSE
#     - AgPowerRangeAuto(%).Max    0    FALSE
#     - AgPowerRangeAuto(%).Min    0    FALSE
#     - AgPwrLookupFactor(%/RPM)    0    FALSE
#     - AgPowerActualRequest(%)    0    FALSE
#     - AgAutoMaxStartup(%)    0    FALSE
#     - MainGasModeActual    0    FALSE
#     - MainGasActualRequest(LPM)    0    FALSE
#     - MainGasFeedback(LPM)    0.01    TRUE
#     - AgMinPower(%)    0    FALSE
#     - DOO2FlowControllerRequestLimited(mLPM)    0    FALSE
#     - AgGasAutoMaxStartup(LPM)    0    FALSE
#     - AgMainGasRangeManMax(LPM)    0    FALSE
#     - AgPowerRangeManMax(%)    0    FALSE
#     - DOO2RangeManMax(mLPM)    0    FALSE
#     - DON2RangeManMax(%)    0    FALSE
#     - MainGasRangeManMax(LPM)    0    FALSE
#     - FilterOvenDutyRangeManMax(%)    0    FALSE
#     - CalMFCAir.m(LPM/V)    0    FALSE
#     - CalMFCAir.b(LPM)    0    FALSE
#     - CalMFCCO2.m(LPM/V)    0    FALSE
#     - CalMFCCO2.b(LPM)    0    FALSE
#     - CalMFCN2.m(LPM/V)    0    FALSE
#     - CalMFCN2.b(LPM)    0    FALSE
#     - CalMFCO2.m(LPM/V)    0    FALSE
#     - CalMFCO2.b(LPM)    0    FALSE
#     - MFCLoopTime(ticks/Cycle)    0    FALSE
#     - HarvestDelay(s)    0    FALSE
#     - HarvestTimeout    0    FALSE
#     - DOO2ControlMag.PGain(%/%)    0    FALSE
#     - DOO2ControlMag.ITime(min)    0    FALSE
#     - DOO2ControlMag.DTime(min)    0    FALSE
#     - DOO2RangeManMax(%)    0    FALSE
#     - DOO2FlowControllerRequest(%)    0    FALSE
#     - DOO2FlowControllerRequestLimited(%)    1    TRUE
#     - AgControlAlpha    0    FALSE
#     - AgControlBeta    0    FALSE
#     - AgControlGamma    0    FALSE
#     - AgControlLinearity    0    FALSE
#     - DOO2ControlAlpha    0    FALSE
#     - DOO2ControlBeta    0    FALSE
#     - DOO2ControlGamma    0    FALSE
#     - DOO2ControlLinearity    0    FALSE
#     - DON2ControlAlpha    0    FALSE
#     - DON2ControlBeta    0    FALSE
#     - DON2ControlGamma    0    FALSE
#     - DON2ControlLinearity    0    FALSE
#     - FilterOvenDutyControlAlpha    0    FALSE
#     - FilterOvenDutyControlBeta    0    FALSE
#     - FilterOvenDutyControlGamma    0    FALSE
#     - FilterOvenDutyControlLinearity    0    FALSE
#     - pHBaseDutyControlAlpha    0    FALSE
#     - pHBaseDutyControlBeta    0    FALSE
#     - pHBaseDutyControlGamma    0    FALSE
#     - pHBaseDutyControlLinearity    0    FALSE
#     - pHCO2ControlAlpha    0    FALSE
#     - pHCO2ControlBeta    0    FALSE
#     - pHCO2ControlGamma    0    FALSE
#     - pHCO2ControlLinearity    0    FALSE
#     - TempHeatDutyControlAlpha    0    FALSE
#     - TempHeatDutyControlBeta    0    FALSE
#     - TempHeatDutyControlGamma    0    FALSE
#     - TempHeatDutyControlLinearity    0    FALSE
#     - InterlockAgMotor    0    FALSE
#     - DOO2RangeAutoMax(mLPM)    0    FALSE
#     - DOO2RangeAutoMax(%)    0    FALSE
#     - DON2RangeAutoMax(%)    0    FALSE
#     - FilterOvenDutyRangeAutoMax(%)    0    FALSE
#     - Pumps&ValvesPumpUser1    0    FALSE
#     - Pumps&ValvesPumpUser2    0    FALSE
#     - TempSP(C)    0    FALSE
#     - AgSP(RPM)    0    FALSE
#     - TempAIsPrimaryUser    0    FALSE
#     - AgModeUser    0    FALSE
#     - AgMainGasUser(LPM)    0    FALSE
#     - TempModeUser    0    FALSE
#     - TempHeatDutyUser(%)    0    FALSE
#     - AlarmBuzzerUser    0    FALSE
#     - Pumps&ValvesFillSpeed(RPM)    0    FALSE
#     - pHSP    0    FALSE
#     - pHModeUser    0    FALSE
#     - pHAIsPrimaryUser    0    FALSE
#     - pHCO2User(%)    0    FALSE
#     ?                 ^         ----
#     + pHCO2User(%)    1    FALSE
#     ?                 ^
#     + pHDeadband    0.001    TRUE
#     - pHBaseDutyUser(%)    0    FALSE
#     - DOSP(%)    0    TRUE
#     - DOModeUser    0    FALSE
#     - DOAisPrimaryUser    0    FALSE
#     - DOO2FlowUser(mLPM)    0    FALSE
#     - DON2FlowUser(%)    0    FALSE
#     - FilterOvenDutyUser(%)    0    FALSE
#     - Pumps&ValvesPumpSmplRevrsReq    0    FALSE
#     - Pumps&ValvesPumpSmplReq    0    FALSE
#     - FilterOvenSP(C)    0    FALSE
#     - FilterOvenModeUser    0    FALSE
#     - FilterOvenSensorActive    0    FALSE
#     - Pumps&ValvesBasePumpSelection    0    FALSE
#     - DOAIsPrimaryActual    0    FALSE
#     - LEDWhiteLEDOn    0    FALSE
#     - DOAtLeast1GoodSensor    0    FALSE
#     - LevelSensorEnable    0    FALSE
#     - Pumps&ValvesFillSpeed(RPM) 2    0    FALSE
#     - Pumps&ValvesFillSpeed(RPM) 3    0    FALSE
#     - AgPowerUser(%)    0    FALSE
#     - MainGasUser(LPM)    0    FALSE
#     - MainGasModeUser    0    FALSE
#     - pHHardware    0    FALSE
#     ?                         ----
#     + pHHardware    0.5    FALSE
#     ?                ++
#     + pHInRange.A    0.5    FALSE
#     + pHInRange.B    0.5    FALSE
#     + pHMismatchThresh    0.001    FALSE
#     + pHModeActual    0.5    TRUE
#     + pHModeUser    0.5    FALSE
#     + pHPV    0.05    TRUE
#     + pHRateFailDeltaPV    0.001    FALSE
#     + pHRateFailDeltaTime(ms)    1    FALSE
#     + pHSP    0.01    TRUE
#     - pHUserConfig    0    FALSE
#     ?                           ----
#     + pHUserConfig    0.5    FALSE
#     ?                  ++
#     + pHValidMax    0.001    FALSE
#     + pHValidMin    0.001    FALSE
#     - TempHardware    0    FALSE
#     - TempUserConfig    0    FALSE
#     - DOHardware    0    FALSE
#     - DOUserConfig    0    FALSE
#     - HarvestMode    0    FALSE
#     - DOO2FlowUser(%)    0    FALSE
#     - AgRPMLoopTime(ticks/Cycle)    0    FALSE
#
# OQ-Alarms Verification.sys:
#     var                                           type   user      pbs
#     Safety.Max Level (L)                          val    3.5    != 4.0
#     Process Alarms.Agitation Low Low (RPM)        val    -1.0   != 10.0
#     Process Alarms.Agitation Low (RPM)            val    -1.0   != 15.0
#     Process Alarms.Agitation High (RPM)           val    100.0  != 35.0
#     Process Alarms.Agitation High High (RPM)      val    100.0  != 38.0
#     Process Alarms.Temp Low Low (C)               val    0.0    != 35.0
#     Process Alarms.Temp Low (C)                   val    0.0    != 36.0
#     Process Alarms.Temp High (C)                  val    99.0   != 38.0
#     Process Alarms.Temp High High (C)             val    99.0   != 39.0
#     Process Alarms.DO Low Low (%)                 val    0.0    != 30.0
#     Process Alarms.DO Low (%)                     val    0.0    != 40.0
#     Process Alarms.DO High (%)                    val    999.0  != 60.0
#     Process Alarms.DO High High (%)               val    999.0  != 70.0
#     Process Alarms.pH Low Low                     val    0.0    != 7.1
#     Process Alarms.pH Low                         val    0.0    != 7.15
#     Process Alarms.pH High                        val    99.0   != 7.25
#     Process Alarms.pH High High                   val    99.0   != 7.3
#     Process Alarms.Pressure Low Low (psi)         val    -9.0   != -1.0
#     Process Alarms.Pressure Low (psi)             val    -9.0   != -0.5
#     Process Alarms.Pressure High (psi)            val    9.0    != 0.2
#     Process Alarms.Pressure High High (psi)       val    9.0    != 0.3
#     Process Alarms.Level Low Low (L)              val    0.0    != 0.5
#     Process Alarms.Level Low (L)                  val    0.0    != 1.3
#     Process Alarms.Level High (L)                 val    7.0    != 3.25
#     Process Alarms.Level High High (L)            val    7.0    != 3.5
#     Process Alarms.Filter Oven Low Low (C)        val    0.0    != 45.0
#     Process Alarms.Filter Oven Low (C)            val    0.0    != 47.0
#     Process Alarms.Filter Oven High (C)           val    999.0  != 53.0
#     Process Alarms.Filter Oven High High (C)      val    999.0  != 55.0
#     Process Alarms.Main Gas Low Low (LPM)         val    -9.0   != 0.05
#     Process Alarms.Main Gas Low (LPM)             val    -9.0   != 0.1
#     Process Alarms.Main Gas High (LPM)            val    9.0    != 0.4
#     Process Alarms.Main Gas High High (LPM)       val    9.0    != 0.45
#     System.Max Data Log Interval (min)            val    10.0   != 60.0
#
# sv backup.sys:
#     var                                           type   user      pbs
#     Safety.Max Level (L)                          val    3.5    != 4.0
#     System.Max Data Log Interval (min)            val    10.0   != 60.0
#
# System Variables.sys:
#     var                                           type   user      pbs
#     DO.Valid High (DO%)                           val    350.0  != 200.0
#     Safety.Max Level (L)                          val    3.5    != 4.0
#     Process Alarms.Agitation Low Low (RPM)        val    0.0    != 10.0
#     Process Alarms.Agitation Low (RPM)            val    -4.0   != 15.0
#     Process Alarms.Agitation High (RPM)           val    80.0   != 35.0
#     Process Alarms.Agitation High High (RPM)      val    80.0   != 38.0
#     Process Alarms.Temp Low Low (C)               val    0.0    != 35.0
#     Process Alarms.Temp Low (C)                   val    0.0    != 36.0
#     Process Alarms.Temp High (C)                  val    80.0   != 38.0
#     Process Alarms.Temp High High (C)             val    80.0   != 39.0
#     Process Alarms.DO Low Low (%)                 val    0.0    != 30.0
#     Process Alarms.DO Low (%)                     val    0.0    != 40.0
#     Process Alarms.DO High (%)                    val    800.0  != 60.0
#     Process Alarms.DO High High (%)               val    800.0  != 70.0
#     Process Alarms.pH Low Low                     val    0.0    != 7.1
#     Process Alarms.pH Low                         val    0.0    != 7.15
#     Process Alarms.pH High                        val    88.0   != 7.25
#     Process Alarms.pH High High                   val    80.0   != 7.3
#     Process Alarms.Pressure Low Low (psi)         val    -9.0   != -1.0
#     Process Alarms.Pressure Low (psi)             val    -9.0   != -0.5
#     Process Alarms.Pressure High (psi)            val    9.0    != 0.2
#     Process Alarms.Pressure High High (psi)       val    9.0    != 0.3
#     Process Alarms.Level Low Low (L)              val    0.0    != 0.5
#     Process Alarms.Level Low (L)                  val    0.0    != 1.3
#     Process Alarms.Level High (L)                 val    8.0    != 3.25
#     Process Alarms.Level High High (L)            val    8.0    != 3.5
#     Process Alarms.Filter Oven Low Low (C)        val    0.0    != 45.0
#     Process Alarms.Filter Oven Low (C)            val    0.0    != 47.0
#     Process Alarms.Filter Oven High (C)           val    888.0  != 53.0
#     Process Alarms.Filter Oven High High (C)      val    99.0   != 55.0
#     Process Alarms.Main Gas Low Low (LPM)         val    -9.0   != 0.05
#     Process Alarms.Main Gas Low (LPM)             val    -9.0   != 0.1
#     Process Alarms.Main Gas High (LPM)            val    9.0    != 0.4
#     Process Alarms.Main Gas High High (LPM)       val    9.0    != 0.45
#     System.Max Data Log Interval (min)            val    10.0   != 60.0
