# %%
from hello.hello import open_hello
app = open_hello('192.168.1.132')

# %%
app.login()
data = app.getTrendData('2hr', 'temperature')
data
# Out:
# {'message': {'last': [[1462392255479, 40.002],
#    [1462392279479, 40.029],
#    [1462392303479, 40.047],
#    [1462392327479, 40.068],
#    [1462392351479, 40.094],
#    [1462392375479, 40.129],
#    [1462392399479, 40.164],
#    [1462392423479, 40.207],
#    [1462392447479, 40.237],
#    [1462392471479, 40.268],
#    [1462392495479, 40.29],
#    [1462392519479, 40.31],
#    [1462392543479, 40.326],
#    [1462392567479, 40.339],
#    [1462392591479, 40.352],
#    [1462392615479, 40.363],
#    [1462392639479, 40.367],
#    [1462392663479, 40.377],
#    [1462392687479, 40.381],
#    [1462392711479, 40.381],
#    [1462392735479, 40.385],
#    [1462392759479, 40.388],
#    [1462392783479, 40.389],
#    [1462392807479, 40.382],
#    [1462392831479, 40.383],
#    [1462392855479, 40.382],
#    [1462392879479, 40.378],
#    [1462392903479, 40.375],
#    [1462392927479, 40.371],
#    [1462392951479, 40.365],
#    [1462392975479, 40.362],
#    [1462392999479, 40.355],
# ...

# %%
data['message'].keys()
# Out:
# dict_keys(['max', 'min', 'last'])

# %%
d = data['message']['last']

# %%
# %matplotlib
# Out:
# Using matplotlib backend: TkAgg

# %%
from matplotlib import pyplot as plt

# %%
x, y = zip(*d)
x = [(p-x[0])/1000 for p in x]
x = [p if p > 3000 else None for p in x ]
x2 = []
y2 = []
for p1, p2 in zip(x, y):
    if p1 is not None:
        x2.append(p1); y2.append(p2)
x = x2
y = y2

# %%
plt.scatter(x,y)

# %%
from matplotlib.animation import FuncAnimation

# %%
FuncAnimation?

# %%
def update():
    de
