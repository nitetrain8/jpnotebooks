# %%
pth = "C:\\Users\\Administrator\\Documents\\pyprojects\\python\\scripts\\toys\\empty.c"
with open(pth, 'r') as f:
    src = f.read()

# %%
lines = src.splitlines()
it = iter(lines)
sz = 0
i = 1
s=""
while sz < 23782:
    s= next(it)
    sz += len(s) + 1
    i += 1
    print(i - 1, s)
# Out:
# 1 /* Generated by Cython 0.24 */
# 2
# 3 /* BEGIN: Cython Metadata
# 4 {
# 5     "distutils": {}
# 6 }
# 7 END: Cython Metadata */
# 8
# 9 #define PY_SSIZE_T_CLEAN
# 10 #include "Python.h"
# 11 #ifndef Py_PYTHON_H
# 12     #error Python headers needed to compile C extensions, please install development version of Python.
# 13 #elif PY_VERSION_HEX < 0x02060000 || (0x03000000 <= PY_VERSION_HEX && PY_VERSION_HEX < 0x03020000)
# 14     #error Cython requires Python 2.6+ or Python 3.2+.
# 15 #else
# 16 #define CYTHON_ABI "0_24"
# 17 #include <stddef.h>
# 18 #ifndef offsetof
# 19   #define offsetof(type, member) ( (size_t) & ((type*)0) -> member )
# 20 #endif
# 21 #if !defined(WIN32) && !defined(MS_WINDOWS)
# 22   #ifndef __stdcall
# 23     #define __stdcall
# 24   #endif
# 25   #ifndef __cdecl
# 26     #define __cdecl
# 27   #endif
# 28   #ifndef __fastcall
# 29     #define __fastcall
# 30   #endif
# 31 #endif
# 32 #ifndef DL_IMPORT
# 33   #define DL_IMPORT(t) t
# 34 #endif
# 35 #ifndef DL_EXPORT
# 36   #define DL_EXPORT(t) t
# 37 #endif
# 38 #ifndef PY_LONG_LONG
# 39   #define PY_LONG_LONG LONG_LONG
# 40 #endif
# 41 #ifndef Py_HUGE_VAL
# 42   #define Py_HUGE_VAL HUGE_VAL
# 43 #endif
# 44 #ifdef PYPY_VERSION
# 45   #define CYTHON_COMPILING_IN_PYPY 1
# 46   #define CYTHON_COMPILING_IN_CPYTHON 0
# 47 #else
# 48   #define CYTHON_COMPILING_IN_PYPY 0
# 49   #define CYTHON_COMPILING_IN_CPYTHON 1
# 50 #endif
# 51 #if !defined(CYTHON_USE_PYLONG_INTERNALS) && CYTHON_COMPILING_IN_CPYTHON && PY_VERSION_HEX >= 0x02070000
# 52   #define CYTHON_USE_PYLONG_INTERNALS 1
# 53 #endif
# 54 #if CYTHON_USE_PYLONG_INTERNALS
# 55   #include "longintrepr.h"
# 56   #undef SHIFT
# 57   #undef BASE
# 58   #undef MASK
# 59 #endif
# 60 #if CYTHON_COMPILING_IN_PYPY && PY_VERSION_HEX < 0x02070600 && !defined(Py_OptimizeFlag)
# 61   #define Py_OptimizeFlag 0
# 62 #endif
# 63 #define __PYX_BUILD_PY_SSIZE_T "n"
# 64 #define CYTHON_FORMAT_SSIZE_T "z"
# 65 #if PY_MAJOR_VERSION < 3
# 66   #define __Pyx_BUILTIN_MODULE_NAME "__builtin__"
# 67   #define __Pyx_PyCode_New(a, k, l, s, f, code, c, n, v, fv, cell, fn, name, fline, lnos)\
# 68           PyCode_New(a+k, l, s, f, code, c, n, v, fv, cell, fn, name, fline, lnos)
# 69   #define __Pyx_DefaultClassType PyClass_Type
# 70 #else
# 71   #define __Pyx_BUILTIN_MODULE_NAME "builtins"
# 72   #define __Pyx_PyCode_New(a, k, l, s, f, code, c, n, v, fv, cell, fn, name, fline, lnos)\
# 73           PyCode_New(a, k, l, s, f, code, c, n, v, fv, cell, fn, name, fline, lnos)
# 74   #define __Pyx_DefaultClassType PyType_Type
# 75 #endif
# 76 #ifndef Py_TPFLAGS_CHECKTYPES
# 77   #define Py_TPFLAGS_CHECKTYPES 0
# 78 #endif
# 79 #ifndef Py_TPFLAGS_HAVE_INDEX
# 80   #define Py_TPFLAGS_HAVE_INDEX 0
# 81 #endif
# 82 #ifndef Py_TPFLAGS_HAVE_NEWBUFFER
# 83   #define Py_TPFLAGS_HAVE_NEWBUFFER 0
# 84 #endif
# 85 #ifndef Py_TPFLAGS_HAVE_FINALIZE
# 86   #define Py_TPFLAGS_HAVE_FINALIZE 0
# 87 #endif
# 88 #if PY_VERSION_HEX > 0x03030000 && defined(PyUnicode_KIND)
# 89   #define CYTHON_PEP393_ENABLED 1
# 90   #define __Pyx_PyUnicode_READY(op)       (likely(PyUnicode_IS_READY(op)) ?\
# 91                                               0 : _PyUnicode_Ready((PyObject *)(op)))
# 92   #define __Pyx_PyUnicode_GET_LENGTH(u)   PyUnicode_GET_LENGTH(u)
# 93   #define __Pyx_PyUnicode_READ_CHAR(u, i) PyUnicode_READ_CHAR(u, i)
# 94   #define __Pyx_PyUnicode_KIND(u)         PyUnicode_KIND(u)
# 95   #define __Pyx_PyUnicode_DATA(u)         PyUnicode_DATA(u)
# 96   #define __Pyx_PyUnicode_READ(k, d, i)   PyUnicode_READ(k, d, i)
# 97   #define __Pyx_PyUnicode_IS_TRUE(u)      (0 != (likely(PyUnicode_IS_READY(u)) ? PyUnicode_GET_LENGTH(u) : PyUnicode_GET_SIZE(u)))
# 98 #else
# 99   #define CYTHON_PEP393_ENABLED 0
# 100   #define __Pyx_PyUnicode_READY(op)       (0)
# 101   #define __Pyx_PyUnicode_GET_LENGTH(u)   PyUnicode_GET_SIZE(u)
# 102   #define __Pyx_PyUnicode_READ_CHAR(u, i) ((Py_UCS4)(PyUnicode_AS_UNICODE(u)[i]))
# 103   #define __Pyx_PyUnicode_KIND(u)         (sizeof(Py_UNICODE))
# 104   #define __Pyx_PyUnicode_DATA(u)         ((void*)PyUnicode_AS_UNICODE(u))
# 105   #define __Pyx_PyUnicode_READ(k, d, i)   ((void)(k), (Py_UCS4)(((Py_UNICODE*)d)[i]))
# 106   #define __Pyx_PyUnicode_IS_TRUE(u)      (0 != PyUnicode_GET_SIZE(u))
# 107 #endif
# 108 #if CYTHON_COMPILING_IN_PYPY
# 109   #define __Pyx_PyUnicode_Concat(a, b)      PyNumber_Add(a, b)
# 110   #define __Pyx_PyUnicode_ConcatSafe(a, b)  PyNumber_Add(a, b)
# 111 #else
# 112   #define __Pyx_PyUnicode_Concat(a, b)      PyUnicode_Concat(a, b)
# 113   #define __Pyx_PyUnicode_ConcatSafe(a, b)  ((unlikely((a) == Py_None) || unlikely((b) == Py_None)) ?\
# 114       PyNumber_Add(a, b) : __Pyx_PyUnicode_Concat(a, b))
# 115 #endif
# 116 #if CYTHON_COMPILING_IN_PYPY && !defined(PyUnicode_Contains)
# 117   #define PyUnicode_Contains(u, s)  PySequence_Contains(u, s)
# 118 #endif
# 119 #if CYTHON_COMPILING_IN_PYPY && !defined(PyObject_Format)
# 120   #define PyObject_Format(obj, fmt)  PyObject_CallMethod(obj, "__format__", "O", fmt)
# 121 #endif
# 122 #if CYTHON_COMPILING_IN_PYPY && !defined(PyObject_Malloc)
# 123   #define PyObject_Malloc(s)   PyMem_Malloc(s)
# 124   #define PyObject_Free(p)     PyMem_Free(p)
# 125   #define PyObject_Realloc(p)  PyMem_Realloc(p)
# 126 #endif
# 127 #define __Pyx_PyString_FormatSafe(a, b)   ((unlikely((a) == Py_None)) ? PyNumber_Remainder(a, b) : __Pyx_PyString_Format(a, b))
# 128 #define __Pyx_PyUnicode_FormatSafe(a, b)  ((unlikely((a) == Py_None)) ? PyNumber_Remainder(a, b) : PyUnicode_Format(a, b))
# 129 #if PY_MAJOR_VERSION >= 3
# 130   #define __Pyx_PyString_Format(a, b)  PyUnicode_Format(a, b)
# 131 #else
# 132   #define __Pyx_PyString_Format(a, b)  PyString_Format(a, b)
# 133 #endif
# 134 #if PY_MAJOR_VERSION < 3 && !defined(PyObject_ASCII)
# 135   #define PyObject_ASCII(o)            PyObject_Repr(o)
# 136 #endif
# 137 #if PY_MAJOR_VERSION >= 3
# 138   #define PyBaseString_Type            PyUnicode_Type
# 139   #define PyStringObject               PyUnicodeObject
# 140   #define PyString_Type                PyUnicode_Type
# 141   #define PyString_Check               PyUnicode_Check
# 142   #define PyString_CheckExact          PyUnicode_CheckExact
# 143 #endif
# 144 #if PY_MAJOR_VERSION >= 3
# 145   #define __Pyx_PyBaseString_Check(obj) PyUnicode_Check(obj)
# 146   #define __Pyx_PyBaseString_CheckExact(obj) PyUnicode_CheckExact(obj)
# 147 #else
# 148   #define __Pyx_PyBaseString_Check(obj) (PyString_Check(obj) || PyUnicode_Check(obj))
# 149   #define __Pyx_PyBaseString_CheckExact(obj) (PyString_CheckExact(obj) || PyUnicode_CheckExact(obj))
# 150 #endif
# 151 #ifndef PySet_CheckExact
# 152   #define PySet_CheckExact(obj)        (Py_TYPE(obj) == &PySet_Type)
# 153 #endif
# 154 #define __Pyx_TypeCheck(obj, type) PyObject_TypeCheck(obj, (PyTypeObject *)type)
# 155 #if PY_MAJOR_VERSION >= 3
# 156   #define PyIntObject                  PyLongObject
# 157   #define PyInt_Type                   PyLong_Type
# 158   #define PyInt_Check(op)              PyLong_Check(op)
# 159   #define PyInt_CheckExact(op)         PyLong_CheckExact(op)
# 160   #define PyInt_FromString             PyLong_FromString
# 161   #define PyInt_FromUnicode            PyLong_FromUnicode
# 162   #define PyInt_FromLong               PyLong_FromLong
# 163   #define PyInt_FromSize_t             PyLong_FromSize_t
# 164   #define PyInt_FromSsize_t            PyLong_FromSsize_t
# 165   #define PyInt_AsLong                 PyLong_AsLong
# 166   #define PyInt_AS_LONG                PyLong_AS_LONG
# 167   #define PyInt_AsSsize_t              PyLong_AsSsize_t
# 168   #define PyInt_AsUnsignedLongMask     PyLong_AsUnsignedLongMask
# 169   #define PyInt_AsUnsignedLongLongMask PyLong_AsUnsignedLongLongMask
# 170   #define PyNumber_Int                 PyNumber_Long
# 171 #endif
# 172 #if PY_MAJOR_VERSION >= 3
# 173   #define PyBoolObject                 PyLongObject
# 174 #endif
# 175 #if PY_MAJOR_VERSION >= 3 && CYTHON_COMPILING_IN_PYPY
# 176   #ifndef PyUnicode_InternFromString
# 177     #define PyUnicode_InternFromString(s) PyUnicode_FromString(s)
# 178   #endif
# 179 #endif
# 180 #if PY_VERSION_HEX < 0x030200A4
# 181   typedef long Py_hash_t;
# 182   #define __Pyx_PyInt_FromHash_t PyInt_FromLong
# 183   #define __Pyx_PyInt_AsHash_t   PyInt_AsLong
# 184 #else
# 185   #define __Pyx_PyInt_FromHash_t PyInt_FromSsize_t
# 186   #define __Pyx_PyInt_AsHash_t   PyInt_AsSsize_t
# 187 #endif
# 188 #if PY_MAJOR_VERSION >= 3
# 189   #define __Pyx_PyMethod_New(func, self, klass) ((self) ? PyMethod_New(func, self) : PyInstanceMethod_New(func))
# 190 #else
# 191   #define __Pyx_PyMethod_New(func, self, klass) PyMethod_New(func, self, klass)
# 192 #endif
# 193 #if PY_VERSION_HEX >= 0x030500B1
# 194 #define __Pyx_PyAsyncMethodsStruct PyAsyncMethods
# 195 #define __Pyx_PyType_AsAsync(obj) (Py_TYPE(obj)->tp_as_async)
# 196 #elif CYTHON_COMPILING_IN_CPYTHON && PY_MAJOR_VERSION >= 3
# 197 typedef struct {
# 198     unaryfunc am_await;
# 199     unaryfunc am_aiter;
# 200     unaryfunc am_anext;
# 201 } __Pyx_PyAsyncMethodsStruct;
# 202 #define __Pyx_PyType_AsAsync(obj) ((__Pyx_PyAsyncMethodsStruct*) (Py_TYPE(obj)->tp_reserved))
# 203 #else
# 204 #define __Pyx_PyType_AsAsync(obj) NULL
# 205 #endif
# 206 #ifndef CYTHON_RESTRICT
# 207   #if defined(__GNUC__)
# 208     #define CYTHON_RESTRICT __restrict__
# 209   #elif defined(_MSC_VER) && _MSC_VER >= 1400
# 210     #define CYTHON_RESTRICT __restrict
# 211   #elif defined (__STDC_VERSION__) && __STDC_VERSION__ >= 199901L
# 212     #define CYTHON_RESTRICT restrict
# 213   #else
# 214     #define CYTHON_RESTRICT
# 215   #endif
# 216 #endif
# 217 #define __Pyx_void_to_None(void_result) ((void)(void_result), Py_INCREF(Py_None), Py_None)
# 218
# 219 #ifndef CYTHON_INLINE
# 220   #if defined(__GNUC__)
# 221     #define CYTHON_INLINE __inline__
# 222   #elif defined(_MSC_VER)
# 223     #define CYTHON_INLINE __inline
# 224   #elif defined (__STDC_VERSION__) && __STDC_VERSION__ >= 199901L
# 225     #define CYTHON_INLINE inline
# 226   #else
# 227     #define CYTHON_INLINE
# 228   #endif
# 229 #endif
# 230
# 231 #if defined(WIN32) || defined(MS_WINDOWS)
# 232   #define _USE_MATH_DEFINES
# 233 #endif
# 234 #include <math.h>
# 235 #ifdef NAN
# 236 #define __PYX_NAN() ((float) NAN)
# 237 #else
# 238 static CYTHON_INLINE float __PYX_NAN() {
# 239   float value;
# 240   memset(&value, 0xFF, sizeof(value));
# 241   return value;
# 242 }
# 243 #endif
# 244
# 245
# 246 #define __PYX_ERR(f_index, lineno, Ln_error) \
# 247 { \
# 248   __pyx_filename = __pyx_f[f_index]; __pyx_lineno = lineno; __pyx_clineno = __LINE__; goto Ln_error; \
# 249 }
# 250
# 251 #if PY_MAJOR_VERSION >= 3
# 252   #define __Pyx_PyNumber_Divide(x,y)         PyNumber_TrueDivide(x,y)
# 253   #define __Pyx_PyNumber_InPlaceDivide(x,y)  PyNumber_InPlaceTrueDivide(x,y)
# 254 #else
# 255   #define __Pyx_PyNumber_Divide(x,y)         PyNumber_Divide(x,y)
# 256   #define __Pyx_PyNumber_InPlaceDivide(x,y)  PyNumber_InPlaceDivide(x,y)
# 257 #endif
# 258
# 259 #ifndef __PYX_EXTERN_C
# 260   #ifdef __cplusplus
# 261     #define __PYX_EXTERN_C extern "C"
# 262   #else
# 263     #define __PYX_EXTERN_C extern
# 264   #endif
# 265 #endif
# 266
# 267 #define __PYX_HAVE__empty
# 268 #define __PYX_HAVE_API__empty
# 269 #ifdef _OPENMP
# 270 #include <omp.h>
# 271 #endif /* _OPENMP */
# 272
# 273 #ifdef PYREX_WITHOUT_ASSERTIONS
# 274 #define CYTHON_WITHOUT_ASSERTIONS
# 275 #endif
# 276
# 277 #ifndef CYTHON_UNUSED
# 278 # if defined(__GNUC__)
# 279 #   if !(defined(__cplusplus)) || (__GNUC__ > 3 || (__GNUC__ == 3 && __GNUC_MINOR__ >= 4))
# 280 #     define CYTHON_UNUSED __attribute__ ((__unused__))
# 281 #   else
# 282 #     define CYTHON_UNUSED
# 283 #   endif
# 284 # elif defined(__ICC) || (defined(__INTEL_COMPILER) && !defined(_MSC_VER))
# 285 #   define CYTHON_UNUSED __attribute__ ((__unused__))
# 286 # else
# 287 #   define CYTHON_UNUSED
# 288 # endif
# 289 #endif
# 290 #ifndef CYTHON_NCP_UNUSED
# 291 # if CYTHON_COMPILING_IN_CPYTHON
# 292 #  define CYTHON_NCP_UNUSED
# 293 # else
# 294 #  define CYTHON_NCP_UNUSED CYTHON_UNUSED
# 295 # endif
# 296 #endif
# 297 typedef struct {PyObject **p; const char *s; const Py_ssize_t n; const char* encoding;
# 298                 const char is_unicode; const char is_str; const char intern; } __Pyx_StringTabEntry;
# 299
# 300 #define __PYX_DEFAULT_STRING_ENCODING_IS_ASCII 0
# 301 #define __PYX_DEFAULT_STRING_ENCODING_IS_DEFAULT 0
# 302 #define __PYX_DEFAULT_STRING_ENCODING ""
# 303 #define __Pyx_PyObject_FromString __Pyx_PyBytes_FromString
# 304 #define __Pyx_PyObject_FromStringAndSize __Pyx_PyBytes_FromStringAndSize
# 305 #define __Pyx_uchar_cast(c) ((unsigned char)c)
# 306 #define __Pyx_long_cast(x) ((long)x)
# 307 #define __Pyx_fits_Py_ssize_t(v, type, is_signed)  (\
# 308     (sizeof(type) < sizeof(Py_ssize_t))  ||\
# 309     (sizeof(type) > sizeof(Py_ssize_t) &&\
# 310           likely(v < (type)PY_SSIZE_T_MAX ||\
# 311                  v == (type)PY_SSIZE_T_MAX)  &&\
# 312           (!is_signed || likely(v > (type)PY_SSIZE_T_MIN ||\
# 313                                 v == (type)PY_SSIZE_T_MIN)))  ||\
# 314     (sizeof(type) == sizeof(Py_ssize_t) &&\
# 315           (is_signed || likely(v < (type)PY_SSIZE_T_MAX ||\
# 316                                v == (type)PY_SSIZE_T_MAX)))  )
# 317 #if defined (__cplusplus) && __cplusplus >= 201103L
# 318     #include <cstdlib>
# 319     #define __Pyx_sst_abs(value) std::abs(value)
# 320 #elif SIZEOF_INT >= SIZEOF_SIZE_T
# 321     #define __Pyx_sst_abs(value) abs(value)
# 322 #elif SIZEOF_LONG >= SIZEOF_SIZE_T
# 323     #define __Pyx_sst_abs(value) labs(value)
# 324 #elif defined (_MSC_VER) && defined (_M_X64)
# 325     #define __Pyx_sst_abs(value) _abs64(value)
# 326 #elif defined (__STDC_VERSION__) && __STDC_VERSION__ >= 199901L
# 327     #define __Pyx_sst_abs(value) llabs(value)
# 328 #elif defined (__GNUC__)
# 329     #define __Pyx_sst_abs(value) __builtin_llabs(value)
# 330 #else
# 331     #define __Pyx_sst_abs(value) ((value<0) ? -value : value)
# 332 #endif
# 333 static CYTHON_INLINE char* __Pyx_PyObject_AsString(PyObject*);
# 334 static CYTHON_INLINE char* __Pyx_PyObject_AsStringAndSize(PyObject*, Py_ssize_t* length);
# 335 #define __Pyx_PyByteArray_FromString(s) PyByteArray_FromStringAndSize((const char*)s, strlen((const char*)s))
# 336 #define __Pyx_PyByteArray_FromStringAndSize(s, l) PyByteArray_FromStringAndSize((const char*)s, l)
# 337 #define __Pyx_PyBytes_FromString        PyBytes_FromString
# 338 #define __Pyx_PyBytes_FromStringAndSize PyBytes_FromStringAndSize
# 339 static CYTHON_INLINE PyObject* __Pyx_PyUnicode_FromString(const char*);
# 340 #if PY_MAJOR_VERSION < 3
# 341     #define __Pyx_PyStr_FromString        __Pyx_PyBytes_FromString
# 342     #define __Pyx_PyStr_FromStringAndSize __Pyx_PyBytes_FromStringAndSize
# 343 #else
# 344     #define __Pyx_PyStr_FromString        __Pyx_PyUnicode_FromString
# 345     #define __Pyx_PyStr_FromStringAndSize __Pyx_PyUnicode_FromStringAndSize
# 346 #endif
# 347 #define __Pyx_PyObject_AsSString(s)    ((signed char*) __Pyx_PyObject_AsString(s))
# 348 #define __Pyx_PyObject_AsUString(s)    ((unsigned char*) __Pyx_PyObject_AsString(s))
# 349 #define __Pyx_PyObject_FromCString(s)  __Pyx_PyObject_FromString((const char*)s)
# 350 #define __Pyx_PyBytes_FromCString(s)   __Pyx_PyBytes_FromString((const char*)s)
# 351 #define __Pyx_PyByteArray_FromCString(s)   __Pyx_PyByteArray_FromString((const char*)s)
# 352 #define __Pyx_PyStr_FromCString(s)     __Pyx_PyStr_FromString((const char*)s)
# 353 #define __Pyx_PyUnicode_FromCString(s) __Pyx_PyUnicode_FromString((const char*)s)
# 354 #if PY_MAJOR_VERSION < 3
# 355 static CYTHON_INLINE size_t __Pyx_Py_UNICODE_strlen(const Py_UNICODE *u)
# 356 {
# 357     const Py_UNICODE *u_end = u;
# 358     while (*u_end++) ;
# 359     return (size_t)(u_end - u - 1);
# 360 }
# 361 #else
# 362 #define __Pyx_Py_UNICODE_strlen Py_UNICODE_strlen
# 363 #endif
# 364 #define __Pyx_PyUnicode_FromUnicode(u)       PyUnicode_FromUnicode(u, __Pyx_Py_UNICODE_strlen(u))
# 365 #define __Pyx_PyUnicode_FromUnicodeAndLength PyUnicode_FromUnicode
# 366 #define __Pyx_PyUnicode_AsUnicode            PyUnicode_AsUnicode
# 367 #define __Pyx_NewRef(obj) (Py_INCREF(obj), obj)
# 368 #define __Pyx_Owned_Py_None(b) __Pyx_NewRef(Py_None)
# 369 #define __Pyx_PyBool_FromLong(b) ((b) ? __Pyx_NewRef(Py_True) : __Pyx_NewRef(Py_False))
# 370 static CYTHON_INLINE int __Pyx_PyObject_IsTrue(PyObject*);
# 371 static CYTHON_INLINE PyObject* __Pyx_PyNumber_IntOrLong(PyObject* x);
# 372 static CYTHON_INLINE Py_ssize_t __Pyx_PyIndex_AsSsize_t(PyObject*);
# 373 static CYTHON_INLINE PyObject * __Pyx_PyInt_FromSize_t(size_t);
# 374 #if CYTHON_COMPILING_IN_CPYTHON
# 375 #define __pyx_PyFloat_AsDouble(x) (PyFloat_CheckExact(x) ? PyFloat_AS_DOUBLE(x) : PyFloat_AsDouble(x))
# 376 #else
# 377 #define __pyx_PyFloat_AsDouble(x) PyFloat_AsDouble(x)
# 378 #endif
# 379 #define __pyx_PyFloat_AsFloat(x) ((float) __pyx_PyFloat_AsDouble(x))
# 380 #if PY_MAJOR_VERSION >= 3
# 381 #define __Pyx_PyNumber_Int(x) (PyLong_CheckExact(x) ? __Pyx_NewRef(x) : PyNumber_Long(x))
# 382 #else
# 383 #define __Pyx_PyNumber_Int(x) (PyInt_CheckExact(x) ? __Pyx_NewRef(x) : PyNumber_Int(x))
# 384 #endif
# 385 #define __Pyx_PyNumber_Float(x) (PyFloat_CheckExact(x) ? __Pyx_NewRef(x) : PyNumber_Float(x))
# 386 #if PY_MAJOR_VERSION < 3 && __PYX_DEFAULT_STRING_ENCODING_IS_ASCII
# 387 static int __Pyx_sys_getdefaultencoding_not_ascii;
# 388 static int __Pyx_init_sys_getdefaultencoding_params(void) {
# 389     PyObject* sys;
# 390     PyObject* default_encoding = NULL;
# 391     PyObject* ascii_chars_u = NULL;
# 392     PyObject* ascii_chars_b = NULL;
# 393     const char* default_encoding_c;
# 394     sys = PyImport_ImportModule("sys");
# 395     if (!sys) goto bad;
# 396     default_encoding = PyObject_CallMethod(sys, (char*) "getdefaultencoding", NULL);
# 397     Py_DECREF(sys);
# 398     if (!default_encoding) goto bad;
# 399     default_encoding_c = PyBytes_AsString(default_encoding);
# 400     if (!default_encoding_c) goto bad;
# 401     if (strcmp(default_encoding_c, "ascii") == 0) {
# 402         __Pyx_sys_getdefaultencoding_not_ascii = 0;
# 403     } else {
# 404         char ascii_chars[128];
# 405         int c;
# 406         for (c = 0; c < 128; c++) {
# 407             ascii_chars[c] = c;
# 408         }
# 409         __Pyx_sys_getdefaultencoding_not_ascii = 1;
# 410         ascii_chars_u = PyUnicode_DecodeASCII(ascii_chars, 128, NULL);
# 411         if (!ascii_chars_u) goto bad;
# 412         ascii_chars_b = PyUnicode_AsEncodedString(ascii_chars_u, default_encoding_c, NULL);
# 413         if (!ascii_chars_b || !PyBytes_Check(ascii_chars_b) || memcmp(ascii_chars, PyBytes_AS_STRING(ascii_chars_b), 128) != 0) {
# 414             PyErr_Format(
# 415                 PyExc_ValueError,
# 416                 "This module compiled with c_string_encoding=ascii, but default encoding '%.200s' is not a superset of ascii.",
# 417                 default_encoding_c);
# 418             goto bad;
# 419         }
# 420         Py_DECREF(ascii_chars_u);
# 421         Py_DECREF(ascii_chars_b);
# 422     }
# 423     Py_DECREF(default_encoding);
# 424     return 0;
# 425 bad:
# 426     Py_XDECREF(default_encoding);
# 427     Py_XDECREF(ascii_chars_u);
# 428     Py_XDECREF(ascii_chars_b);
# 429     return -1;
# 430 }
# 431 #endif
# 432 #if __PYX_DEFAULT_STRING_ENCODING_IS_DEFAULT && PY_MAJOR_VERSION >= 3
# 433 #define __Pyx_PyUnicode_FromStringAndSize(c_str, size) PyUnicode_DecodeUTF8(c_str, size, NULL)
# 434 #else
# 435 #define __Pyx_PyUnicode_FromStringAndSize(c_str, size) PyUnicode_Decode(c_str, size, __PYX_DEFAULT_STRING_ENCODING, NULL)
# 436 #if __PYX_DEFAULT_STRING_ENCODING_IS_DEFAULT
# 437 static char* __PYX_DEFAULT_STRING_ENCODING;
# 438 static int __Pyx_init_sys_getdefaultencoding_params(void) {
# 439     PyObject* sys;
# 440     PyObject* default_encoding = NULL;
# 441     char* default_encoding_c;
# 442     sys = PyImport_ImportModule("sys");
# 443     if (!sys) goto bad;
# 444     default_encoding = PyObject_CallMethod(sys, (char*) (const char*) "getdefaultencoding", NULL);
# 445     Py_DECREF(sys);
# 446     if (!default_encoding) goto bad;
# 447     default_encoding_c = PyBytes_AsString(default_encoding);
# 448     if (!default_encoding_c) goto bad;
# 449     __PYX_DEFAULT_STRING_ENCODING = (char*) malloc(strlen(default_encoding_c));
# 450     if (!__PYX_DEFAULT_STRING_ENCODING) goto bad;
# 451     strcpy(__PYX_DEFAULT_STRING_ENCODING, default_encoding_c);
# 452     Py_DECREF(default_encoding);
# 453     return 0;
# 454 bad:
# 455     Py_XDECREF(default_encoding);
# 456     return -1;
# 457 }
# 458 #endif
# 459 #endif
# 460
# 461
# 462 /* Test for GCC > 2.95 */
# 463 #if defined(__GNUC__)     && (__GNUC__ > 2 || (__GNUC__ == 2 && (__GNUC_MINOR__ > 95)))
# 464   #define likely(x)   __builtin_expect(!!(x), 1)
# 465   #define unlikely(x) __builtin_expect(!!(x), 0)
# 466 #else /* !__GNUC__ or GCC < 2.95 */
# 467   #define likely(x)   (x)
# 468   #define unlikely(x) (x)
# 469 #endif /* __GNUC__ */
# 470
# 471 static PyObject *__pyx_m;
# 472 static PyObject *__pyx_d;
# 473 static PyObject *__pyx_b;
# 474 static PyObject *__pyx_empty_tuple;
# 475 static PyObject *__pyx_empty_bytes;
# 476 static PyObject *__pyx_empty_unicode;
# 477 static int __pyx_lineno;
# 478 static int __pyx_clineno = 0;
# 479 static const char * __pyx_cfilenm= __FILE__;
# 480 static const char *__pyx_filename;
# 481
# 482
# 483 static const char *__pyx_f[] = {
# 484   "empty.pyx",
# 485 };
# 486
# 487 /*--- Type declarations ---*/
# 488 struct __pyx_obj_5empty_A;
# 489 struct __pyx_obj_5empty_Empty;
# 490
# 491 /* "empty.pyx":2
# 492  *
# 493  * cdef class A:             # <<<<<<<<<<<<<<
# 494  *     pass
# 495  *
# 496  */
# 497 struct __pyx_obj_5empty_A {
# 498   PyObject_HEAD
# 499 };
# 500
# 501
# 502 /* "empty.pyx":5
# 503  *     pass
# 504  *
# 505  * cdef class Empty:             # <<<<<<<<<<<<<<
# 506  *     def __init__(self):
# 507  *         pass
# 508  */
# 509 struct __pyx_obj_5empty_Empty {
# 510   PyObject_HEAD
# 511   struct __pyx_vtabstruct_5empty_Empty *__pyx_vtab;
# 512 };
# 513
# 514
# 515
# 516 struct __pyx_vtabstruct_5empty_Empty {
# 517   PyObject *(*dummy)(struct __pyx_obj_5empty_Empty *, int, double, char *, struct __pyx_obj_5empty_A *, int __pyx_skip_dispatch);
# 518 };
# 519 static struct __pyx_vtabstruct_5empty_Empty *__pyx_vtabptr_5empty_Empty;
# 520
# 521 /* --- Runtime support code (head) --- */
# 522 /* Refnanny.proto */
# 523 #ifndef CYTHON_REFNANNY
# 524   #define CYTHON_REFNANNY 0
# 525 #endif
# 526 #if CYTHON_REFNANNY
# 527   typedef struct {
# 528     void (*INCREF)(void*, PyObject*, int);
# 529     void (*DECREF)(void*, PyObject*, int);
# 530     void (*GOTREF)(void*, PyObject*, int);
# 531     void (*GIVEREF)(void*, PyObject*, int);
# 532     void* (*SetupContext)(const char*, int, const char*);
# 533     void (*FinishContext)(void**);
# 534   } __Pyx_RefNannyAPIStruct;
# 535   static __Pyx_RefNannyAPIStruct *__Pyx_RefNanny = NULL;
# 536   static __Pyx_RefNannyAPIStruct *__Pyx_RefNannyImportAPI(const char *modname);
# 537   #define __Pyx_RefNannyDeclarations void *__pyx_refnanny = NULL;
# 538 #ifdef WITH_THREAD
# 539   #define __Pyx_RefNannySetupContext(name, acquire_gil)\
# 540           if (acquire_gil) {\
# 541               PyGILState_STATE __pyx_gilstate_save = PyGILState_Ensure();\
# 542               __pyx_refnanny = __Pyx_RefNanny->SetupContext((name), __LINE__, __FILE__);\
# 543               PyGILState_Release(__pyx_gilstate_save);\
# 544           } else {\
# 545               __pyx_refnanny = __Pyx_RefNanny->SetupContext((name), __LINE__, __FILE__);\
# 546           }
# 547 #else
# 548   #define __Pyx_RefNannySetupContext(name, acquire_gil)\
# 549           __pyx_refnanny = __Pyx_RefNanny->SetupContext((name), __LINE__, __FILE__)
# 550 #endif
# 551   #define __Pyx_RefNannyFinishContext()\
# 552           __Pyx_RefNanny->FinishContext(&__pyx_refnanny)
# 553   #define __Pyx_INCREF(r)  __Pyx_RefNanny->INCREF(__pyx_refnanny, (PyObject *)(r), __LINE__)
# 554   #define __Pyx_DECREF(r)  __Pyx_RefNanny->DECREF(__pyx_refnanny, (PyObject *)(r), __LINE__)
# 555   #define __Pyx_GOTREF(r)  __Pyx_RefNanny->GOTREF(__pyx_refnanny, (PyObject *)(r), __LINE__)
# 556   #define __Pyx_GIVEREF(r) __Pyx_RefNanny->GIVEREF(__pyx_refnanny, (PyObject *)(r), __LINE__)
# 557   #define __Pyx_XINCREF(r)  do { if((r) != NULL) {__Pyx_INCREF(r); }} while(0)
# 558   #define __Pyx_XDECREF(r)  do { if((r) != NULL) {__Pyx_DECREF(r); }} while(0)
# 559   #define __Pyx_XGOTREF(r)  do { if((r) != NULL) {__Pyx_GOTREF(r); }} while(0)
# 560   #define __Pyx_XGIVEREF(r) do { if((r) != NULL) {__Pyx_GIVEREF(r);}} while(0)
# 561 #else
# 562   #define __Pyx_RefNannyDeclarations
# 563   #define __Pyx_RefNannySetupContext(name, acquire_gil)
# 564   #define __Pyx_RefNannyFinishContext()
# 565   #define __Pyx_INCREF(r) Py_INCREF(r)
# 566   #define __Pyx_DECREF(r) Py_DECREF(r)
# 567   #define __Pyx_GOTREF(r)
# 568   #define __Pyx_GIVEREF(r)
# 569   #define __Pyx_XINCREF(r) Py_XINCREF(r)
# 570   #define __Pyx_XDECREF(r) Py_XDECREF(r)
# 571   #define __Pyx_XGOTREF(r)
# 572   #define __Pyx_XGIVEREF(r)
# 573 #endif
# 574 #define __Pyx_XDECREF_SET(r, v) do {\
# 575         PyObject *tmp = (PyObject *) r;\
# 576         r = v; __Pyx_XDECREF(tmp);\
# 577     } while (0)
# 578 #define __Pyx_DECREF_SET(r, v) do {\
# 579         PyObject *tmp = (PyObject *) r;\
# 580         r = v; __Pyx_DECREF(tmp);\
# 581     } while (0)
# 582 #define __Pyx_CLEAR(r)    do { PyObject* tmp = ((PyObject*)(r)); r = NULL; __Pyx_DECREF(tmp);} while(0)
# 583 #define __Pyx_XCLEAR(r)   do { if((r) != NULL) {PyObject* tmp = ((PyObject*)(r)); r = NULL; __Pyx_DECREF(tmp);}} while(0)
# 584
# 585 /* RaiseArgTupleInvalid.proto */
# 586 static void __Pyx_RaiseArgtupleInvalid(const char* func_name, int exact,
# 587     Py_ssize_t num_min, Py_ssize_t num_max, Py_ssize_t num_found);
# 588
# 589 /* KeywordStringCheck.proto */
# 590 static CYTHON_INLINE int __Pyx_CheckKeywordStrings(PyObject *kwdict, const char* function_name, int kw_allowed);
# 591
# 592 /* PyObjectGetAttrStr.proto */
# 593 #if CYTHON_COMPILING_IN_CPYTHON
# 594 static CYTHON_INLINE PyObject* __Pyx_PyObject_GetAttrStr(PyObject* obj, PyObject* attr_name) {
# 595     PyTypeObject* tp = Py_TYPE(obj);
# 596     if (likely(tp->tp_getattro))
# 597         return tp->tp_getattro(obj, attr_name);
# 598 #if PY_MAJOR_VERSION < 3
# 599     if (likely(tp->tp_getattr))
# 600         return tp->tp_getattr(obj, PyString_AS_STRING(attr_name));
# 601 #endif
# 602     return PyObject_GetAttr(obj, attr_name);
# 603 }
# 604 #else
# 605 #define __Pyx_PyObject_GetAttrStr(o,n) PyObject_GetAttr(o,n)
# 606 #endif
# 607
# 608 /* PyObjectCall.proto */
# 609 #if CYTHON_COMPILING_IN_CPYTHON
# 610 static CYTHON_INLINE PyObject* __Pyx_PyObject_Call(PyObject *func, PyObject *arg, PyObject *kw);
# 611 #else
# 612 #define __Pyx_PyObject_Call(func, arg, kw) PyObject_Call(func, arg, kw)
# 613 #endif
# 614
# 615 /* RaiseDoubleKeywords.proto */
# 616 static void __Pyx_RaiseDoubleKeywordsError(const char* func_name, PyObject* kw_name);
# 617
# 618 /* ParseKeywords.proto */
# 619 static int __Pyx_ParseOptionalKeywords(PyObject *kwds, PyObject **argnames[],\

# %%
# %qtconsole
