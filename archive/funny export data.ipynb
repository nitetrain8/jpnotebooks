# %%
from hello.hello3 import *
h = HelloApp('192.168.1.21')
h.login()
h.send_request("?call=getbatches")
# Out:
# <Response [200]>

# %%
_.read()
# Out:
# b'<?xml version="1.0" encoding="windows-1252" standalone="no" ?>\n<Reply>\n<Result>True</Result>\n<Message><Array>\r\n<Name>Batches (cluster)</Name>\r\n<Dimsize>48</Dimsize>\r\n<Cluster>\r\n<Name>Batch</Name>\r\n<NumElts>5</NumElts>\r\n<I32>\r\n<Name>ID</Name>\r\n<Val>96</Val>\r\n</I32>\r\n<String>\r\n<Name>Name</Name>\r\n<Val>do 1.3</Val>\r\n</String>\r\n<String>\r\n<Name>User</Name>\r\n<Val>user1</Val>\r\n</String>\r\n<String>\r\n<Name>Start Time</Name>\r\n<Val>11:00:30 AM\n05/04/2017</Val>\r\n</String>\r\n<String>\r\n<Name>Stop Time</Name>\r\n<Val>11:00:30 AM\n05/04/2017</Val>\r\n</String>\r\n</Cluster>\r\n<Cluster>\r\n<Name>Batch</Name>\r\n<NumElts>5</NumElts>\r\n<I32>\r\n<Name>ID</Name>\r\n<Val>94</Val>\r\n</I32>\r\n<String>\r\n<Name>Name</Name>\r\n<Val>do 1.2</Val>\r\n</String>\r\n<String>\r\n<Name>User</Name>\r\n<Val>user1</Val>\r\n</String>\r\n<String>\r\n<Name>Start Time</Name>\r\n<Val>02:25:20 PM\n05/03/2017</Val>\r\n</String>\r\n<String>\r\n<Name>Stop Time</Name>\r\n<Val><
# ...

# %%
print(_2.decode())
# Out:
# <?xml version="1.0" encoding="windows-1252" standalone="no" ?>
# <Reply>
# <Result>True</Result>
# <Message><Array>
# <Name>Batches (cluster)</Name>
# <Dimsize>48</Dimsize>
# <Cluster>
# <Name>Batch</Name>
# <NumElts>5</NumElts>
# <I32>
# <Name>ID</Name>
# <Val>96</Val>
# </I32>
# <String>
# <Name>Name</Name>
# <Val>do 1.3</Val>
# </String>
# <String>
# <Name>User</Name>
# <Val>user1</Val>
# </String>
# <String>
# <Name>Start Time</Name>
# <Val>11:00:30 AM
# 05/04/2017</Val>
# </String>
# <String>
# <Name>Stop Time</Name>
# <Val>11:00:30 AM
# 05/04/2017</Val>
# </String>
# </Cluster>
# <Cluster>
# <Name>Batch</Name>
# <NumElts>5</NumElts>
# <I32>
# <Name>ID</Name>
# <Val>94</Val>
# </I32>
# <String>
# <Name>Name</Name>
# <Val>do 1.2</Val>
# </String>
# <String>
# <Name>User</Name>
# <Val>user1</Val>
# </String>
# <String>
# <Name>Start Time</Name>
# <Val>02:25:20 PM
# 05/03/2017</Val>
# </String>
# <String>
# <Name>Stop Time</Name>
# <Val></Val>
# </String>
# </Cluster>
# <Cluster>
# ...
