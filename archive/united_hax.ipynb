# %%
import requests

# %%
sess = requests.Session()

# %%
r = sess.get("https://www.unitedwifi.com/portal/l/entertainment#/pde/browse")

# %%
lines = r.content.decode().split()

# %%
l2 = [l for l in lines if 'class="swiper-slide' in l]

# %%
l2 = [l for l in lines if "swiper" in l]
l2
# Out:
# ['href="../assets/css/v1/swiper.css?1508115941"']

# %%
lines
# Out:
# ['<!DOCTYPE',
#  'html>',
#  '<html',
#  'lang="en"',
#  'class="no-js">',
#  '<head>',
#  '<!--[if',
#  'lte',
#  'IE',
#  '8]>',
#  '<meta',
#  'http-equiv="refresh"',
#  'content="0;url=notsupported"',
#  '/>',
#  '<![endif]-->',
#  '<meta',
#  'http-equiv="Content-Type"',
#  'content="text/html;',
#  'charset=UTF-8"',
#  '/>',
#  '<meta',
#  'name="viewport"',
#  'content="width=device-width,',
#  'initial-scale=1.0,',
#  'minimum-scale=1.0,',
#  'maximum-scale=1.0,',
#  'user-scalable=no,',
#  'user-scalable=0">',
#  '<link',
#  'rel="stylesheet"',
#  'href="../assets/css/v1/ResetNormalize.css?1508115941"',
#  '/>',
#  '<link',
#  'rel="stylesheet"',
#  'href="../assets/css/v1/main.css?1508115941"',
#  '/>',
#  '<link',
#  'rel="stylesheet"',
#  'href="../assets/css/v1/header.css?1508115941"',
#  '/>',
#  '<link',
#  'rel="stylesheet"',
#  'href="../assets/css/v1/menuOnePage.css?1508115941"',
#  '/>',
#  '<!--/Icons',
#  'and',
#  'colors/-->',
#  '<link',
# ...
