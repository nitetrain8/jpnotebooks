# %%
from hello.hello3 import *
import os
from datetime import datetime,timedelta

# %%
def hts(d):
    return int(d.timestamp()*1)

def fmt(d):
    return d.strftime("%m/%d/%y %I:%M%p")

def call(h, f, *args):
    while True:
        try:
            rv = f(*args)
        except NotLoggedInError:
            h.login()
        else:
            return rv

def download(h, d1, d2):
    s1 = hts(d1)
    s2 = hts(d2)
    fn = call(h, h.getReport, 'byDate', 'process_data', s1, s2)
    b  = call(h, h.getfile, fn)
    return b

# %%
d1 = datetime(2017, 5, 31, 7, 46)
span = timedelta(hours=2)
end = datetime(2017, 6, 13, 17, 17, 21)
h = HelloApp('192.168.1.3')
path = "15L bio lab downloads\\"
os.makedirs(path, exist_ok=True)
print("Start:", fmt(d1))
print("End:  ", fmt(d2))
while d1 < end:
    d2 = d1+span
    if d2 > end:
        d2 = end
    print("Downloading from %s to %s" % (fmt(d1),fmt(d2)))
    b = download(h, d1, d2)
    dfmt = "%m-%d-%y %H.%M"
    fn = path + "%s to %s.csv" % (d1.strftime(dfmt), d2.strftime(dfmt))
    with open(fn, 'wb') as f:
        f.write(b)
    d1 += span
print("Done")
# Out:
# Downloading from 05/31/17 07:46AM to 05/31/17 09:46AM
# Downloading from 05/31/17 09:46AM to 05/31/17 11:46AM
# Downloading from 05/31/17 11:46AM to 05/31/17 01:46PM
# Downloading from 05/31/17 01:46PM to 05/31/17 03:46PM
# Downloading from 05/31/17 03:46PM to 05/31/17 05:46PM
# Downloading from 05/31/17 05:46PM to 05/31/17 07:46PM
# Downloading from 05/31/17 07:46PM to 05/31/17 09:46PM
# Downloading from 05/31/17 09:46PM to 05/31/17 11:46PM
# Downloading from 05/31/17 11:46PM to 06/01/17 01:46AM
# Downloading from 06/01/17 01:46AM to 06/01/17 03:46AM
# Downloading from 06/01/17 03:46AM to 06/01/17 05:46AM
# Downloading from 06/01/17 05:46AM to 06/01/17 07:46AM
# Downloading from 06/01/17 07:46AM to 06/01/17 09:46AM
# Downloading from 06/01/17 09:46AM to 06/01/17 11:46AM
# Downloading from 06/01/17 11:46AM to 06/01/17 01:46PM
# Downloading from 06/01/17 01:46PM to 06/01/17 03:46PM
# Downloading from 06/01/17 03:46PM to 06/01/17 05:46PM
# Downloading from 06/01/17 05:46PM to 06/01/17 07:46PM
# Downloading from 06/01/17 07:46PM to 06/01/17 09:46PM
# Downloading from 06/01/17 09:46PM to 06/01/17 11:46PM
# Downloading from 06/01/17 11:46PM to 06/02/17 01:46AM
# Downloading from 06/02/17 01:46AM to 06/02/17 03:46AM
# Downloading from 06/02/17 03:46AM to 06/02/17 05:46AM
# Downloading from 06/02/17 05:46AM to 06/02/17 07:46AM
# Downloading from 06/02/17 07:46AM to 06/02/17 09:46AM
# Downloading from 06/02/17 09:46AM to 06/02/17 11:46AM
# Downloading from 06/02/17 11:46AM to 06/02/17 01:46PM
# Downloading from 06/02/17 01:46PM to 06/02/17 03:46PM
# Downloading from 06/02/17 03:46PM to 06/02/17 05:46PM
# Downloading from 06/02/17 05:46PM to 06/02/17 07:46PM
# Downloading from 06/02/17 07:46PM to 06/02/17 09:46PM
#  '06-10-17 09.46 to 06-10-17 11.46.csv',
#  '06-10-17 11.46 to 06-10-17 13.46.csv',
#  '06-10-17 13.46 to 06-10-17 15.46.csv',
#  '06-10-17 15.46 to 06-10-17 17.46.csv',
#  '06-10-17 17.46 to 06-10-17 19.46.csv',
#  '06-10-17 19.46 to 06-10-17 21.46.csv',
#  '06-10-17 21.46 to 06-10-17 23.46.csv',
#  '06-10-17 23.46 to 06-11-17 01.46.csv',
#  '06-11-17 01.46 to 06-11-17 03.46.csv',
#  '06-11-17 03.46 to 06-11-17 05.46.csv',
#  '06-11-17 05.46 to 06-11-17 07.46.csv',
#  '06-11-17 07.46 to 06-11-17 09.46.csv',
#  '06-11-17 09.46 to 06-11-17 11.46.csv',
#  '06-11-17 11.46 to 06-11-17 13.46.csv',
#  '06-11-17 13.46 to 06-11-17 15.46.csv',
#  '06-11-17 15.46 to 06-11-17 17.46.csv',
#  '06-11-17 17.46 to 06-11-17 19.46.csv',
#  '06-11-17 19.46 to 06-11-17 21.46.csv',
#  '06-11-17 21.46 to 06-11-17 23.46.csv',
#  '06-11-17 23.46 to 06-12-17 01.46.csv',
#  '06-12-17 01.46 to 06-12-17 03.46.csv',
#  '06-12-17 03.46 to 06-12-17 05.46.csv',
#  '06-12-17 05.46 to 06-12-17 07.46.csv',
#  '06-12-17 07.46 to 06-12-17 09.46.csv',
#  '06-12-17 09.46 to 06-12-17 11.46.csv',
#  '06-12-17 11.46 to 06-12-17 13.46.csv',
#  '06-12-17 13.46 to 06-12-17 15.46.csv',
#  '06-12-17 15.46 to 06-12-17 17.46.csv',
#  '06-12-17 17.46 to 06-12-17 19.46.csv',
#  '06-12-17 19.46 to 06-12-17 21.46.csv',
#  '06-12-17 21.46 to 06-12-17 23.46.csv',
#  '06-12-17 23.46 to 06-13-17 01.46.csv',
#  '06-13-17 01.46 to 06-13-17 03.46.csv',
#  '06-13-17 03.46 to 06-13-17 05.46.csv',
#  '06-13-17 05.46 to 06-13-17 07.46.csv',
#  '06-13-17 07.46 to 06-13-17 09.46.csv',
#  '06-13-17 09.46 to 06-13-17 11.46.csv',
#  '06-13-17 11.46 to 06-13-17 13.46.csv',
#  '06-13-17 13.46 to 06-13-17 15.46.csv',
#  '06-13-17 15.46 to 06-13-17 17.17.csv']

# %%
with open("compiled.csv", 'w') as bigf:
    for file in files:
        print("Compiling %s..."%file)
        with open(path + file, 'r') as f:
            chunk = f.read()
        bigf.write(chunk)
        if chunk[-1] != "\n":
            bigf.write("\n")
# Out:
# Compiling 05-31-17 07.46 to 05-31-17 09.46.csv...
# Compiling 05-31-17 09.46 to 05-31-17 11.46.csv...
# Compiling 05-31-17 11.46 to 05-31-17 13.46.csv...
# Compiling 05-31-17 13.46 to 05-31-17 15.46.csv...
# Compiling 05-31-17 15.46 to 05-31-17 17.46.csv...
# Compiling 05-31-17 17.46 to 05-31-17 19.46.csv...
# Compiling 05-31-17 19.46 to 05-31-17 21.46.csv...
# Compiling 05-31-17 21.46 to 05-31-17 23.46.csv...
# Compiling 05-31-17 23.46 to 06-01-17 01.46.csv...
# Compiling 06-13-17 05.46 to 06-13-17 07.46.csv...
# Compiling 06-13-17 07.46 to 06-13-17 09.46.csv...
# Compiling 06-13-17 09.46 to 06-13-17 11.46.csv...
# Compiling 06-13-17 11.46 to 06-13-17 13.46.csv...
# Compiling 06-13-17 13.46 to 06-13-17 15.46.csv...
# Compiling 06-13-17 15.46 to 06-13-17 17.17.csv...

# %%
file = files[0]

def columnify(text):
    data = list(zip(*(l.split(",") for l in txt.splitlines())))
    return [list(l) for l in data]

def textify(data):
    data = list(zip(*data))
    data = [",".join(l) for l in data]
    return "\n".join(data)

def merge(src, dst):
    if len(src) != len(dst):
        raise ValueError("Data length mismatch: %s != %s" % (len(src), len(dst)))
    for s, d in zip(src, dst):
        d.extend(c for c in s[1:] if c is not None)

with open(path+file, 'r') as f:
    txt = f.read()
data = columnify(txt)
for file in files[1:]:
    with open(path+file, 'r') as f:
        txt = f.read()
    new = columnify(txt)
    print("Merging %s"%file)
    merge(new, data)
txt = textify(data)
with open("compiled2.csv", 'w') as bigf:
    bigf.write(txt)
# Out:
# Merging 05-31-17 09.46 to 05-31-17 11.46.csv
# Merging 05-31-17 11.46 to 05-31-17 13.46.csv
# Merging 05-31-17 13.46 to 05-31-17 15.46.csv
# Merging 05-31-17 15.46 to 05-31-17 17.46.csv
# Merging 05-31-17 17.46 to 05-31-17 19.46.csv
# Merging 05-31-17 19.46 to 05-31-17 21.46.csv
# Merging 05-31-17 21.46 to 05-31-17 23.46.csv
# Merging 05-31-17 23.46 to 06-01-17 01.46.csv
# Merging 06-01-17 01.46 to 06-01-17 03.46.csv
# Merging 06-01-17 03.46 to 06-01-17 05.46.csv
# Merging 06-01-17 05.46 to 06-01-17 07.46.csv
# Merging 06-01-17 07.46 to 06-01-17 09.46.csv
# Merging 06-01-17 09.46 to 06-01-17 11.46.csv
# Merging 06-01-17 11.46 to 06-01-17 13.46.csv
# Merging 06-01-17 13.46 to 06-01-17 15.46.csv
# Merging 06-01-17 15.46 to 06-01-17 17.46.csv
# Merging 06-01-17 17.46 to 06-01-17 19.46.csv
# Merging 06-01-17 19.46 to 06-01-17 21.46.csv
# Merging 06-01-17 21.46 to 06-01-17 23.46.csv
# Merging 06-01-17 23.46 to 06-02-17 01.46.csv
# Merging 06-02-17 01.46 to 06-02-17 03.46.csv
# Merging 06-02-17 03.46 to 06-02-17 05.46.csv
# Merging 06-02-17 05.46 to 06-02-17 07.46.csv
# Merging 06-02-17 07.46 to 06-02-17 09.46.csv
# Merging 06-02-17 09.46 to 06-02-17 11.46.csv
# Merging 06-02-17 11.46 to 06-02-17 13.46.csv
# Merging 06-02-17 13.46 to 06-02-17 15.46.csv
# Merging 06-02-17 15.46 to 06-02-17 17.46.csv
# Merging 06-02-17 17.46 to 06-02-17 19.46.csv
# Merging 06-02-17 19.46 to 06-02-17 21.46.csv
# Merging 06-02-17 21.46 to 06-02-17 23.46.csv
# Merging 06-02-17 23.46 to 06-03-17 01.46.csv
# Merging 06-03-17 01.46 to 06-03-17 03.46.csv
# Merging 06-03-17 03.46 to 06-03-17 05.46.csv
# Merging 06-03-17 05.46 to 06-03-17 07.46.csv
# Merging 06-03-17 07.46 to 06-03-17 09.46.csv
# Merging 06-03-17 09.46 to 06-03-17 11.46.csv
# Merging 06-03-17 11.46 to 06-03-17 13.46.csv
# Merging 06-03-17 13.46 to 06-03-17 15.46.csv
# Merging 06-03-17 15.46 to 06-03-17 17.46.csv
# Merging 06-03-17 17.46 to 06-03-17 19.46.csv
# Merging 06-03-17 19.46 to 06-03-17 21.46.csv
# Merging 06-03-17 21.46 to 06-03-17 23.46.csv
# Merging 06-03-17 23.46 to 06-04-17 01.46.csv
# Merging 06-04-17 01.46 to 06-04-17 03.46.csv
# Merging 06-04-17 03.46 to 06-04-17 05.46.csv
# Merging 06-04-17 05.46 to 06-04-17 07.46.csv
# Merging 06-04-17 07.46 to 06-04-17 09.46.csv
# Merging 06-04-17 09.46 to 06-04-17 11.46.csv
# Merging 06-04-17 11.46 to 06-04-17 13.46.csv
# Merging 06-04-17 13.46 to 06-04-17 15.46.csv
# Merging 06-04-17 15.46 to 06-04-17 17.46.csv
# Merging 06-04-17 17.46 to 06-04-17 19.46.csv
# Merging 06-04-17 19.46 to 06-04-17 21.46.csv
# Merging 06-04-17 21.46 to 06-04-17 23.46.csv
# Merging 06-04-17 23.46 to 06-05-17 01.46.csv
# Merging 06-05-17 01.46 to 06-05-17 03.46.csv
# Merging 06-05-17 03.46 to 06-05-17 05.46.csv
# Merging 06-05-17 05.46 to 06-05-17 07.46.csv
# Merging 06-05-17 07.46 to 06-05-17 09.46.csv
# Merging 06-05-17 09.46 to 06-05-17 11.46.csv
# Merging 06-05-17 11.46 to 06-05-17 13.46.csv
# Merging 06-05-17 13.46 to 06-05-17 15.46.csv
# Merging 06-05-17 15.46 to 06-05-17 17.46.csv
# Merging 06-05-17 17.46 to 06-05-17 19.46.csv
# Merging 06-05-17 19.46 to 06-05-17 21.46.csv
# Merging 06-05-17 21.46 to 06-05-17 23.46.csv
# Merging 06-05-17 23.46 to 06-06-17 01.46.csv
# Merging 06-06-17 01.46 to 06-06-17 03.46.csv
# Merging 06-06-17 03.46 to 06-06-17 05.46.csv
# Merging 06-06-17 05.46 to 06-06-17 07.46.csv
# Merging 06-06-17 07.46 to 06-06-17 09.46.csv
# Merging 06-06-17 09.46 to 06-06-17 11.46.csv
# Merging 06-06-17 11.46 to 06-06-17 13.46.csv
# Merging 06-06-17 13.46 to 06-06-17 15.46.csv
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-d95e2f2effd7> in <module>()
#      24     new = columnify(txt)
#      25     print("Merging %s"%file)
# ---> 26     merge(new, data)
#      27 txt = textify(data)
#      28 with open("compiled2.csv", 'w') as bigf:
#
# <ipython-input-8-d95e2f2effd7> in merge(src, dst)
#      12 def merge(src, dst):
#      13     if len(src) != len(dst):
# ---> 14         raise ValueError("Data length mismatch: %s != %s" % (len(src), len(dst)))
#      15     for s, d in zip(src, dst):
#      16         d.extend(c for c in s[1:] if c is not None)
#
# ValueError: Data length mismatch: 191 != 143

# %%
from itertools import zip_longest, chain
class column():
    def __init__(x=(), y=()):
        self.x = x or []
        self.y = y or []

def grouper(iterable, n, fillvalue=None):
    "Collect data into fixed-length chunks or blocks"
    # grouper('ABCDEFG', 3, 'x') --> ABC DEF Gxx"
    args = [iter(iterable)] * n
    return zip_longest(*args, fillvalue=fillvalue)

def extract(f, ignore=None):
    ignore = ignore or ()
    data = f.read().splitlines()
    data = [l.split(",") for l in data]
    data = list(zip(*data))
    
    # I hate embedded metadata in a csv
    # this is the easiest way to parse it out
    
    for i, col in enumerate(data):
        if col[0] == "Start Time":
            found = True
            break
    else:
        found = False
    if found:
        data = data[:i-1]
    
    rv = {}
    for x, y, _ in grouper(data, 3, None):
        assert x[0] == y[0], (x[0], y[0])
        h = x[0]
        if h in ignore:
            continue
        x = [i for i in x if i != ""]
        y = [i for i in y if i != ""]
        rv[h] = x[1:], y[1:]
    return rv

def dmerge(src, dst):
    for k, (x, y) in src.items():
        if k not in dst:
            dst[k] = [],[]
        dst[k][0].extend(x)
        dst[k][1].extend(y)

def fcompile(files, ignore=None):
    data = {}
    for file in files:
        fp = path+file
        print("\rOpening %s                          " % file, end="")
        with open(fp, 'r') as f:
            d = extract(f, ignore)
        dmerge(d, data)
    print()
    return data
    
def write(fn, data):
    d = []
    for key in sorted(data):
        x, y = data[key]
        l1 = chain((key,), x)
        l2 = chain((key,), y)
        d.extend((l1, l2, []))
                  
#     for c in cols:
#         headers.extend((c, c, ""))
#         x,y = data[c]
#         d.extend((x, y, ()))
#     hs = ",".join(headers)
    
    d = list(zip_longest(*d, fillvalue=""))
    ds = "\n".join(",".join(l) for l in d)
    with open(fn, 'w') as f:
        f.write(ds)

# %%
with open(path+files[0], 'r') as f:
    d = extract(f)
d['MFCCO2FlowFeedback(LPM)']
# Out:
# (['5/31/2017 8:26:41 AM', '5/31/2017 9:26:43 AM'], ['0.068538', '0.068635'])

# %%
ignore = ['MFCCO2MeasRaw(V)', 'MFCN2OutRaw(V).AO(V)', 'MFCCO2OutRaw.AO(V)', 'MFCN2MeasRaw(V)', 'MFCO2MeasRaw(V)', 'MFCAirOutRaw(V).AO(V)', 'MFCN2OutRaw(V).Period(iter)', 'MFCAirMeasRaw(V)']
data = fcompile(files, ignore)
write("15L Biolab Data 170630.csv", data)
# Out:
# Opening 06-13-17 15.46 to 06-13-17 17.17.csv

# %%
def mytimeit(f, n=1):
    from time import time
    start = time()
    for i in range(n):
        f()
    end = time()
    print("%d iteration(s) in %.2f seconds" % (n,end - start))

# %%
def doit():
    data = fcompile(files, ignore)
    write("test2.csv", data)
mytimeit(doit)
# Out:
# Opening 06-13-17 15.46 to 06-13-17 17.17.csv
# 1 iteration(s) in -22.26 seconds

# %%
cols = list(data.keys())
headers = []
d = []
for c in cols:
    headers.extend((c, c, ""))
    x,y = data[c]
    d.extend((x, y, ()))
len(d)
len(headers)
# Out:
# 192

# %%
write("test.csv", data)

# %%
from officelib.xllib import *
from officelib.const import xlconst as xlc

# %%
xl = Excel()
wb = xl.RecentFiles(1).Open()

# %%
ws = wb.Worksheets(1)
cells = ws.Cells
cell_range = cells.Range

# %%
cell_range("CM1").EntireColumn._prop_map_get_.keys()

# %%
cell_range("CM1").End(xlc.xlDown).End(xlc.xlDown).Address

# %%
xlDown=xlc.xlDown
c = cell_range("CM1")
while True:
    c = c.End(xlDown)
    c2 = c.End(xlDown)
    if c2.Value != "pHPV":
        break
    c = c2

# %%
c.Address

# %%
def find_range(c):
    c1 = c
    c1v = c1.Value
    while True:
        c = c.End(xlDown)
        c2 = c.End(xlDown)
        if c2.Value != c1v:
            break
        c = c2
    return cell_range(c1, c.Offset(1,2))
def fix_data(d):
    c1v = d[0][0]
    return [(a,b) for a,b in d if a is not None and a != c1v]

# %%
r = find_range(cell_range("CM1"))
d = r.Value
c1v = cell_range("CM1").Value
# only need to check a or b for None and header values
d2 = [(a, b) for a, b in d if a is not None and a != c1v]
r.Clear()
def paste(data, cell):
    rows = len(data)
    columns = len(data[0])
    br = cell.Offset(rows, columns)
    cell_range(cell, br).Value = data
paste(d2, cell_range("CM1"))

# %%
paste(d2, cell_range("CM2"))

# %%
len([r for r in d if r[0]])

# %%
c = cell_range("A1")
while True:
    print("Fixing data for", c.Value)
    r = find_range(c)
    v = r.Value
    d = fix_data(v)
    hr = cell_range(c, c.Offset(1,2))
    header = hr.Value
    r.Clear()
    hr.Value = header
    paste(d, c.Offset(2,1))
    c = c.Offset(1, 4)
    if c.Value == "Start Time":
        break

# %%
cells = wb.Worksheets("100%").Cells
cell_range = cells.Range
phxp_data = cell_range("CZ7")
diff_data = phxp_data.Offset(1,2)
phxp = cell_range("CY2")
diff = cell_range("DB4")
with screen_lock(xl):
    for i in range(30):
        i /= 100
        xp = 6+i
        phxp.Value = xp
        phxp_data.Value = xp
        diff_data.Value = diff.Value
        phxp_data = phxp_data.Offset(2,1)
        diff_data = diff_data.Offset(2,1)

# %% [markdown]
# # pH Model Analysis 3/14/17

# %%
from officelib.xllib import *
xl = Excel()

# %%
wb = xl.RecentFiles(2).Open()

# %%
ws = wb.Worksheets("40%")
cells = ws.Cells
cell_range = cells.Range

# %%
fudge = cell_range("CS2")
k = cell_range("DH5")
x = []
y = []
xl_nan = -2146826273
with screen_lock(xl):
    for i in range(30):
        fudge.Value = i/100
        v = k.Value
        if v != xl_nan:
            x.append(i/100)
            y.append(v)
        print("\rTesting fudge = %.2f" % (i/100), end="")

# %%
# %matplotlib
import matplotlib.pyplot as plt
plt.plot(x,y)

# %%
c = xl.Selection
br = c.Offset(len(y), 2)
cell_range(c,br).Value = list(zip(x,y))

# %%
hcpc = cell_range("DI3")
hcp = 3.4e-2
x = []
y = []
for offs in range(11):
    newv = hcp - offs/1000
    hcpc.Value = newv
    v = k.Value
    if v != xl_nan:
        x.append(newv)
        y.append(-v)
    print("\rTesting hcp = %.3f" % (newv), end="")

# %%
plt.plot(x,y)

# %%
import numpy as np
bicarb = cell_range("DG3")
bicarbs = np.linspace(0.018, 0.026, 10)
bicarb_value = bicarb.Value
x,y = [],[]
with screen_lock(xl):
    for bc in bicarbs:
        bicarb.Value = bc
        v = k.Value
        if v != xl_nan:
            x.append(bc)
            y.append(-v)
    bicarb.Value = bicarb_value
