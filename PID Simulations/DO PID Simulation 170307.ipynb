# %%
import numpy as np

class PIDController():

    AUTO = 0
    MAN = 1
    OFF = 2

    def __init__(self, pgain=1, itime=1, dtime=0, auto_max=100,
                 auto_min=0, beta=1, linearity=1, alpha=1, deadband=0,
                 sp_high=100, sp_low=0, gamma=0, man_request=0, mode=0):

        self.auto_min = auto_min
        self.auto_max = auto_max
        self.pgain = pgain
        self._itime = itime
        if self._itime:
            self.oneoveritime = 1 / self.itime
        else:
            self.oneoveritime = 0
        self.dtime = dtime
        self.g = gamma
        self.man_request = man_request

        self.bump = 0
        self.last_output = 0
        self.last_err = 0
        self.last_gerr = 0
        self.last_pv = 0
        self.b = beta
        self.l = linearity
        self.a = alpha
        self.deadband = deadband
        self._mode = mode
        
        self.sp_high = sp_high
        self.sp_low = sp_low
        
        self.Uk = self.Up = self.Ui = self.Ud = 0
        
    @property
    def mode(self):
        return self._mode
    
    def set_mode(self, m, pv, sp):
        if m not in (0,1,2):
            raise ValueError(m)
        if m == self._mode:
            return
        elif self._mode == self.OFF and m == self.AUTO:
            self.off_to_auto(pv, sp)
        elif self._mode == self.MAN and m == self.AUTO:
            self.man_to_auto(pv, sp, self.man_request)
        self._mode = m
        
    @property
    def itime(self):
        return self._itime

    @itime.setter
    def itime(self, v):
        self._itime = v
        if v:
            self.oneoveritime = 1 / v
        else:
            self.oneoveritime = 0

    def off_to_auto(self, pv, sp):
        """
        Calculate bump for off-to-auto transfer
        :param pv: current process temp to use for bumpless xfer calculation
        """
        self.man_to_auto(pv, sp, 0)

    def man_to_auto(self, pv, sp, op):
        err_for_pgain = (self.b*sp-pv)*(self.l+(1-self.l)*(abs(self.b*sp-pv))/100)
        uk0 = self.pgain * err_for_pgain
        self.Ui = op - uk0
        self.last_pv = pv
        self.last_err = 0
        self.last_ierr = 0
        self.last_gerr = self.g * sp - pv
        self.last_berr = self.b * sp - pv
        self.last_output = op
   
    set_bump = man_to_auto

    def reset(self):
        self.Ui = 0
        self.last_pv = 0
        self.last_err = 0
        self.last_ierr = 0
        self.last_berr = 0
    
    def step(self, pv, sp):
        
        if self._mode != 0:
            if self._mode == 1:
                return self.man_request
            elif self._mode == 2:
                return 0
            else:
                raise ValueError(self._mode)
        err = sp - pv
        berr = self.b * sp - pv
        gerr = self.g * sp - pv
        
        # Based on Labview's `PID Get Advanced Error (DBL).vi`
        if self.l == 1 or self.sp_high == self.sp_low:
            nl_int_factor = 1
        else:
            assert False
            sp_rng = self.sp_high - self.sp_low
            oml = 1 - self.l
            nl_int_factor = 1 / (1+err*err/ (sp_rng*sp_rng))
            err = err * (self.l + oml*abs(err)/sp_rng)
            berr = berr * (self.l + oml*abs(berr)/sp_rng)
            gerr = gerr * (self.l + oml*abs(gerr)/sp_rng)
        
        errs_avg = (err + self.last_err) / 2
        ierr = errs_avg * nl_int_factor * self.pgain * self.oneoveritime
        
        Up = self.pgain * berr
        Ui = self.Ui + ierr
        if 0 < self.a <= 1:
            Ud = (self.Ud - ((self.pgain / self.a) * (gerr - self.last_gerr))) * (self.dtime / (self.dtime + (1 / self.a)))
        else:
            Ud = -(self.last_gerr - gerr) * self.pgain * self.dtime 
        Uk = Up + Ui + Ud
        
        # Coercion & back calculation      
        if Uk > self.auto_max:
            Uk = self.auto_max
            Ui = Uk - Up - Ud
        elif Uk < self.auto_min:
            Uk = self.auto_min
            Ui = Uk - Up - Ud
            
        # XXX debugging
        self.Ui = Ui
        self.Uk = Uk
        self.Ud = Ud
        self.Up = Up
            
        # "Shift Register"
        self.last_output = Uk
        self.last_pv = pv
        self.last_err = err
        self.last_ierr = ierr
        self.last_gerr = gerr
        
        return Uk

    def __repr__(self):
        return "Output: %.2f Pgain: %.1f Itime: %.2f" % (self.last_output,
                                                                          self.pgain,
                                                                          self.itime)
    __str__ = __repr__
    

def assert_equal(a,b):
    assert a == b, (a, b)
def test_trap_integration1():
    data = [
        (0, 1, .5),
        (0, 2, 2),
        (0, 3, 4.5)
    ]
    p = PIDController(1,1)
    for pv, sp, op in data:
        p.Ui -= 1  # counteract effect of increasing set point on Up
        res_op = p.step(pv, sp)
        assert_equal(p.last_err, sp)
        assert_equal(p.Uk, op)
        assert_equal(res_op, op)
test_trap_integration1()

def check_Ui_backcalc(it, pg, Up, Ud, ierr, accum, val):
    Ui2 = it * (ierr + accum) * pg
    Uk2 = Up + Ud + Ui
    Uk2 = round(Uk2, 8)
    am = round(val, 8)
    assert Uk2 == am, (Up, Ud, Ui, Uk2, val)

# %%
seconds = 1
minutes = seconds * 60
hours = minutes * 60
days = hours * 24

def m2s(m):
    return m*60
def s2m(s):
    return s/60
def h2s(h):
    return m2s(h*60)

from types import FunctionType, MethodType
def printdir(o):
    for a in dir(o):
        if not a.startswith("__"):
            v = getattr(o, a)
            if not isinstance(v, (FunctionType, MethodType)):
                print(a, v)

from collections import deque
class DelayBuffer(deque):
    def __init__(self, delay=30, startvalue=0):
        delay = int(delay)
        self.delay = delay
        super().__init__(startvalue for _ in range(delay + 1))

    def cycle(self, hd):
        self[0] = hd
        self.rotate(1)
        return self[0]
  
from decimal import Decimal as D
class DelaySink():
    def __init__(self, delay, initial, pc_decay=0.95):
        assert 0 < pc_decay <= 1, "don't be a retard"
        self.df = self.calc_df(delay, pc_decay)
        if delay:
            #self.sink = (self.df + initial) / self.df # fill the sink
            self.sink = initial * (1-self.df) / self.df
        else:
            self.sink = 0
        self._delay = delay
        self._pc = pc_decay
        
    def calc_df(self, delay, pc):
        if not delay:
            return 1
        # Attempt to be precise by temporarily using decimal.Decimal
        # to perform the math
        one = D(1)
        return float(one - (one - D(pc))**(one / D(delay)))
        
    def set_delay(self, delay):
        self.df = self.calc_df(delay, self._pc)
        self._delay = delay
        
    def delay(self, op):
        self.sink += op
        dNdt = self.sink*self.df
        self.sink -= dNdt
        return dNdt

# %%
TOTAL_RVOLUME = {
    3: 4,
    15: 17,
    80: 90,
}

class DOProcess():
    """ DO Process
    Uses cascaded calculation model,
    First using HeadspaceProcess to estimate
    headspace gas concentrations, and using
    the result to calculate change in PV. 
    """
    # process gain constant units of  
    # % per delta% per hour 
    # dpv/dt = k*([O2]/0.2095 * 100 - DOPV)
    # where [02] is volume fraction, DOPV is in %
    default_k = 0.1306
    
    # consumption rate constant in units of % per hour
    # presumably, consumption rate is "Constant"
    # within approximation, as long as cellular conditions
    # don't transition between aerobic and anaerobic
    default_c = 0
    
    # volume fraction of CO2, N2, O2 in air
    # note the remaining 1% is trace gasses
    AIR_CNO = (0.0004, 0.7809, 0.2095)
    
    def __init__(self, main_gas=1, initial_pv=60, initial_cno=AIR_CNO, reactor_size=80, volume=55, delay=0):
        """
        :param g: gain in units of C/min/%
        :param k: decay rate in units of C/min/dT
        """
        self.sink = DelaySink(delay, initial_cno[2])
        self.delay = self.sink.delay
        
        self.k = 0
        self.k_mult = 0
        self._k = 0
        self.c = 0
        self.dc = 0
        self.d2c = 0
        self.set_values(k=self.default_k, k_mult=1, c=self.default_c, dc=0, d2c=0)
        
        self._reactor_size = reactor_size
        self._volume = volume
        self.main_gas = main_gas
    
        hs_volume = TOTAL_RVOLUME[reactor_size] - volume
        c, n, o = initial_cno
        self.hp = HeadspaceProcess(hs_volume, c, n, o)
        
    @property
    def volume(self): 
        return self._volume
    
    def set_values(self, **kw):
        if any(not hasattr(self, a) for a in kw):
            raise KeyError(next(set(kw) - set(dir(self))))
            
        if kw.get('k') is not None or kw.get('k_mult') is not None:
            if kw.get('k') is not None:
                self.k = kw['k'] / 3600
            
            if kw.get('k_mult') is not None:
                self.k_mult = kw['k_mult']
                
            self._k = self.k_mult * self.k
    
        if kw.get('c') is not None:
            self.c = kw['c'] / 3600
        if kw.get('dc') is not None:
            self.dc = kw['dc'] / 3600 / 3600
        if kw.get('d2c') is not None:
            self.d2c = kw['d2c'] / 3600 / 3600 / 3600
            
        if kw.get('delay') is not None:
            self.sink.set_delay(kw['delay'])
    
    @volume.setter
    def volume(self, v):
        self._volume = v
        self.hp.vol = TOTAL_RVOLUME[self._reactor_size] - v

    def step(self, pv, co2_req, n2_req, o2_req, air_req):
        self.hp.calc_gas(self.main_gas, co2_req, n2_req, o2_req, air_req)
        o2 = self.hp.o2A
        o2 = self.delay(o2)
        pvarg = (o2 * 100 / 0.2095 - pv)
        dpv = self._k * pvarg
        pv += dpv
        self.dc += self.d2c
        self.c += self.dc
        pv -= self.c
        if pv < 0:
            return 0
        return pv      
    

class HeadspaceProcess():
    def __init__(self, vol, co2A=0, n2A=0.78, o2A=0.21):
        """ 
        vol: volume headspace (L)
        main_gas: main gas flow rate (L/min)
        co2: CO2 request (%)
        n2: N2 request (%)
        
        Calculate headspace concentration. DT = 1 second. 
        """
        self.vol = vol
        self.co2A = co2A
        self.n2A = n2A
        self.o2A = o2A
        self.airA = 1 - (co2A+n2A+o2A)
        
    def step(self, main_gas, co2_req, n2_req, o2_req, air_req):
        self.calc_gas(main_gas, co2_req, n2_req, o2_req, air_req)
        return self.o2A
    
    def calc_gas(self, main_gas, co2_req, n2_req, o2_req, air_req):
        """ 
        Calculate new headspace gas concentration.
        Assumptions:
            - Mixing time is 0 seconds, i.e. gas mixture is always perfectly mixed
            - Gas lost from headspace is always equal to gas entering headspace
            - Concentration of individual gasses lost match headspace concentration of gasses. 
            - Mass transfer coefficient of Air <-> liquid k <<< Mg (no volume lost due to absorption to liquid)
            - Air O2: 20.95%, N2: 78.09%, CO2=0.04%, other = 1-(o2+n2+co2)
        """
        mg = main_gas / 60
        
        # volume of gas lost
        co2L = mg * self.co2A
        n2L = mg * self.n2A
        o2L = mg * self.o2A
        airL = mg * self.airA
        
        # volume of gas gained
        # airG is non-corrected volume of air added
        co2G = mg * co2_req
        n2G = mg * n2_req
        o2G = mg * o2_req
        airG = mg * air_req
        
        # air contribution to gases
        # airG is corrected to reflect
        # the volume of non-tracked gases
        # ie the 1% of trace elements or so
        co2G += 0.0004 * airG
        o2G += 0.2095 * airG
        n2G += 0.7809 * airG
        airG = .0092 * airG
        
        # new volume of each gas
        co2V = co2G - co2L + self.co2A * self.vol
        n2V = n2G - n2L + self.n2A * self.vol
        o2V = o2G - o2L + self.o2A * self.vol
        airV = airG - airL + self.airA * self.vol
        
        # finally, new percentages
        self.co2A = co2V / self.vol
        self.n2A = n2V / self.vol
        self.o2A = o2V / self.vol
        self.airA = airV / self.vol
        
        # Sanity checks
        # Errors should be on the order of 
        # floating point rounding error ~1e-14
        self._err_ = self.vol - sum((co2V, n2V, o2V, airV))
        self._err2_ = 1 - (self.co2A + self.n2A + self.o2A + self.airA)
        self._err3_ = (co2L+n2L+o2L+airL) - (co2G + n2G + o2G + airG)
        
    @staticmethod
    def actual_from_request(co2, n2, o2, air):
        total = co2 + n2 + o2 + air
        co2 /= total
        n2 /= total
        o2 /= total
        air /= total
        
        co2 += 0.0004 * air
        n2 += 0.7809 * air
        o2 += 0.2095 * air
        air = 1 - (co2+n2+o2)
        return co2, n2, o2, air

# %%
class GasController():
    def __init__(self, co2mfcmax, n2mfcmax, o2mfcmax, airmfcmax):
        self.cm = co2mfcmax
        self.nm = n2mfcmax
        self.om = o2mfcmax
        self.am = airmfcmax
        self.mg_max = max((self.cm, self.nm, self.om, self.am))
   
    def request(self, main_gas, co2_req, n2_req, o2_req):

        if main_gas > self.mg_max: main_gas = self.mg_max
        co2_req_max = 1
        if co2_req > co2_req_max: co2_req = co2_req_max
        co2max = self.cm / main_gas
        co2pc = co2max if co2_req > co2max else co2_req

        o2_req_max = 1 - co2pc
        if o2_req > o2_req_max: o2_req = o2_req_max
        o2max = self.om / main_gas
        o2pc = o2max if o2_req > o2max else o2_req
        
        n2_req_max = 1 - co2pc - o2pc
        if n2_req > n2_req_max: n2_req = n2_req_max
        n2max = self.nm / main_gas
        n2pc = n2max if n2_req > n2max else n2_req
        
        apc = 1 - co2pc - o2pc - n2pc
        return co2pc, n2pc, o2pc, apc

# %%
def _round(dig, *args):
    rv = []
    for a in args:
        rv.append(round(a, dig))
    return rv
def test_gas_controller():
    ctrl = GasController(1, 10, 2, 10)
    
    c,o,n = (0.8, 0.3, 1)
    rc, rn, ro, ra = _round(5, *ctrl.request(0.5, c,n,o))
    assert rc == 0.8, rc
    assert ro == 0.2, ro
    assert rn == 0, rn
    assert ra == 0, ra
    
    rc, rn, ro, ra = _round(5, *ctrl.request(10, c,n,o))
    assert rc == 0.1, rc
    assert ro == 0.2, ro
    assert rn == 0.7, rn
    assert ra == 0, ra
    
    c,o,n = (0.8, 0, 1)
    rc, rn, ro, ra = _round(5, *ctrl.request(10, c,n,o))
    assert rc == 0.1, rc
    assert ro == 0, ro
    assert rn == 0.9, rn
    assert ra == 0, ra
    
    c,o,n = (0.07, 0.1, 0.3)
    rc, rn, ro, ra = _round(5, *ctrl.request(10, c,n,o))
    assert rc == 0.07, rc
    assert ro == 0.1, ro
    assert rn == 0.3, rn
    assert ra == 0.53, ra
    
    for mg in (0.5, 1, 5, 10):
        for c in 0.1, 0.5, 0.8, 1:
            for o in 0.1, 0.5, 0.8, 1:
                for n in 0.1, 0.5, 0.8, 1:
                    args = (mg, c, n, o)
                    ec = round(min(1/mg, c), 5)
                    eo = round(min(2/mg, (1-ec), o),5)
                    en = round(min(1-ec-eo, n),5)
                    ea = round(1-ec-eo-en,5)
                    rc, rn, ro, ra = _round(5, *ctrl.request(*args))
                    assert rc == ec, (rc, ec, args)
                    assert ro == eo, (ro, eo, args, (rc, rn, ro, ra))
                    assert rn == en, (rn, en, args)
                    assert ra >= 0 and ra == ea, (ra, ea, args)
    
test_gas_controller()

# %%
import json

class OptionCategory():
    def __iter__(self):
        d = self.__class__.__dict__.copy()
        d.update(self.__dict__)
        ob = ((k, v) for k,v in d.items() if k[0] != "_" and k[-1]!="_")
        return iter(ob)
    
    def __repr__(self):
        buf = []
        for k, v in self:
            if isinstance(v, OptionCategory):
                v = "<More Options...>"
            buf.append("%s: %s" %(k,v))
        return "\n".join(buf)
    
    def __init__(self):
        self.__dict__.update(self.__class__.__dict__)
    
    def __setattr__(self, k, v):
        if k not in self.__dict__:
            raise AttributeError(k)
        object.__setattr__(self, k, v)
        
    def asdict(self):
        basedict = dict(iter(self))
        rv = {}
        for k in basedict:
            v = basedict[k]
            if isinstance(v, OptionCategory):
                v = v.asdict()
            rv[k] = v
        return rv
    
    def jsonify(self, **kw):
        kw['indent'] = kw.get('indent') or 4
        return json.dumps(self.asdict(), **kw)

class PIDOps(OptionCategory):
    p = 5
    i = 5
    d = 0
    amax = 100
    amin = 0
    alpha = 1
    beta = 1
    linearity = 1
    gamma = 0
    deadband = 0
    man_request = 0
    mode = 0
    
class MFCOps(OptionCategory):
    co2_max = 1
    o2_max = 2
    n2_max = 10
    air_max = 10
    
class PlotOps(OptionCategory):
    xscale = 'auto'
    xmin = 0
    xmax = 72
    xscale_factor = 3600

class SimOps(OptionCategory):
    
    o2_pid = PIDOps()
    o2_pid.p = 5
    o2_pid.i = 5
    o2_pid.d = 0
    o2_pid.amax = 100
    o2_pid.amin = 0
    o2_pid.beta = 1
    o2_pid.linearity = 1
    o2_pid.alpha = 1
    
    n2_pid = PIDOps()
    n2_pid.p = 5
    n2_pid.i = 5
    n2_pid.d = 0
    n2_pid.amax = 0
    n2_pid.amin = 0
    n2_pid.beta = 1
    n2_pid.linearity = 1
    n2_pid.alpha = 1
    
    mfcs = MFCOps()
    mfcs.co2_max = 1
    mfcs.o2_max = 10
    mfcs.n2_max = 10
    mfcs.air_max = 10
    
    plots = PlotOps()
    plots.xscale = 'auto'
    plots.xmin = 0
    plots.xmax = 72
    plots.xscale_factor = 3600
    
    delay = 0
    end = 10000
    initial_actual_cno = DOProcess.AIR_CNO
    initial_request_cno = (0.07, 0, 0)
    initial_pv = 90
    set_point = 40
    set_point_deadband = 1
    k_mult = 1.1
    k = None
    c = None
    dc = 0
    d2c = 0
    mode = "m2a"
    main_gas = 1.0
    reactor_size = 80
    reactor_volume = reactor_size * 55/80
    time_unit = hours
    max_iters = 3 * days

# %%
ops = SimOps()
ops.delay = 0
ops.end = 10000
ops.initial_actual_cno = DOProcess.AIR_CNO
ops.initial_request_cno = (0.07, 0, 0)
ops.initial_pv = 100
ops.set_point = 90
ops.k = DOProcess.default_k
ops.c = 0
ops.mode = "o2a"
ops.main_gas = 1.0
ops.reactor_size = 80
ops.reactor_volume = 55

# %%
# O2 pid
ops.o2_pid.p = 2
ops.o2_pid.i = 10
ops.o2_pid.d = 0
ops.o2_pid.alpha = -1
ops.o2_pid.amax = 100
ops.o2_pid.amin = 0
ops.o2_pid.linearity = 1
ops.o2_pid.beta = 1

# %%
# N2 PID
ops.n2_pid.p = -5
ops.n2_pid.i = 5
ops.n2_pid.d = 0
ops.n2_pid.amax = 100
ops.n2_pid.amin = 0
ops.n2_pid.alpha = -1
ops.n2_pid.beta = 1
ops.n2_pid.linearity = 1

# %%
def _setpid(ob, state, name, value):
    pid = state[ob]
    if name == "pgain":
        pid.pgain = value
    elif name == "itime":
        pid.itime = m2s(value)
    elif name == "dtime":
        pid.dtime = m2s(value)
    elif name == "beta":
        pid.b = value
    elif name == "mode":
        sp = state['sp']
        if ob[:2] == "n2":
            sp += state['db']
        elif ob[:2] == 'o2':
            sp -= state['db']
        else:
            print("BAD PID")
        pid.set_mode(value, state['pv'], sp)
    elif name == "man":
        pid.man_request = int(value)
    else:
        print("WARNING: Invalid attribute for %r: %r" % (ob, name, name == "man"))

def _update_value(ops, state, proc, ob, name, value):
    if ob == "process":
        if name == "delay":
            value *= 60
        proc.set_values(**{name:value})
        return
    elif ob in ("o2_pid", "n2_pid"):
        _setpid(ob, state, name, value)
        return
    print("WARNING: Invalid attribute or object: %r %r" % (ob, name))


def do_sim_coroutine(ops, state, xq, pvq, cq,
                     co2q, n2q, o2q, aq, 
                     nukq, nupq, nuiq, nudq,
                     oukq, oupq, ouiq, oudq):
    
    """ This is the longest function in the history of man. 
    Its long becaues there are a *lot* of values to use and unpack for the inner PID loop,
    including code needed to synchronize with UI updates.
    Yay. 
    """
    
    o2_pid = PIDController(pgain=ops.o2_pid.p,              itime=m2s(ops.o2_pid.i),
                            dtime=m2s(ops.o2_pid.d),        auto_max=ops.o2_pid.amax,
                            auto_min=ops.o2_pid.amin,       
                            beta=ops.o2_pid.beta,
                            linearity=ops.o2_pid.linearity, alpha=ops.o2_pid.alpha,
                            deadband=ops.o2_pid.deadband,   sp_high=100, sp_low=0,
                            gamma=ops.o2_pid.gamma,         man_request=ops.o2_pid.man_request,
                            mode=ops.o2_pid.mode)
    
    n2_pid = PIDController(pgain=ops.n2_pid.p,              itime=m2s(ops.n2_pid.i),
                            dtime=m2s(ops.n2_pid.d),        auto_max=ops.n2_pid.amax,
                            auto_min=ops.n2_pid.amin,      
                            beta=ops.n2_pid.beta,
                            linearity=ops.n2_pid.linearity, alpha=ops.n2_pid.alpha,
                            deadband=ops.n2_pid.deadband,   sp_high=100, sp_low=0,
                            gamma=ops.n2_pid.gamma,         man_request=ops.n2_pid.man_request, 
                            mode=ops.n2_pid.mode)
    
    co2_req, n2_req, o2_req = ops.initial_request_cno
    air_req = max(1-co2_req - n2_req - o2_req, 0)
    pv = ops.initial_pv
    sp = ops.set_point
    mode = ops.mode
    db = ops.set_point_deadband
    
    if mode == "o2a":
        n2_req = 0
        o2_req = 0
        o2_pid.off_to_auto(pv, sp-db)
        n2_pid.off_to_auto(pv, sp+db)

    if mode == 'm2a':
        o2_pid.man_to_auto(pv, sp-db, o2_req*100)
        n2_pid.man_to_auto(pv, sp+db, n2_req*100)
        
    delay = ops.delay
    mg = ops.main_gas
    co2a, n2a, o2a = ops.initial_actual_cno
    
    proc = DOProcess(mg, pv,     (co2a, n2a, o2a), 
                     ops.reactor_size, ops.reactor_volume, 
                     ops.delay)
    
    proc.set_values(k=ops.k, k_mult=ops.k_mult, c=ops.c, dc=ops.dc, d2c=ops.d2c)
        
    ctrl = GasController(ops.mfcs.co2_max, ops.mfcs.n2_max, ops.mfcs.o2_max, ops.mfcs.air_max)
    
    t = 0
    time_unit = ops.time_unit
    mi = ops.max_iters
    msg = None

    while True:

        cmd, arg = yield msg
        msg = None
        
        state['c'] = proc.c * 3600
        state['dc'] = proc.dc * 3600 * 3600
        state['d2c'] = proc.d2c * 3600 * 3600 * 3600
        state['k'] = proc.k
        state['sp'] = sp
        state['db'] = db
        state['pv'] = pv
        state['mg'] = mg
        state['t'] = t
        state['co2_req'] = co2_req
        state['n2_req'] = n2_req
        state['o2_req'] = o2_req
        state['air_req'] = air_req
        state['o2_pid'] = o2_pid
        state['n2_pid'] = n2_pid

        if cmd == "SIM_ITERS":
            
            iters = arg
            if iters < 0:
                continue
            elif iters > mi:
                iters = mi

            # One approximation made in this simulation
            # is that no values, including oxygen consumption
            # (c), change during the inner iteration period 
            # outside of modification by the process or PID
            # classes themselves. 

            while iters > 0:

                t += 1
                iters -= 1
                o2_req = o2_pid.step(pv, sp-db) / 100
                n2_req = n2_pid.step(pv, sp+db) / 100
                co2_req, n2_req, o2_req, air_req = ctrl.request(mg, co2_req, n2_req, o2_req)
                pv = proc.step(pv, co2_req, n2_req, o2_req, air_req)

                xq.put(t/time_unit)
                pvq.put(pv)
                cq.put(proc.c * 3600)

                co2q.put(co2_req)
                n2q.put(n2_req)
                o2q.put(o2_req)
                aq.put(air_req)

                nukq.put(n2_pid.Uk)
                nupq.put(n2_pid.Up)
                nuiq.put(n2_pid.Ui)
                nudq.put(n2_pid.Ud)

                oukq.put(o2_pid.Uk)
                oupq.put(o2_pid.Up)
                ouiq.put(o2_pid.Ui)
                oudq.put(o2_pid.Ud)

        elif cmd == "SET_TIME":
            t = arg
        elif cmd == "UPDATE_VALUE":
            ob, name, value = arg
            rsp = _update_value(ops, state, proc, ob, name, value)
        elif cmd == "MODIFY_STATE":
            name, value = arg
            if name == "sp":
                sp = state['sp'] = value
            elif name == "pv":
                pv = state['pv'] = value
            elif name == "main_gas":
                mg = state['mg'] = value
            else:
                print("WARNING: Unrecognized name: %r" % name)
        else:
            raise ValueError(cmd)

# %%
def do_sim2(ops):
    # standalone sim function compatible with the do_sim_coroutine
    # function used for interactive use
    state = {}
    
    class MyList(list):
        put = list.append
    
    xq = MyList()
    pvq = MyList()
    cq = MyList()
    co2q = MyList()
    n2q = MyList()
    o2q = MyList()
    aq = MyList()
    nukq = MyList()
    nupq = MyList()
    nuiq = MyList()
    nudq = MyList()
    oukq = MyList()
    oupq = MyList()
    ouiq = MyList()
    oudq = MyList()
    coro = do_sim_coroutine(ops, state, xq, pvq, cq,
                     co2q, n2q, o2q, aq, 
                     nukq, nupq, nuiq, nudq,
                     oukq, oupq, ouiq, oudq)
    
    next(coro)
    coro.send(("SIM_ITERS", ops.end))
    
    data = list(zip(xq, pvq, cq,
                     co2q, n2q, o2q, aq))
    data2 = list(zip(nukq, nupq, nuiq, nudq))
    data3 = list(zip(oukq, oupq, ouiq, oudq))
    return data, data2, data3
    
def do_sim3(ops):
    # standalone sim function compatible with the do_sim_coroutine
    # function used for interactive use
    state = {}
    
    class MyList(list):
        put = list.append
    
    xq = MyList()
    pvq = MyList()
    cq = MyList()
    co2q = MyList()
    n2q = MyList()
    o2q = MyList()
    aq = MyList()
    nukq = MyList()
    nupq = MyList()
    nuiq = MyList()
    nudq = MyList()
    oukq = MyList()
    oupq = MyList()
    ouiq = MyList()
    oudq = MyList()
    coro = do_sim_coroutine(ops, state, xq, pvq, cq,
                     co2q, n2q, o2q, aq, 
                     nukq, nupq, nuiq, nudq,
                     oukq, oupq, ouiq, oudq)
    
    next(coro)
    yield coro
    data = list(zip(xq, pvq, cq,
                     co2q, n2q, o2q, aq))
    data2 = list(zip(nukq, nupq, nuiq, nudq))
    data3 = list(zip(oukq, oupq, ouiq, oudq))
    yield data, data2, data3

# %%
# O2 needs an extra padding space because the negative sign
# for N2 pgain doesn't count, i guesss
def fmt_float(f):
    if not f:
        return "0"
    f = str(f)
    if "." not in f:
        return f
    else:
        f = f.strip("0")
        if f[-1] == ".":
            f = f[:-1]
        if f[0] == ".":
            f = "0" + f
    return f
def get_text(ops):

    text = \
"""
O2: P=%3d  I=%5d  Initial PV: %3d  k: %.4f/hr (%sx Est.)
N2: P=%3d  I=%4d  Set Point:  %3d  c: %s%%/hr

 """ % (ops.o2_pid.p, ops.o2_pid.i,ops.initial_pv, ops.k*ops.k_mult, fmt_float(ops.k_mult),
        ops.n2_pid.p, ops.n2_pid.i, ops.set_point, fmt_float(ops.c))
    text = text.strip()
    return text

# %%
def run(ops):
    global data, data2, text, data3
    data, data2, data3 = do_sim2(ops)
    text = get_text(ops)
    plot(ops)

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
# %matplotlib

def plot(ops):    
    print("Parsing Data")
    global x, pv, mg, cs, co2_req, n2_req, o2_req, air_req, co2a, n2a, o2a, uk, up, ui, ud
    x, pv, cs, co2_req, n2_req, o2_req, air_req = list(zip(*data))
    uk, up, ui, ud = list(zip(*data2))
    print("Closing Plot")
    plt.close()
    print("Plotting Data")

    step = 100
    xs = x[::step]
    xs = np.array(xs) / ops.plots.xscale_factor * ops.time_unit
    fig = plt.figure()
    ax1 = plt.subplot(311)
    ax2 = plt.subplot(312)
    ax3 = plt.subplot(313)

    pvs = np.array(pv[::step])
    ax1.plot(xs, pvs, "blue", ls="-", label="PV")
    ax1.axhline(y=sp, ls="--", color="black")
    # abs_err = np.abs(sp - pvs)
    # esq **= 2
    # esq = np.sqrt(esq)
    #ax1.plot(xs, abs_err, "red", ls="-", label="Err^2")

    #ax2.plot(xs, co2_req[::step], "purple", ls="-", label="CO2")
    ax2.plot(xs, n2_req[::step], "red", ls="-", label="N2")
    ax2.plot(xs, o2_req[::step], "green", ls="-", label="O2")
    ax2.plot(xs, air_req[::step], "cyan", ls="-", label="Air")
    fm1 = FuncFormatter(lambda y, _: "%.2f%%"%y)
    fm2 = FuncFormatter(lambda y, _: "%.2f%%"%(y*100))

    ax3.plot(xs, uk[::step], "blue", ls="-", label="Uk")
    ax3.plot(xs, up[::step], "red", ls="-", label="Up")
    ax3.plot(xs, ui[::step], "green", ls="-", label="Ui")
    ax3.plot(xs, ud[::step], "purple", ls="-", label="Ud")

    ax1.yaxis.set_major_formatter(fm1)
    ax2.yaxis.set_major_formatter(fm2)
    ax2.set_ylim((0, 1.1))
    
    m, ma = ax1.get_ylim()
    if np.min(pvs) - 1 < m:
        m -= 1
    if np.max(pvs) + 1 > ma:
        ma += 1
    ax1.set_ylim((m, ma))
    #ax1.set_ylim((sp-5, sp+5))


    for a in ax1, ax2, ax3: 
        b = a.get_position()
        a.set_position([b.x0, b.y0, b.width*0.9, b.height])
        a.legend(bbox_to_anchor=(0.99, 1.06), loc="upper left")
        a.grid()
        if ops.plots.xscale == 'man':
            a.set_xlim((ops.plots.xmin, ops.plots.xmax))
    
    fig.text(0.15, 0.95, get_text(ops), transform=ax1.transAxes, fontsize=12,
        verticalalignment='top')
    
    wm=plt.get_current_fig_manager()
    wm.window.attributes('-topmost', 1)
    wm.window.attributes('-topmost', 0)
    # h = wm.window.winfo_height()
    # w = wm.window.winfo_width()
    wm.window.geometry("%sx%s+%s+%s"%(700,720,50, 20))
# Out:
# Using matplotlib backend: TkAgg

# %%
ops.end = 10 * hours
sp = 80

ops.o2_pid.p = 10
ops.o2_pid.i = 80
ops.o2_pid.amax = 100
ops.o2_pid.deadband = 0
ops.o2_pid.d = 0
ops.o2_pid.alpha = -1

ops.n2_pid.p = -2
ops.n2_pid.i = 60
ops.n2_pid.amax = 100
ops.n2_pid.deadband = 0
ops.n2_pid.d = 0
ops.n2_pid.alpha = -1

ops.initial_pv = 20
ops.set_point = sp
ops.c = 0
ops.dc = 0
ops.d2c = 0

# k_mult = 1.25
ops.k_mult = 1
ops.k = 0.19314
ops.initial_actual_cno = (0.0000, .90, .1)
ops.initial_request_cno = (0.00, .78, 0)
ops.mode = 'm2a'
ops.plots.xscale = 'auto'
ops.plots.xmin = 20
ops.plots.xmax = 30
ops.set_point_deadband = 1
ops.delay = 0

run(ops)

from matplotlib.ticker import MultipleLocator
l = MultipleLocator(1)
for a in plt.gcf().axes:
    a.xaxis.set_major_locator(l)
# Out:
# Parsing Data
# Closing Plot
# Plotting Data

# %%
class Fitness():
    ramp_coef = 0
    settle_coef = 0.1
    curve_coef = 100
    sp_margin = 3
    ramp_margin = 3
    curve_margin = 10
    score_max = 100000
    settle_target = 2.5 * hours
    ramp_target = 1 * hours
    
    def __init__(self, x, y, setpoint):
        
        ts = self.time_stable(x, y, setpoint)
        self._settle = ts - self.settle_target
        
        rt = self.ramp_time(x, y, setpoint)
        self._ramp = rt - self.ramp_target
        
        curvy = self.curviness(x, y, setpoint)
        self._curve = curvy
        
    @classmethod
    def from_fitness(cls, f):
        return cls(f.x, f.y, f.setpoint)
        
    def ramp_time(self, x, y, setpoint):
        return self._margin(y, setpoint, self.ramp_margin)
    
    def _margin(self, y, setpoint, margin):
        hi = setpoint + margin
        lo = setpoint - margin
        return next((i for i,pv in enumerate(y) if lo <= pv <= hi), 1e7)
        
    def score(self):
        score = self.settle_score()
        score += self.curve_score()
        score += self.ramp_score()
        if score > self.score_max:
            score = self.score_max
        return score
    
    def settle_score(self):
        return (self._settle/10)**2 * self.settle_coef
    
    def curve_score(self):
        return self._curve * self.curve_coef
    
    def ramp_score(self):
        return self._ramp * self.ramp_coef
        
    def time_stable(self, x, y, setpoint):
        hi = setpoint + self.sp_margin
        lo = setpoint - self.sp_margin
        for t, pv in reversed(list(zip(x,y))):
            if not lo <= pv <= hi:
                break
        t += 1
        if t > x[-1]:
            t *= 10
            
        return (t) * 3600
    
    def curviness(self, x, y, setpoint):
        # dividing by 60 instead of 1 reduces the number
        # to a more manageable level
        cv = (np.gradient((np.gradient(y, 1/3600)),1/3600 ) ** 2).sum() / len(y)
        return cv
    
    def __str__(self):
        return "Total: %d Settle: %s Ramp: %s Curve: %s" % (int(self.score()), int(self.settle_score()),
                                                           int(self.ramp_score()), int(self.curve_score()))

# %%
class Fitness2():
    stable_osc_max = 1
    settle_osc_max = 3
    settle_target = 3 * hours
    def __init__(self, x, y, sp):
        self.settle_time = self.time_stable(x,y,sp)
        self.osc = self.oscillation(x,y,sp)
        
    def result_reason(self):
        rv = True
        reason = ""
        if self.settle_time > self.settle_target:
            reason += "Settle %d > %d " % (self.settle_time, self.settle_target)
            rv = False
        if self.osc > self.stable_osc_max:
            reason += "Osc %d > %d " % (int(sef.osc), self.stable_osc_max)
            rv = False
        return rv, reason
    
    def result(self):
        return self.result_reason()[0]
    
    def reason(self):
        return self.result_reason()[1]
        
    def oscillation(self, x, y, sp):
        span = y[10*hours:]
        if not span:
            return -1
        ymin = np.min(span)
        ymax = np.max(span)
        return (ymin - ymax) / 2
        
    def time_stable(self, x, y, setpoint):
        hi = setpoint + self.settle_osc_max
        lo = setpoint - self.settle_osc_max
        for t, pv in reversed(list(zip(x,y))):
            if not lo <= pv <= hi:
                break
        t += 1
        return t * 3600

# %%
# %matplotlib
ops.end = 10 * hours
sp = 150

ops.o2_pid.p = 1
ops.o2_pid.i = 50
ops.o2_pid.amax = 100
ops.o2_pid.deadband = 0
ops.o2_pid.d = 0
ops.o2_pid.alpha = -1

ops.n2_pid.p = -0.5
ops.n2_pid.i = 60
ops.n2_pid.amax = 100
ops.n2_pid.deadband = 0
ops.n2_pid.d = 0
ops.n2_pid.alpha = -1

ops.initial_pv = 100
ops.set_point = sp
ops.c = 0
ops.dc = 0
ops.d2c = 0

# k_mult = 1.25
ops.k_mult = 1
ops.k = 0.19314
ops.initial_actual_cno = (0.0000, .78, .2095)
ops.initial_request_cno = (0.00, 0, 0)
ops.mode = 'm2a'
ops.plots.xscale = 'auto'
ops.plots.xmin = 20
ops.plots.xmax = 30
ops.set_point_deadband = 1
ops.delay = 0


results = []
f = FuncFormatter(lambda y, _: "%.1f%%"%y)
plt.close()
fig = plt.figure()
ax = fig.add_subplot(3,1,1)
ax2 = fig.add_subplot(3,1,2)
ax3 = fig.add_subplot(3,1,3)
ax.axhline(y=sp, ls="--", color="black")
ax.grid()

ax.yaxis.set_major_formatter(f)
ax2.yaxis.set_major_formatter(f)
ax3.yaxis.set_major_formatter(f)

lines = []

def plot2(x, pv, o2_req, n2_req, label):
    ax.plot(x, pv, label=label)
    ax2.plot(x, np.array(o2_req)*100, label=label)
    ax3.plot(x, np.array(n2_req)*100, label=label)

for p in [10]:
    ops.o2_pid.p = p
    d1, d2, d3 = do_sim2(ops)
    x, pv, cs, co2_req, n2_req, o2_req, air_req = list(zip(*d1))
    plot2(x, pv, o2_req, n2_req, "O2 PGain:%.1f"%p)
    score = Fitness(x, pv, sp)
    results.append((p, score))

# for i in (50, 70, 100, 120, 150, 200):
#     ops.o2_pid.i = i
#     d1, d2, d3 = do_sim2(ops)
#     x, pv, cs, co2_req, n2_req, o2_req, air_req = list(zip(*d1))
#     plot2(x, pv, o2_req, n2_req, "O2 Itime:%.1f"%i)
#     score = Fitness2(x, pv, sp)
#     results.append((i, score))

leg_map = {}

def on_legend_clicked(event):
    ll = event.artist
    line = leg_map[ll]
    line.set_visible(not line.get_visible())
    fig.canvas.draw()

for a in (ax, ax2, ax3):
    b = a.get_position()
    a.set_position([b.x0, b.y0, b.width*0.9, b.height])
    a.legend(bbox_to_anchor=(0.99, 1.06), loc="upper left", fontsize=10)
    
    for lline in a.legend_.get_lines():
        for aline in a.get_lines():
            if lline.get_label() == aline.get_label():
                leg_map[lline] = aline
                lline.set_picker(5)
                aline.set_visible(True)
        
fig.canvas.mpl_connect("pick_event", on_legend_clicked)
    
results.sort(key=lambda t:t[1].score())
for p, s in results:
    print("ITime: %.1f" % p, str(s))
# Out:
# Using matplotlib backend: TkAgg
# ITime: 10.0 Total: 58342 Settle: -36 Ramp: 0 Curve: 58378

# %%
from mpl_toolkits.mplot3d import Axes3D
leg_map = {}

try:
    plot_test_results
except NameError:
    plot_test_results = {}


def on_legend_clicked(event):
    ll = event.artist
    line = leg_map[ll]
    line.set_visible(not line.get_visible())
    fig.canvas.draw()
fig.canvas.mpl_connect("pick_event", on_legend_clicked)

def test(ops):
    d1, d2, d3 = do_sim2(ops)
    x, pv, cs, co2_req, n2_req, o2_req, air_req = [np.array(d) for d in zip(*d1)]
    cs = cs[::120]
    co2_req = co2_req[::120]
    n2_req = n2_req[::120]
    o2_req = o2_req[::120]
    air_req = air_req[::120]
    del d1, d2, d3  # garbage collect
    score = Fitness(x, pv, ops.set_point)
    score2 = Fitness2(x, pv, ops.set_point)
    x = x[::120]
    pv = pv[::120]
    return locals().copy()

def plot2(x, pv, o2_req, n2_req, label, update=True):
    l1 = ax.plot(x, pv, label=label)
    #l2 = ax2.plot(x, np.array(o2_req)*100, label=label)
    #l3 = ax3.plot(x, np.array(n2_req)*100, label=label)
    ax.legend(bbox_to_anchor=(0.99, 1.06), loc="upper left", fontsize=10)
    #ax2.legend(bbox_to_anchor=(0.99, 1.06), loc="upper left", fontsize=10)
    #ax3.legend(bbox_to_anchor=(0.99, 1.06), loc="upper left", fontsize=10)
    if update:
        fig.canvas.draw()
        fig.canvas.flush_events()
    
scatter_data = [[],[],[]]
def plot3(p, i, score, update=True):
    x,y,z = scatter_data
    x.append(p)
    y.append(i)
    z.append(score)
    ax3d.clear()
    ax3d.scatter(x,y,z, antialiased=False)
    if update:
        fig.canvas.draw()
        fig.canvas.flush_events()

plt.close()
fig = plt.figure()
ax = fig.add_subplot(2,1,1)
ax3d = fig.add_subplot(2,1,2, projection='3d')
#ax2 = fig.add_subplot(3,1,2)
#ax3 = fig.add_subplot(3,1,3)
ax.axhline(y=sp, ls="--", color="black")
ax.grid()

ax.yaxis.set_major_formatter(f)
#ax2.yaxis.set_major_formatter(f)
#ax3.yaxis.set_major_formatter(f)

# axes = [ax, ax2, ax3]
axes = [ax, ax3d]

for a in axes:
    b = a.get_position()
    a.set_position([b.x0, b.y0, b.width*0.9, b.height])
    #a.legend(bbox_to_anchor=(0.99, 1.06), loc="upper left", fontsize=10)

passing = []
update = True
noupdate = 0
for p in range(1, 21):
    for i in range(50, 251, 10):
        print("\rTesting P:%d I:%d " % (p,i), end="")
        if (p,i) not in plot_test_results:
            ops.o2_pid.p = p
            ops.o2_pid.i = i
            data = test(ops)
            update = True
        else:
            data = plot_test_results[(p,i)]
            update = False
            noupdate += 1
            if noupdate > 10:
                noupdate = 0
                update = True
        s2 = data['score2']
        res, reason = s2.result_reason()
        if res == True:
            passing.append((p,i))
            label = "P:%3d I:%3d" % (p, i)
            plot2(data['x'], data['pv'],data['o2_req'], data['n2_req'], label, update)
        #plot_test_results[(p,i)] = data
        plot3(p,i, data['score'].score(), update)
        print("Result: %s %s %s" % (str(data['score']), res, reason))
        fig.canvas.flush_events()
print("Done")
# Out:
# Testing P:1 I:50 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 16406 False Settle 39600 > 10800
# Testing P:1 I:60 Result: Total: 100000 Settle: 667188 Ramp: 0 Curve: 10710 False Settle 34830 > 10800
# Testing P:1 I:70 Result: Total: 100000 Settle: 712783 Ramp: 0 Curve: 7226 False Settle 35698 > 10800
# Testing P:1 I:80 Result: Total: 100000 Settle: 689955 Ramp: 0 Curve: 5196 False Settle 35267 > 10800
# Testing P:1 I:90 Result: Total: 100000 Settle: 290532 Ramp: 0 Curve: 3904 False Settle 26045 > 10800
# Testing P:1 I:100 Result: Total: 100000 Settle: 285677 Ramp: 0 Curve: 3032 False Settle 25902 > 10800
# Testing P:1 I:110 Result: Total: 97539 Settle: 95121 Ramp: 0 Curve: 2418 False Settle 18753 > 10800
# Testing P:1 I:120 Result: Total: 100000 Settle: 124032 Ramp: 0 Curve: 1970 False Settle 20137 > 10800
# Testing P:1 I:130 Result: Total: 100000 Settle: 161518 Ramp: 0 Curve: 1638 False Settle 21709 > 10800
# Testing P:1 I:140 Result: Total: 100000 Settle: 211382 Ramp: 0 Curve: 1388 False Settle 23539 > 10800
# Testing P:1 I:150 Result: Total: 100000 Settle: 279123 Ramp: 0 Curve: 1192 False Settle 25707 > 10800
# Testing P:1 I:160 Result: Total: 100000 Settle: 371448 Ramp: 0 Curve: 1034 False Settle 28273 > 10800
# Testing P:1 I:170 Result: Total: 100000 Settle: 492129 Ramp: 0 Curve: 906 False Settle 31184 > 10800
# Testing P:1 I:180 Result: Total: 100000 Settle: 636098 Ramp: 0 Curve: 800 False Settle 34221 > 10800
# Testing P:1 I:190 Result: Total: 100000 Settle: 131609328 Ramp: 0 Curve: 712 False Settle 37178 > 10800
# Testing P:1 I:200 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 637 False Settle 39600 > 10800
# Testing P:1 I:210 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 574 False Settle 39600 > 10800
# Testing P:1 I:220 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 519 False Settle 39600 > 10800
# Testing P:1 I:230 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 472 False Settle 39600 > 10800
# Testing P:1 I:240 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 431 False Settle 39600 > 10800
# Testing P:1 I:250 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 395 False Settle 39600 > 10800
# Testing P:2 I:50 Result: Total: 100000 Settle: 277622 Ramp: 0 Curve: 33577 False Settle 25662 > 10800
# Testing P:2 I:60 Result: Total: 100000 Settle: 270799 Ramp: 0 Curve: 23479 False Settle 25456 > 10800
# Testing P:2 I:70 Result: Total: 100000 Settle: 275925 Ramp: 0 Curve: 17046 False Settle 25611 > 10800
# Testing P:2 I:80 Result: Total: 100000 Settle: 259081 Ramp: 0 Curve: 12106 False Settle 25096 > 10800
# Testing P:2 I:90 Result: Total: 31491 Settle: 22477 Ramp: 0 Curve: 9014 False Settle 13741 > 10800
# Testing P:2 I:100 Result: Total: 43195 Settle: 36240 Ramp: 0 Curve: 6955 False Settle 15020 > 10800
# Testing P:2 I:110 Result: Total: 68971 Settle: 63441 Ramp: 0 Curve: 5530 False Settle 16965 > 10800
# Testing P:2 I:120 Result: Total: 100000 Settle: 256544 Ramp: 0 Curve: 4516 False Settle 25017 > 10800
# Testing P:2 I:130 Result: Total: 100000 Settle: 322166 Ramp: 0 Curve: 3761 False Settle 26949 > 10800
# Testing P:2 I:140 Result: Total: 100000 Settle: 387814 Ramp: 0 Curve: 3181 False Settle 28693 > 10800
# Testing P:2 I:150 Result: Total: 100000 Settle: 463454 Ramp: 0 Curve: 2726 False Settle 30528 > 10800
# Testing P:2 I:160 Result: Total: 100000 Settle: 553331 Ramp: 0 Curve: 2362 False Settle 32522 > 10800
# Testing P:2 I:170 Result: Total: 100000 Settle: 658846 Ramp: 0 Curve: 2067 False Settle 34668 > 10800
# Testing P:2 I:180 Result: Total: 100000 Settle: 129571201 Ramp: 0 Curve: 1823 False Settle 36896 > 10800
# Testing P:2 I:190 Result: Total: 100000 Settle: 146199169 Ramp: 0 Curve: 1621 False Settle 39136 > 10800
# Testing P:2 I:200 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 1450 False Settle 39600 > 10800
# Testing P:2 I:210 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 1305 False Settle 39600 > 10800
# Testing P:2 I:220 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 1180 False Settle 39600 > 10800
# Testing P:2 I:230 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 1073 False Settle 39600 > 10800
# Testing P:2 I:240 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 979 False Settle 39600 > 10800
# Testing P:2 I:250 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 898 False Settle 39600 > 10800
# Testing P:3 I:50 Result: Total: 100000 Settle: 165353 Ramp: 0 Curve: 48702 False Settle 21859 > 10800
# Testing P:3 I:60 Result: Total: 100000 Settle: 143808 Ramp: 0 Curve: 34367 False Settle 20992 > 10800
# Testing P:3 I:70 Result: Total: 100000 Settle: 142611 Ramp: 0 Curve: 25345 False Settle 20942 > 10800
# Testing P:3 I:80 Result: Total: 100000 Settle: 155326 Ramp: 0 Curve: 19209 False Settle 21463 > 10800
# Testing P:3 I:90 Result: Total: 100000 Settle: 161823 Ramp: 0 Curve: 14251 False Settle 21721 > 10800
# Testing P:3 I:100 Result: Total: 100000 Settle: 182115 Ramp: 0 Curve: 10980 False Settle 22495 > 10800
# Testing P:3 I:110 Result: Total: 100000 Settle: 211120 Ramp: 0 Curve: 8745 False Settle 23530 > 10800
# Testing P:3 I:120 Result: Total: 100000 Settle: 249513 Ramp: 0 Curve: 7137 False Settle 24796 > 10800
# Testing P:3 I:130 Result: Total: 100000 Settle: 306320 Ramp: 0 Curve: 5936 False Settle 26502 > 10800
# Testing P:3 I:140 Result: Total: 100000 Settle: 389351 Ramp: 0 Curve: 5016 False Settle 28732 > 10800
# Testing P:3 I:150 Result: Total: 100000 Settle: 490091 Ramp: 0 Curve: 4295 False Settle 31138 > 10800
# Testing P:3 I:160 Result: Total: 100000 Settle: 592435 Ramp: 0 Curve: 3719 False Settle 33340 > 10800
# Testing P:3 I:170 Result: Total: 100000 Settle: 697118 Ramp: 0 Curve: 3252 False Settle 35403 > 10800
# Testing P:3 I:180 Result: Total: 100000 Settle: 133531776 Ramp: 0 Curve: 2868 False Settle 37442 > 10800
# Testing P:3 I:190 Result: Total: 100000 Settle: 149057766 Ramp: 0 Curve: 2548 False Settle 39508 > 10800
# Testing P:3 I:200 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 2279 False Settle 39600 > 10800
# Testing P:3 I:210 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 2050 False Settle 39600 > 10800
# Testing P:3 I:220 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 1854 False Settle 39600 > 10800
# Testing P:3 I:230 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 1685 False Settle 39600 > 10800
# Testing P:3 I:240 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 1538 False Settle 39600 > 10800
# Testing P:3 I:250 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 1410 False Settle 39600 > 10800
# Testing P:4 I:50 Result: Total: 93342 Settle: 39690 Ramp: 0 Curve: 53652 False Settle 15300 > 10800
# Testing P:4 I:60 Result: Total: 73529 Settle: 29354 Ramp: 0 Curve: 44174 False Settle 14418 > 10800
# Testing P:4 I:70 Result: Total: 100000 Settle: 90193 Ramp: 0 Curve: 32789 False Settle 18497 > 10800
# Testing P:4 I:80 Result: Total: 100000 Settle: 103734 Ramp: 0 Curve: 25131 False Settle 19185 > 10800
# Testing P:4 I:90 Result: Total: 100000 Settle: 122412 Ramp: 0 Curve: 19526 False Settle 20064 > 10800
# Testing P:4 I:100 Result: Total: 100000 Settle: 144817 Ramp: 0 Curve: 15052 False Settle 21034 > 10800
# Testing P:4 I:110 Result: Total: 100000 Settle: 178837 Ramp: 0 Curve: 11991 False Settle 22373 > 10800
# Testing P:4 I:120 Result: Total: 100000 Settle: 247149 Ramp: 0 Curve: 9778 False Settle 24721 > 10800
# Testing P:4 I:130 Result: Total: 100000 Settle: 348643 Ramp: 0 Curve: 8127 False Settle 27672 > 10800
# Testing P:4 I:140 Result: Total: 100000 Settle: 429111 Ramp: 0 Curve: 6864 False Settle 29715 > 10800
# Testing P:4 I:150 Result: Total: 100000 Settle: 509269 Ramp: 0 Curve: 5874 False Settle 31567 > 10800
# Testing P:4 I:160 Result: Total: 100000 Settle: 600152 Ramp: 0 Curve: 5085 False Settle 33498 > 10800
# Testing P:4 I:170 Result: Total: 100000 Settle: 704690 Ramp: 0 Curve: 4445 False Settle 35546 > 10800
# Testing P:4 I:180 Result: Total: 100000 Settle: 134931328 Ramp: 0 Curve: 3919 False Settle 37633 > 10800
# Testing P:4 I:190 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 3481 False Settle 39600 > 10800
# Testing P:4 I:200 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 3113 False Settle 39600 > 10800
# Testing P:4 I:210 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 2800 False Settle 39600 > 10800
# Testing P:4 I:220 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 2532 False Settle 39600 > 10800
# Testing P:4 I:230 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 2301 False Settle 39600 > 10800
# Testing P:4 I:240 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 2100 False Settle 39600 > 10800
# Testing P:4 I:250 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 1924 False Settle 39600 > 10800
# Testing P:5 I:50 Result: Total: 79986 Settle: 24502 Ramp: 0 Curve: 55483 False Settle 13950 > 10800
# Testing P:5 I:60 Result: Total: 63573 Settle: 13965 Ramp: 0 Curve: 49608 False Settle 12737 > 10800
# Testing P:5 I:70 Result: Total: 100000 Settle: 65480 Ramp: 0 Curve: 39571 False Settle 17092 > 10800
# Testing P:5 I:80 Result: Total: 100000 Settle: 79049 Ramp: 0 Curve: 30478 False Settle 17891 > 10800
# Testing P:5 I:90 Result: Total: 100000 Settle: 96589 Ramp: 0 Curve: 24027 False Settle 18828 > 10800
# Testing P:5 I:100 Result: Total: 100000 Settle: 123899 Ramp: 0 Curve: 19145 False Settle 20131 > 10800
# Testing P:5 I:110 Result: Total: 100000 Settle: 219395 Ramp: 0 Curve: 15248 False Settle 23812 > 10800
# Testing P:5 I:120 Result: Total: 100000 Settle: 296872 Ramp: 0 Curve: 12427 False Settle 26230 > 10800
# Testing P:5 I:130 Result: Total: 100000 Settle: 355020 Ramp: 0 Curve: 10325 False Settle 27842 > 10800
# Testing P:5 I:140 Result: Total: 100000 Settle: 423371 Ramp: 0 Curve: 8717 False Settle 29576 > 10800
# Testing P:5 I:150 Result: Total: 100000 Settle: 510488 Ramp: 0 Curve: 7458 False Settle 31593 > 10800
# Testing P:5 I:160 Result: Total: 100000 Settle: 611572 Ramp: 0 Curve: 6455 False Settle 33730 > 10800
# Testing P:5 I:170 Result: Total: 100000 Settle: 716847 Ramp: 0 Curve: 5641 False Settle 35774 > 10800
# Testing P:5 I:180 Result: Total: 100000 Settle: 135851216 Ramp: 0 Curve: 4973 False Settle 37758 > 10800
# Testing P:5 I:190 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 4417 False Settle 39600 > 10800
# Testing P:5 I:200 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 3949 False Settle 39600 > 10800
# Testing P:5 I:210 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 3552 False Settle 39600 > 10800
# Testing P:5 I:220 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 3212 False Settle 39600 > 10800
# Testing P:5 I:230 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 2918 False Settle 39600 > 10800
# Testing P:5 I:240 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 2663 False Settle 39600 > 10800
# Testing P:5 I:250 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 2440 False Settle 39600 > 10800
# Testing P:6 I:50 Result: Total: 70246 Settle: 13660 Ramp: 0 Curve: 56585 False Settle 12696 > 10800
# Testing P:6 I:60 Result: Total: 51250 Settle: 123 Ramp: 0 Curve: 51127 True
# Testing P:6 I:70 Result: Total: 97693 Settle: 51868 Ramp: 0 Curve: 45825 False Settle 16202 > 10800
# Testing P:6 I:80 Result: Total: 100000 Settle: 64786 Ramp: 0 Curve: 35387 False Settle 17049 > 10800
# Testing P:6 I:90 Result: Total: 100000 Settle: 83010 Ramp: 0 Curve: 28014 False Settle 18111 > 10800
# Testing P:6 I:100 Result: Total: 100000 Settle: 181575 Ramp: 0 Curve: 22704 False Settle 22475 > 10800
# Testing P:6 I:110 Result: Total: 100000 Settle: 241522 Ramp: 0 Curve: 18511 False Settle 24541 > 10800
# Testing P:6 I:120 Result: Total: 100000 Settle: 285576 Ramp: 0 Curve: 15081 False Settle 25899 > 10800
# Testing P:6 I:130 Result: Total: 100000 Settle: 345030 Ramp: 0 Curve: 12527 False Settle 27575 > 10800
# Testing P:6 I:140 Result: Total: 100000 Settle: 430562 Ramp: 0 Curve: 10573 False Settle 29750 > 10800
# Testing P:6 I:150 Result: Total: 100000 Settle: 525143 Ramp: 0 Curve: 9045 False Settle 31916 > 10800
# Testing P:6 I:160 Result: Total: 100000 Settle: 618268 Ramp: 0 Curve: 7827 False Settle 33865 > 10800
# Testing P:6 I:170 Result: Total: 100000 Settle: 718293 Ramp: 0 Curve: 6839 False Settle 35801 > 10800
# Testing P:6 I:180 Result: Total: 100000 Settle: 136183140 Ramp: 0 Curve: 6028 False Settle 37803 > 10800
# Testing P:6 I:190 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 5354 False Settle 39600 > 10800
# Testing P:6 I:200 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 4786 False Settle 39600 > 10800
# Testing P:6 I:210 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 4305 False Settle 39600 > 10800
# Testing P:6 I:220 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 3892 False Settle 39600 > 10800
# Testing P:6 I:230 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 3537 False Settle 39600 > 10800
# Testing P:6 I:240 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 3227 False Settle 39600 > 10800
# Testing P:6 I:250 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 2957 False Settle 39600 > 10800
# Testing P:7 I:50 Result: Total: 57304 Settle: 1 Ramp: 0 Curve: 57303 True
# Testing P:7 I:60 Result: Total: 87836 Settle: 35772 Ramp: 0 Curve: 52064 False Settle 14980 > 10800
# Testing P:7 I:70 Result: Total: 93092 Settle: 45724 Ramp: 0 Curve: 47368 False Settle 15762 > 10800
# Testing P:7 I:80 Result: Total: 95686 Settle: 55741 Ramp: 0 Curve: 39945 False Settle 16466 > 10800
# Testing P:7 I:90 Result: Total: 100000 Settle: 77862 Ramp: 0 Curve: 31697 False Settle 17823 > 10800
# Testing P:7 I:100 Result: Total: 100000 Settle: 185286 Ramp: 0 Curve: 25773 False Settle 22612 > 10800
# Testing P:7 I:110 Result: Total: 100000 Settle: 224580 Ramp: 0 Curve: 21374 False Settle 23986 > 10800
# Testing P:7 I:120 Result: Total: 100000 Settle: 274332 Ramp: 0 Curve: 17737 False Settle 25563 > 10800
# Testing P:7 I:130 Result: Total: 100000 Settle: 356907 Ramp: 0 Curve: 14731 False Settle 27892 > 10800
# Testing P:7 I:140 Result: Total: 100000 Settle: 444450 Ramp: 0 Curve: 12431 False Settle 30082 > 10800
# Testing P:7 I:150 Result: Total: 100000 Settle: 526105 Ramp: 0 Curve: 10633 False Settle 31937 > 10800
# Testing P:7 I:160 Result: Total: 100000 Settle: 617472 Ramp: 0 Curve: 9200 False Settle 33849 > 10800
# Testing P:7 I:170 Result: Total: 100000 Settle: 722265 Ramp: 0 Curve: 8039 False Settle 35875 > 10800
# Testing P:7 I:180 Result: Total: 100000 Settle: 136811214 Ramp: 0 Curve: 7085 False Settle 37888 > 10800
# Testing P:7 I:190 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 6291 False Settle 39600 > 10800
# Testing P:7 I:200 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 5624 False Settle 39600 > 10800
# Testing P:7 I:210 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 5058 False Settle 39600 > 10800
# Testing P:7 I:220 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 4573 False Settle 39600 > 10800
# Testing P:7 I:230 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 4155 False Settle 39600 > 10800
# Testing P:7 I:240 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 3792 False Settle 39600 > 10800
# Testing P:7 I:250 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 3474 False Settle 39600 > 10800
# Testing P:8 I:50 Result: Total: 57790 Settle: 3 Ramp: 0 Curve: 57787 True
# Testing P:8 I:60 Result: Total: 86548 Settle: 33860 Ramp: 0 Curve: 52687 False Settle 14818 > 10800
# Testing P:8 I:70 Result: Total: 89285 Settle: 41062 Ramp: 0 Curve: 48223 False Settle 15407 > 10800
# Testing P:8 I:80 Result: Total: 93890 Settle: 49984 Ramp: 0 Curve: 43905 False Settle 16069 > 10800
# Testing P:8 I:90 Result: Total: 100000 Settle: 131308 Ramp: 0 Curve: 35134 False Settle 20459 > 10800
# Testing P:8 I:100 Result: Total: 100000 Settle: 172843 Ramp: 0 Curve: 28620 False Settle 22147 > 10800
# Testing P:8 I:110 Result: Total: 100000 Settle: 211033 Ramp: 0 Curve: 23786 False Settle 23527 > 10800
# Testing P:8 I:120 Result: Total: 100000 Settle: 282912 Ramp: 0 Curve: 20061 False Settle 25820 > 10800
# Testing P:8 I:130 Result: Total: 100000 Settle: 370909 Ramp: 0 Curve: 16936 False Settle 28259 > 10800
# Testing P:8 I:140 Result: Total: 100000 Settle: 441924 Ramp: 0 Curve: 14291 False Settle 30022 > 10800
# Testing P:8 I:150 Result: Total: 100000 Settle: 524226 Ramp: 0 Curve: 12222 False Settle 31895 > 10800
# Testing P:8 I:160 Result: Total: 100000 Settle: 622752 Ramp: 0 Curve: 10574 False Settle 33955 > 10800
# Testing P:8 I:170 Result: Total: 100000 Settle: 726733 Ramp: 0 Curve: 9238 False Settle 35958 > 10800
# Testing P:8 I:180 Result: Total: 100000 Settle: 136929601 Ramp: 0 Curve: 8141 False Settle 37904 > 10800
# Testing P:8 I:190 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 7229 False Settle 39600 > 10800
# Testing P:8 I:200 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 6463 False Settle 39600 > 10800
# Testing P:8 I:210 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 5812 False Settle 39600 > 10800
# Testing P:8 I:220 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 5255 False Settle 39600 > 10800
# Testing P:8 I:230 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 4774 False Settle 39600 > 10800
# Testing P:8 I:240 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 4357 False Settle 39600 > 10800
# Testing P:8 I:250 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 3992 False Settle 39600 > 10800
# Testing P:9 I:50 Result: Total: 58168 Settle: 35 Ramp: 0 Curve: 58133 True
# Testing P:9 I:60 Result: Total: 84155 Settle: 31036 Ramp: 0 Curve: 53119 False Settle 14570 > 10800
# Testing P:9 I:70 Result: Total: 86498 Settle: 37699 Ramp: 0 Curve: 48799 False Settle 15140 > 10800
# Testing P:9 I:80 Result: Total: 93439 Settle: 48636 Ramp: 0 Curve: 44802 False Settle 15974 > 10800
# Testing P:9 I:90 Result: Total: 100000 Settle: 129777 Ramp: 0 Curve: 38368 False Settle 20392 > 10800
# Testing P:9 I:100 Result: Total: 100000 Settle: 161620 Ramp: 0 Curve: 31289 False Settle 21713 > 10800
# Testing P:9 I:110 Result: Total: 100000 Settle: 207072 Ramp: 0 Curve: 26032 False Settle 23390 > 10800
# Testing P:9 I:120 Result: Total: 100000 Settle: 297700 Ramp: 0 Curve: 21991 False Settle 26254 > 10800
# Testing P:9 I:130 Result: Total: 100000 Settle: 365192 Ramp: 0 Curve: 18802 False Settle 28110 > 10800
# Testing P:9 I:140 Result: Total: 100000 Settle: 438274 Ramp: 0 Curve: 16151 False Settle 29935 > 10800
# Testing P:9 I:150 Result: Total: 100000 Settle: 530242 Ramp: 0 Curve: 13812 False Settle 32027 > 10800
# Testing P:9 I:160 Result: Total: 100000 Settle: 626901 Ramp: 0 Curve: 11948 False Settle 34038 > 10800
# Testing P:9 I:170 Result: Total: 100000 Settle: 726572 Ramp: 0 Curve: 10439 False Settle 35955 > 10800
# Testing P:9 I:180 Result: Total: 100000 Settle: 137062848 Ramp: 0 Curve: 9199 False Settle 37922 > 10800
# Testing P:9 I:190 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 8168 False Settle 39600 > 10800
# Testing P:9 I:200 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 7301 False Settle 39600 > 10800
# Testing P:9 I:210 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 6566 False Settle 39600 > 10800
# Testing P:9 I:220 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 5936 False Settle 39600 > 10800
# Testing P:9 I:230 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 5393 False Settle 39600 > 10800
# Testing P:9 I:240 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 4921 False Settle 39600 > 10800
# Testing P:9 I:250 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 4509 False Settle 39600 > 10800
# Testing P:10 I:50 Result: Total: 58513 Settle: 134 Ramp: 0 Curve: 58378 True
# Testing P:10 I:60 Result: Total: 82008 Settle: 28579 Ramp: 0 Curve: 53429 False Settle 14346 > 10800
# Testing P:10 I:70 Result: Total: 84658 Settle: 35462 Ramp: 0 Curve: 49196 False Settle 14955 > 10800
# Testing P:10 I:80 Result: Total: 100000 Settle: 90250 Ramp: 0 Curve: 45348 False Settle 18500 > 10800
# Testing P:10 I:90 Result: Total: 100000 Settle: 122832 Ramp: 0 Curve: 41430 False Settle 20083 > 10800
# Testing P:10 I:100 Result: Total: 100000 Settle: 153363 Ramp: 0 Curve: 33808 False Settle 21384 > 10800
# Testing P:10 I:110 Result: Total: 100000 Settle: 220225 Ramp: 0 Curve: 28145 False Settle 23840 > 10800
# Testing P:10 I:120 Result: Total: 100000 Settle: 295427 Ramp: 0 Curve: 23796 False Settle 26188 > 10800
# Testing P:10 I:130 Result: Total: 100000 Settle: 357436 Ramp: 0 Curve: 20369 False Settle 27906 > 10800
# Testing P:10 I:140 Result: Total: 100000 Settle: 441084 Ramp: 0 Curve: 17620 False Settle 30002 > 10800
# Testing P:10 I:150 Result: Total: 100000 Settle: 534950 Ramp: 0 Curve: 15375 False Settle 32129 > 10800
# Testing P:10 I:160 Result: Total: 100000 Settle: 625850 Ramp: 0 Curve: 13323 False Settle 34017 > 10800
# Testing P:10 I:170 Result: Total: 100000 Settle: 727434 Ramp: 0 Curve: 11639 False Settle 35971 > 10800
# Testing P:10 I:180 Result: Total: 100000 Settle: 137403662 Ramp: 0 Curve: 10256 False Settle 37968 > 10800
# Testing P:10 I:190 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 9107 False Settle 39600 > 10800
# Testing P:10 I:200 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 8140 False Settle 39600 > 10800
# Testing P:10 I:210 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 7320 False Settle 39600 > 10800
# Testing P:10 I:220 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 6618 False Settle 39600 > 10800
# Testing P:10 I:230 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 6012 False Settle 39600 > 10800
# Testing P:10 I:240 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 5486 False Settle 39600 > 10800
# Testing P:10 I:250 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 5027 False Settle 39600 > 10800
# Testing P:11 I:50 Result: Total: 75237 Settle: 16679 Ramp: 0 Curve: 58558 False Settle 13084 > 10800
# Testing P:11 I:60 Result: Total: 80217 Settle: 26563 Ramp: 0 Curve: 53654 False Settle 14154 > 10800
# Testing P:11 I:70 Result: Total: 83839 Settle: 34363 Ramp: 0 Curve: 49476 False Settle 14862 > 10800
# Testing P:11 I:80 Result: Total: 100000 Settle: 96294 Ramp: 0 Curve: 45726 False Settle 18813 > 10800
# Testing P:11 I:90 Result: Total: 100000 Settle: 117744 Ramp: 0 Curve: 42214 False Settle 19851 > 10800
# Testing P:11 I:100 Result: Total: 100000 Settle: 149059 Ramp: 0 Curve: 36201 False Settle 21209 > 10800
# Testing P:11 I:110 Result: Total: 100000 Settle: 231283 Ramp: 0 Curve: 30148 False Settle 24208 > 10800
# Testing P:11 I:120 Result: Total: 100000 Settle: 288456 Ramp: 0 Curve: 25500 False Settle 25984 > 10800
# Testing P:11 I:130 Result: Total: 100000 Settle: 355548 Ramp: 0 Curve: 21841 False Settle 27856 > 10800
# Testing P:11 I:140 Result: Total: 100000 Settle: 445421 Ramp: 0 Curve: 18909 False Settle 30105 > 10800
# Testing P:11 I:150 Result: Total: 100000 Settle: 531210 Ramp: 0 Curve: 16522 False Settle 32047 > 10800
# Testing P:11 I:160 Result: Total: 100000 Settle: 624750 Ramp: 0 Curve: 14552 False Settle 33995 > 10800
# Testing P:11 I:170 Result: Total: 100000 Settle: 123397638 Ramp: 0 Curve: 12840 False Settle 36028 > 10800
# Testing P:11 I:180 Result: Total: 100000 Settle: 137507472 Ramp: 0 Curve: 11314 False Settle 37982 > 10800
# Testing P:11 I:190 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 10045 False Settle 39600 > 10800
# Testing P:11 I:200 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 8979 False Settle 39600 > 10800
# Testing P:11 I:210 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 8074 False Settle 39600 > 10800
# Testing P:11 I:220 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 7300 False Settle 39600 > 10800
# Testing P:11 I:230 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 6632 False Settle 39600 > 10800
# Testing P:11 I:240 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 6052 False Settle 39600 > 10800
# Testing P:11 I:250 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 5544 False Settle 39600 > 10800
# Testing P:12 I:50 Result: Total: 77360 Settle: 18671 Ramp: 0 Curve: 58689 False Settle 13321 > 10800
# Testing P:12 I:60 Result: Total: 78789 Settle: 24970 Ramp: 0 Curve: 53819 False Settle 13997 > 10800
# Testing P:12 I:70 Result: Total: 84705 Settle: 35022 Ramp: 0 Curve: 49683 False Settle 14917 > 10800
# Testing P:12 I:80 Result: Total: 100000 Settle: 93315 Ramp: 0 Curve: 45998 False Settle 18660 > 10800
# Testing P:12 I:90 Result: Total: 100000 Settle: 113422 Ramp: 0 Curve: 42646 False Settle 19650 > 10800
# Testing P:12 I:100 Result: Total: 100000 Settle: 151757 Ramp: 0 Curve: 38484 False Settle 21319 > 10800
# Testing P:12 I:110 Result: Total: 100000 Settle: 229734 Ramp: 0 Curve: 32055 False Settle 24157 > 10800
# Testing P:12 I:120 Result: Total: 100000 Settle: 282609 Ramp: 0 Curve: 27120 False Settle 25811 > 10800
# Testing P:12 I:130 Result: Total: 100000 Settle: 360278 Ramp: 0 Curve: 23236 False Settle 27981 > 10800
# Testing P:12 I:140 Result: Total: 100000 Settle: 444408 Ramp: 0 Curve: 20126 False Settle 30081 > 10800
# Testing P:12 I:150 Result: Total: 100000 Settle: 527529 Ramp: 0 Curve: 17596 False Settle 31967 > 10800
# Testing P:12 I:160 Result: Total: 100000 Settle: 625500 Ramp: 0 Curve: 15510 False Settle 34010 > 10800
# Testing P:12 I:170 Result: Total: 100000 Settle: 123299299 Ramp: 0 Curve: 13769 False Settle 36014 > 10800
# Testing P:12 I:180 Result: Total: 100000 Settle: 137403662 Ramp: 0 Curve: 12300 False Settle 37968 > 10800
# Testing P:12 I:190 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 10984 False Settle 39600 > 10800
# Testing P:12 I:200 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 9818 False Settle 39600 > 10800
# Testing P:12 I:210 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 8829 False Settle 39600 > 10800
# Testing P:12 I:220 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 7982 False Settle 39600 > 10800
# Testing P:12 I:230 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 7251 False Settle 39600 > 10800
# Testing P:12 I:240 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 6617 False Settle 39600 > 10800
# Testing P:12 I:250 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 6062 False Settle 39600 > 10800
# Testing P:13 I:50 Result: Total: 76933 Settle: 18147 Ramp: 0 Curve: 58785 False Settle 13260 > 10800
# Testing P:13 I:60 Result: Total: 77713 Settle: 23775 Ramp: 0 Curve: 53937 False Settle 13876 > 10800
# Testing P:13 I:70 Result: Total: 100000 Settle: 69089 Ramp: 0 Curve: 49838 False Settle 17312 > 10800
# Testing P:13 I:80 Result: Total: 100000 Settle: 89567 Ramp: 0 Curve: 46199 False Settle 18464 > 10800
# Testing P:13 I:90 Result: Total: 100000 Settle: 110796 Ramp: 0 Curve: 42954 False Settle 19526 > 10800
# Testing P:13 I:100 Result: Total: 100000 Settle: 169598 Ramp: 0 Curve: 39858 False Settle 22023 > 10800
# Testing P:13 I:110 Result: Total: 100000 Settle: 224700 Ramp: 0 Curve: 33881 False Settle 23990 > 10800
# Testing P:13 I:120 Result: Total: 100000 Settle: 280663 Ramp: 0 Curve: 28667 False Settle 25753 > 10800
# Testing P:13 I:130 Result: Total: 100000 Settle: 364275 Ramp: 0 Curve: 24566 False Settle 28086 > 10800
# Testing P:13 I:140 Result: Total: 100000 Settle: 440580 Ramp: 0 Curve: 21283 False Settle 29990 > 10800
# Testing P:13 I:150 Result: Total: 100000 Settle: 527115 Ramp: 0 Curve: 18613 False Settle 31959 > 10800
# Testing P:13 I:160 Result: Total: 100000 Settle: 625850 Ramp: 0 Curve: 16413 False Settle 34017 > 10800
# Testing P:13 I:170 Result: Total: 100000 Settle: 727111 Ramp: 0 Curve: 14578 False Settle 35965 > 10800
# Testing P:13 I:180 Result: Total: 100000 Settle: 137240611 Ramp: 0 Curve: 13032 False Settle 37946 > 10800
# Testing P:13 I:190 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 11717 False Settle 39600 > 10800
# Testing P:13 I:200 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 10588 False Settle 39600 > 10800
# Testing P:13 I:210 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 9583 False Settle 39600 > 10800
# Testing P:13 I:220 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 8664 False Settle 39600 > 10800
# Testing P:13 I:230 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 7871 False Settle 39600 > 10800
# Testing P:13 I:240 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 7182 False Settle 39600 > 10800
# Testing P:13 I:250 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 6580 False Settle 39600 > 10800
# Testing P:14 I:50 Result: Total: 76243 Settle: 17388 Ramp: 0 Curve: 58854 False Settle 13170 > 10800
# Testing P:14 I:60 Result: Total: 76976 Settle: 22953 Ramp: 0 Curve: 54023 False Settle 13791 > 10800
# Testing P:14 I:70 Result: Total: 100000 Settle: 69505 Ramp: 0 Curve: 49956 False Settle 17337 > 10800
# Testing P:14 I:80 Result: Total: 100000 Settle: 86099 Ramp: 0 Curve: 46350 False Settle 18279 > 10800
# Testing P:14 I:90 Result: Total: 100000 Settle: 111471 Ramp: 0 Curve: 43180 False Settle 19558 > 10800
# Testing P:14 I:100 Result: Total: 100000 Settle: 177209 Ramp: 0 Curve: 40228 False Settle 22312 > 10800
# Testing P:14 I:110 Result: Total: 100000 Settle: 219543 Ramp: 0 Curve: 35633 False Settle 23817 > 10800
# Testing P:14 I:120 Result: Total: 100000 Settle: 284124 Ramp: 0 Curve: 30151 False Settle 25856 > 10800
# Testing P:14 I:130 Result: Total: 100000 Settle: 363512 Ramp: 0 Curve: 25841 False Settle 28066 > 10800
# Testing P:14 I:140 Result: Total: 100000 Settle: 437646 Ramp: 0 Curve: 22390 False Settle 29919 > 10800
# Testing P:14 I:150 Result: Total: 100000 Settle: 528816 Ramp: 0 Curve: 19585 False Settle 31996 > 10800
# Testing P:14 I:160 Result: Total: 100000 Settle: 624100 Ramp: 0 Curve: 17273 False Settle 33982 > 10800
# Testing P:14 I:170 Result: Total: 100000 Settle: 725494 Ramp: 0 Curve: 15347 False Settle 35935 > 10800
# Testing P:14 I:180 Result: Total: 100000 Settle: 137173936 Ramp: 0 Curve: 13723 False Settle 37937 > 10800
# Testing P:14 I:190 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 12343 False Settle 39600 > 10800
# Testing P:14 I:200 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 11160 False Settle 39600 > 10800
# Testing P:14 I:210 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 10137 False Settle 39600 > 10800
# Testing P:14 I:220 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 9248 False Settle 39600 > 10800
# Testing P:14 I:230 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 8468 False Settle 39600 > 10800
# Testing P:14 I:240 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 7747 False Settle 39600 > 10800
# Testing P:14 I:250 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 7098 False Settle 39600 > 10800
# Testing P:15 I:50 Result: Total: 75518 Settle: 16613 Ramp: 0 Curve: 58904 False Settle 13076 > 10800
# Testing P:15 I:60 Result: Total: 76655 Settle: 22572 Ramp: 0 Curve: 54083 False Settle 13751 > 10800
# Testing P:15 I:70 Result: Total: 100000 Settle: 67453 Ramp: 0 Curve: 50037 False Settle 17213 > 10800
# Testing P:15 I:80 Result: Total: 100000 Settle: 83265 Ramp: 0 Curve: 46462 False Settle 18125 > 10800
# Testing P:15 I:90 Result: Total: 100000 Settle: 121859 Ramp: 0 Curve: 43349 False Settle 20039 > 10800
# Testing P:15 I:100 Result: Total: 100000 Settle: 176491 Ramp: 0 Curve: 40488 False Settle 22285 > 10800
# Testing P:15 I:110 Result: Total: 100000 Settle: 215707 Ramp: 0 Curve: 37322 False Settle 23687 > 10800
# Testing P:15 I:120 Result: Total: 100000 Settle: 289510 Ramp: 0 Curve: 31580 False Settle 26015 > 10800
# Testing P:15 I:130 Result: Total: 100000 Settle: 360278 Ramp: 0 Curve: 27066 False Settle 27981 > 10800
# Testing P:15 I:140 Result: Total: 100000 Settle: 437520 Ramp: 0 Curve: 23453 False Settle 29917 > 10800
# Testing P:15 I:150 Result: Total: 100000 Settle: 529276 Ramp: 0 Curve: 20517 False Settle 32005 > 10800
# Testing P:15 I:160 Result: Total: 100000 Settle: 621853 Ramp: 0 Curve: 18097 False Settle 33937 > 10800
# Testing P:15 I:170 Result: Total: 100000 Settle: 725332 Ramp: 0 Curve: 16081 False Settle 35932 > 10800
# Testing P:15 I:180 Result: Total: 100000 Settle: 137011022 Ramp: 0 Curve: 14383 False Settle 37915 > 10800
# Testing P:15 I:190 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 12939 False Settle 39600 > 10800
# Testing P:15 I:200 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 11701 False Settle 39600 > 10800
# Testing P:15 I:210 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 10632 False Settle 39600 > 10800
# Testing P:15 I:220 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 9702 False Settle 39600 > 10800
# Testing P:15 I:230 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 8888 False Settle 39600 > 10800
# Testing P:15 I:240 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 8172 False Settle 39600 > 10800
# Testing P:15 I:250 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 7538 False Settle 39600 > 10800
# Testing P:16 I:50 Result: Total: 74833 Settle: 15896 Ramp: 0 Curve: 58937 False Settle 12987 > 10800
# Testing P:16 I:60 Result: Total: 76945 Settle: 22819 Ramp: 0 Curve: 54126 False Settle 13777 > 10800
# Testing P:16 I:70 Result: Total: 100000 Settle: 64995 Ramp: 0 Curve: 50086 False Settle 17062 > 10800
# Testing P:16 I:80 Result: Total: 100000 Settle: 81324 Ramp: 0 Curve: 46546 False Settle 18018 > 10800
# Testing P:16 I:90 Result: Total: 100000 Settle: 136399 Ramp: 0 Curve: 43475 False Settle 20679 > 10800
# Testing P:16 I:100 Result: Total: 100000 Settle: 173844 Ramp: 0 Curve: 40678 False Settle 22185 > 10800
# Testing P:16 I:110 Result: Total: 100000 Settle: 216472 Ramp: 0 Curve: 37989 False Settle 23713 > 10800
# Testing P:16 I:120 Result: Total: 100000 Settle: 291350 Ramp: 0 Curve: 32958 False Settle 26069 > 10800
# Testing P:16 I:130 Result: Total: 100000 Settle: 357134 Ramp: 0 Curve: 28247 False Settle 27898 > 10800
# Testing P:16 I:140 Result: Total: 100000 Settle: 439531 Ramp: 0 Curve: 24477 False Settle 29965 > 10800
# Testing P:16 I:150 Result: Total: 100000 Settle: 527804 Ramp: 0 Curve: 21414 False Settle 31974 > 10800
# Testing P:16 I:160 Result: Total: 100000 Settle: 620807 Ramp: 0 Curve: 18890 False Settle 33916 > 10800
# Testing P:16 I:170 Result: Total: 100000 Settle: 725171 Ramp: 0 Curve: 16787 False Settle 35929 > 10800
# Testing P:16 I:180 Result: Total: 100000 Settle: 136796419 Ramp: 0 Curve: 15015 False Settle 37886 > 10800
# Testing P:16 I:190 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 13509 False Settle 39600 > 10800
# Testing P:16 I:200 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 12219 False Settle 39600 > 10800
# Testing P:16 I:210 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 11104 False Settle 39600 > 10800
# Testing P:16 I:220 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 10134 False Settle 39600 > 10800
# Testing P:16 I:230 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 9286 False Settle 39600 > 10800
# Testing P:16 I:240 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 8540 False Settle 39600 > 10800
# Testing P:16 I:250 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 7879 False Settle 39600 > 10800
# Testing P:17 I:50 Result: Total: 74209 Settle: 15249 Ramp: 0 Curve: 58960 False Settle 12905 > 10800
# Testing P:17 I:60 Result: Total: 78736 Settle: 24581 Ramp: 0 Curve: 54154 False Settle 13958 > 10800
# Testing P:17 I:70 Result: Total: 100000 Settle: 62615 Ramp: 0 Curve: 50117 False Settle 16913 > 10800
# Testing P:17 I:80 Result: Total: 100000 Settle: 80766 Ramp: 0 Curve: 46607 False Settle 17987 > 10800
# Testing P:17 I:90 Result: Total: 100000 Settle: 138485 Ramp: 0 Curve: 43569 False Settle 20768 > 10800
# Testing P:17 I:100 Result: Total: 100000 Settle: 171269 Ramp: 0 Curve: 40819 False Settle 22087 > 10800
# Testing P:17 I:110 Result: Total: 100000 Settle: 222845 Ramp: 0 Curve: 38227 False Settle 23928 > 10800
# Testing P:17 I:120 Result: Total: 100000 Settle: 289884 Ramp: 0 Curve: 34292 False Settle 26026 > 10800
# Testing P:17 I:130 Result: Total: 100000 Settle: 355737 Ramp: 0 Curve: 29390 False Settle 27861 > 10800
# Testing P:17 I:140 Result: Total: 100000 Settle: 440958 Ramp: 0 Curve: 25467 False Settle 29999 > 10800
# Testing P:17 I:150 Result: Total: 100000 Settle: 525693 Ramp: 0 Curve: 22280 False Settle 31928 > 10800
# Testing P:17 I:160 Result: Total: 100000 Settle: 621106 Ramp: 0 Curve: 19655 False Settle 33922 > 10800
# Testing P:17 I:170 Result: Total: 100000 Settle: 724148 Ramp: 0 Curve: 17467 False Settle 35910 > 10800
# Testing P:17 I:180 Result: Total: 100000 Settle: 136641122 Ramp: 0 Curve: 15624 False Settle 37865 > 10800
# Testing P:17 I:190 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 14058 False Settle 39600 > 10800
# Testing P:17 I:200 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 12716 False Settle 39600 > 10800
# Testing P:17 I:210 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 11557 False Settle 39600 > 10800
# Testing P:17 I:220 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 10549 False Settle 39600 > 10800
# Testing P:17 I:230 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 9667 False Settle 39600 > 10800
# Testing P:17 I:240 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 8891 False Settle 39600 > 10800
# Testing P:17 I:250 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 8204 False Settle 39600 > 10800
# Testing P:18 I:50 Result: Total: 73671 Settle: 14699 Ramp: 0 Curve: 58971 False Settle 12834 > 10800
# Testing P:18 I:60 Result: Total: 100000 Settle: 45846 Ramp: 0 Curve: 54171 False Settle 15771 > 10800
# Testing P:18 I:70 Result: Total: 100000 Settle: 60466 Ramp: 0 Curve: 50136 False Settle 16776 > 10800
# Testing P:18 I:80 Result: Total: 100000 Settle: 83064 Ramp: 0 Curve: 46652 False Settle 18114 > 10800
# Testing P:18 I:90 Result: Total: 100000 Settle: 137170 Ramp: 0 Curve: 43639 False Settle 20712 > 10800
# Testing P:18 I:100 Result: Total: 100000 Settle: 169780 Ramp: 0 Curve: 40925 False Settle 22030 > 10800
# Testing P:18 I:110 Result: Total: 100000 Settle: 230766 Ramp: 0 Curve: 38397 False Settle 24191 > 10800
# Testing P:18 I:120 Result: Total: 100000 Settle: 287099 Ramp: 0 Curve: 35584 False Settle 25944 > 10800
# Testing P:18 I:130 Result: Total: 100000 Settle: 356643 Ramp: 0 Curve: 30496 False Settle 27885 > 10800
# Testing P:18 I:140 Result: Total: 100000 Settle: 440454 Ramp: 0 Curve: 26425 False Settle 29987 > 10800
# Testing P:18 I:150 Result: Total: 100000 Settle: 524455 Ramp: 0 Curve: 23118 False Settle 31901 > 10800
# Testing P:18 I:160 Result: Total: 100000 Settle: 621455 Ramp: 0 Curve: 20394 False Settle 33929 > 10800
# Testing P:18 I:170 Result: Total: 100000 Settle: 722695 Ramp: 0 Curve: 18124 False Settle 35883 > 10800
# Testing P:18 I:180 Result: Total: 100000 Settle: 136574593 Ramp: 0 Curve: 16213 False Settle 37856 > 10800
# Testing P:18 I:190 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 14588 False Settle 39600 > 10800
# Testing P:18 I:200 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 13196 False Settle 39600 > 10800
# Testing P:18 I:210 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 11994 False Settle 39600 > 10800
# Testing P:18 I:220 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 10948 False Settle 39600 > 10800
# Testing P:18 I:230 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 10033 False Settle 39600 > 10800
# Testing P:18 I:240 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 9228 False Settle 39600 > 10800
# Testing P:18 I:250 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 8516 False Settle 39600 > 10800
# Testing P:19 I:50 Result: Total: 73205 Settle: 14227 Ramp: 0 Curve: 58977 False Settle 12772 > 10800
# Testing P:19 I:60 Result: Total: 99946 Settle: 45765 Ramp: 0 Curve: 54181 False Settle 15765 > 10800
# Testing P:19 I:70 Result: Total: 100000 Settle: 58629 Ramp: 0 Curve: 50146 False Settle 16656 > 10800
# Testing P:19 I:80 Result: Total: 100000 Settle: 95121 Ramp: 0 Curve: 46682 False Settle 18753 > 10800
# Testing P:19 I:90 Result: Total: 100000 Settle: 134908 Ramp: 0 Curve: 43689 False Settle 20615 > 10800
# Testing P:19 I:100 Result: Total: 100000 Settle: 170537 Ramp: 0 Curve: 41003 False Settle 22059 > 10800
# Testing P:19 I:110 Result: Total: 100000 Settle: 234243 Ramp: 0 Curve: 38522 False Settle 24305 > 10800
# Testing P:19 I:120 Result: Total: 100000 Settle: 285677 Ramp: 0 Curve: 36116 False Settle 25902 > 10800
# Testing P:19 I:130 Result: Total: 100000 Settle: 358950 Ramp: 0 Curve: 31570 False Settle 27946 > 10800
# Testing P:19 I:140 Result: Total: 100000 Settle: 438693 Ramp: 0 Curve: 27355 False Settle 29945 > 10800
# Testing P:19 I:150 Result: Total: 100000 Settle: 524593 Ramp: 0 Curve: 23931 False Settle 31904 > 10800
# Testing P:19 I:160 Result: Total: 100000 Settle: 620956 Ramp: 0 Curve: 21111 False Settle 33919 > 10800
# Testing P:19 I:170 Result: Total: 100000 Settle: 721674 Ramp: 0 Curve: 18762 False Settle 35864 > 10800
# Testing P:19 I:180 Result: Total: 100000 Settle: 136530250 Ramp: 0 Curve: 16783 False Settle 37850 > 10800
# Testing P:19 I:190 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 15102 False Settle 39600 > 10800
# Testing P:19 I:200 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 13661 False Settle 39600 > 10800
# Testing P:19 I:210 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 12416 False Settle 39600 > 10800
# Testing P:19 I:220 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 11334 False Settle 39600 > 10800
# Testing P:19 I:230 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 10387 False Settle 39600 > 10800
# Testing P:19 I:240 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 9554 False Settle 39600 > 10800
# Testing P:19 I:250 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 8817 False Settle 39600 > 10800
# Testing P:20 I:50 Result: Total: 72830 Settle: 13853 Ramp: 0 Curve: 58976 False Settle 12722 > 10800
# Testing P:20 I:60 Result: Total: 98979 Settle: 44796 Ramp: 0 Curve: 54183 False Settle 15693 > 10800
# Testing P:20 I:70 Result: Total: 100000 Settle: 57138 Ramp: 0 Curve: 50147 False Settle 16559 > 10800
# Testing P:20 I:80 Result: Total: 100000 Settle: 102921 Ramp: 0 Curve: 46702 False Settle 19145 > 10800
# Testing P:20 I:90 Result: Total: 100000 Settle: 132549 Ramp: 0 Curve: 43723 False Settle 20513 > 10800
# Testing P:20 I:100 Result: Total: 100000 Settle: 174979 Ramp: 0 Curve: 41059 False Settle 22228 > 10800
# Testing P:20 I:110 Result: Total: 100000 Settle: 234365 Ramp: 0 Curve: 38614 False Settle 24309 > 10800
# Testing P:20 I:120 Result: Total: 100000 Settle: 285948 Ramp: 0 Curve: 36286 False Settle 25910 > 10800
# Testing P:20 I:130 Result: Total: 100000 Settle: 360544 Ramp: 0 Curve: 32615 False Settle 27988 > 10800
# Testing P:20 I:140 Result: Total: 100000 Settle: 436893 Ramp: 0 Curve: 28259 False Settle 29902 > 10800
# Testing P:20 I:150 Result: Total: 100000 Settle: 525418 Ramp: 0 Curve: 24721 False Settle 31921 > 10800
# Testing P:20 I:160 Result: Total: 100000 Settle: 619711 Ramp: 0 Curve: 21808 False Settle 33894 > 10800
# Testing P:20 I:170 Result: Total: 100000 Settle: 721405 Ramp: 0 Curve: 19380 False Settle 35859 > 10800
# Testing P:20 I:180 Result: Total: 100000 Settle: 136426809 Ramp: 0 Curve: 17337 False Settle 37836 > 10800
# Testing P:20 I:190 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 15600 False Settle 39600 > 10800
# Testing P:20 I:200 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 14111 False Settle 39600 > 10800
# Testing P:20 I:210 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 12826 False Settle 39600 > 10800
# Testing P:20 I:220 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 11708 False Settle 39600 > 10800
# Testing P:20 I:230 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 10730 False Settle 39600 > 10800
# Testing P:20 I:240 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 9870 False Settle 39600 > 10800
# Testing P:20 I:250 Result: Total: 100000 Settle: 149769000 Ramp: 0 Curve: 9109 False Settle 39600 > 10800
# Done

# %%
def on_legend_clicked(event):
    ll = event.artist
    line = leg_map[ll]
    line.set_visible(not line.get_visible())
    fig.canvas.draw()
fig.canvas.mpl_connect("pick_event", on_legend_clicked)

plt.close()
fig = plt.figure()
ax = fig.add_subplot(2,1,1)
ax3d = fig.add_subplot(2,1,2, projection='3d')
ax.axhline(y=sp, ls="--", color="black")
ax.grid()

f = FuncFormatter(lambda y, _: "%.1f%%"%y)
ax.yaxis.set_major_formatter(f)

axes = [ax, ax3d]

for a in axes:
    b = a.get_position()
    a.set_position([b.x0, b.y0, b.width*0.9, b.height])


def plot4(results):
    lines = []
    sx, sy, sz = [], [], []
    for k, data in results.items():
        p,i=k
        x = data['x']
        pv = data['pv']
        score = data['score']
        score2 = data['score2']
        if score2.result() == True:
            lines.append((x, pv, "P:%d I:%d"%(p,i)))
        sx.append(p)
        sy.append(i)
        sz.append(score.score())
    ax3d.scatter(sx,sy,sz, antialiased=False)
    for x,y,label in lines:
        ax.plot(x,y,label=label)
plot4(results)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-f9682158919d> in <module>()
#      40     for x,y,label in lines:
#      41         ax.plot(x,y,label=label)
# ---> 42 plot4(results)
#      43
#      44
#
# <ipython-input-26-f9682158919d> in plot4(results)
#      26     lines = []
#      27     sx, sy, sz = [], [], []
# ---> 28     for k, data in results.items():
#      29         p,i=k
#      30         x = data['x']
#
# AttributeError: 'list' object has no attribute 'items'

# %%
margin=3
lo = sp - margin
hi = sp + margin
ax.set_ylim(lo, hi)

# %%
ops.initial_pv = 20
ops.set_point = 80
ops.delay = 0
d1, d2, d3 = do_sim2(ops)
ops.delay = 40 * minutes
d4, d5, d6 = do_sim2(ops)
ops.n2_pid.i = 60
ops.o2_pid.i = 80

x1, pv1, *_ = list(zip(*d1))
x2, pv2, *_ = list(zip(*d4))
plt.close()
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
ax1.plot(x1, pv1, "blue", label="delay=0")
ax1.plot(x2, pv2, "red", label = "delay=1hr")
ax1.legend(loc="lower right")

# %%
plot(ops)

# %%
# Maximum value of c that O2 controller can sustain for a given k
ops.k*ops.k_mult*(100/20.95)*100

# %%
# manually constructed list of [(o2p, o2i),(n2p, n2i)]
maybe_good_params = [
    [
        (10, 10),
        (-10, 100)
    ],
    [
        (2, 40),
        (-10, 50)
    ]
]

# %%
class RingBuffer():
    """ Numpy-based ring buffer """

    def __init__(self, maxsize, dtype=np.float32):
        if not maxsize or maxsize < 0:
            raise ValueError("%s requires max size argument" % self.__class__.__name__)
        self._queue = np.zeros(maxsize, dtype)
        self._dtype = dtype
        self._maxsize = maxsize
        self._end = 0
        self._sz = 0

    def put(self, d):
        self._queue[self._end] = d
        self._end += 1
        if self._end == self._maxsize:
            self._end = 0
        if self._sz < self._maxsize:
            self._sz += 1

    def put_list(self, lst):
        """
        :param lst: list to extend data from
        :type lst: list | tuple | np.ndarray
        """
        slen = len(lst)
        if slen > self._maxsize:
            self._queue = np.array(lst, dtype=self._dtype)[slen-self._maxsize:]
            self._sz = self._maxsize
            self._end = 0
            return
        if slen + self._end <= self._maxsize:
            start = self._end
            end = slen + self._end
            self._queue[start:end] = lst
            self._end = end
        else:
            # add slice in two steps
            first_step = self._maxsize - self._end
            self._queue[self._end: self._maxsize] = lst[:first_step]
            second_step = slen - first_step
            self._queue[:second_step] = lst[first_step:]
            self._end = second_step

        if self._sz < self._maxsize:
            self._sz += slen
        if self._end == self._maxsize:
            self._end = 0

    def extend(self, it):
        try:
            it.__len__  # list, tuple, nparray
        except AttributeError:
            it = tuple(it)
        self.put_list(it)

    def get(self):
        """
        Get method. Returns the entire queue but does NOT
        drain the queue.
        """
        if self._sz < self._maxsize:
            return self._queue[: self._end]
        else:
            return np.roll(self._queue, -self._end)

    def __len__(self):
        return self._sz

    def clear(self):
        self._end = 0
        self._sz = 0

# %%
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg, NavigationToolbar2TkAgg
from matplotlib.backend_bases import key_press_handler
from matplotlib.figure import Figure
from matplotlib.ticker import MultipleLocator
import tkinter as tk


class Data():
    def __init__(self, pts):
        self.values = RingBuffer(pts)
        self.pending = []
        self.put = self.pending.append
        
    def __len__(self):
        return len(self.values)
        
    def push(self, n):
        self.values.extend(self.pending[:n])
        self.pending = self.pending[n:]
        self.put = self.pending.append
        
    def get(self):
        return self.values.get()

    def clear(self):
        self.values.clear()
        self.pending.clear()
        
    def resize(self, new_sz):
        nv = RingBuffer(new_sz)
        self.values.extend(self.pending)
        self.pending = []
        self.put = self.pending.append
        nv.extend(self.values.get())
        self.values = nv

class SeriesData(Data):
    def __init__(self, name, ax, xdata, pts, **line_kw):
        self.name = name
        super().__init__(pts)
        self.x = xdata
        self.line, = ax.plot((), (), **line_kw)
        
    def update_line(self):
        self.line.set_data(self.x.get(), self.values.get())
        
    def hide(self):
        self.line.set_visible(False)
        
    def show(self):
        self.line.set_visible(False)
        
    def set_visible(self, visible):
        self.line.set_visible(visible)
        
    def get_visible(self):
        return self.line.get_visible()
    
    def toggle_visible(self):
        self.set_visible(not self.get_visible())
        
    
# Plot classes contain custom configuration code
# so SimWindow doesn't need to know how to set them up

class Plot():
    def __init__(self, ax, xdata, pts, yformatter=None, *series_ops):
        self.ax = ax
        self.x = xdata
        self.series = []
        for ops in series_ops:
            name, kw = ops
            # default
            kw['ls'] = kw.get('ls') or "-"
            s = SeriesData(name, ax, xdata, pts, **kw)
            self.series.append(s)
            setattr(self, name, s)
        b = ax.get_position()
        ax.set_position([b.x0, b.y0, b.width*0.9, b.height])
        ax.legend(bbox_to_anchor=(0.99, 1.06), loc="upper left")
        self.leg_line_map = {}
        for lline, s in zip(ax.legend_.get_lines(), self.series):
            self.leg_line_map[lline] = s
        ax.grid()
        if yformatter:
            ax.yaxis.set_major_formatter(yformatter)
        self._hline = None
        
    def get_leg_map(self):
        return self.leg_line_map.copy()
            
    def put(self, *values):
        if len(values) != len(self.series):
            raise ValueError("Invalid argument to put: got %d values (expected %d)" \
                            % (len(values), len(self.series)))
        for s, v in zip(self.series, values):
            s.put(v)
            
    def push(self, n):
        for s in self.series:
            s.push(n)
            
    def update(self):
        for s in self.series:
            s.update_line()
        self.rescale()
        
    def rescale(self):
        self.ax.relim(True)
        self.ax.autoscale_view(True,True,True)
        
    def axhline(self, y, **kw):
        kw['ls'] = kw.get('ls') or "--"
        kw['color'] = kw.get('color') or 'black'
        if self._hline:
            self._hline.remove()
        self._hline = self.ax.axhline(y=y, **kw)
        
    def set_tick_interval(self, n):
        l = MultipleLocator(n)
        self.ax.xaxis.set_major_locator(l)
        
    def clear(self):
        for s in self.series:
            s.clear()
            

class PVPlot(Plot):
    """ Plot for PV """
    def __init__(self, ax, xdata, pts):
        series = [
            ("pv", dict(color="blue", ls="-", label="PV")),
            ("c", dict(color="green", ls="-", label="c"))
        ]
        fm = FuncFormatter(lambda y, _: "%.2f%%"%y)
        super().__init__(ax, xdata, pts, fm, *series)
        self.c.line.set_visible(False)
        
    def rescale(self):
        self.ax.relim(True)
        self.ax.autoscale_view(True,True,True)
        lower, upper = self.ax.get_ybound()
        padding = 5
        self.ax.set_ylim(lower - padding, upper + padding, True, None)
    
class GasesPlot(Plot):
    def __init__(self, ax, xdata, pts):
        
        series = [
            ("co2", dict(color="purple", ls="-", label="CO2")),
            ("n2", dict(color="red", ls="-", label="N2")),
            ("o2", dict(color="green", ls="-", label="O2")),
            ("air", dict(color="cyan", ls="-", label="Air")),
        ]
        fm = FuncFormatter(lambda y, _: "%.2f%%"%(y*100))
        super().__init__(ax, xdata, pts, fm, *series)
        self.ax.set_ylim((-0.05, 1.1))
        
    def rescale(self):
        self.ax.relim(True)
        self.ax.autoscale_view(True,True,False)
        
        
class PIDPlot(Plot):
    def __init__(self, ax, xdata, pts):
        series = [
            ("uk", dict(color="blue", ls="-", label="Uk")),
            ("up", dict(color="red", ls="-", label="Up")),
            ("ui", dict(color="green", ls="-", label="Ui")),
            ("ud", dict(color="purple", ls="-", label="Ud")),
        ]
        
        super().__init__(ax, xdata, pts, None, *series)

# %%
class SimConfig(OptionCategory):
    simops = ops or SimOps()
    xwindow_hrs = 20
    pause = False
    update_interval = 100
    time_factor = 200
    time_unit = 3600
    max_iters = hours * 24 * 7  # max number of iters to simulate in one graph update interval
    x_tick_interval = 1         # spacing between ticks (in hours)
    
    fig_width  = 7  # inches
    fig_height = 9 # inches
cfg = SimConfig()

# %%
class EventDispatcher():
    def __init__(self):
        self.handlers = {}
        
    def create_event(self, ev):
        self.handlers[ev] = self.handlers.get(ev, [])
        
    def register(self, ev, handler):
        if ev not in self.handlers:
            self.create_event(ev)
        self.handlers[ev].append(handler)
        
    def unregister(self, ev, handler):
        self.handlers[ev].remove(handler)
        
    def fire(self, ev, *args):
        for h in self.handlers.get(ev, ()):
            h(ev, *args)
            
    def unregister_all(self, ev):
        self.handlers[ev] = []
        
    def create_callback(self, ev, *args):
        def cb():
            self.fire(ev, *args)
        return cb

# %%
class DOSimWindow():
    """ Sim Window handles common MPL functions & data storage 
    as well as non-MPL tkinter configuration 
    """
    def __init__(self, frame, sim_config, events):
        
        # Unpack config items
        self.cfg = sim_config
        self.update_interval = cfg.update_interval
        self.xwindow = cfg.xwindow_hrs
        
        # MPL objects
        self.fig = Figure(figsize=(self.cfg.fig_width, self.cfg.fig_height))
        ax1 = self.fig.add_subplot(411)
        ax2 = self.fig.add_subplot(412)
        ax3 = self.fig.add_subplot(413)
        ax4 = self.fig.add_subplot(414)
        
        self.xdata = Data(self.xwindow*3600)
        self.pv_plot = PVPlot(ax1, self.xdata, self.xwindow*3600)
        self.gases_plot = GasesPlot(ax2, self.xdata, self.xwindow*3600)
        self.n2_pid_plot = PIDPlot(ax3, self.xdata, self.xwindow*3600)
        self.o2_pid_plot = PIDPlot(ax4, self.xdata, self.xwindow*3600)
        
        x_spacing = self.cfg.time_unit / (self.cfg.x_tick_interval * 3600)
        self.pv_plot.set_tick_interval(x_spacing)
        self.gases_plot.set_tick_interval(x_spacing)
        self.n2_pid_plot.set_tick_interval(x_spacing)
        self.o2_pid_plot.set_tick_interval(x_spacing)

        # misc
        self.pv_plot.axhline(self.cfg.simops.set_point)
        
        # Tkinter setup
        self.root = frame
        
        self.fig_frame = tk.Frame(self.root)
        
        # a tk.DrawingArea
        self.canvas = FigureCanvasTkAgg(self.fig, master=self.fig_frame)
        self.canvas.show()
        self.canvas.get_tk_widget().pack(side=tk.TOP, fill=tk.BOTH, expand=1)

        self.toolbar = NavigationToolbar2TkAgg(self.canvas, self.root)
        self.toolbar.update()
        self.canvas.get_tk_widget().pack(side=tk.TOP, fill=tk.BOTH, expand=1)
        
        self._running = False
        self._monitor_id = None
        self._monitor_interval = 500
        
        # coroutine support
        self.do_coro = None
        self._current_state = {}
        
        # Periodic update support
        self.updating = True
        
        # Event handling for callbacks
        # All event handling works by modifying
        # Commands are sent directly to the coroutine
        # via use of command codes. 
        # The primary code is (obviously) used to run
        # the simulation. All the codes used below 
        # signal the coroutine to take specific action,
        # including modifying stateful values
        
        self.events = events
        
        def register_update_state(event, arg):
            def on_modified(ev, value, *args):
                self.trigger_update_state(arg, value)
                print("State Value Updated: %s %s " % (arg, value))
            self.events.register(event, on_modified)
                
        register_update_state("SP_CHANGED", "sp")
        register_update_state("PV_CHANGED", "pv")
        register_update_state("MG_CHANGED", "mg")
        
        def set_target_line(event, value):
            self.pv_plot.axhline(value)
        self.events.register("SP_CHANGED", set_target_line)

        
        def on_pid_changed(ev, value, *args):
            ev = ev.lower()
            ctrl, param, _ = ev.split("_")
            ctrl += "_pid"
            print("Value Changed: %s.%s: %.2f" % (ctrl, param, value))
            self.trigger_update_value(ctrl, param, value)
            
        for c in "N2", "O2":
            for p in "PGAIN", "ITIME", "DTIME", "BETA", "MODE", "MAN":
                ev = "%s_%s_CHANGED" % (c,p)
                self.events.register(ev, on_pid_changed)
        
        def on_process_gain_changed(ev, value, *args):
            c = ev.split("_")[0].lower()
            if c == "kmult":
                c = "k_mult"
            self.trigger_update_value("process", c, value)
            print("Changed value: %s to %s" % (c, value))
            
        for c in "K", "KMULT", "C", "DC", "D2C", "DELAY":
            ev = c + "_CHANGED"
            self.events.register(ev, on_process_gain_changed)
            
        def on_timefactor_changed(ev, value, *args):
            self.cfg.time_factor = value
            print(ev, ":", value)
        self.events.register("TIMEFACTOR_CHANGED", on_timefactor_changed)
        
        def on_clear_all_data(ev, *args):
            self.xdata.clear()
            for p in self.iter_plots():
                p.clear()
            self.do_coro.send(("SET_TIME", 0))
        self.events.register("CLEAR_ALL_DATA", on_clear_all_data)
        
        def on_advance_sim(ev, value, *args):
            if not value: return
            try:
                value = int(value)
            except ValueError:
                print("Invalid value: %r" % value)
                return
            print("Advancing simulation %d seconds..." % value)
            self._run_sim(value)
        self.events.register("ADVANCE_SIM", on_advance_sim)
        
        def on_legend_clicked(event):
            ll = event.artist
            series = self.leg_map[ll]
            series.toggle_visible()
            
        def on_xwindow_changed(ev, value, *args):
            nv = int(value * 3600)
            for p in self.iter_plots():
                for s in p.series:
                    if len(s) != nv:
                        s.resize(nv)
            if len(self.xdata) != nv:
                self.xdata.resize(nv)
        self.events.register("XWINDOW_CHANGED", on_xwindow_changed)
            
        # legend picker support
        self.leg_map = {}
        for p in self.iter_plots():
            m = p.get_leg_map()
            for leg, s in m.items():
                leg.set_picker(5)
                self.leg_map[leg] = s
        self.fig.canvas.mpl_connect("pick_event", on_legend_clicked)

        
    def trigger_update_value(self, ob, name, value):
        cmd = "UPDATE_VALUE"
        args = (ob, name, value)
        self.do_coro.send((cmd, args))
        
    def trigger_update_state(self, name, value):
        cmd = "MODIFY_STATE"
        args = (name, value)
        self.do_coro.send((cmd, args))
        
    def iter_plots(self):
        return (self.pv_plot, self.gases_plot, self.n2_pid_plot, self.o2_pid_plot)
        
    def pack(self, side=tk.TOP, fill=tk.BOTH, expand=1):
        self.fig_frame.pack(side=side, fill=fill, expand=expand)
        
    def start(self):
        self._updating = True
        self.begin_sim()
        self.schedule_update()
        
    def stop(self):
        self._updating = False
        
    def resume(self):
        if not self.do_coro:
            self.start()
        else:
            self.schedule_update()
        
    def begin_sim(self):
        self.do_coro = do_sim_coroutine(self.cfg.simops, self._current_state,
                         self.xdata, self.pv_plot.pv, self.pv_plot.c, self.gases_plot.co2,
                         self.gases_plot.n2, self.gases_plot.o2, self.gases_plot.air,
                         self.n2_pid_plot.uk, self.n2_pid_plot.up, self.n2_pid_plot.ui, self.n2_pid_plot.ud,
                         self.o2_pid_plot.uk, self.o2_pid_plot.up, self.o2_pid_plot.ui, self.o2_pid_plot.ud)
        next(self.do_coro)
        
    def update(self):
        n = self.cfg.time_factor
        n = int(n)
        self._run_sim(n)
        self.events.fire("PROCESS_STATE_UPDATE", self._current_state.copy())
        
    def _run_sim(self, n):
        self.do_coro.send(("SIM_ITERS", n))
        
        self.xdata.push(n)
        self.pv_plot.push(n)
        self.gases_plot.push(n)
        self.o2_pid_plot.push(n)
        self.n2_pid_plot.push(n)
        
        self.pv_plot.update()
        self.gases_plot.update()
        self.n2_pid_plot.update()
        self.o2_pid_plot.update()
        
        self.fig.canvas.draw()
        
    def schedule_update(self):
        def update(self=self):
            if self.updating:
                self.update()
                self.root.after(self.update_interval, update)
        self.root.after(self.update_interval, update)

# %%
class TkQuitHack(tk.Tk):
    def _hacky_monitor_running(self):
        # hack to allow closing tkinter window by 
        # "X" button in this interactive prompt
        # unsure if this is an ipython/mpl artifact or not
        # but it works
        def monitor():
            if not self._hacky_running:
                for cb in self._hacky_on_destroyed:
                    cb()
                self.quit()
                self.destroy()
                self._hacky_destroyed = True
                
            else:
                self.after(self._hacky_monitor_interval, monitor)
        self.after(self._hacky_monitor_interval, monitor)
    def __init__(self, *args, **kw):
        super().__init__(*args, **kw)
        self._hacky_running = True
        self._hacky_monitor_interval = 200
        self._hacky_monitor_running()
        self.protocol("WM_DELETE_WINDOW", self.hacky_destroy)
        self._hacky_destroyed = False
        self._hacky_on_destroyed = []
        
    def hacky_destroy(self):
        self._hacky_running = False
        
    def register_destroy_callback(self, cb):
        self._hacky_on_destroyed.append(cb)
        
    def is_destroyed(self):
        return self._hacky_destroyed

# %%
import tkinter as tk, tkinter.ttk as ttk
class LabeledEntry(tk.Frame):
    def __init__(self, master, text, def_value, events, value_changed_event, pos="top", *args, **kw):
        super().__init__(master, *args, **kw)
        self.label = tk.Label(self, text=text)
        self.entry = tk.Entry(self)
        
        if pos.lower() == "top":
            r1, c1 = 0, 0
            r2, c2 = 1, 0
        elif pos.lower() == "left":
            r1, c1 = 0, 0
            r2, c2 = 0, 1
        elif pos.lower() == "right":
            r1, c1 = 0, 1
            r2, c2 = 0, 0
        else:
            raise ValueError("Bad Position: %r" % pos)
            
        self.label.grid(row=r1, column=c1, sticky=(tk.E, tk.W))
        self.entry.grid(row=r2, column=c2, sticky=(tk.E, tk.W))
            
        if def_value is None:
            def_value = ""
        self.value = def_value
        self.set(def_value)
        self._trigger_mode = "on_change"
            
        self.entry.bind("<Return>", self.maybe_value_changed)
        self.entry.bind("<FocusOut>", self.maybe_value_changed)
        self.events = events
        self.value_changed_event = value_changed_event
        
    def label_width(self, value):
        self.label.config(width=value)
        
    def entry_width(self, value):
        self.entry.config(width=value)
        
    def maybe_value_changed(self, e):
        value = self.get()
        try:
            v = float(value or 0)
        except ValueError:
            print("Could not coerce string to float: %r" % value)
            return
        
        if v == float(self.value) and self._trigger_mode == "on_change" and \
                e.keycode != 13:
            return
        
        self.value = value
        self.trigger_value_changed(v)
        
    def trigger_value_changed(self, v):
            self.events.fire(self.value_changed_event, v)
        
    def get(self):
        return self.entry.get()
    
    def set(self, value):
        value = str(value)
        if not value:
            value = "0"
        self.entry.delete(0, tk.END)
        self.entry.insert(0, value)
        self.value = value
        
    def set_trigger_mode(self, mode):
        if mode not in ("always", "on_change"):
            raise ValueError("Unrecognized mode: %r" % mode)
        self._trigger_mode = mode
        
        
class EntryButton(tk.Frame):
    def __init__(self, master, text, events, event):
        super().__init__(master)
        self.entry = tk.Entry(self)
        self.entry.insert(0, 3600)
        self.button = ttk.Button(self, text=text, command=self.fire)
        self.entry.bind("<Return>", self.fire)
        self.events = events
        self.event = event
        
        self.entry.grid(row=0, column=1)
        self.button.grid(row=1, column=1)
        
    def fire(self, e=None):
        self.events.fire(self.event, self.entry.get())
    

# Patched tkinter settit. For some reason, setting the internal
# Variable isn't properly being used to update the OptionMenu
# widget text. 
      
# Also, this makes more sense as a function constructor
# than a class (imo)
    
def _setit(menu, var, value, cb=None):
    def func(*args):
        var.set(value)
        menu.config(text=value)
        if cb is not None:
            cb(value, *args)
    return func
        
# Patched tkinter optionmenu to work properly. The only changes
# are changing the default "textvariable" to "text" in kw to super,
# and re-running the code to bind to the patched _settit class. 

class PatchedOptionMenu(tk.Menubutton):
    """OptionMenu which allows the user to select a value from a menu."""
    def __init__(self, master, variable, value, *values, **kwargs):
        """Construct an optionmenu widget with the parent MASTER, with
        the resource textvariable set to VARIABLE, the initially selected
        value VALUE, the other menu values VALUES and an additional
        keyword argument command."""
        kw = {"borderwidth": 2, "text": value,
              "indicatoron": 1, "relief": tk.RAISED, "anchor": "c",
              "highlightthickness": 2}
        tk.Widget.__init__(self, master, "menubutton", kw)
        self.widgetName = 'tk_optionMenu'
        menu = self.__menu = tk.Menu(self, name="menu", tearoff=0)
        self.menuname = menu._w
        # 'command' is the only supported keyword
        callback = kwargs.get('command')
        if 'command' in kwargs:
            del kwargs['command']
        if kwargs:
            raise TclError('unknown option -'+kwargs.keys()[0])
        menu.add_command(label=value,
                 command=_setit(self, variable, value, callback))
        for v in values:
            menu.add_command(label=v,
                     command=_setit(self, variable, v, callback))
        self["menu"] = menu

    def __getitem__(self, name):
        if name == 'menu':
            return self.__menu
        return tk.Widget.__getitem__(self, name)

    def destroy(self):
        """Destroy this widget and the associated menu."""
        tk.Menubutton.destroy(self)
        self.__menu = None
        
class MenuFrame(tk.LabelFrame):
    def __init__(self, master, text, events, event, entries):
        super().__init__(master, text=text)
        self.entries = entries
        self.events = events
        self.event = event
        
        self.entries = []
        entry_names = []
        
        for i, (var, val, ev) in enumerate(entries, 1):
            w = LabeledEntry(self, var, val, events, ev)
            w.grid(row=i, column=0)
            self.entries.append(w)
            entry_names.append(var)
        
        self.tkvar = tk.StringVar(self)
        self.tkvar.set(entry_names[0])
        self.menu = OptionMenu(self, self.tkvar, *entry_names)
        self.menu.grid(column=0, row=0)
        self.events.register(self.event, self.on_menu_changed)
            
    def on_menu_changed(self, _):
        self.events.fire(self.event, self.tkvar.get())
        
            
class LabelFrameWithLabelEntries(tk.LabelFrame):
    def __init__(self, master, text, events, entries=()):
        super().__init__(master, text=text)
        self.events = events
        self.entries = []
        for text, val, ev in entries:
            self.add_entry(text, val, ev)
            
    def set_trigger_mode(self, mode):
        for e in self.entries:
            e.set_trigger_mode(mode)
            
    def add_entry(self, text, val, ev):
        e = LabeledEntry(self, text, val, self.events, ev, pos="left")
        e.label_width(10)
        e.entry_width(8)
        e.grid(row=len(self.entries), column=0)
        self.entries.append(e)
            
class LabelDisplay(tk.Frame):
    def __init__(self, master, events, event, text, value="", w1=None, w2=None):
        super().__init__(master)
        self.label = tk.Label(self, text=text, anchor=tk.E)
        self.display = tk.Label(self, text=value, anchor=tk.E)
        if w1:
            self.label.config(width=w1)
        if w2:
            self.display.config(width=w2)
        
        self.label.grid(row=0, column=0, sticky=(tk.W, tk.E))
        self.display.grid(row=0, column=1, sticky=(tk.W, tk.E))
        self.events = events
        self.events.register(event, self.on_value_update)
        
    def on_value_update(self, ev, value, *args):
        self.set(value)
        
    def set(self, value):
        value = str(value)
        self.display['text'] = value
    
    def get(self):
        return self.display['text']
        
class LabelDisplayFrame(tk.LabelFrame):
    def __init__(self, master, text, events):
        super().__init__(master, text=text)
        self.labels = {}
        self.events = events
        
    def add_label(self, id, event, text, value="", w1=None, w2=None):
        label = LabelDisplay(self, self.events, event, text, value, w1, w2)
        label.grid(row=len(self.labels), column=0, sticky=(tk.E, tk.W, tk.N, tk.S))
        self.labels[id] = label
        
    def add_labels(self, *args):
        for a in args:
            self.add_label(*args)
        
class Combobox(ttk.Combobox):
    def __init__(self, master, **kw):
        super().__init__(master, **kw)
        vcmd = self.register(self.nomodify,)
        self.config(validate="key", validatecommand=vcmd)
        self.bind("<Return>", lambda _: self.event_generate("<1>"))
        self.bind("<Button-1>", lambda _: self.event_generate("<Down>", when='head'))
        self.current(0)
        
    def nomodify(self):
        return False
        
class MenuLabel(tk.Frame):
    def __init__(self, master, text, events, event, values, w1=10, w2=6, map=None, **kw):
        super().__init__(master, **kw)
        self.label = tk.Label(self, text=text)
        self.label.config(width=w1)
        
        if map is None:
            map = {k:k for k in values}
        else:
            if not all(k in map for k in values):
                raise ValueError("Unmapped keys: " % " ".join(set(values)-set(map)))
        
        self.map = map
        self.events = events
        self.event = event
        
        self.menu = Combobox(self, values=values)
        self.menu.bind("<<ComboboxSelected>>", self.menu_selected)
        self.menu.config(width=w2)
        
        self.label.grid(row=0, column=0, sticky=(tk.E, tk.W, tk.N, tk.S))
        self.menu.grid(row=0, column=1, sticky=(tk.E, tk.W, tk.N, tk.S))
        
        
    def get_raw(self):
        return self.menu.get()
    
    def get(self):
        return self.map[self.menu.get()]
        
    def menu_selected(self, e):
        self.events.fire(self.event, self.get())

# %%
class StatusDisplay(LabelDisplayFrame):
    def __init__(self, master, text, events, cfg):
        super().__init__(master, text, events)

        # text config....
        c,n,o = cfg.simops.initial_request_cno
        a = 1-(c+n+o)
        sub2 = "\u2082:"
        co2 = "CO"+sub2
        n2 = "N"+sub2
        o2 = "O"+sub2
        
        self.add_label("PV", "PV_PROCESS_UPDATE", "PV:", cfg.simops.initial_pv, 3, 6)
        self.add_label("CO2", "CO2_PROCESS_UPDATE", co2, "%.1f%%" % (c*100), 3, 6)
        self.add_label("N2", "N2_PROCESS_UPDATE", n2, "%.1f%%" % (n*100), 3, 6)
        self.add_label("O2", "O2_PROCESS_UPDATE", o2, "%.1f%%" % (o*100), 3, 6)
        self.add_label("Air", "AIR_PROCESS_UPDATE", "Air:", "%.1f%%" % (a*100), 3, 6)
        
        self.add_label("c", "C_PROCESS_UPDATE", "c:", cfg.simops.c, 3, 6)
        self.add_label("dc", "DC_PROCESS_UPDATE", "dc:", cfg.simops.dc, 3, 6)
        self.add_label("d2c", "D2C_PROCESS_UPDATE", "d\u00B2c:", cfg.simops.d2c, 3, 6)
        
        self.events.register("PROCESS_STATE_UPDATE", self.on_state_update)
        
    def on_state_update(self, ev, state, *args):
        self.labels['c'].set("%.4g" % state['c'])
        self.labels['dc'].set("%.4g" % state['dc'])
        self.labels['d2c'].set("%.4g" % state['d2c'])
        
        self.labels['PV'].set("%.2f%%" % state['pv'])
        self.labels["CO2"].set("%.1f%%" % (state['co2_req']*100))
        self.labels["N2"].set("%.1f%%" % (state['n2_req']*100))
        self.labels["O2"].set("%.1f%%" % (state['o2_req']*100))
        self.labels["Air"].set("%.1f%%" % (state['air_req']*100))
        
class PIDFrame(LabelFrameWithLabelEntries):
    def __init__(self, master, text, events, prefix, pid_ops):
        super().__init__(master, text, events)
        
        self.add_entry("PGain:", pid_ops.p, prefix + "_PGAIN_CHANGED")
        self.add_entry("ITime:", pid_ops.i, prefix + "_ITIME_CHANGED")
        self.add_entry("DTime:", pid_ops.d, prefix + "_DTIME_CHANGED")
        self.add_entry("Beta:", pid_ops.beta, prefix + "_BETA_CHANGED")
        self.add_entry("Man:", pid_ops.man_request, prefix + "_MAN_CHANGED")
        
        # Modes
        modes = [
            ("Auto", PIDController.AUTO),
            ("Man", PIDController.MAN),
            ("Off", PIDController.OFF)
        ]
        mode_order = [m[0] for m in modes]
        map = dict(modes)
        self.menu = MenuLabel(self, "Mode:", events, prefix + "_MODE_CHANGED", mode_order, map=map)
        self.menu.grid(row=len(self.entries), column=0, sticky=(tk.E,tk.W,tk.N,tk.S))

# %%
class PIDSimFrame():
    def __init__(self, master, WindowClass, sim_cfg, events=None):
        if events is None:
            events = EventDispatcher()
        self.cfg = sim_cfg
        ops = cfg.simops
        self.events = events
        self.frame = tk.Frame(master)
        self.w = WindowClass(self.frame, sim_cfg, events)
        self.w.pack(side=tk.LEFT, fill=tk.BOTH, expand=1)
        self.settings_frame = sf = tk.Frame(self.frame)
        self.settings_frame.pack(side=tk.RIGHT, fill=tk.BOTH, expand=1)
        
        # Widgets
        
        # N2 PID
        n2pid = PIDFrame(sf, "N\u2082 PID:", events, "N2", ops.n2_pid)

        # O2 PID
        o2pid = PIDFrame(sf, "O\u2082 PID:", events, "O2", ops.o2_pid)  
        
        # Process values
        proc = LabelFrameWithLabelEntries(sf, "Process:", events)
        proc.add_entry("Set Point:", ops.set_point, "SP_CHANGED")
        proc.add_entry("PV:", ops.initial_pv, "PV_CHANGED")
        proc.add_entry("k:", ops.k, "K_CHANGED")
        proc.add_entry("k_mult:", ops.k_mult, "KMULT_CHANGED")
        proc.add_entry("delay:", s2m(ops.delay), "DELAY_CHANGED")
        
        # Simulation options
        sim = LabelFrameWithLabelEntries(sf, "Simulation:", events)
        sim.add_entry("time factor:", cfg.time_factor, "TIMEFACTOR_CHANGED")
        sim.add_entry("x window(hr):", cfg.xwindow_hrs, "XWINDOW_CHANGED")
        
        # buttons
        clear = ttk.Button(sf, text="Clear", command=events.create_callback("CLEAR_ALL_DATA"))
        advance = EntryButton(sf, "Advance(s)", events, "ADVANCE_SIM")

        # Consumption constants
        c_frame = LabelFrameWithLabelEntries(sf, "Consumption:", events)
        c_frame.add_entry("c", ops.c, "C_CHANGED")
        c_frame.add_entry("dc/dt", 0, "DC_CHANGED")
        c_frame.add_entry("d\u00B2c/dt\u00B2", 0, "D2C_CHANGED")
        c_frame.set_trigger_mode("always")
        
        # Output display
        cstate = StatusDisplay(sf, "Current:", events, self.cfg)    
        
        tk_all = (tk.E, tk.W, tk.N, tk.S)
        n2pid.grid(row=1, column=1, sticky=tk_all)
        o2pid.grid(row=1, column=2, sticky=tk_all)
        
        proc.grid(row=2, column=1, sticky=tk_all)
        sim.grid(row=2, column=2, sticky=tk_all)

        c_frame.grid(row=3, column=1, rowspan=3, sticky=(tk.E, tk.W, tk.N, tk.S))
        cstate.grid(row=3, column=2, rowspan=8, sticky=(tk.E, tk.W, tk.N, tk.S))
        
        advance.grid(row=11, column=1)
        clear.grid(row=11, column=2, sticky=tk.S)
        
        self.wl = {}
        self.wl.update((k,v) for k,v in locals().items() if isinstance(v, tk.Widget))
        
        self.w.start()
        master.register_destroy_callback(self.w.stop)
        
        self.n2pid = n2pid
        self.o2pid = o2pid
        
        
    def pack(self, **kw):
        self.frame.pack(**kw)

# %%
def run2():
    global root, f
    cfg.simops.o2_pid.p = 10
    cfg.simops.o2_pid.i = 80
    cfg.simops.o2_pid.amax = 100
    cfg.simops.o2_pid.deadband = 0
    cfg.simops.o2_pid.beta = 0
    cfg.simops.o2_pid.man_request = 10

    cfg.simops.n2_pid.p = -2
    cfg.simops.n2_pid.i = 60
    cfg.simops.n2_pid.amax = 90
    cfg.simops.n2_pid.deadband = 0
    cfg.simops.n2_pid.beta = 0
    cfg.simops.n2_pid.man_request = 10
    cfg.simops.delay=0*minutes

    cfg.update_interval = 50
    cfg.time_factor = 200

    cfg.simops.initial_pv = 20
    cfg.simops.set_point = 20

    cfg.xwindow_hrs = 10

    root = TkQuitHack()
    root.wm_title("DO Simulation")
    #root.geometry("%dx%d"%(600, 800))
    f = PIDSimFrame(root, DOSimWindow, cfg)
    f.pack()
    root.mainloop()
run2()

# %%
#f.w._current_state['o2_pid'].b
