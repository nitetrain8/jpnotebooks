# %%
import numpy as np
from hello.pid.lvpid import PIDController
from hello.pid.delay import seconds, minutes, hours, days, m2s, s2m, h2s, DelayBuffer, DelaySink
from hello.pid.gas_process import HeadspaceProcess, GasController
from hello.pid.do_simulation.doprocess import DOProcess, AIR_CNO, DOProcessMicro

from hello.pid.do_simulation.options import SimOps, SimConfig
from hello.pid.picker import mk_picker
from hello.pid.do_simulation.sim_window import PIDSimFrame
from hello.pid.ui import TkQuitHack
from hello.pid.do_simulation.do_sim import do_sim_coroutine, do_sim
from matplotlib.ticker import MultipleLocator, FormatStrFormatter, FuncFormatter
# %matplotlib
# %load_ext autoreload
# %autoreload 2
from matplotlib import pyplot as plt
# Out:
# Using matplotlib backend: TkAgg

# %% [markdown]
# ### Copy this template to ensure all sim options are set correctly

# %%
ops = SimOps()
ops.o2_pid.p = 2
ops.o2_pid.i = 10
ops.o2_pid.d = 0
ops.o2_pid.amax = 100
ops.o2_pid.amin = 0
ops.o2_pid.beta = 1
ops.o2_pid.linearity = 1
ops.o2_pid.alpha = -1

ops.n2_pid.p = 5
ops.n2_pid.i = 5
ops.n2_pid.d = 0
ops.n2_pid.amax = 90
ops.n2_pid.amin = 0
ops.n2_pid.beta = 1
ops.n2_pid.linearity = 1
ops.n2_pid.alpha = -1

ops.mfcs.co2_max = 1
ops.mfcs.o2_max = 10
ops.mfcs.n2_max = 10
ops.mfcs.air_max = 10

ops.plots.xscale = 'auto'
ops.plots.xmin = 0
ops.plots.xmax = 72
ops.plots.xscale_factor = 3600

ops.end = 10000
ops.initial_request_cno = (0.07, 0, 0)
ops.initial_pv = 90
ops.set_point = 40
ops.set_point_deadband = 1
ops.mode = "o2a"
ops.time_unit = hours
ops.max_iters = 3 * days

# Used by DOProcess (headspace)
ops.main_gas = 1.0
ops.initial_actual_cno = AIR_CNO
ops.reactor_size = 80
ops.volume = 55
ops.delay = 0
ops.k_mult = 1.1             # Not used by Micro Process!!!
ops.k = DOProcess.default_k  # Not used by Micro Process!!!
ops.c = 0
ops.dc = 0
ops.d2c = 0

# Used by DOProcessMicro, but not by DOProcess
ops.km_hs = 1  # Separate multiplier for headspace
ops.km_ms = 1  # Separate multiplier for microsparger
ops.m1 = 4.403227
ops.m2 = 0.500656
ops.m3 = 0.111072
ops.b  = 0.445392

# Maximum value of c that O2 controller can sustain for a given k
ops.k*ops.k_mult*(100/20.95)*100
# Out:
# 68.57279236276851

# %%
# O2 needs an extra padding space because the negative sign
# for N2 pgain doesn't count, i guesss
def fmt_float(f):
    if not f:
        return "0"
    f = str(f)
    if "." not in f:
        return f
    else:
        f = f.strip("0")
        if f[-1] == ".":
            f = f[:-1]
        if f[0] == ".":
            f = "0" + f
    return f
def get_text(ops):

    text = \
"""
O2: P=%3d  I=%5d  Initial PV: %3d  k: %.4f/hr (%sx Est.)
N2: P=%3d  I=%4d  Set Point:  %3d  c: %s%%/hr

 """ % (ops.o2_pid.p, ops.o2_pid.i,ops.initial_pv, ops.k*ops.k_mult, fmt_float(ops.k_mult),
        ops.n2_pid.p, ops.n2_pid.i, ops.set_point, fmt_float(ops.c))
    text = text.strip()
    return text

# %%
# headspace constants
k_80L = 0.1306
k_15L = 0.19314
k_3L  = 0.24286

# Micro sparging scheme constants
kvals_3L = (4.403227, 0.500656, 0.111072, 0.445392)

def np_unpack(l):
    return [np.array(data) for data in list(zip(*l))]

# %% [markdown]
# # 3L DO Tuning and Characterization

# %% [markdown]
# ### 3L Basic Options

# %%
ops = SimOps()
ops.o2_pid.p = 2
ops.o2_pid.i = 40
ops.o2_pid.d = 0
ops.o2_pid.amax = 100
ops.o2_pid.amin = 0
ops.o2_pid.beta = 0
ops.o2_pid.linearity = 1
ops.o2_pid.alpha = -1

ops.n2_pid.p = -5
ops.n2_pid.i = 40
ops.n2_pid.d = 0
ops.n2_pid.amax = 90
ops.n2_pid.amin = 0
ops.n2_pid.beta = 0
ops.n2_pid.linearity = 1
ops.n2_pid.alpha = -1

ops.mfcs.co2_max = .1
ops.mfcs.o2_max = .5
ops.mfcs.n2_max = .5
ops.mfcs.air_max = .5

ops.plots.xscale = 'auto'
ops.plots.xmin = 0
ops.plots.xmax = 72
ops.plots.xscale_factor = 3600

ops.Process = DOProcessMicro

ops.end = 10000
ops.initial_request_cno = (0.07, 0, 0)
ops.initial_pv = 90
ops.set_point = 40
ops.set_point_deadband = 1
ops.mode = "o2a"
ops.time_unit = hours
ops.max_iters = 3 * days

# Used by DOProcess (headspace)
ops.main_gas = 0.2
ops.initial_actual_cno = AIR_CNO
ops.reactor_size = 3
ops.volume = 2.5
ops.delay = 0
ops.k_mult = 1.1             # Not used by Micro Process!!!
ops.k = k_3L                 # Not used by Micro Process!!!
ops.c = 0
ops.dc = 0
ops.d2c = 0

# Used by DOProcessMicro, but not by DOProcess
ops.km_hs = 1  # Separate multiplier for headspace
ops.km_ms = 1  # Separate multiplier for microsparger
ops.m1 = kvals_3L[0]
ops.m2 = kvals_3L[1]
ops.m3 = kvals_3L[2]
ops.b  = kvals_3L[3]

# %% [markdown]
# ### 3L Graphs for Report

# %%
ax_list2 = []
fig = None

def axes():
    return ax_list2

def setup2(new=False):
    global fig, ax1, ax2, ax3, ax4, ax5, ax6
    global ax_list2
    
    if not plt.get_fignums() or new or not fig:
        fig = plt.figure()
        ax1 = fig.add_subplot(1,1,1)
        #ax2 = fig.add_subplot(2,1,2)
        ax2 = ax1.twinx()
        ax_list2 = [ax1, ax2]
        for a in axes():
            b = a.get_position()
            a.set_position([b.x0, b.y0+.1, b.width*.95, b.height*.9])
            a.grid()
    else:
        for a in axes():
            a.clear()
            a.grid()
        for t in fig.texts:
            t.remove()
    
    
    global colors, color
    colors = [
        "blue",
        "red",
        "green",
        "cyan",
        "purple",
        "orange",
        "black"
    ]

    import itertools
    color = itertools.cycle(colors).__next__
    
def test2(ops):
    d1, d2, d3 = do_sim(ops)
    x, pv, _, _, n2, o2, *_, o2a = np_unpack(d1)
    return x,pv, n2, o2, o2a*100/0.21

def _p1(ax, x, y, color, label, ylabel=None):
    ax.plot(x,y, color=color, label=label)
    if ylabel:
        ax.set_ylabel(ylabel)

def plot2(x, pv, n2, o2, o2a):
    c = color()
    _p1(ax1, x, pv, "blue", "pv", "DO (%)")
    _p1(ax2, x, o2, "green", "O2", "Gas Flow (%)")
    _p1(ax2, x, n2, "red", "N2")
    #_p1(ax3, x, pv, "blue", "pv", "DO (%)")
    #_p1(ax3, x, o2a, "red", "hs")
    
    ax1.axhline(y=ops.set_point, ls="--", color="black")
    ax1.axhline(y=ops.set_point-ops.set_point_deadband, ls="--", color="black", lw=0.5)
    ax1.axhline(y=ops.set_point+ops.set_point_deadband, ls="--", color="black", lw=0.5)
    ax1.yaxis.set_major_formatter(FormatStrFormatter("%d%%"))
    ax2.yaxis.set_major_formatter(FuncFormatter(lambda y, _: "%d%%"%(y*100)))
    
    h = []
    l = []
    for a in axes():
        a.xaxis.set_major_locator(MultipleLocator(1))
        h_, l_ = a.get_legend_handles_labels()
        h.extend(h_)
        l.extend(l_)
    ax1.legend(h, l, loc="center", ncol=3, bbox_to_anchor=(0.5, -.18))
    
    ax1.set_xlabel("Time (hr)")
    
    fig.canvas.flush_events()
    fig.canvas.draw()
    
def finish2():
    for a in axes():
        if a.legend_:
            mk_picker(fig, a)
    
def run2(ops):
    global x, pv, n2, o2, o2a
    x, pv, n2, o2, o2a = test2(ops)
    plot2(x, pv, n2, o2, o2a)
    finish2()

# %% [markdown]
# #### Export figures for report

# %%
setup2()
ops.initial_request_cno = (0, 0, 0)
ops.initial_actual_cno = (0.0004, .78, .21)
ops.set_point = 50
ops.initial_pv = 100
ops.end = 10*hours
ops.Process = DOProcessMicro
# Slower
ops.o2_pid.p = o2p = 4
ops.o2_pid.i = o2i = 55
ops.n2_pid.p = n2p = -20
ops.n2_pid.i = n2i = 40

run2(ops)
ax1.set_xlim(0, 12)
ax1.set_ylim(ops.set_point-10, ops.set_point+10)
a,b = ax2.set_ylim()
ax1.yaxis.set_major_locator(MultipleLocator(2))
ax2.set_ylim(0, 1)
ax1.set_title("Ramp Up 100% to 150%")
ax1.text(.7, .91, "O\u2082  P:%.1f I:%3d\nN\u2082  P:%3d I:%3d"%(o2p, o2i, n2p, n2i), transform=fig.transFigure)
#path = 'C:\\PBSCloudStation\\(2) R&D-Product Engineering\\Software Development\\3.0 Project\\Phase 2 Working Copy\\IE00005 PID Tuning\\IE00005-06 DO\\Raw Data'
#fig.savefig(path+"\\3L ramp up new 170728.png")
#fig

# %%
setup2()
ops.set_point = 50
ops.initial_pv = 100
ops.initial_request_cno = (0, 0, 0)
ops.initial_actual_cno = (0.0004, .78, .21)

# Slower
ops.o2_pid.p = o2p = 4
ops.o2_pid.i = o2i = 55
ops.n2_pid.p = n2p = -20
ops.n2_pid.i = n2i = 40
ops.n2_pid.amax = 100

run2(ops)
ax1.set_xlim(0, 12)
ax1.set_ylim(40, 60)
ax2.set_ylim(0, 1)
ax1.yaxis.set_major_locator(MultipleLocator(2))
ax1.set_title("Ramp Down 100% to 50%")
ax1.text(.7, .91, "O\u2082  P:%.1f I:%3d\nN\u2082  P:%3d I:%3d"%(o2p, o2i, n2p, n2i), transform=fig.transFigure)
path = 'C:\\PBSCloudStation\\(2) R&D-Product Engineering\\Software Development\\3.0 Project\\Phase 2 Working Copy\\IE00005 PID Tuning\\IE00005-06 DO\\Raw Data'
#fig.savefig(path+"\\3L ramp down new 170728.png")
#fig

# %% [markdown]
# #### More tuning.....

# %%
def rampup(ops, x, y):
    setup2(True)
    ops.set_point = 150
    ops.initial_pv = 100
    run2(ops)
    ax1.set_xlim(0, 12)
    ax1.set_ylim(140, 160)
    a,b = ax2.set_ylim()
    ax2.set_ylim(0, b)
    ax1.set_title("Ramp Up: Gradual")
    w=fig.canvas._tkcanvas.master
    set_win_sz(w, x, y)
    
def set_win_sz(win, x,y):
    w, h = 565,433
    w*= 0.8
    h *=0.8
    win.geometry('%dx%d+%d+%d'%(w, h, x,y))
    
def rampdown(ops, x, y):
    setup2(True)
    ops.set_point = 50
    ops.initial_pv = 100
    run2(ops)
    ax1.set_xlim(0, 12)
    ax1.set_ylim(40, 60)
    ax2.set_ylim(0, 1)
    ax1.set_title("Ramp Down: Gradual")
    w=fig.canvas._tkcanvas.master
    set_win_sz(w, x, y)
    
def rampup2(ops):
    ops.set_point = 150
    ops.initial_pv = 100
    return test2(ops)
    
def rampdown2(ops):
    ops.set_point = 50
    ops.initial_pv = 100
    return test2(ops)
    
def run3(ops):
    x, pv, n2, o2, o2a = test2(ops)
    #plot2(x, pv, n2, o2, o2a)
    #finish2()
    return x, pv, n2, o2, o2a

def plot3(x, pv, n2, o2, o2a):
    c = color()
    _p1(ax1, x, pv, "blue", "pv", "DO (%)")
    _p1(ax2, x, o2, "green", "O2", "Gas Flow (%)")
    _p1(ax2, x, n2, "red", "N2")
    #_p1(ax3, x, pv, "blue", "pv", "DO (%)")
    #_p1(ax3, x, o2a, "red", "hs")
    
    ax1.axhline(y=ops.set_point, ls="--", color="black")
    ax1.axhline(y=ops.set_point-ops.set_point_deadband, ls="--", color="black", lw=0.5)
    ax1.axhline(y=ops.set_point+ops.set_point_deadband, ls="--", color="black", lw=0.5)
    ax1.yaxis.set_major_formatter(FormatStrFormatter("%d%%"))
    ax2.yaxis.set_major_formatter(FuncFormatter(lambda y, _: "%d%%"%(y*100)))
    
    h = []
    l = []
    for a in axes():
        a.xaxis.set_major_locator(MultipleLocator(1))
        h_, l_ = a.get_legend_handles_labels()
        h.extend(h_)
        l.extend(l_)
    ax1.legend(h, l, loc="center", ncol=3, bbox_to_anchor=(0.5, -.18))
    
    ax1.set_xlabel("Time (hr)")
    
    fig.canvas.flush_events()
    fig.canvas.draw()

# %%
# Balanced?
for i in range(100): plt.close()
ops.o2_pid.p = 4
ops.o2_pid.i = 70
ops.n2_pid.p = -5
ops.n2_pid.i = 50

rampup(ops, 1932, 0)
rampdown(ops, 2502, 0)

ops.o2_pid.p = 4
ops.o2_pid.i = 60
ops.n2_pid.p = -5
ops.n2_pid.i = 50

rampup(ops, 1932, 500)
rampdown(ops, 2502, 500)

# %% [markdown]
# ### Comparison tuning

# %%
ax_list3 = []
fig = None

def axes():
    return ax_list3

def setup3(new=False):
    global fig, ax1, ax2, ax3, ax4, ax5, ax6
    global ax_list3
    
    if not plt.get_fignums() or new or not fig:
        fig = plt.figure()
        ax1 = fig.add_subplot(2,1,1)
        ax2 = fig.add_subplot(2,1,2)
        #ax2 = ax1.twinx()
        ax_list3 = [ax1, ax2]
        for a in axes():
            b = a.get_position()
            a.set_position([b.x0, b.y0+.1, b.width*.95, b.height*.9])
            a.grid()
    else:
        for a in axes():
            a.clear()
            a.grid()
        for t in fig.texts:
            t.remove()
    
    ax1.xaxis.set_major_locator(MultipleLocator(1))
    ax1.yaxis.set_major_formatter(FormatStrFormatter("%d%%"))
    ax1.set_ylabel("DO PV(%)")
    
    ax2.xaxis.set_major_locator(MultipleLocator(1))
    ax2.yaxis.set_major_formatter(FuncFormatter(lambda y, _: "%d%%"%(y*100)))
    ax2.set_ylabel("Gas Flow (%)")
    
    ax1.set_xlabel("Time (hr)")
    ax2.set_xlabel("Time (hr)")
    
    ax1.axhline(y=ops.set_point, ls="--", color="black")
    ax1.axhline(y=ops.set_point-ops.set_point_deadband, ls="--", color="black", lw=0.5)
    ax1.axhline(y=ops.set_point+ops.set_point_deadband, ls="--", color="black", lw=0.5)
    
    global colors, color
    colors = [
        "blue",
        "red",
        "green",
        "cyan",
        "purple",
        "orange",
        "black"
    ]

    import itertools
    color = itertools.cycle(colors).__next__
    
def test3(ops):
    d1, d2, d3 = do_sim(ops)
    x, pv, _, _, n2, o2, *_, o2a = np_unpack(d1)
    return x,pv, n2, o2, o2a*(100/0.21)

def _p3(ax, x, y, label):
    ax.plot(x, y, label=label)

def plot3(x, pv, n2, o2, o2a, label=""):
    c = color()
    _p3(ax1, x, pv, label) 
    _p3(ax2, x, o2, label+"_o2")
    _p3(ax2, x, n2, label+"_n2")
    ax1.legend()
    ax2.legend()
    fig.canvas.flush_events()
    fig.canvas.draw()
    
def finish3():
    for a in axes():
        if a.legend_:
            mk_picker(fig, a)
    
def run3(ops, label=None):
    global x, pv, n2, o2, o2a
    x, pv, n2, o2, o2a = test3(ops)
    plot3(x, pv, n2, o2, o2a, label)
    finish3()

# %%
# rampdown
setup3()

ops.main_gas = 0.1
ops.initial_pv = 100
ops.set_point = 50
ops.end = 12*hours
ops.o2_pid.p = 4
ops.o2_pid.i = 55
ops.n2_pid.p = -20
ops.n2_pid.i = 40

ops.Process = DOProcess
run3(ops, "Headspace")

ops.Process = DOProcessMicro
run3(ops, "Micro")

ax1.set_ylim(40, 60)
# Out:
# (40, 60)

# %%
# rampup
setup3(True)

ops.main_gas = 0.1
ops.initial_pv = 100
ops.set_point = 150
ops.end = 12*hours
ops.o2_pid.p = 4
ops.o2_pid.i = 55
ops.n2_pid.p = -20
ops.n2_pid.i = 40

ops.Process = DOProcess
run3(ops, "Headspace")

ops.Process = DOProcessMicro
run3(ops, "Micro")

ax1.set_ylim(ops.set_point-10, ops.set_point+10)
ax1.title.set_text("Rampup 0.1LPM")

# %%
# rampdown
setup3(True)

ops.main_gas = 0.1
ops.initial_pv = 100
ops.set_point = 50
ops.end = 12*hours
ops.o2_pid.p = 4
ops.o2_pid.i = 55
ops.n2_pid.p = -20
ops.n2_pid.i = 40

ops.Process = DOProcess
run3(ops, "Headspace")

ops.Process = DOProcessMicro
run3(ops, "Micro")

ax1.set_ylim(40, 60)
ax1.title.set_text("Rampdown 0.1LPM")

# %%
# rampdown
setup3(True)

ops.main_gas = 0.5
ops.initial_pv = 100
ops.set_point = 50
ops.end = 12*hours
ops.o2_pid.p = 4
ops.o2_pid.i = 55
ops.n2_pid.p = -20
ops.n2_pid.i = 40

ops.Process = DOProcess
run3(ops, "Headspace")

ops.Process = DOProcessMicro
run3(ops, "Micro")

ax1.set_ylim(40, 60)
ax1.title.set_text("Rampdown 0.5LPM")

# %%
# rampup
setup3(True)

ops.main_gas = 0.5
ops.initial_pv = 100
ops.set_point = 150
ops.end = 12*hours
ops.o2_pid.p = 4
ops.o2_pid.i = 55
ops.n2_pid.p = -20
ops.n2_pid.i = 40

ops.Process = DOProcess
run3(ops, "Headspace")

ops.Process = DOProcessMicro
run3(ops, "Micro")

ax1.set_ylim(ops.set_point-10, ops.set_point+10)
ax1.title.set_text("Rampup 0.5LPM")

# %% [markdown]
# ### Shotgun stuff...

# %%
def pid_iter():
    def lr(a,b, s=1):
        return list(range(a,b+s,s))
    p  = lr(1, 10) + lr(12, 20, 2)
    i = lr(40, 120, 5)
    for o2p in p:
        for n2p in p:
            n2p = -n2p
            for o2i in i:
                for n2i in i:
                    yield o2p, n2p, o2i, n2i

# %%
def getscore(n2, o2_2, pv, pv2):
    pv1t = 4*hours
    pv2t = 5*hours
    pv_where1 = pv[pv1t:]
    pv1_passed = np.any(np.abs(149 - pv[:pv1t]) < 1)
    pv_where2 = pv2[pv2t:]
    pv2_passed = np.any(np.abs(51 - pv2[:pv2t]) < 1)
    if not (pv1_passed and pv2_passed):
        return -1
    score = n2.sum()**2/len(n2) + o2_2.sum()**2/len(o2_2) + (np.abs(149-pv_where1).sum()/len(pv_where1) + np.abs(51-pv_where2).sum()/len(pv_where2))*10
    return score

# %%
o = "OVERRIDE"
if 'bdata' in globals() and bdata:
    r = input("Input %s to continue data reset: "%o)
else:
    r = o
    
if r == o:
    print("Resetting data!")
    best = None
    nbest = 0
    bdata = {}
    bdata2 = {}
# Out:
# Input OVERRIDE to continue data reset: OVERRIDE
# Resetting data!

# %%
ops.end=12*hours
for i, params in enumerate(pid_iter()):
    o2p, n2p, o2i, n2i = params
    ops.o2_pid.p = o2p
    ops.o2_pid.i = o2i
    ops.n2_pid.p = n2p
    ops.n2_pid.i = n2i
    print("\rTesting %d %d %d %d           "%(o2p, n2p, o2i, n2i), end="")
    x, pv, n2, o2, o2a = rampup2(ops)
    x2, pv2, n2_2, o2_2, o2a_2 = rampdown2(ops)
    score = getscore(n2, o2_2, pv, pv2)
    if best is None or score < best and score >= 0:
        nbest += 1
        best = score
        print("New Best: %.1f"%best)
    bdata[params] = score
    bdata2[i] = params
# Out:
# Testing 1 -1 40 40           New Best: 525.1
# Testing 1 -1 45 40            New Best: 351.6
# Testing 1 -1 50 40            New Best: 240.4
# Testing 1 -1 55 40            New Best: 172.7
# Testing 1 -1 60 40            New Best: 134.6
# Testing 1 -1 65 40            New Best: 115.1
# Testing 1 -1 70 40            New Best: 106.8
# Testing 1 -1 75 40            New Best: 105.4
# Testing 1 -1 75 60           New Best: 102.7
# Testing 1 -1 80 60            New Best: 94.7
# Testing 1 -1 85 60            New Best: 92.7
# Testing 1 -2 70 40             New Best: 72.3
# Testing 1 -2 75 40            New Best: 63.9
# Testing 1 -3 70 40             New Best: 62.5
# Testing 1 -3 75 40            New Best: 46.2
# Testing 1 -3 80 40            New Best: 43.1
# Testing 1 -4 75 40             New Best: 39.3
# Testing 1 -4 80 40            New Best: 33.2
# Testing 1 -5 80 40             New Best: 28.1
# Testing 1 -6 80 40             New Best: 25.1
# Testing 1 -6 85 40            New Best: 24.9
# Testing 1 -6 85 45           New Best: 24.8
# Testing 1 -7 80 40             New Best: 23.2
# Testing 1 -7 85 40            New Best: 22.3
# Testing 1 -7 85 45           New Best: 22.1
# Testing 1 -8 80 40             New Best: 21.9
# Testing 1 -8 85 40            New Best: 20.5
# Testing 1 -8 85 45           New Best: 20.2
# Testing 1 -9 85 40             New Best: 19.1
# Testing 1 -9 85 45           New Best: 18.8
# Testing 1 -10 85 40            New Best: 18.1
# Testing 1 -10 85 45           New Best: 17.8
# Testing 1 -12 85 40             New Best: 16.6
# Testing 1 -12 85 45           New Best: 16.4
# Testing 1 -14 85 40             New Best: 15.6
# Testing 1 -14 85 45           New Best: 15.4
# Testing 1 -16 85 40             New Best: 15.0
# Testing 1 -16 85 45           New Best: 14.7
# Testing 1 -18 85 40             New Best: 14.4
# Testing 1 -18 85 45           New Best: 14.3
# Testing 1 -20 85 40             New Best: 14.0
# Testing 1 -20 85 45           New Best: 13.9
# Testing 2 -5 60 40              New Best: 13.8
# Testing 2 -5 65 40            New Best: 13.7
# Testing 2 -6 60 40             New Best: 11.7
# Testing 2 -6 65 40            New Best: 10.4
# Testing 2 -7 65 40             New Best: 8.3
# Testing 2 -8 65 40             New Best: 6.8
# Testing 2 -9 65 40             New Best: 5.8
# Testing 2 -9 80 65            New Best: 5.5
# Testing 2 -10 65 40            New Best: 5.0
# Testing 2 -10 80 65            New Best: 4.6
# Testing 2 -12 65 40             New Best: 3.9
# Testing 2 -12 70 50            New Best: 3.9
# Testing 2 -12 75 55            New Best: 3.7
# Testing 2 -12 80 65            New Best: 3.3
# Testing 2 -14 65 40             New Best: 3.2
# Testing 2 -14 70 50            New Best: 3.2
# Testing 2 -14 75 55            New Best: 2.8
# Testing 2 -14 80 65            New Best: 2.6
# Testing 2 -16 75 55             New Best: 2.2
# Testing 2 -16 80 65            New Best: 2.1
# Testing 2 -18 75 55             New Best: 1.8
# Testing 2 -20 75 55             New Best: 1.5
# Testing 3 -14 60 45             New Best: 1.2
# Testing 3 -16 60 45             New Best: 0.9
# Testing 3 -18 60 45             New Best: 0.7
# Testing 3 -20 60 45             New Best: 0.5
# Testing 4 -20 55 40             New Best: 0.5
# Testing 20 -20 120 120
